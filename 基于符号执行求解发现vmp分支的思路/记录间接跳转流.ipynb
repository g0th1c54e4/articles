# %%
import triton
import SupertracePybind as Supertrace
from supertrace_util import compatibleProcessing, initTritonCtxEnv, mergeRepeatIns, checkIndirectIns

# %%
# tracepath = "11111111-3.9.4.trace64"
tracepath = "deadbeef-3.9.4.trace64"

trace = Supertrace.parse_x64dbg_trace(tracepath)
record = trace.getRecord() # 获取trace的记录指令列表
print(f"trace instruction num: {len(record)}")
# Out:
# trace instruction num: 170728

# %%
modules = trace.user.meta.getModules()
for mod in modules:
    if mod.isMainModule:
        main_module = mod
        break

main_secs = main_module.getSections()
print("No\tName")
for i, sec in enumerate(main_secs):
    print(f"{i}\t{sec.name}")
# Out:
# No	Name
# 0	.text
# 1	.rdata
# 2	.data
# 3	.pdata
# 4	.u<l
# 5	.4R^
# 6	.gJ2
# 7	.rsrc
# 8	.reloc

# %%
vmpsec_begin = main_secs[4].addr
vmpsec_end = main_secs[6].addr
print(f"vmp begin: {hex(vmpsec_begin)}")
print(f"vmp end: {hex(vmpsec_end)}")
# Out:
# vmp begin: 0x140006000
# vmp end: 0x1407da000

# %%
ctx = triton.TritonContext()
ctx.setArchitecture(triton.ARCH.X86_64)
ctx.setMode(triton.MODE.ALIGNED_MEMORY, True)
ctx.setMode(triton.MODE.AST_OPTIMIZATIONS, True)
ctx.setMode(triton.MODE.CONSTANT_FOLDING, True)
ctx.setMode(triton.MODE.ONLY_ON_TAINTED, True)
ctx.setMode(triton.MODE.TAINT_THROUGH_POINTERS, True) # 开启内存指针污染

# %%
record = mergeRepeatIns(ctx, record, True) # 合并trace里的rep指令
print(f"after mergeing 'rep' instructions, trace instruction num: {len(record)}")
# Out:
# after mergeing 'rep' instructions, trace instruction num: 170728

# %%
threads = trace.user.meta.getThreads()
for th in threads:
    if th.id == record[0].thread_id:
        main_thread = th
        break
print(f"main thread id: {main_thread.id} ({hex(main_thread.id)})")
print(f"teb: {hex(main_thread.teb)}") # 获取线程TEB地址
initTritonCtxEnv(ctx, record[0], main_thread.teb) # 初始化寄存器环境
# Out:
# main thread id: 3088 (0xc10)
# teb: 0x47e7b21000

# %%
for i, ins in enumerate(record):
    if (i + 1 >= len(record)): nextIns = None
    else: nextIns = record[i + 1]

    ttins = triton.Instruction()
    ttins.setAddress(ins.ins_address)
    ttins.setOpcode(ins.bytes)
    ctx.disassembly(ttins)

    for memAcc in ins.mem_accs:
        if (memAcc.type == Supertrace.AccessType.READ and (vmpsec_begin <= memAcc.acc_address <= vmpsec_end)):
            ctx.taintMemory(triton.MemoryAccess(memAcc.acc_address, memAcc.acc_size)) # 污染来自VM区块的字节码（确保不会把混淆间接跳转也给识别进去）

    compatibleProcessing(ctx, ttins, ins, nextIns, True, False) # 执行指令

    if (checkIndirectIns(ttins) and (nextIns is not None) and ttins.isTainted()):
        jumpAddr = nextIns.ins_address
        print(f"{hex(ins.dbg_id)}\t{ttins.getDisassembly()}\t\t{hex(jumpAddr)}") # 打印指令序号、指令反汇编文本以及对应的跳转地址
# Out:
# 0x96	ret		0x1406fb2d5
# 0xf9	ret		0x1406fb2d5
# 0x15c	ret		0x1406fb2d5
# 0x1bf	ret		0x1406fb2d5
# 0x222	ret		0x14075f8ad
# 0x288	jmp rbp		0x1406fb2d5
# 0x2eb	ret		0x1406fb2d5
# 0x34e	ret		0x1406fb2d5
# 0x3b1	ret		0x140495723
# 0x403	jmp rcx		0x1403af4ce
# 0x43d	jmp r11		0x14044be7c
# 0x47e	jmp rbp		0x140667e11
# 0x4b9	ret 0x10		0x1403ab876
# 0x51b	jmp rbp		0x1407b883f
# 0x55b	ret 0x10		0x1406e954b
# 0x5b4	ret 0x18		0x1406e954b
# 0x60d	ret 0x18		0x1406e954b
# 0x666	ret 0x18		0x1406e954b
# 0x6bf	ret 0x18		0x14042268f
# 0x716	jmp rbp		0x14036d4f3
# 0x77c	jmp rbp		0x14036d4f3
# 0x7e2	jmp rbp		0x1404f671a
# 0x816	ret 0x10		0x14069b96d
# 0x88c	jmp rbp		0x1404b3955
# 0x901	ret 8		0x140541546
# 0x951	jmp rbp		0x1406f179c
# 0x9a9	jmp rbx		0x1403b6e72
# 0x9fa	ret 8		0x1403b4c6a
# 0xa7e	jmp rbp		0x14069af6d
# 0xaca	jmp rbp		0x14032d73b
# 0xb27	jmp rbp		0x1406d361d
# 0xb6f	ret 0x18		0x140312106
# 0xba4	ret 8		0x140464b86
# 0xc25	jmp rbp		0x1406fc028
# 0xc62	jmp rdx		0x14067bb8c
# 0xcb6	ret 0x10		0x14032d73b
# 0xd13	jmp rbp		0x1406d361d
# 0xd5b	ret 0x18		0x140312106
# 0xd90	ret 8		0x1403e837c
# 0xddd	jmp rbp		0x1406701bc
# 0xe4e	jmp rbp		0x1406d361d
# 0xe96	ret 0x18		0x1403b90a1
# 0xed6	jmp rdx		0x1403db497
# 0xf13	jmp rbp		0x1403c10b2
# 0xf42	ret		0x140717909
# 0xf7b	jmp rbp		0x140601d72
# 0xfc7	jmp rbp		0x14032d73b
# 0x1024	jmp rbp		0x1406d361d
# 0x106c	ret 0x18		0x140312106
# 0x10a1	ret 8		0x1406fdc22
# 0x10e3	jmp rbp		0x14062b896
# 0x110b	ret 0x18		0x1404504d1
# 0x1164	jmp rdx		0x1407b087d
# 0x1197	ret		0x1406fc028
# 0x11d4	jmp rdx		0x140756738
# 0x11fd	jmp rcx		0x14079528f
# 0x1257	jmp rbp		0x1406c0588
# 0x12d7	jmp rbp		0x1406d361d
# 0x131f	ret 0x18		0x140312106
# 0x1354	ret 8		0x140464b86
# 0x13d5	jmp rbp		0x1406fc028
# 0x1412	jmp rdx		0x14067bb8c
# 0x1466	ret 0x10		0x14032d73b
# 0x14c3	jmp rbp		0x1406d361d
# 0x150b	ret 0x18		0x140312106
# 0x1540	ret 8		0x1403e837c
# 0x158d	jmp rbp		0x1406701bc
# 0x15fe	jmp rbp		0x1406d361d
# 0x1646	ret 0x18		0x1403b90a1
# 0x1686	jmp rdx		0x1403db497
# 0x16c3	jmp rbp		0x140683d3d
# 0x1715	jmp rbp		0x1404c024e
# 0x1766	jmp rbp		0x1403af4ce
# 0x17a0	jmp r11		0x14044be7c
# 0x17e1	jmp rbp		0x140667e11
# 0x181c	ret 0x10		0x1406b3d3a
# 0x1872	ret 0x20		0x14032d73b
# 0x18cf	jmp rbp		0x1406d361d
# 0x1917	ret 0x18		0x140312106
# 0x194c	ret 8		0x1407b1c66
# 0x19ba	jmp rbp		0x14066ea13
# 0x19f6	ret		0x1407378c8
# 0x1a4d	ret		0x14073b931
# 0x1a94	jmp rbp		0x140609ce4
# 0x1ac8	ret 8		0x14032d73b
# 0x1b25	jmp rbp		0x1406d361d
# 0x1b6d	ret 0x18		0x140312106
# 0x1ba2	ret 8		0x1406a3278
# 0x1bf0	ret		0x14061870a
# 0x1c31	jmp rbp		0x14073b931
# 0x1c78	jmp rbp		0x1403dddef
# 0x1cc0	ret 0x10		0x14069af6d
# 0x1d0c	jmp rbp		0x14063ad8f
# 0x1d69	ret		0x14043040e
# 0x1de5	jmp rbp		0x1406f179c
# 0x1e3d	jmp rbx		0x1407816cf
# 0x1e9d	ret		0x1403b4c6a
# 0x1f21	jmp rbp		0x1403af4ce
# 0x1f5b	jmp r11		0x14044be7c
# 0x1f9c	jmp rbp		0x1404bf352
# 0x1fed	ret		0x140736e91
# 0x2032	ret 0x10		0x1406c9d91
# 0x207f	ret 0x18		0x1403af4ce
# 0x20b9	jmp r11		0x14044be7c
# 0x20fa	jmp rbp		0x140312106
# 0x212f	ret 8		0x140314a61
# 0x2166	ret 0x10		0x140507073
# 0x21aa	ret 0x10		0x140684d6c
# 0x21ee	ret 0x10		0x14042268f
# 0x2245	jmp rbp		0x14049ed60
# 0x22cc	jmp rbp		0x1406c5d65
# 0x2329	jmp rbp		0x140341a84
# 0x2382	jmp rbp		0x140713828
# 0x23c1	jmp rbp		0x1406c9d91
# 0x240e	ret 0x18		0x1403af4ce
# 0x2448	jmp r11		0x14044be7c
# 0x2489	jmp rbp		0x140312106
# 0x24be	ret 8		0x1403c3f6b
# 0x250a	jmp rbp		0x1404108f9
# 0x2551	jmp rcx		0x14073b931
# 0x2598	jmp rbp		0x1403dddef
# 0x25e0	ret 0x10		0x1403af4ce
# 0x261a	jmp r11		0x14044be7c
# 0x265b	jmp rbp		0x140312106
# 0x2690	ret 8		0x1406ffc0b
# 0x26fb	jmp rbp		0x1406d361d
# 0x2743	ret 0x18		0x140667e11
# 0x277e	ret 0x10		0x14032d73b
# 0x27db	jmp rbp		0x1406d361d
# 0x2823	ret 0x18		0x140312106
# 0x2858	ret 8		0x1406329c1
# 0x28a1	ret		0x1404a230e
# 0x28fb	jmp r9		0x140652d40
# 0x292f	jmp rax		0x140672fe9
# 0x2981	ret 0x20		0x1404dd261
# 0x29d3	jmp rbp		0x14071dd67
# 0x2a26	ret 8		0x14069af6d
# 0x2a72	jmp rbp		0x140464b86
# 0x2af3	jmp rbp		0x1406fba03
# 0x2b40	ret 0x10		0x140713828
# 0x2b7f	jmp rbp		0x1406c9d91
# 0x2bcc	ret 0x18		0x1403af4ce
# 0x2c06	jmp r11		0x14044be7c
# 0x2c47	jmp rbp		0x140312106
# 0x2c7c	ret 8		0x1406a3278
# 0x2cca	ret		0x14079c06a
# 0x2d42	jmp rbp		0x1404ddb1c
# 0x2d6e	ret 8		0x1406c9d91
# 0x2dbb	ret 0x18		0x1403af4ce
# 0x2df5	jmp r11		0x14044be7c
# 0x2e36	jmp rbp		0x140312106
# 0x2e6b	ret 8		0x1406c9d91
# 0x2eb8	ret 0x18		0x1403af4ce
# 0x2ef2	jmp r11		0x14044be7c
# 0x2f33	jmp rbp		0x140312106
# 0x2f68	ret 8		0x140314a61
# 0x2f9f	ret 0x10		0x140507073
# 0x2fe3	ret 0x10		0x140684d6c
# 0x3027	ret 0x10		0x1406d0477
# 0x3064	jmp rbp		0x14032d73b
# 0x30c1	jmp rbp		0x1406d361d
# 0x3109	ret 0x18		0x140312106
# 0x313e	ret 8		0x1404c4fe7
# 0x31a4	jmp rbp		0x1403db497
# 0x31e1	jmp rbp		0x14074aaa7
# 0x321f	jmp rdx		0x140727bd5
# 0x3264	jmp rbp		0x1406c513c
# 0x32bb	jmp rbp		0x1403af4ce
# 0x32f5	jmp r11		0x14044be7c
# 0x3336	jmp rbp		0x140312106
# 0x336b	ret 8		0x1404c4fe7
# 0x33d1	jmp rbp		0x1406f2273
# 0x3457	jmp rbp		0x1406d361d
# 0x349f	ret 0x18		0x1406d0477
# 0x34dc	jmp rbp		0x1406d91c2
# 0x3554	jmp rbp		0x1407035cc
# 0x35ae	ret		0x1407a7dd7
# 0x3600	ret 0x10		0x1406e3f66
# 0x364c	ret		0x140464b86
# 0x36cd	jmp rbp		0x1406fc028
# 0x370a	jmp rdx		0x140727bd5
# 0x374f	jmp rbp		0x1403af4ce
# 0x3789	jmp r11		0x14044be7c
# 0x37ca	jmp rbp		0x1406d0477
# 0x3807	jmp rbp		0x140464b86
# 0x3888	jmp rbp		0x1406fc028
# 0x38c5	jmp rdx		0x140727bd5
# 0x390a	jmp rbp		0x140464b86
# 0x398b	jmp rbp		0x1406fc028
# 0x39c8	jmp rdx		0x140727bd5
# 0x3a0d	jmp rbp		0x1404e2580
# 0x3a89	jmp rbp		0x140387fdd
# 0x3aef	jmp rbp		0x14069a5d0
# 0x3b2a	ret 0x10		0x140697253
# 0x3b93	jmp rbp		0x1406d91c2
# 0x3c0b	jmp rbp		0x14068a4b9
# 0x3c66	jmp rbp		0x140311d3f
# 0x3c8f	ret		0x1406b3652
# 0x3cdc	ret 0x18		0x1406d361d
# 0x3d24	ret 0x18		0x1404bf352
# 0x3d75	ret		0x140464b86
# 0x3df6	jmp rbp		0x1406fc028
# 0x3e33	jmp rdx		0x140727bd5
# 0x3e78	jmp rbp		0x140464b86
# 0x3ef9	jmp rbp		0x1406fc028
# 0x3f36	jmp rdx		0x14042e9e9
# 0x3f9b	ret 0x20		0x1406f2273
# 0x4021	jmp rbp		0x1406d361d
# 0x4069	ret 0x18		0x1404bf352
# 0x40ba	ret		0x140464b86
# 0x413b	jmp rbp		0x140464b86
# 0x41bc	jmp rbp		0x1406fc028
# 0x41f9	jmp rdx		0x140462fb8
# 0x4244	ret 8		0x140777a16
# 0x428f	jmp rbp		0x1406e3f66
# 0x42db	ret		0x140464b86
# 0x435c	jmp rbp		0x140464b86
# 0x43dd	jmp rbp		0x1406fc028
# 0x441a	jmp rdx		0x14042e9e9
# 0x447f	ret 0x20		0x1406f179c
# 0x44d7	jmp rbx		0x14044cfdf
# 0x455e	jmp rbp		0x140719b6a
# 0x45a3	jmp rbp		0x1406f807c
# 0x45d9	jmp rbp		0x1404c8248
# 0x4611	ret 0x20		0x1406fc028
# 0x464e	jmp rdx		0x140727bd5
# 0x4693	jmp rbp		0x1406fc028
# 0x46d0	jmp rdx		0x140727bd5
# 0x4715	jmp rbp		0x1404e132b
# 0x474b	ret 8		0x1406d361d
# 0x4793	ret 0x18		0x1407af653
# 0x4818	jmp rbp		0x140474c44
# 0x488e	jmp rbp		0x140474c44
# 0x4904	jmp rbp		0x140474c44
# 0x497a	jmp rbp		0x140474c44
# 0x49f0	jmp rbp		0x14032d73b
# 0x4a4d	jmp rbp		0x1406d361d
# 0x4a95	ret 0x18		0x140312106
# 0x4aca	ret 8		0x140464b86
# 0x4b4b	jmp rbp		0x1406fc028
# 0x4b88	jmp rdx		0x1405d2616
# 0x4bab	jmp rax		0x140464b86
# 0x4c2c	jmp rbp		0x1406fc028
# 0x4c69	jmp rdx		0x1406577db
# 0x4cb2	ret 0x18		0x1406d1c03
# 0x4cf8	jmp rbp		0x14067f52e
# 0x4d42	ret 8		0x1403af4ce
# 0x4d7c	jmp r11		0x14044be7c
# 0x4dbd	jmp rbp		0x1403b90a1
# 0x4dfd	jmp rdx		0x1403db497
# 0x4e3a	jmp rbp		0x140799941
# 0x4e8d	ret 8		0x1403af4ce
# 0x4ec7	jmp r11		0x14044be7c
# 0x4f08	jmp rbp		0x1406d0477
# 0x4f45	jmp rbp		0x1406e8609
# 0x4fa0	jmp rbp		0x14065dcde
# 0x5013	jmp rbp		0x14066abcc
# 0x5073	ret		0x140745083
# 0x50e0	jmp rbp		0x1407246dd
# 0x5142	ret 0x10		0x14043040e
# 0x51be	jmp rbp		0x1406fc8f3
# 0x51fb	ret 0x20		0x1406d9059
# 0x525f	jmp rbp		0x14077adde
# 0x52c3	jmp rbp		0x1405cb3b6
# 0x52f6	ret		0x14067f52e
# 0x5340	ret 8		0x1403af4ce
# 0x537a	jmp r11		0x14044be7c
# 0x53bb	jmp rbp		0x1403b90a1
# 0x53fb	jmp rdx		0x1403db497
# 0x5438	jmp rbp		0x1404b2a00
# 0x546f	ret 8		0x14032d73b
# 0x54cc	jmp rbp		0x1406d361d
# 0x5514	ret 0x18		0x140312106
# 0x5549	ret 8		0x1406a72b3
# 0x55a6	ret		0x14032d73b
# 0x5603	jmp rbp		0x1406d361d
# 0x564b	ret 0x18		0x140312106
# 0x5680	ret 8		0x14032d73b
# 0x56dd	jmp rbp		0x1406d361d
# 0x5725	ret 0x18		0x140312106
# 0x575a	ret 8		0x140464b86
# 0x57db	jmp rbp		0x1406fc028
# 0x5818	jmp rdx		0x14038c624
# 0x5860	jmp rbp		0x140791dbe
# 0x58e8	jmp rbp		0x140644ec6
# 0x5928	ret		0x14065737d
# 0x59a2	jmp rbp		0x14044fb49
# 0x59d3	jmp rdx		0x140391b5c
# 0x5a37	ret 0x18		0x1403af4ce
# 0x5a71	jmp r11		0x14044be7c
# 0x5ab2	jmp rbp		0x140312106
# 0x5ae7	ret 8		0x1406fdc22
# 0x5b29	jmp rbp		0x1406b0a8b
# 0x5b5d	jmp rdx		0x14032d73b
# 0x5bba	jmp rbp		0x1406d361d
# 0x5c02	ret 0x18		0x140312106
# 0x5c37	ret 8		0x14073d18d
# 0x5c7b	ret 0x10		0x1403af4ce
# 0x5cb5	jmp r11		0x14044be7c
# 0x5cf6	jmp rbp		0x140312106
# 0x5d2b	ret 8		0x1406fdc22
# 0x5d6d	jmp rbp		0x1405c4f87
# 0x5d9e	ret 0x10		0x1404aca47
# 0x5dea	ret 0x18		0x14032d73b
# 0x5e47	jmp rbp		0x1406d361d
# 0x5e8f	ret 0x18		0x140312106
# 0x5ec4	ret 8		0x140464b86
# 0x5f45	jmp rbp		0x1406fc028
# 0x5f82	jmp rdx		0x140653012
# 0x5fd8	jmp rbp		0x14067f52e
# 0x6022	ret 8		0x1403af4ce
# 0x605c	jmp r11		0x14044be7c
# 0x609d	jmp rbp		0x1406d0477
# 0x60da	jmp rbp		0x1404091b2
# 0x611f	ret 0x10		0x14032d73b
# 0x617c	jmp rbp		0x1406d361d
# 0x61c4	ret 0x18		0x140312106
# 0x61f9	ret 8		0x140464b86
# 0x627a	jmp rbp		0x1406fc028
# 0x62b7	jmp rdx		0x1406f0414
# 0x6329	jmp rbp		0x140334c79
# 0x63a5	jmp rbp		0x1404b8f1d
# 0x63f3	ret 0x10		0x1407a7dd7
# 0x6445	ret 0x10		0x14041a319
# 0x648d	ret 0x20		0x14074b8f1
# 0x64cf	ret 8		0x14044cfdf
# 0x6556	jmp rbp		0x14041a319
# 0x659e	ret 0x20		0x14074b8f1
# 0x65e0	ret 8		0x1404b2b3d
# 0x6625	ret 0x10		0x1403db497
# 0x6662	jmp rbp		0x1406e787d
# 0x66ca	jmp rbp		0x1406d361d
# 0x6712	ret 0x18		0x1403b90a1
# 0x6752	jmp rdx		0x1403db497
# 0x678f	jmp rbp		0x1404091b2
# 0x67d4	ret 0x10		0x14032d73b
# 0x6831	jmp rbp		0x1406d361d
# 0x6879	ret 0x18		0x140312106
# 0x68ae	ret 8		0x140464b86
# 0x692f	jmp rbp		0x1406fc028
# 0x696c	jmp rdx		0x1406f0414
# 0x69de	jmp rbp		0x14037774f
# 0x6a2c	ret		0x140777a16
# 0x6a77	jmp rbp		0x1406dc5ea
# 0x6ac4	ret 0x20		0x14043040e
# 0x6b40	jmp rbp		0x140330d13
# 0x6b7b	ret 8		0x1406d09d3
# 0x6c03	jmp rbp		0x1407a7dd7
# 0x6c55	ret 0x10		0x14041a319
# 0x6c9d	ret 0x20		0x140777a16
# 0x6ce8	jmp rbp		0x140420847
# 0x6d2f	ret 8		0x1406f807c
# 0x6d65	jmp rbp		0x140464b86
# 0x6de6	jmp rbp		0x1406fc028
# 0x6e23	jmp rdx		0x14064d529
# 0x6e67	ret 8		0x1406e87b1
# 0x6eae	ret		0x1406f4db1
# 0x6ef6	ret		0x1404ec6da
# 0x6f5b	jmp rbp		0x1406d361d
# 0x6fa3	ret 0x18		0x140667e11
# 0x6fde	ret 0x10		0x1403f77cd
# 0x7019	ret		0x140680845
# 0x704b	jmp rdx		0x1403f0d97
# 0x7097	ret 8		0x1406819d6
# 0x710f	jmp rbp		0x140474c44
# 0x7185	jmp rbp		0x140474c44
# 0x71fb	jmp rbp		0x140474c44
# 0x7271	jmp rbp		0x1405b4e23
# 0x72af	jmp r9		0x1404658d2
# 0x7314	jmp rdx		0x1404658d2
# 0x7379	jmp rdx		0x1404658d2
# 0x73de	jmp rdx		0x1404658d2
# 0x7443	jmp rdx		0x1404658d2
# 0x74a8	jmp rdx		0x1403d2c4a
# 0x7511	ret 0x20		0x14046c7f1
# 0x7591	jmp r9		0x1406adfe3
# 0x75e1	ret 0x20		0x1403cadf7
# 0x762c	ret 0x10		0x14072d23c
# 0x768a	jmp r9		0x140642d10
# 0x76d7	jmp rdx		0x14068b9e8
# 0x771c	jmp r9		0x14046c7f1
# 0x779c	jmp r9		0x140756cf2
# 0x77ce	ret		0x140419df6
# 0x7827	jmp r9		0x140642d10
# 0x7874	jmp rdx		0x1403adf40
# 0x78a9	jmp rdx		0x1405d81dc
# 0x78f5	jmp r9		0x140529e56
# 0x792e	ret 0x30		0x14040b1e3
# 0x796e	jmp r9		0x140737574
# 0x79a9	jmp r9		0x14072d23c
# 0x7a07	jmp r9		0x140642d10
# 0x7a54	jmp rdx		0x140756cf2
# 0x7a86	ret		0x1405229d4
# 0x7ab9	ret 0x18		0x14040b1e3
# 0x7af9	jmp r9		0x14058504b
# 0x7b33	ret 0x18		0x14032bf5c
# 0x7b68	ret		0x1405a2ad5
# 0x7b87	jmp r9		0x1404658d2
# 0x7bec	jmp rdx		0x1406bba89
# 0x7c52	jmp r9		0x140432895
# 0x7c93	ret 0x10		0x1406bba89
# 0x7cf9	jmp r9		0x1406bba89
# 0x7d5f	jmp r9		0x1406bba89
# 0x7dc5	jmp r9		0x1406bba89
# 0x7e2b	jmp r9		0x1406bba89
# 0x7e91	jmp r9		0x1406bba89
# 0x7ef7	jmp r9		0x1406bba89
# 0x7f5d	jmp r9		0x1406bba89
# 0x7fc3	jmp r9		0x1406bba89
# 0x8029	jmp r9		0x1405f304f
# 0x8062	jmp r9		0x1404658d2
# 0x80c7	jmp rdx		0x1407817c0
# 0x811e	ret 0x28		0x1404658d2
# 0x8183	jmp rdx		0x1404658d2
# 0x81e8	jmp rdx		0x1407817c0
# 0x823f	ret 0x28		0x1404658d2
# 0x82a4	jmp rdx		0x14047276a
# 0x82fa	ret		0x1405c86e1
# 0x834d	jmp r9		0x14037b097
# 0x8394	jmp r9		0x140445c4a
# 0x83cf	ret		0x1404128e5
# 0x841f	jmp rax		0x1407a57b7
# 0x847e	jmp r9		0x1406bba89
# 0x84e4	jmp r9		0x1406a213c
# 0x856f	jmp r9		0x1406bba89
# 0x85d5	jmp r9		0x1406bba89
# 0x863b	jmp r9		0x1406bba89
# 0x86a1	jmp r9		0x14074b16b
# 0x8711	jmp r9		0x1406bba89
# 0x8777	jmp r9		0x1404a0ad4
# 0x87c1	jmp r10		0x140684e06
# 0x8824	ret		0x140503fcb
# 0x8897	ret 8		0x140503fcb
# 0x890a	ret 8		0x140503fcb
# 0x897d	ret 8		0x1403ef950
# 0x89e8	jmp r9		0x1407106f5
# 0x8a2a	ret 8		0x14054131f
# 0x8a67	ret 0x18		0x14070fc3a
# 0x8ad7	jmp r10		0x14040039b
# 0x8b09	jmp rbp		0x140715473
# 0x8b51	ret		0x1406c5088
# 0x8bbf	jmp r10		0x1406c9baa
# 0x8c30	jmp r10		0x14046b53e
# 0x8c6a	ret		0x1405f80d5
# 0x8c94	ret 0x18		0x1406e9018
# 0x8cd5	ret 0x10		0x1406c9baa
# 0x8d46	jmp r10		0x14046b53e
# 0x8d80	ret		0x140765423
# 0x8db5	ret 8		0x1406c9baa
# 0x8e26	jmp r10		0x14046b53e
# 0x8e60	ret		0x140765423
# 0x8e95	ret 8		0x14057a2e6
# 0x8ec9	jmp r10		0x14070fc3a
# 0x8f39	jmp r10		0x14040039b
# 0x8f6b	jmp rbp		0x1405600fb
# 0x8f94	ret 0x20		0x1403c45e0
# 0x8fca	ret 8		0x1406872cc
# 0x9009	jmp r8		0x14064cfc2
# 0x909c	jmp r10		0x14064658f
# 0x90d0	ret 0x10		0x14053ed28
# 0x9106	jmp r10		0x1404dece3
# 0x9136	jmp r10		0x1405274b1
# 0x9178	ret		0x14064cfc2
# 0x920b	jmp r10		0x14064658f
# 0x923f	ret 0x10		0x14064cfc2
# 0x92d2	jmp r10		0x14064658f
# 0x9306	ret 0x10		0x1405b14b3
# 0x935a	jmp r10		0x1404b5aa8
# 0x93b3	ret 0x30		0x14036c013
# 0x9406	jmp r10		0x140456013
# 0x946b	jmp r10		0x140388205
# 0x94c2	jmp rdx		0x14064cfc2
# 0x9555	jmp r10		0x14064658f
# 0x9589	ret 0x10		0x14055b854
# 0x95c7	ret 0x18		0x14046b53e
# 0x9601	ret		0x140424340
# 0x9642	jmp r10		0x14038a520
# 0x96a0	jmp r10		0x1406f719e
# 0x96d2	jmp r10		0x140765423
# 0x9707	ret 8		0x14071277a
# 0x976a	ret 0x18		0x1403188ad
# 0x97c8	jmp r10		0x14038a520
# 0x9826	jmp r10		0x14064658f
# 0x985a	ret 0x10		0x1406c9baa
# 0x98cb	jmp r10		0x14046b53e
# 0x9905	ret		0x140765423
# 0x993a	ret 8		0x1406c9baa
# 0x99ab	jmp r10		0x14046b53e
# 0x99e5	ret		0x140765423
# 0x9a1a	ret 8		0x1404388e3
# 0x9a5e	jmp rax		0x14043aafe
# 0x9a94	jmp r10		0x140430f60
# 0x9ac8	jmp rdx		0x140573437
# 0x9b00	jmp r10		0x14030668c
# 0x9b3a	ret 0x10		0x14038a520
# 0x9b98	jmp r10		0x140482140
# 0x9bd8	ret 0x18		0x14039ec0b
# 0x9c32	jmp r10		0x14038a520
# 0x9c90	jmp r10		0x14040039b
# 0x9cc2	jmp rbp		0x1403358a9
# 0x9cf3	jmp r10		0x1403df42e
# 0x9d40	ret 0x10		0x140714c67
# 0x9d9e	jmp rcx		0x140433c07
# 0x9dd3	jmp r10		0x140685cf6
# 0x9e24	ret		0x140751245
# 0x9e70	jmp r10		0x14062737a
# 0x9ea9	jmp r10		0x140567ceb
# 0x9ed3	ret 0x10		0x140326f96
# 0x9f48	jmp r10		0x14046b53e
# 0x9f82	ret		0x140765423
# 0x9fb7	ret 8		0x14073bc08
# 0xa00d	ret 8		0x1407b5e7c
# 0xa072	ret 0x20		0x14070fc3a
# 0xa0e2	jmp r10		0x14040039b
# 0xa114	jmp rbp		0x14054172a
# 0xa143	ret 0x18		0x14066dad2
# 0xa19d	ret 8		0x1406c9baa
# 0xa20e	jmp r10		0x14046b53e
# 0xa248	ret		0x140765423
# 0xa27d	ret 8		0x1406c9baa
# 0xa2ee	jmp r10		0x14046b53e
# 0xa328	ret		0x140765423
# 0xa35d	ret 8		0x14064cfc2
# 0xa3f0	jmp r10		0x14064658f
# 0xa424	ret 0x10		0x14072fa38
# 0xa47a	jmp r10		0x140418599
# 0xa4d4	jmp r10		0x14079b5f4
# 0xa505	jmp r10		0x14057ea41
# 0xa546	jmp r10		0x140746a2c
# 0xa58b	ret		0x14069a350
# 0xa5cf	ret 0x28		0x1403402f8
# 0xa603	ret 0x10		0x1406c9baa
# 0xa674	jmp r10		0x14046b53e
# 0xa6ae	ret		0x140765423
# 0xa6e3	ret 8		0x14064cfc2
# 0xa776	jmp r10		0x14064658f
# 0xa7aa	ret 0x10		0x1406ed355
# 0xa818	jmp r10		0x1405be842
# 0xa860	jmp r10		0x14070c17e
# 0xa88f	ret 8		0x1403c193c
# 0xa8e6	jmp r10		0x14046b53e
# 0xa920	ret		0x140765423
# 0xa955	ret 8		0x1405a01ca
# 0xa9a4	jmp r10		0x140747dd0
# 0xa9f5	jmp rsi		0x1406c9baa
# 0xaa66	jmp r10		0x14046b53e
# 0xaaa0	ret		0x140765423
# 0xaad5	ret 8		0x1406c9baa
# 0xab46	jmp r10		0x14046b53e
# 0xab80	ret		0x140765423
# 0xabb5	ret 8		0x14064cfc2
# 0xac48	jmp r10		0x14064658f
# 0xac7c	ret 0x10		0x140661696
# 0xacf5	jmp r10		0x140529f04
# 0xad49	jmp r10		0x140696cf4
# 0xad94	ret 0x20		0x14079f1a6
# 0xae12	jmp r10		0x1406b5d3b
# 0xae5f	ret 8		0x1406c9baa
# 0xaed0	jmp r10		0x14046b53e
# 0xaf0a	ret		0x140765423
# 0xaf3f	ret 8		0x140666b94
# 0xaf7b	ret 0x18		0x14069f93c
# 0xb00b	jmp r10		0x14046b53e
# 0xb045	ret		0x140765423
# 0xb07a	ret 8		0x1406e16bb
# 0xb0b2	ret		0x1406c9baa
# 0xb123	jmp r10		0x14046b53e
# 0xb15d	ret		0x140765423
# 0xb192	ret 8		0x140666b94
# 0xb1ce	ret 0x18		0x14060540d
# 0xb203	jmp r10		0x14065cde5
# 0xb235	ret 8		0x14039319f
# 0xb27d	ret		0x1406ba7fd
# 0xb2f3	jmp r10		0x14038a520
# 0xb351	jmp r10		0x14040039b
# 0xb383	jmp rbp		0x1405600fb
# 0xb3ac	ret 0x20		0x140396005
# 0xb3d1	jmp rdx		0x1403a4bb0
# 0xb418	ret 0x20		0x14031b59c
# 0xb45c	jmp r10		0x14069b222
# 0xb4c9	jmp r10		0x1403aa8fc
# 0xb51e	jmp r10		0x140747dd0
# 0xb56f	jmp rsi		0x1405cf50e
# 0xb5b1	jmp r10		0x1403aa8fc
# 0xb606	jmp r10		0x1406c9baa
# 0xb677	jmp r10		0x14046b53e
# 0xb6b1	ret		0x140765423
# 0xb6e6	ret 8		0x14039ec0b
# 0xb740	jmp r10		0x14038a520
# 0xb79e	jmp r10		0x14040039b
# 0xb7d0	jmp rbp		0x1403358a9
# 0xb801	jmp r10		0x1403e8679
# 0xb836	ret		0x1403ab2b5
# 0xb87c	jmp r10		0x14046d042
# 0xb8b7	jmp r10		0x14032ec3a
# 0xb8f2	ret 0x10		0x1407a4364
# 0xb933	ret 0x10		0x14052fba7
# 0xb975	ret 8		0x140516e70
# 0xb9be	jmp r10		0x1403c8c8c
# 0xba17	jmp r10		0x14038a520
# 0xba75	jmp r10		0x140482140
# 0xbab5	ret 0x18		0x14047b165
# 0xbb21	jmp r10		0x14038a520
# 0xbb7f	jmp r10		0x14040039b
# 0xbbb1	jmp rbp		0x1403358a9
# 0xbbe2	jmp r10		0x1406978ff
# 0xbc35	ret 0x20		0x14064cfc2
# 0xbcc8	jmp r10		0x14064658f
# 0xbcfc	ret 0x10		0x14059969b
# 0xbd3c	ret 0x10		0x14069bd45
# 0xbd8b	ret 8		0x14050397a
# 0xbe15	jmp r10		0x14046b53e
# 0xbe4f	ret		0x140765423
# 0xbe84	ret 8		0x1403f2024
# 0xbed5	jmp r10		0x1406c9baa
# 0xbf46	jmp r10		0x14046b53e
# 0xbf80	ret		0x140765423
# 0xbfb5	ret 8		0x14064cfc2
# 0xc048	jmp r10		0x14064658f
# 0xc07c	ret 0x10		0x14033171e
# 0xc0f7	jmp r10		0x14046b53e
# 0xc131	ret		0x140765423
# 0xc166	ret 8		0x14050d4e2
# 0xc1b9	ret 0x10		0x1405611a9
# 0xc1fb	jmp r10		0x140357687
# 0xc234	ret		0x1403f5adb
# 0xc2a1	ret 0x20		0x1405e9454
# 0xc2de	jmp r10		0x14072c04d
# 0xc304	ret 8		0x140326f96
# 0xc379	jmp r10		0x14046b53e
# 0xc3b3	ret		0x140765423
# 0xc3e8	ret 8		0x140326f96
# 0xc45d	jmp r10		0x14046b53e
# 0xc497	ret		0x140765423
# 0xc4cc	ret 8		0x1406e9018
# 0xc50d	ret 0x10		0x1407895cc
# 0xc561	ret 8		0x14064cfc2
# 0xc5f4	jmp r10		0x14064658f
# 0xc628	ret 0x10		0x1403757fc
# 0xc69b	jmp r10		0x140681b28
# 0xc6e5	jmp r10		0x140388205
# 0xc73c	jmp rdx		0x14064cfc2
# 0xc7cf	jmp r10		0x14064658f
# 0xc803	ret 0x10		0x14040de60
# 0xc86d	ret		0x1405ed678
# 0xc8a5	jmp rbp		0x140388205
# 0xc8fc	jmp rdx		0x14040de60
# 0xc966	ret		0x1406ceb0d
# 0xc995	ret 0x10		0x14046b53e
# 0xc9cf	ret		0x14048c15d
# 0xca0f	jmp r10		0x14039386e
# 0xca7e	jmp r10		0x14038a520
# 0xcadc	jmp r10		0x14064658f
# 0xcb10	ret 0x10		0x1405419f0
# 0xcb5e	jmp r10		0x14066f444
# 0xcbac	jmp r10		0x1406e58e9
# 0xcbf5	jmp rcx		0x1406e58e9
# 0xcc3e	jmp rcx		0x140367b94
# 0xcca7	jmp r10		0x1406af532
# 0xccd8	ret 0x18		0x14067ca1b
# 0xcd4d	ret 0x18		0x14038a520
# 0xcdab	jmp r10		0x14064658f
# 0xcddf	ret 0x10		0x14035d0bf
# 0xce2b	jmp r10		0x14045051a
# 0xce97	jmp r10		0x140668a73
# 0xcec2	jmp rsi		0x14069f93c
# 0xcf52	jmp r10		0x14079b98d
# 0xcfa3	jmp r10		0x1406c9baa
# 0xd014	jmp r10		0x14046b53e
# 0xd04e	ret		0x140765423
# 0xd083	ret 8		0x14064cfc2
# 0xd116	jmp r10		0x14064658f
# 0xd14a	ret 0x10		0x14033171e
# 0xd1c5	jmp r10		0x14046b53e
# 0xd1ff	ret		0x140765423
# 0xd234	ret 8		0x14050d4e2
# 0xd287	ret 0x10		0x140793b96
# 0xd2ef	jmp r10		0x14056dbd1
# 0xd326	ret 0x18		0x14032c608
# 0xd389	jmp r10		0x14038a520
# 0xd3e7	jmp r10		0x14040039b
# 0xd419	jmp rbp		0x1403008db
# 0xd453	jmp rax		0x1406c4f38
# 0xd483	jmp r10		0x1403a4bb0
# 0xd4ca	ret 0x20		0x1406693c9
# 0xd535	jmp r10		0x1406c4f38
# 0xd565	jmp r10		0x1406dc3d8
# 0xd5b4	ret 0x10		0x14038a520
# 0xd612	jmp r10		0x140482140
# 0xd652	ret 0x18		0x14064cfc2
# 0xd6e5	jmp r10		0x14064658f
# 0xd719	ret 0x10		0x14047b165
# 0xd785	jmp r10		0x14038a520
# 0xd7e3	jmp r10		0x14040039b
# 0xd815	jmp rbp		0x1403358a9
# 0xd846	jmp r10		0x14055cf72
# 0xd86d	jmp r10		0x140684277
# 0xd8c2	jmp rsi		0x14038a520
# 0xd920	jmp r10		0x14064658f
# 0xd954	ret 0x10		0x140749700
# 0xd9b4	ret 0x10		0x14038a520
# 0xda12	jmp r10		0x140482140
# 0xda52	ret 0x18		0x1406c9baa
# 0xdac3	jmp r10		0x14079f1a6
# 0xdb41	jmp r10		0x14064cfc2
# 0xdbd4	jmp r10		0x14064658f
# 0xdc08	ret 0x10		0x1406c1046
# 0xdc60	jmp r10		0x1406a5134
# 0xdccc	jmp r10		0x14046b53e
# 0xdd06	ret		0x1405c43b5
# 0xdd32	jmp r10		0x140655ef8
# 0xdd80	ret 8		0x1406a0c05
# 0xddc3	jmp r10		0x1406d3b33
# 0xde24	ret		0x14064cfc2
# 0xdeb7	jmp r10		0x14064658f
# 0xdeeb	ret 0x10		0x1406ab97b
# 0xdf42	ret		0x14064cfc2
# 0xdfd5	jmp r10		0x14064658f
# 0xe009	ret 0x10		0x1406481f0
# 0xe07d	jmp r10		0x140655d9a
# 0xe0c4	jmp r10		0x140657d00
# 0xe118	ret		0x1406c37ee
# 0xe14b	ret 0x18		0x14044b15c
# 0xe1c1	ret 0x10		0x1407c8d69
# 0xe20d	ret 8		0x140765423
# 0xe242	ret 8		0x14039ec0b
# 0xe29c	jmp r10		0x14038a520
# 0xe2fa	jmp r10		0x14040039b
# 0xe32c	jmp rbp		0x1403358a9
# 0xe35d	jmp r10		0x140397d30
# 0xe386	ret 0x10		0x1406c4f38
# 0xe3b6	jmp r10		0x14070fc3a
# 0xe426	jmp r10		0x14070fc3a
# 0xe496	jmp r10		0x14040039b
# 0xe4c8	jmp rbp		0x1403358a9
# 0xe4f9	jmp r10		0x14048c15d
# 0xe539	jmp r10		0x14046b53e
# 0xe573	ret		0x1406ceb0d
# 0xe5a2	ret 0x10		0x140728291
# 0xe5e4	ret 8		0x140356ff0
# 0xe631	ret		0x14071d2bf
# 0xe666	ret 0x18		0x140661901
# 0xe6d6	jmp r10		0x1404ecc2b
# 0xe737	jmp rax		0x140386c11
# 0xe771	jmp r10		0x140326f96
# 0xe7e6	jmp r10		0x14046b53e
# 0xe820	ret		0x140765423
# 0xe855	ret 8		0x1406e0aaf
# 0xe8b4	jmp r10		0x14038a520
# 0xe912	jmp r10		0x14040039b
# 0xe944	jmp rbp		0x1406b240c
# 0xe97b	jmp rcx		0x140690eee
# 0xe9e2	jmp r10		0x140664233
# 0xea52	jmp r10		0x14046b53e
# 0xea8c	ret		0x1406ceb0d
# 0xeabb	ret 0x10		0x1405a3810
# 0xeaeb	ret 0x18		0x140329b60
# 0xeb75	jmp r10		0x14046b53e
# 0xebaf	ret		0x1406ceb0d
# 0xebde	ret 0x10		0x1404205cb
# 0xec38	jmp r10		0x14052937b
# 0xec77	ret 0x10		0x14046b53e
# 0xecb1	ret		0x14075f680
# 0xed22	ret 0x10		0x1403052d6
# 0xed72	ret 0x28		0x140481dc6
# 0xedaa	jmp r10		0x140612354
# 0xedd6	jmp r10		0x140437ee1
# 0xee2d	ret		0x140454387
# 0xee85	jmp r10		0x140386c11
# 0xeebf	jmp r10		0x14043aafe
# 0xeef5	jmp r10		0x1405c29fc
# 0xef23	ret 8		0x1404bd0aa
# 0xefab	jmp r10		0x14038a520
# 0xf009	jmp r10		0x14040039b
# 0xf03b	jmp rbp		0x1403a4bb0
# 0xf082	ret 0x20		0x14039c19a
# 0xf109	jmp r10		0x14072789c
# 0xf197	jmp r10		0x1406c9baa
# 0xf208	jmp r10		0x14046b53e
# 0xf242	ret		0x140765423
# 0xf277	ret 8		0x14070fc3a
# 0xf2e7	jmp r10		0x14040039b
# 0xf319	jmp rbp		0x140715473
# 0xf361	ret		0x1406ba7fd
# 0xf3d7	jmp r10		0x14038a520
# 0xf435	jmp r10		0x14040039b
# 0xf467	jmp rbp		0x1403008db
# 0xf4a1	jmp rax		0x1406c4f38
# 0xf4d1	jmp r10		0x1404e620a
# 0xf541	jmp r10		0x140429157
# 0xf5b1	jmp r10		0x1403a41c4
# 0xf5f7	ret		0x1403052d6
# 0xf647	ret 0x28		0x1406a7b5e
# 0xf694	ret		0x140690eee
# 0xf6fb	jmp r10		0x14061beb9
# 0xf72a	jmp r10		0x140690eee
# 0xf791	jmp r10		0x1403adcc1
# 0xf7d0	ret 8		0x140690eee
# 0xf837	jmp r10		0x140392701
# 0xf88d	jmp r10		0x14038a520
# 0xf8eb	jmp r10		0x14040039b
# 0xf91d	jmp rbp		0x1403008db
# 0xf957	jmp rax		0x1406c4f38
# 0xf987	jmp r10		0x1403c193c
# 0xf9de	jmp r10		0x14046b53e
# 0xfa18	ret		0x140765423
# 0xfa4d	ret 8		0x14047b165
# 0xfab9	jmp r10		0x14038a520
# 0xfb17	jmp r10		0x14040039b
# 0xfb49	jmp rbp		0x1403008db
# 0xfb83	jmp rax		0x1406c4f38
# 0xfbb3	jmp r10		0x14059fd57
# 0xfbe3	ret		0x1403c193c
# 0xfc3a	jmp r10		0x14046b53e
# 0xfc74	ret		0x140765423
# 0xfca9	ret 8		0x14050d0ad
# 0xfd19	ret 8		0x1406c9baa
# 0xfd8a	jmp r10		0x14046b53e
# 0xfdc4	ret		0x140765423
# 0xfdf9	ret 8		0x1406c9baa
# 0xfe6a	jmp r10		0x14046b53e
# 0xfea4	ret		0x140765423
# 0xfed9	ret 8		0x14064cfc2
# 0xff6c	jmp r10		0x14064658f
# 0xffa0	ret 0x10		0x140661696
# 0x10019	jmp r10		0x1405cf50e
# 0x1005b	jmp r10		0x140696cf4
# 0x100a6	ret 0x20		0x14079f1a6
# 0x10124	jmp r10		0x1406b5d3b
# 0x10171	ret 8		0x1406c9baa
# 0x101e2	jmp r10		0x14046b53e
# 0x1021c	ret		0x140765423
# 0x10251	ret 8		0x140666b94
# 0x1028d	ret 0x18		0x14069f93c
# 0x1031d	jmp r10		0x14046b53e
# 0x10357	ret		0x140765423
# 0x1038c	ret 8		0x1404def09
# 0x103d7	jmp rcx		0x14038a520
# 0x10435	jmp r10		0x140482140
# 0x10475	ret 0x18		0x140666b94
# 0x104b1	ret 0x18		0x140359501
# 0x104fa	ret		0x140690eee
# 0x10561	jmp r10		0x14046cb2e
# 0x10596	ret 8		0x14070fc3a
# 0x10606	jmp r10		0x14040039b
# 0x10638	jmp rbp		0x14067b2c6
# 0x10681	ret 0x10		0x1406826f8
# 0x106e0	ret 0x18		0x14039c19a
# 0x10767	jmp r10		0x140690eee
# 0x107ce	jmp r10		0x14072789c
# 0x1085c	jmp r10		0x140690eee
# 0x108c3	jmp r10		0x140664b72
# 0x108e4	jmp r10		0x140503fcb
# 0x10957	ret 8		0x140503fcb
# 0x109ca	ret 8		0x140684e06
# 0x10a2d	ret		0x140503fcb
# 0x10aa0	ret 8		0x140503fcb
# 0x10b13	ret 8		0x1407106f5
# 0x10b55	ret 8		0x140329b60
# 0x10bdf	jmp r10		0x14046b53e
# 0x10c19	ret		0x1406ceb0d
# 0x10c48	ret 0x10		0x14046b53e
# 0x10c82	ret		0x14031f147
# 0x10ceb	ret		0x140684277
# 0x10d40	jmp rsi		0x14038a520
# 0x10d9e	jmp r10		0x14064658f
# 0x10dd2	ret 0x10		0x14064cfc2
# 0x10e65	jmp r10		0x14064658f
# 0x10e99	ret 0x10		0x1406481f0
# 0x10f0d	jmp r10		0x140655d9a
# 0x10f54	jmp r10		0x1403d583a
# 0x10f84	jmp r10		0x140658f14
# 0x10ff3	ret 8		0x14070fc3a
# 0x11063	jmp r10		0x14040039b
# 0x11095	jmp rbp		0x140315ebe
# 0x110f2	jmp r10		0x14046b53e
# 0x1112c	ret		0x1406ceb0d
# 0x1115b	ret 0x10		0x1405bc6d8
# 0x1118d	jmp r10		0x1406c9baa
# 0x111fe	jmp r10		0x14064cfc2
# 0x11291	jmp r10		0x14064658f
# 0x112c5	ret 0x10		0x1406481f0
# 0x11339	jmp r10		0x1405dd2bb
# 0x11371	ret 0x18		0x14064cfc2
# 0x11404	jmp r10		0x14064658f
# 0x11438	ret 0x10		0x1404b5aa8
# 0x11491	ret 0x30		0x140684277
# 0x114e6	jmp rsi		0x140457980
# 0x1153d	ret 0x10		0x1406dc856
# 0x115b6	jmp r10		0x140428192
# 0x1162b	jmp r10		0x14074b4aa
# 0x1166e	ret 8		0x1406872cc
# 0x116ad	jmp r8		0x14059969b
# 0x116ed	ret 0x10		0x14038a520
# 0x1174b	jmp r10		0x14064658f
# 0x1177f	ret 0x10		0x14040de60
# 0x117e9	ret		0x140765423
# 0x1181e	ret 8		0x14064cfc2
# 0x118b1	jmp r10		0x14064658f
# 0x118e5	ret 0x10		0x14064cfc2
# 0x11978	jmp r10		0x14064658f
# 0x119ac	ret 0x10		0x1404b9216
# 0x119e7	ret		0x1406d3956
# 0x11a49	jmp r10		0x14038a520
# 0x11aa7	jmp r10		0x14064658f
# 0x11adb	ret 0x10		0x1405d1bf8
# 0x11b0e	ret		0x1406872cc
# 0x11b4d	jmp r8		0x1404b2110
# 0x11b9c	ret 0x10		0x1406c9baa
# 0x11c0d	jmp r10		0x14046b53e
# 0x11c47	ret		0x140765423
# 0x11c7c	ret 8		0x1406f469f
# 0x11cc4	jmp r10		0x14070fc3a
# 0x11d34	jmp r10		0x14040039b
# 0x11d66	jmp rbp		0x1403008db
# 0x11da0	jmp rax		0x1406c4f38
# 0x11dd0	jmp r10		0x14037f513
# 0x11e04	jmp r8		0x14065652a
# 0x11e43	jmp rdx		0x1406693a0
# 0x11ecb	ret 0x20		0x14046b53e
# 0x11f05	ret		0x1404e39db
# 0x11f5e	ret 0x20		0x140690eee
# 0x11fc5	jmp r10		0x1406c9baa
# 0x12036	jmp r10		0x14046b53e
# 0x12070	ret		0x140765423
# 0x120a5	ret 8		0x14050d0ad
# 0x12115	ret 8		0x1406c9baa
# 0x12186	jmp r10		0x14046b53e
# 0x121c0	ret		0x140765423
# 0x121f5	ret 8		0x1406c9baa
# 0x12266	jmp r10		0x14046b53e
# 0x122a0	ret		0x140765423
# 0x122d5	ret 8		0x14064cfc2
# 0x12368	jmp r10		0x14064658f
# 0x1239c	ret 0x10		0x140661696
# 0x12415	jmp r10		0x1406ede9b
# 0x124aa	jmp r10		0x14079f1a6
# 0x12528	jmp r10		0x1406b5d3b
# 0x12575	ret 8		0x1406c9baa
# 0x125e6	jmp r10		0x14046b53e
# 0x12620	ret		0x140765423
# 0x12655	ret 8		0x140666b94
# 0x12691	ret 0x18		0x140326f96
# 0x12706	jmp r10		0x14046b53e
# 0x12740	ret		0x140765423
# 0x12775	ret 8		0x1404def09
# 0x127c0	jmp rcx		0x14038a520
# 0x1281e	jmp r10		0x140482140
# 0x1285e	ret 0x18		0x140666b94
# 0x1289a	ret 0x18		0x1404d9f02
# 0x128f4	jmp r9		0x14038a520
# 0x12952	jmp r10		0x140482140
# 0x12992	ret 0x18		0x14064cfc2
# 0x12a25	jmp r10		0x14064658f
# 0x12a59	ret 0x10		0x140367b94
# 0x12ac2	jmp r10		0x14064cfc2
# 0x12b55	jmp r10		0x14064658f
# 0x12b89	ret 0x10		0x14077858b
# 0x12bc4	jmp r10		0x1403c193c
# 0x12c1b	jmp r10		0x14046b53e
# 0x12c55	ret		0x140765423
# 0x12c8a	ret 8		0x14064cfc2
# 0x12d1d	jmp r10		0x14064658f
# 0x12d51	ret 0x10		0x14064cfc2
# 0x12de4	jmp r10		0x14064658f
# 0x12e18	ret 0x10		0x1404b9216
# 0x12e53	ret		0x1406d3956
# 0x12eb5	jmp r10		0x14038a520
# 0x12f13	jmp r10		0x14064658f
# 0x12f47	ret 0x10		0x1406af532
# 0x12f78	ret 0x18		0x1406872cc
# 0x12fb7	jmp r8		0x1406862de
# 0x12fea	jmp rbp		0x1406c9baa
# 0x1305b	jmp r10		0x14046b53e
# 0x13095	ret		0x140765423
# 0x130ca	ret 8		0x14064cfc2
# 0x1315d	jmp r10		0x14064658f
# 0x13191	ret 0x10		0x140367b94
# 0x131fa	jmp r10		0x1406481f0
# 0x1326e	jmp r10		0x14044e189
# 0x132c2	ret		0x1404b5aa8
# 0x1331b	ret 0x30		0x140367b94
# 0x13384	jmp r10		0x140367b94
# 0x133ed	jmp r10		0x14044e189
# 0x13441	ret		0x1404b5aa8
# 0x1349a	ret 0x30		0x1406932b2
# 0x134d0	jmp r10		0x1404e559c
# 0x1353e	jmp r10		0x14046b53e
# 0x13578	ret		0x140617f93
# 0x135a7	ret 8		0x140762168
# 0x135e2	ret 0x18		0x1406872cc
# 0x13621	jmp r8		0x1406862de
# 0x13654	jmp rbp		0x14064cfc2
# 0x136e7	jmp r10		0x14064658f
# 0x1371b	ret 0x10		0x1406481f0
# 0x1378f	jmp r10		0x1406481f0
# 0x13803	jmp r10		0x14044e189
# 0x13857	ret		0x1404b5aa8
# 0x138b0	ret 0x30		0x140692710
# 0x13944	jmp r10		0x1406e58e9
# 0x1398d	jmp rcx		0x1406a0c05
# 0x139d0	jmp r10		0x14044e189
# 0x13a24	ret		0x1404b5aa8
# 0x13a7d	ret 0x30		0x14064cfc2
# 0x13b10	jmp r10		0x14064658f
# 0x13b44	ret 0x10		0x1406932b2
# 0x13b7a	jmp r10		0x1406f4c55
# 0x13bb4	ret		0x1406c9baa
# 0x13c25	jmp r10		0x14046b53e
# 0x13c5f	ret		0x140765423
# 0x13c94	ret 8		0x14064cfc2
# 0x13d27	jmp r10		0x14064658f
# 0x13d5b	ret 0x10		0x140367b94
# 0x13dc4	jmp r10		0x1406a0c05
# 0x13e07	jmp r10		0x1406872cc
# 0x13e46	jmp r8		0x1406dc856
# 0x13ebf	jmp r10		0x1406a0c05
# 0x13f02	jmp r10		0x14044e189
# 0x13f56	ret		0x1406a0c05
# 0x13f99	jmp r10		0x1404b5aa8
# 0x13ff2	ret 0x30		0x1406a0c05
# 0x14035	jmp r10		0x1406872cc
# 0x14074	jmp r8		0x140534390
# 0x140a4	ret 0x18		0x14043aafe
# 0x140da	jmp r10		0x1406a5134
# 0x14146	jmp r10		0x14046b53e
# 0x14180	ret		0x1405ae874
# 0x141b3	jmp rsi		0x140762168
# 0x141ee	ret 0x18		0x1406872cc
# 0x1422d	jmp r8		0x1406862de
# 0x14260	jmp rbp		0x14047b165
# 0x142cc	jmp r10		0x14038a520
# 0x1432a	jmp r10		0x14040039b
# 0x1435c	jmp rbp		0x1403008db
# 0x14396	jmp rax		0x140481dc6
# 0x143ce	jmp r10		0x140301d1a
# 0x1440e	jmp rdx		0x1404e39db
# 0x14467	ret 0x20		0x14039c19a
# 0x144ee	jmp r10		0x14039c19a
# 0x14575	jmp r10		0x14039c19a
# 0x145fc	jmp r10		0x14072789c
# 0x1468a	jmp r10		0x140690eee
# 0x146f1	jmp r10		0x14057169c
# 0x14724	jmp r10		0x140503fcb
# 0x14797	ret 8		0x1403ef950
# 0x14802	jmp r9		0x140503fcb
# 0x14875	ret 8		0x140503fcb
# 0x148e8	ret 8		0x1403ef950
# 0x14953	jmp r9		0x1404b5d9a
# 0x149c4	ret 0x10		0x14038a520
# 0x14a22	jmp r10		0x14040039b
# 0x14a54	jmp rbp		0x140715473
# 0x14a9c	ret		0x1404e39db
# 0x14af5	ret 0x20		0x14039c19a
# 0x14b7c	jmp r10		0x14072789c
# 0x14c0a	jmp r10		0x14039c19a
# 0x14c91	jmp r10		0x14039c19a
# 0x14d18	jmp r10		0x14072789c
# 0x14da6	jmp r10		0x140690eee
# 0x14e0d	jmp r10		0x1406a5568
# 0x14e45	jmp rdi		0x14060cd9c
# 0x14e8a	ret 0x10		0x1404240d7
# 0x14eee	ret 0x18		0x14068ff8c
# 0x14f4a	ret		0x14068ff8c
# 0x14fa6	ret		0x14068ff8c
# 0x15002	ret		0x14068ff8c
# 0x1505e	ret		0x14068ff8c
# 0x150ba	ret		0x14048faae
# 0x150f3	ret 0x10		0x1403bd6f1
# 0x1516a	jmp rdi		0x1406824c3
# 0x1519a	jmp rdi		0x1406caae9
# 0x151e5	jmp rdx		0x1404ed5f5
# 0x15243	ret 8		0x14033509a
# 0x1529a	jmp rdi		0x1406e1ed9
# 0x15302	jmp rdi		0x1406824c3
# 0x15332	jmp rdi		0x1406caae9
# 0x1537d	jmp rdx		0x1404a31e4
# 0x153c5	ret		0x14068ed47
# 0x1544c	jmp rdi		0x1406380ad
# 0x154da	jmp rdi		0x14066b12f
# 0x15546	jmp rdi		0x14078c63e
# 0x155a2	jmp rdi		0x1406380ad
# 0x15630	jmp rdi		0x1406380ad
# 0x156be	jmp rdi		0x1406380ad
# 0x1574c	jmp rdi		0x1405db818
# 0x15789	ret 8		0x140640579
# 0x157e1	ret		0x140640579
# 0x15839	ret		0x140640579
# 0x15891	ret		0x14066b73a
# 0x158f7	jmp rbp		0x140640579
# 0x1594f	ret		0x140640579
# 0x159a7	ret		0x1406a0ea7
# 0x15a0d	ret 0x30		0x140640579
# 0x15a65	ret		0x14049b724
# 0x15ac2	jmp r11		0x14062e1f9
# 0x15b09	ret 0x10		0x1406fba55
# 0x15b3a	ret 8		0x14062e1f9
# 0x15b81	ret 0x10		0x140460a10
# 0x15bd2	ret 8		0x14071f356
# 0x15c32	jmp r11		0x1406fba55
# 0x15c63	ret 8		0x140725e5f
# 0x15ce7	jmp r11		0x14064109f
# 0x15d1a	ret		0x1406ce6d6
# 0x15d69	jmp r11		0x14071f356
# 0x15dc9	jmp r11		0x1406fba55
# 0x15dfa	ret 8		0x140736f46
# 0x15e55	ret 0x18		0x1403207d8
# 0x15ecc	ret		0x14043e8ca
# 0x15f5a	jmp r11		0x14062e1f9
# 0x15fa1	ret 0x10		0x1406fba55
# 0x15fd2	ret 8		0x14062e1f9
# 0x16019	ret 0x10		0x1403207d8
# 0x16090	ret		0x140725e5f
# 0x16114	jmp r11		0x1406d1dd4
# 0x161b8	jmp r11		0x140798283
# 0x16218	jmp r11		0x140763701
# 0x1627a	jmp r11		0x14062e1f9
# 0x162c1	ret 0x10		0x1404721e3
# 0x162f5	jmp rbx		0x14066576d
# 0x16360	jmp r11		0x14062e1f9
# 0x163a7	ret 0x10		0x1406fba55
# 0x163d8	ret 8		0x140442f12
# 0x16424	ret 0x20		0x14077f621
# 0x16458	ret 8		0x1407441e7
# 0x164bf	jmp r11		0x14062e1f9
# 0x16506	ret 0x10		0x1404721e3
# 0x1653a	jmp rbx		0x14049b724
# 0x16597	jmp r11		0x14062e1f9
# 0x165de	ret 0x10		0x1406fba55
# 0x1660f	ret 8		0x14071ece1
# 0x1666a	jmp r11		0x1406ce6d6
# 0x166b9	jmp r11		0x14071f356
# 0x16719	jmp r11		0x1406fba55
# 0x1674a	ret 8		0x140442f12
# 0x16796	ret 0x20		0x140696640
# 0x167d6	ret 8		0x1404ab52a
# 0x16810	ret 8		0x14071f356
# 0x16870	jmp r11		0x1404721e3
# 0x168a4	jmp rbx		0x14036e745
# 0x16913	ret		0x140763701
# 0x16975	jmp r11		0x14062e1f9
# 0x169bc	ret 0x10		0x1404721e3
# 0x169f0	jmp rbx		0x140763701
# 0x16a52	jmp r11		0x14062e1f9
# 0x16a99	ret 0x10		0x1404721e3
# 0x16acd	jmp rbx		0x1404d36f4
# 0x16b52	jmp r11		0x1403d5159
# 0x16b83	jmp r11		0x140676705
# 0x16bcb	jmp r11		0x140737a4f
# 0x16c09	jmp r8		0x1403e5f84
# 0x16c70	jmp r11		0x140690cee
# 0x16ccf	jmp r11		0x14063fb27
# 0x16cfe	ret		0x14072dbbe
# 0x16d46	ret 0x10		0x140763701
# 0x16da8	jmp r11		0x14062e1f9
# 0x16def	ret 0x10		0x1404721e3
# 0x16e23	jmp rbx		0x1403d4963
# 0x16e5a	jmp r11		0x1403a7004
# 0x16e95	ret 8		0x14071f356
# 0x16ef5	jmp r11		0x1404721e3
# 0x16f29	jmp rbx		0x14070dcce
# 0x16f5f	ret 0x10		0x140763701
# 0x16fc1	jmp r11		0x14062e1f9
# 0x17008	ret 0x10		0x1404721e3
# 0x1703c	jmp rbx		0x1403d4963
# 0x17073	jmp r11		0x140766c6a
# 0x170a8	ret 8		0x14069f43d
# 0x170fe	ret 0x20		0x14049b724
# 0x1715b	jmp r11		0x14062e1f9
# 0x171a2	ret 0x10		0x1406fba55
# 0x171d3	ret 8		0x140442f12
# 0x1721f	ret 0x20		0x14047bfae
# 0x1725e	ret		0x1403207d8
# 0x172d5	ret		0x140725e5f
# 0x17359	jmp r11		0x140725e5f
# 0x173dd	jmp r11		0x1406d1dd4
# 0x17481	jmp r11		0x140725e5f
# 0x17505	jmp r11		0x14065d035
# 0x17549	ret		0x1406fb2d5
# 0x175ac	ret		0x140617f15
# 0x175ef	ret 0x10		0x14075f8ad
# 0x17655	jmp rbp		0x1406fb2d5
# 0x176b8	ret		0x1406fb2d5
# 0x1771b	ret		0x1406fb2d5
# 0x1777e	ret		0x1406fb2d5
# 0x177e1	ret		0x1406fb2d5
# 0x17844	ret		0x1403bc605
# 0x178bc	ret 0x18		0x1406b784b
# 0x17929	jmp rbp		0x140667e11
# 0x17964	ret 0x10		0x140386589
# 0x179be	ret 0x20		0x1404ec6da
# 0x17a23	jmp rbp		0x1404eaae5
# 0x17a59	ret 0x10		0x14077d9e3
# 0x17a99	jmp rbp		0x1406f4db1
# 0x17ae1	ret		0x1403f0d97
# 0x17b2d	ret 8		0x140474c44
# 0x17ba3	jmp rbp		0x140474c44
# 0x17c19	jmp rbp		0x140474c44
# 0x17c8f	jmp rbp		0x140683d82
# 0x17d04	jmp rbp		0x1406819d6
# 0x17d7c	jmp rbp		0x1406819d6
# 0x17df4	jmp rbp		0x140474c44
# 0x17e6a	jmp rbp		0x140474c44
# 0x17ee0	jmp rbp		0x140474c44
# 0x17f56	jmp rbp		0x1404c682f
# 0x17f91	ret 8		0x14066fa13
# 0x17fc2	ret 8		0x1406a360b
# 0x17ff7	jmp r9		0x14047b8df
# 0x18068	ret 0x20		0x14047b8df
# 0x180d9	ret 0x20		0x14047b8df
# 0x1814a	ret 0x20		0x14047b8df
# 0x181bb	ret 0x20		0x1405533bb
# 0x18207	ret 0x28		0x14066db6d
# 0x18247	jmp rsi		0x1403596e0
# 0x182b1	jmp r9		0x14032cfcd
# 0x182ee	jmp r9		0x140337e48
# 0x18330	ret 0x10		0x1406be240
# 0x18389	ret 8		0x140321c29
# 0x183e3	jmp r9		0x140768d32
# 0x18420	ret		0x140423a43
# 0x1849f	jmp r9		0x1406950ee
# 0x18506	jmp r9		0x140774121
# 0x18541	jmp r9		0x1403422c3
# 0x1856e	ret 8		0x140580806
# 0x1859a	jmp r9		0x1405c1b2d
# 0x185de	ret 0x10		0x1406e774c
# 0x18631	jmp r9		0x140423a43
# 0x186b0	jmp r9		0x14066d928
# 0x186e2	ret 8		0x140549e8f
# 0x1870d	jmp r9		0x1404da78a
# 0x18765	ret 0x10		0x140464c91
# 0x187a3	ret		0x14066d928
# 0x187d5	ret 8		0x1406dfd42
# 0x1883a	jmp r9		0x14031de5d
# 0x1886f	ret 0x28		0x1403277b9
# 0x188bb	ret 0x10		0x1406c6b00
# 0x188f8	ret 0x18		0x140587488
# 0x18936	jmp r9		0x1406c6b00
# 0x18973	ret 0x18		0x14032c5f5
# 0x189b7	jmp r11		0x140423a43
# 0x18a36	jmp r9		0x14066d928
# 0x18a68	ret 8		0x1403cfb5d
# 0x18ad5	jmp r9		0x140337e48
# 0x18b17	ret 0x10		0x1405c4cad
# 0x18b43	ret 0x18		0x140572d09
# 0x18b79	jmp rdx		0x140542f5d
# 0x18bca	jmp r9		0x1403596e0
# 0x18c34	jmp r9		0x1405fce42
# 0x18c6b	ret 8		0x1404aca35
# 0x18cb7	ret 8		0x140551722
# 0x18d0c	jmp r9		0x1406ba9be
# 0x18d47	jmp r11		0x140423fed
# 0x18d92	ret 0x18		0x14070def4
# 0x18de8	jmp r9		0x14075215a
# 0x18e34	ret 0x10		0x14047b762
# 0x18e89	jmp r9		0x1403cb94f
# 0x18ee3	jmp r9		0x14032cfcd
# 0x18f20	jmp r9		0x140657edf
# 0x18f5f	jmp rsi		0x14046a17e
# 0x18f9f	jmp rsi		0x140762b3d
# 0x18fe4	ret		0x1403596e0
# 0x1904e	jmp r9		0x14066d928
# 0x19080	ret 8		0x14057acf7
# 0x190aa	ret 0x10		0x140719b91
# 0x19103	jmp r9		0x1406646ed
# 0x19145	ret 0x18		0x1404da78a
# 0x1919d	ret 0x10		0x1405a7170
# 0x191fd	jmp r9		0x140686a0e
# 0x19252	ret		0x14071de93
# 0x192b7	jmp r9		0x140337e48
# 0x192f9	ret 0x10		0x140345909
# 0x1933a	jmp r9		0x1403cb94f
# 0x19394	jmp r9		0x14032cfcd
# 0x193d1	jmp r9		0x140729575
# 0x1940e	ret 8		0x14045b402
# 0x1943c	ret		0x1406c1ff1
# 0x1947d	jmp r9		0x140652ecf
# 0x194aa	ret 0x18		0x14043808f
# 0x194f7	ret 0x20		0x1403d5405
# 0x1953a	ret 8		0x1406c6b00
# 0x19577	ret 0x18		0x140423a43
# 0x195f6	jmp r9		0x14066d928
# 0x19628	ret 8		0x1406c5319
# 0x19676	jmp rdx		0x140423a43
# 0x196f5	jmp r9		0x14066d928
# 0x19727	ret 8		0x1403cfb5d
# 0x19794	jmp r9		0x140337e48
# 0x197d6	ret 0x10		0x140345909
# 0x19817	jmp r9		0x1403cb94f
# 0x19871	jmp r9		0x14032cfcd
# 0x198ae	jmp r9		0x140465cce
# 0x198e2	ret 8		0x14074ad3c
# 0x19925	jmp r9		0x140450249
# 0x19981	ret 0x10		0x1403596e0
# 0x199eb	jmp r9		0x140652624
# 0x19a1e	ret		0x14070c398
# 0x19a59	ret 8		0x14030fe43
# 0x19a94	ret 0x10		0x1406f5493
# 0x19b0b	jmp r9		0x1405900be
# 0x19b61	jmp r9		0x1406ede6f
# 0x19bb4	jmp r9		0x14076f3ac
# 0x19c05	ret 8		0x14073a92d
# 0x19c33	ret 0x10		0x1406228bb
# 0x19c5f	jmp r9		0x1404de529
# 0x19cad	jmp r9		0x1406c6b00
# 0x19cea	ret 0x18		0x14069a372
# 0x19d3b	jmp r9		0x1405579a0
# 0x19d90	jmp r9		0x1403596e0
# 0x19dfa	jmp r9		0x14067e3ad
# 0x19e3c	jmp rdi		0x1406f7244
# 0x19e87	ret 8		0x140717ce2
# 0x19eeb	ret 8		0x1406be689
# 0x19f50	jmp r9		0x1403cb94f
# 0x19faa	jmp r9		0x14032cfcd
# 0x19fe7	jmp r9		0x14063336e
# 0x1a01e	jmp r9		0x1407bdc5d
# 0x1a04b	jmp r9		0x1406c6b00
# 0x1a088	ret 0x18		0x1403cb94f
# 0x1a0e2	jmp r9		0x14032cfcd
# 0x1a11f	jmp r9		0x140337e48
# 0x1a161	ret 0x10		0x14055b092
# 0x1a1a6	ret		0x1404b7443
# 0x1a224	jmp r9		0x140555e1f
# 0x1a296	jmp r9		0x1407b9f0d
# 0x1a2f1	jmp r9		0x14078761e
# 0x1a355	jmp r9		0x14078761e
# 0x1a3b9	jmp r9		0x1404b7443
# 0x1a437	jmp r9		0x140311d44
# 0x1a4c9	jmp r9		0x14078761e
# 0x1a52d	jmp r9		0x1407b9f0d
# 0x1a588	jmp r9		0x140544405
# 0x1a5bb	jmp r10		0x14034dca4
# 0x1a60b	ret		0x14072b72a
# 0x1a65b	ret		0x14034dca4
# 0x1a6ab	ret		0x14034dca4
# 0x1a6fb	ret		0x140689d5d
# 0x1a774	ret 0x20		0x14034dca4
# 0x1a7c4	ret		0x14034dca4
# 0x1a814	ret		0x1403428f0
# 0x1a886	ret 0x10		0x140573a11
# 0x1a8ce	jmp r10		0x1404f1e32
# 0x1a919	ret 0x18		0x14031ec39
# 0x1a96c	ret 8		0x14065fc7f
# 0x1a9ee	jmp r10		0x1404f1e32
# 0x1aa39	ret 0x18		0x14031ec39
# 0x1aa8c	ret 8		0x1404de750
# 0x1ab14	jmp r10		0x1404dfa6c
# 0x1ab90	jmp r10		0x1405855a6
# 0x1abe3	jmp r10		0x1406e5d44
# 0x1ac4f	jmp r10		0x1404dfa6c
# 0x1accb	jmp r10		0x140737794
# 0x1ad29	jmp r10		0x1404dfa6c
# 0x1ada5	jmp r10		0x1404dfa6c
# 0x1ae21	jmp r10		0x1404dfa6c
# 0x1ae9d	jmp r10		0x1407a3763
# 0x1aeee	jmp r10		0x1405d9a8b
# 0x1af2c	ret		0x1406fb2d5
# 0x1af8f	ret		0x14039c411
# 0x1b006	ret 0x28		0x1406fb2d5
# 0x1b069	ret		0x1406fb2d5
# 0x1b0cc	ret		0x1406fb2d5
# 0x1b12f	ret		0x1406fb2d5
# 0x1b192	ret		0x1406fb2d5
# 0x1b1f5	ret		0x1406fb2d5
# 0x1b258	ret		0x14068ac58
# 0x1b2a8	jmp rbp		0x140688021
# 0x1b2f2	jmp rbp		0x140689317
# 0x1b343	jmp rbp		0x1404e132b
# 0x1b379	ret 8		0x1403ab876
# 0x1b3db	jmp rbp		0x1406969aa
# 0x1b457	jmp rbp		0x1406d361d
# 0x1b49f	ret 0x18		0x1405f5055
# 0x1b4c2	ret		0x1406db822
# 0x1b4f4	ret 0x18		0x140680845
# 0x1b526	jmp rdx		0x14071496c
# 0x1b569	ret 0x28		0x14047d531
# 0x1b5c1	jmp rbp		0x1403f6ab2
# 0x1b619	jmp rbp		0x1405cdb00
# 0x1b669	jmp rbp		0x1406d361d
# 0x1b6b1	ret 0x18		0x140667e11
# 0x1b6ec	ret 0x10		0x1405c4bb9
# 0x1b726	ret 8		0x1406969aa
# 0x1b7a2	jmp rbp		0x1406d361d
# 0x1b7ea	ret 0x18		0x140667e11
# 0x1b825	ret 0x10		0x1403521ab
# 0x1b863	jmp rbp		0x1404fa043
# 0x1b8c5	ret 0x20		0x1406d5053
# 0x1b914	jmp rbp		0x1406d361d
# 0x1b95c	ret 0x18		0x140537ea4
# 0x1b98a	jmp rdx		0x14042e9e9
# 0x1b9ef	ret 0x20		0x1403e1840
# 0x1ba63	jmp rbp		0x14069af6d
# 0x1baaf	jmp rbp		0x1404e132b
# 0x1bae5	ret 8		0x1403ddb04
# 0x1bb2e	ret 0x10		0x14069af6d
# 0x1bb7a	jmp rbp		0x1404e132b
# 0x1bbb0	ret 8		0x1406d91c2
# 0x1bc28	jmp rbp		0x14045d8e0
# 0x1bc7c	jmp rbp		0x1406d91c2
# 0x1bcf4	jmp rbp		0x140351920
# 0x1bd4f	jmp rbp		0x140773931
# 0x1bd79	jmp rbp		0x14032ab34
# 0x1bdb1	jmp rbp		0x140646ed1
# 0x1bdf6	ret 0x10		0x1406e34bb
# 0x1be39	jmp rbp		0x14056771a
# 0x1be7a	ret 8		0x1406d9059
# 0x1bede	jmp rbp		0x140719b6a
# 0x1bf23	jmp rbp		0x1407a93d6
# 0x1bf7c	ret 0x18		0x1404ec6da
# 0x1bfe1	jmp rbp		0x1406d361d
# 0x1c029	ret 0x18		0x140667e11
# 0x1c064	ret 0x10		0x1406d361d
# 0x1c0ac	ret 0x18		0x140356027
# 0x1c0fa	jmp rbp		0x140645521
# 0x1c15d	jmp rbp		0x140474c44
# 0x1c1d3	jmp rbp		0x140474c44
# 0x1c249	jmp rbp		0x14065edf3
# 0x1c2db	jmp rbp		0x1406d361d
# 0x1c323	ret 0x18		0x140312106
# 0x1c358	ret 8		0x14062e403
# 0x1c399	ret 0x10		0x1403e5252
# 0x1c40b	jmp rbp		0x1406d361d
# 0x1c453	ret 0x18		0x140312106
# 0x1c488	ret 8		0x14032d73b
# 0x1c4e5	jmp rbp		0x1406d361d
# 0x1c52d	ret 0x18		0x140312106
# 0x1c562	ret 8		0x140464b86
# 0x1c5e3	jmp rbp		0x1406fc028
# 0x1c620	jmp rdx		0x14044daf8
# 0x1c65c	ret 8		0x14066874f
# 0x1c6b0	ret 0x10		0x140791dbe
# 0x1c738	jmp rbp		0x1405073b7
# 0x1c7b5	jmp rbp		0x1406851b8
# 0x1c7eb	jmp rbp		0x1405e251b
# 0x1c82a	ret 0x18		0x14032d73b
# 0x1c887	jmp rbp		0x1406d361d
# 0x1c8cf	ret 0x18		0x140312106
# 0x1c904	ret 8		0x1405af1a3
# 0x1c932	jmp rbp		0x140319826
# 0x1c969	ret		0x14032d73b
# 0x1c9c6	jmp rbp		0x1406d361d
# 0x1ca0e	ret 0x18		0x140312106
# 0x1ca43	ret 8		0x1403aa70a
# 0x1ca6e	ret		0x14032d73b
# 0x1cacb	jmp rbp		0x1406d361d
# 0x1cb13	ret 0x18		0x140312106
# 0x1cb48	ret 8		0x1406fdc22
# 0x1cb8a	jmp rbp		0x1406b0a8b
# 0x1cbbe	jmp rdx		0x1406afac6
# 0x1cc25	jmp rbp		0x1406d361d
# 0x1cc6d	ret 0x18		0x140312106
# 0x1cca2	ret 8		0x140464b86
# 0x1cd23	jmp rbp		0x1406fc028
# 0x1cd60	jmp rdx		0x1405a2c37
# 0x1cd8d	jmp rdx		0x140464b86
# 0x1ce0e	jmp rbp		0x1406fc028
# 0x1ce4b	jmp rdx		0x140462fb8
# 0x1ce96	ret 8		0x140462fb8
# 0x1cee1	ret 8		0x14067f52e
# 0x1cf2b	ret 8		0x14069af6d
# 0x1cf77	jmp rbp		0x1406fc028
# 0x1cfb4	jmp rdx		0x14064d529
# 0x1cff8	ret 8		0x1406e87b1
# 0x1d03f	ret		0x1404576da
# 0x1d068	ret 0x10		0x14032d73b
# 0x1d0c5	jmp rbp		0x1406d361d
# 0x1d10d	ret 0x18		0x140312106
# 0x1d142	ret 8		0x140464b86
# 0x1d1c3	jmp rbp		0x1406fc028
# 0x1d200	jmp rdx		0x140653012
# 0x1d256	jmp rbp		0x1406ad5a8
# 0x1d29b	ret 8		0x1406715a6
# 0x1d2d8	ret 8		0x140660f60
# 0x1d2ff	ret 8		0x140745083
# 0x1d36c	jmp rbp		0x1406c0904
# 0x1d3af	ret 0x10		0x1404ff485
# 0x1d3f1	jmp rbp		0x1406edcd9
# 0x1d48b	jmp rbp		0x14041a319
# 0x1d4d3	ret 0x20		0x1407a7dd7
# 0x1d525	ret 0x10		0x1404b2b3d
# 0x1d56a	ret 0x10		0x1403db497
# 0x1d5a7	jmp rbp		0x14067f52e
# 0x1d5f1	ret 8		0x14069af6d
# 0x1d63d	jmp rbp		0x1406fc028
# 0x1d67a	jmp rdx		0x14064d529
# 0x1d6be	ret 8		0x14062c816
# 0x1d703	ret		0x1407b9abe
# 0x1d75e	jmp rbp		0x1406d361d
# 0x1d7a6	ret 0x18		0x140312106
# 0x1d7db	ret 8		0x140464b86
# 0x1d85c	jmp rbp		0x1406fc028
# 0x1d899	jmp rdx		0x140462fb8
# 0x1d8e4	ret 8		0x140676ba3
# 0x1d946	jmp rbp		0x14069af6d
# 0x1d992	jmp rbp		0x1406fc028
# 0x1d9cf	jmp rdx		0x1406827f3
# 0x1da01	jmp rdx		0x1405c937f
# 0x1da2f	jmp rbp		0x14047db94
# 0x1da88	jmp rbp		0x14069af6d
# 0x1dad4	jmp rbp		0x1406fc028
# 0x1db11	jmp rdx		0x140653012
# 0x1db67	jmp rbp		0x1406ad5a8
# 0x1dbac	ret 8		0x1406715a6
# 0x1dbe9	ret 8		0x14041a319
# 0x1dc31	ret 0x20		0x1407a7dd7
# 0x1dc83	ret 0x10		0x1407a8d64
# 0x1dcc1	ret 0x18		0x1407884e4
# 0x1dd0c	jmp rbp		0x140334c79
# 0x1dd88	jmp rbp		0x1404b8f1d
# 0x1ddd6	ret 0x10		0x1407a7dd7
# 0x1de28	ret 0x10		0x14067f52e
# 0x1de72	ret 8		0x14069af6d
# 0x1debe	jmp rbp		0x1406fc028
# 0x1defb	jmp rdx		0x14064d529
# 0x1df3f	ret 8		0x140725542
# 0x1df7a	ret		0x1407b9abe
# 0x1dfd5	jmp rbp		0x1406d361d
# 0x1e01d	ret 0x18		0x140312106
# 0x1e052	ret 8		0x140464b86
# 0x1e0d3	jmp rbp		0x1406fc028
# 0x1e110	jmp rdx		0x140653012
# 0x1e166	jmp rbp		0x1406ad5a8
# 0x1e1ab	ret 8		0x14061b295
# 0x1e1e1	jmp rdx		0x1403db497
# 0x1e21e	jmp rbp		0x14041a319
# 0x1e266	ret 0x20		0x14043040e
# 0x1e2e2	jmp rbp		0x140330d13
# 0x1e31d	ret 8		0x1406d9059
# 0x1e381	jmp rbp		0x1407a7dd7
# 0x1e3d3	ret 0x10		0x14069905b
# 0x1e3ff	ret		0x140777a16
# 0x1e44a	jmp rbp		0x140420847
# 0x1e491	ret 8		0x140725542
# 0x1e4cc	ret		0x140464b86
# 0x1e54d	jmp rbp		0x1406fc028
# 0x1e58a	jmp rdx		0x14064d529
# 0x1e5ce	ret 8		0x14062c816
# 0x1e613	ret		0x1406f4db1
# 0x1e65b	ret		0x1405e1ee0
# 0x1e6bf	jmp rbp		0x14075af9e
# 0x1e738	jmp rbp		0x1406d361d
# 0x1e780	ret 0x18		0x140667e11
# 0x1e7bb	ret 0x10		0x1407981f2
# 0x1e7ef	jmp rbp		0x1406b7c30
# 0x1e81a	ret 8		0x1407af653
# 0x1e89f	jmp rbp		0x14032c501
# 0x1e917	jmp rbp		0x140474c44
# 0x1e98d	jmp rbp		0x140474c44
# 0x1ea03	jmp rbp		0x140474c44
# 0x1ea79	jmp rbp		0x140689317
# 0x1eaca	jmp rbp		0x1405bcb58
# 0x1eb04	ret 8		0x140640579
# 0x1eb5c	ret		0x140640579
# 0x1ebb4	ret		0x1406a0ea7
# 0x1ec1a	ret 0x30		0x140640579
# 0x1ec72	ret		0x140640579
# 0x1ecca	ret		0x1406a0ea7
# 0x1ed30	ret 0x30		0x1406d0d5b
# 0x1ed8e	ret		0x140640579
# 0x1ede6	ret		0x14049b724
# 0x1ee43	jmp r11		0x140642949
# 0x1ee96	jmp r11		0x1406525bc
# 0x1eeef	ret 0x10		0x1405f5cbe
# 0x1ef3d	ret 8		0x14049b724
# 0x1ef9a	jmp r11		0x140642949
# 0x1efed	jmp r11		0x140717da1
# 0x1f033	jmp rdx		0x1403282e9
# 0x1f08f	jmp r11		0x1403ee04a
# 0x1f0c4	ret		0x140763701
# 0x1f126	jmp r11		0x1404942d4
# 0x1f16e	ret		0x1403c5b3c
# 0x1f1d0	jmp r11		0x1406453b7
# 0x1f23a	jmp r11		0x140642949
# 0x1f28d	jmp r11		0x14075a772
# 0x1f2b8	ret 8		0x14047bfae
# 0x1f2f7	ret		0x1403846ac
# 0x1f35b	ret 8		0x14042a7bb
# 0x1f39c	ret		0x140725e5f
# 0x1f420	jmp r11		0x14072e83e
# 0x1f480	ret		0x140798283
# 0x1f4e0	jmp r11		0x140318e36
# 0x1f574	jmp r11		0x140725e5f
# 0x1f5f8	jmp r11		0x1406274f6
# 0x1f654	jmp r11		0x1406ca1a0
# 0x1f69e	jmp r11		0x1406d1dd4
# 0x1f742	jmp r11		0x140725e5f
# 0x1f7c6	jmp r11		0x140725e5f
# 0x1f84a	jmp r11		0x140725e5f
# 0x1f8ce	jmp r11		0x1405fea1c
# 0x1f90a	ret 8		0x140640579
# 0x1f962	ret		0x140640579
# 0x1f9ba	ret		0x140640579
# 0x1fa12	ret		0x140382f2b
# 0x1fa4d	jmp rdi		0x1406a0ea7
# 0x1fab3	ret 0x30		0x140640579
# 0x1fb0b	ret		0x1406a0ea7
# 0x1fb71	ret 0x30		0x140640579
# 0x1fbc9	ret		0x1406a0ea7
# 0x1fc2f	ret 0x30		0x14049b724
# 0x1fc8c	jmp r11		0x14062e1f9
# 0x1fcd3	ret 0x10		0x1406fba55
# 0x1fd04	ret 8		0x14062e1f9
# 0x1fd4b	ret 0x10		0x140339572
# 0x1fd9f	jmp r11		0x140318e36
# 0x1fe33	jmp r11		0x1406d1dd4
# 0x1fed7	jmp r11		0x140725e5f
# 0x1ff5b	jmp r11		0x140318e36
# 0x1ffef	jmp r11		0x140725e5f
# 0x20073	jmp r11		0x140725e5f
# 0x200f7	jmp r11		0x1406274f6
# 0x20153	jmp r11		0x140639187
# 0x201a6	ret 8		0x14069ca38
# 0x20211	ret		0x140772090
# 0x2028c	ret 0x28		0x140772090
# 0x20307	ret 0x28		0x140772090
# 0x20382	ret 0x28		0x140793ff6
# 0x203c5	jmp rdx		0x140630e42
# 0x20413	jmp rdi		0x14065fb1e
# 0x2045c	jmp rdi		0x140675dc9
# 0x204b4	jmp rdi		0x1404506d3
# 0x204fc	ret 8		0x140797c91
# 0x20548	ret 0x18		0x14068b7bc
# 0x20577	ret 0x20		0x14041a010
# 0x205e1	jmp rdi		0x1407ba14b
# 0x2062b	ret 0x10		0x140758da5
# 0x20685	jmp rdi		0x1403f8335
# 0x206d5	ret		0x14073c6a3
# 0x20710	ret 0x10		0x140769cd9
# 0x20782	jmp rdi		0x14068fd33
# 0x207e5	jmp rdi		0x1407aa4e2
# 0x20816	jmp rsi		0x14046068c
# 0x20893	jmp rdi		0x1404506d3
# 0x208db	ret 8		0x1406e8807
# 0x2090e	jmp rbx		0x140675dc9
# 0x20966	jmp rdi		0x1404506d3
# 0x209ae	ret 8		0x1406e8807
# 0x209e1	jmp rbx		0x14072a72f
# 0x20a3d	jmp rdi		0x1404506d3
# 0x20a85	ret 8		0x1406e8807
# 0x20ab8	jmp rbx		0x1405a6a1b
# 0x20b01	ret 0x18		0x140635195
# 0x20b69	jmp rdi		0x140596926
# 0x20b9e	ret		0x1406978f5
# 0x20bd8	jmp rdx		0x140549393
# 0x20c28	jmp rdi		0x1405f2239
# 0x20c5c	ret		0x140675dc9
# 0x20cb4	jmp rdi		0x1404506d3
# 0x20cfc	ret 8		0x1406e8807
# 0x20d2f	jmp rbx		0x1406b0562
# 0x20d70	ret 8		0x140681c08
# 0x20db3	jmp rdi		0x14054aa48
# 0x20dfd	jmp rbx		0x1404913f6
# 0x20e7a	jmp rdi		0x14066837f
# 0x20ece	ret 8		0x14069d80c
# 0x20f4d	jmp rdi		0x1404506d3
# 0x20f95	ret 8		0x1406e8807
# 0x20fc8	jmp rbx		0x140410f8e
# 0x21008	ret 0x20		0x1407897b0
# 0x2105c	jmp rdi		0x1406f0616
# 0x210d0	jmp rdi		0x1406f0616
# 0x21144	jmp rdi		0x1406f0616
# 0x211b8	jmp rdi		0x1406f0616
# 0x2122c	jmp rdi		0x1406f0616
# 0x212a0	jmp rdi		0x1406f0616
# 0x21314	jmp rdi		0x1406f0616
# 0x21388	jmp rdi		0x140418534
# 0x213f5	jmp rdi		0x1405318fb
# 0x21442	jmp rdi		0x1405b8d39
# 0x21474	ret 8		0x140731382
# 0x214ce	ret 8		0x1404ccfec
# 0x21523	ret 0x10		0x1406f15f4
# 0x2157f	ret 0x30		0x140772090
# 0x215fa	ret 0x28		0x140772090
# 0x21675	ret 0x28		0x1406f15f4
# 0x216d1	ret 0x30		0x140772090
# 0x2174c	ret 0x28		0x14044add0
# 0x217ad	jmp rdi		0x14068fd33
# 0x21810	jmp rdi		0x1406a6664
# 0x21842	jmp rdx		0x1404506d3
# 0x2188a	ret 8		0x14049bf9e
# 0x218dd	ret 8		0x1406f0616
# 0x21951	jmp rdi		0x140714056
# 0x219a5	jmp rdi		0x1406f0616
# 0x21a19	jmp rdi		0x1406f0616
# 0x21a8d	jmp rdi		0x1406f0616
# 0x21b01	jmp rdi		0x140388911
# 0x21b85	jmp rdi		0x140388911
# 0x21c09	jmp rdi		0x1405a81ac
# 0x21c45	jmp r9		0x1405a5e6d
# 0x21c8a	jmp rax		0x140386ecb
# 0x21cd2	ret		0x1404658d2
# 0x21d37	jmp rdx		0x140760cb5
# 0x21d9b	ret 8		0x1404658d2
# 0x21e00	jmp rdx		0x1404658d2
# 0x21e65	jmp rdx		0x1407759de
# 0x21ec5	jmp rdi		0x1406f39db
# 0x21f19	jmp r9		0x1406adfe3
# 0x21f69	ret 0x20		0x1403cadf7
# 0x21fb4	ret 0x10		0x140543fc8
# 0x21ffb	jmp r9		0x1406f39db
# 0x2204f	jmp r9		0x1406adfe3
# 0x2209f	ret 0x20		0x140432895
# 0x220e0	ret 0x10		0x14066c92e
# 0x22150	jmp r9		0x14044d9a6
# 0x221c4	jmp r9		0x14038e735
# 0x2221c	jmp r9		0x1405e7710
# 0x2226d	jmp r9		0x140429fca
# 0x222aa	ret 8		0x1407c27c2
# 0x22309	ret 0x18		0x14055c477
# 0x22355	ret		0x1406aff7c
# 0x223c2	jmp r9		0x140642d10
# 0x2240f	jmp rdx		0x14039f187
# 0x22446	jmp rdx		0x1405b034c
# 0x22499	jmp r9		0x140783fd7
# 0x224db	jmp r9		0x14073e8cc
# 0x22505	ret		0x1404a0114
# 0x22578	jmp r9		0x140642d10
# 0x225c5	jmp rdx		0x1406adfe3
# 0x22615	ret 0x20		0x140432895
# 0x22656	ret 0x10		0x1404a0114
# 0x226c9	jmp r9		0x140642d10
# 0x22716	jmp rdx		0x1406adfe3
# 0x22766	ret 0x20		0x140432895
# 0x227a7	ret 0x10		0x1406bba89
# 0x2280d	jmp r9		0x1406de23c
# 0x2288d	jmp r9		0x1404051ea
# 0x228b3	ret		0x140656a9b
# 0x2290b	jmp r9		0x1406f39db
# 0x2295f	jmp r9		0x14076adb9
# 0x22997	ret 0x10		0x1406aff7c
# 0x22a04	jmp r9		0x140642d10
# 0x22a51	jmp rdx		0x14076adb9
# 0x22a89	ret 0x10		0x1403485b1
# 0x22acf	ret		0x140347e2c
# 0x22b03	jmp r9		0x1406aff7c
# 0x22b70	jmp r9		0x140642d10
# 0x22bbd	jmp rdx		0x14076adb9
# 0x22bf5	ret 0x10		0x1405f7036
# 0x22c1d	jmp r9		0x140783fd7
# 0x22c5f	jmp r9		0x1404ca158
# 0x22cb4	ret 0x50		0x1406f39db
# 0x22d08	jmp r9		0x1403adf40
# 0x22d3d	jmp rdx		0x1403162d0
# 0x22da5	ret 0x40		0x1406de23c
# 0x22e25	jmp r9		0x1404051ea
# 0x22e4b	ret		0x14066f371
# 0x22ebc	jmp r9		0x140642d10
# 0x22f09	jmp rdx		0x1403adf40
# 0x22f3e	jmp rdx		0x1406aff7c
# 0x22fab	jmp r9		0x140642d10
# 0x22ff8	jmp rdx		0x14076adb9
# 0x23030	ret 0x10		0x140451986
# 0x2307c	jmp r9		0x14076222a
# 0x230c8	ret 0x28		0x14059b641
# 0x23104	ret 0x18		0x14063a96b
# 0x2316a	jmp r9		0x14044f178
# 0x231c4	ret 8		0x1403415b4
# 0x231f2	jmp r9		0x1406de23c
# 0x23272	jmp r9		0x1404051ea
# 0x23298	ret		0x1407a6809
# 0x232e0	ret 8		0x1406bb824
# 0x23317	jmp r9		0x1407bfa12
# 0x2336a	ret 8		0x1406f39db
# 0x233be	jmp r9		0x1403adf40
# 0x233f3	jmp rdx		0x140768956
# 0x2345c	jmp r9		0x140642d10
# 0x234a9	jmp rdx		0x1403adf40
# 0x234de	jmp rdx		0x1406c89b0
# 0x2351c	jmp r9		0x1404bc674
# 0x23546	jmp r9		0x14037e8cd
# 0x2358a	ret 8		0x1406de23c
# 0x2360a	jmp r9		0x1404051ea
# 0x23630	ret		0x140656a9b
# 0x23688	jmp r9		0x1406f39db
# 0x236dc	jmp r9		0x14076adb9
# 0x23714	ret 0x10		0x1407335ce
# 0x2377e	jmp r9		0x14073a325
# 0x237b3	jmp r9		0x1406aff7c
# 0x23820	jmp r9		0x140642d10
# 0x2386d	jmp rdx		0x14076adb9
# 0x238a5	ret 0x10		0x140486a45
# 0x238d0	ret 8		0x14064c402
# 0x2392b	ret 0x30		0x1407a066a
# 0x2395c	ret		0x1404d53f0
# 0x239cd	jmp r9		0x140445c4a
# 0x23a08	ret		0x14071d800
# 0x23a40	ret		0x140432895
# 0x23a81	ret 0x10		0x1406bba89
# 0x23ae7	jmp r9		0x1406bba89
# 0x23b4d	jmp r9		0x1406bba89
# 0x23bb3	jmp r9		0x1406bba89
# 0x23c19	jmp r9		0x14074b16b
# 0x23c89	jmp r9		0x1406a213c
# 0x23d14	jmp r9		0x14074b16b
# 0x23d84	jmp r9		0x1407356ce
# 0x23ddc	jmp r9		0x140574394
# 0x23e0c	ret 8		0x1404ccfec
# 0x23e61	ret 0x10		0x1406f15f4
# 0x23ebd	ret 0x30		0x140772090
# 0x23f38	ret 0x28		0x140772090
# 0x23fb3	ret 0x28		0x140772090
# 0x2402e	ret 0x28		0x140772090
# 0x240a9	ret 0x28		0x1406d3281
# 0x240fc	jmp rdi		0x14068fd33
# 0x2415f	jmp rdi		0x1406a6664
# 0x24191	jmp rdx		0x1404506d3
# 0x241d9	ret 8		0x14063af56
# 0x24229	ret 8		0x14068fd33
# 0x2428c	jmp rdi		0x1406a6664
# 0x242be	jmp rdx		0x1404506d3
# 0x24306	ret 8		0x140675dc9
# 0x2435e	jmp rdi		0x1404506d3
# 0x243a6	ret 8		0x140797c91
# 0x243f2	ret 0x18		0x14052fdea
# 0x24426	ret 0x10		0x1405615fb
# 0x24463	jmp rdi		0x14072e6bd
# 0x244c7	jmp rdi		0x1404506d3
# 0x2450f	ret 8		0x140765eab
# 0x24543	jmp rdi		0x140508d74
# 0x24594	ret 0x10		0x1406ef560
# 0x2460d	jmp rdi		0x1407aa4e2
# 0x2463e	jmp rsi		0x14061fcae
# 0x24693	jmp rdi		0x1406ef560
# 0x2470c	jmp rdi		0x1407aa4e2
# 0x2473d	jmp rsi		0x14069fd25
# 0x2476c	jmp rbx		0x1406ef560
# 0x247e5	jmp rdi		0x1407aa4e2
# 0x24816	jmp rsi		0x1404828e7
# 0x24843	jmp rdi		0x14073059e
# 0x248c7	jmp rdi		0x1406ef560
# 0x24940	jmp rdi		0x1407aa4e2
# 0x24971	jmp rsi		0x140767beb
# 0x249c3	jmp rdi		0x14068fd33
# 0x24a26	jmp rdi		0x1406a6664
# 0x24a58	jmp rdx		0x1404506d3
# 0x24aa0	ret 8		0x14066837f
# 0x24af4	ret 8		0x1406ef560
# 0x24b6d	jmp rdi		0x1407aa4e2
# 0x24b9e	jmp rsi		0x1406ef560
# 0x24c17	jmp rdi		0x1407aa4e2
# 0x24c48	jmp rsi		0x14069d80c
# 0x24cc7	jmp rdi		0x1404506d3
# 0x24d0f	ret 8		0x1406e8807
# 0x24d42	jmp rbx		0x14030b799
# 0x24d98	ret 8		0x1405a1543
# 0x24dcb	jmp rdi		0x140618e75
# 0x24e1e	jmp rdi		0x14068ce2f
# 0x24e54	ret		0x14042d7a6
# 0x24ea8	jmp rdi		0x14030b522
# 0x24f03	ret 0x38		0x1404f3df9
# 0x24f3c	jmp rdi		0x1405f79aa
# 0x24f6d	jmp rdi		0x14073f7b2
# 0x24fab	ret 0x18		0x1405cea3e
# 0x24fe0	jmp rdi		0x1405d718e
# 0x2500c	jmp rdi		0x1407a2c5d
# 0x25062	ret 8		0x1406ef560
# 0x250db	jmp rdi		0x1407aa4e2
# 0x2510c	jmp rsi		0x14073024b
# 0x25150	jmp rdi		0x14065939e
# 0x25191	jmp rdi		0x14048c0db
# 0x251e2	jmp rdi		0x140405606
# 0x25214	ret 0x10		0x1406f0f31
# 0x25256	ret 0x10		0x14042d7a6
# 0x252aa	jmp rdi		0x14030b522
# 0x25305	ret 0x38		0x1406f0f31
# 0x25347	ret 0x10		0x14048c0db
# 0x25398	jmp rdi		0x14036de79
# 0x253ca	ret 0x10		0x140675dc9
# 0x25422	jmp rdi		0x1404506d3
# 0x2546a	ret 8		0x140797c91
# 0x254b6	ret 0x18		0x1406cba03
# 0x254f5	jmp rdi		0x14074a65e
# 0x26436	ret 8		0x140675dc9
# 0x2648e	jmp rdi		0x1404506d3
# 0x264d6	ret 8		0x1406e8807
# 0x26509	jmp rbx		0x1407aa4e2
# 0x2653a	jmp rsi		0x1406e8dab
# 0x265ad	jmp rdi		0x1406f0616
# 0x26621	jmp rdi		0x1406f0616
# 0x26695	jmp rdi		0x14075a592
# 0x2671d	jmp rdi		0x1406f0616
# 0x26791	jmp rdi		0x1406f0616
# 0x26805	jmp rdi		0x1406f0616
# 0x26879	jmp rdi		0x140491168
# 0x268c1	ret		0x140274227
# 0x268da	ret		0x7ffa9798d7d0
# 0x268db	ret		0x1407cb6ed
# 0x2696e	ret		0x140351a61
# 0x269c3	ret 0x20		0x1406fb2d5
# 0x26a26	ret		0x14075f8ad
# 0x26a8b	jmp r11		0x14039e6e4
# 0x26a8c	jmp rbp		0x1406fb2d5
# 0x26aef	ret		0x1406fb2d5
# 0x26b52	ret		0x1406fb2d5
# 0x26bb5	ret		0x1406fb2d5
# 0x26c18	ret		0x1406fb2d5
# 0x26c7b	ret		0x1404ec6da
# 0x26ce0	jmp rbp		0x1406d361d
# 0x26d28	ret 0x18		0x140667e11
# 0x26d63	ret 0x10		0x1403ab876
# 0x26dc5	jmp rbp		0x1407b883f
# 0x26e05	ret 0x10		0x140645521
# 0x26e68	jmp rbp		0x140343bee
# 0x26ede	ret 0x10		0x1406e954b
# 0x26f37	ret 0x18		0x14058c436
# 0x26f8b	jmp rbp		0x14071dd67
# 0x26fde	ret 8		0x1403af4ce
# 0x27018	jmp r11		0x14044be7c
# 0x2702e	jmp r9		0x14068c800
# 0x27059	jmp rbp		0x140667e11
# 0x27094	ret 0x10		0x1406d361d
# 0x270dc	ret 0x18		0x1407af653
# 0x27161	jmp rbp		0x1406819d6
# 0x271d9	jmp rbp		0x140474c44
# 0x2724f	jmp rbp		0x140474c44
# 0x272c5	jmp rbp		0x140474c44
# 0x2733b	jmp rbp		0x140474c44
# 0x273b1	jmp rbp		0x140474c44
# 0x27427	jmp rbp		0x1406819d6
# 0x2749f	jmp rbp		0x140474c44
# 0x27515	jmp rbp		0x14073bfaa
# 0x2754e	jmp rdi		0x14067a913
# 0x27590	ret 8		0x14031f6f0
# 0x275e5	ret 8		0x1405720b3
# 0x2762c	ret		0x1403e0ec8
# 0x27667	jmp rdi		0x14068ff8c
# 0x276c3	ret		0x14068ff8c
# 0x2771f	ret		0x14068ff8c
# 0x2777b	ret		0x14068ff8c
# 0x277d7	ret		0x14068ff8c
# 0x27833	ret		0x14068ff8c
# 0x2788f	ret		0x1403bd6f1
# 0x27906	jmp rdi		0x1406824c3
# 0x27936	jmp rdi		0x1406caae9
# 0x27981	jmp rdx		0x1404ed5f5
# 0x279df	ret 8		0x140683e20
# 0x27a3f	jmp rdi		0x1404d9cca
# 0x27a6a	jmp rdi		0x1406caae9
# 0x27ab5	jmp rdx		0x1405ab318
# 0x27ae8	jmp rcx		0x1406a6f78
# 0x27b10	jmp r11		0x14042a22f
# 0x27b18	jmp rax		0x140699e00
# 0x27b46	ret 0x18		0x1406af043
# 0x27b9e	jmp rdi		0x1406833b3
# 0x27bfc	jmp rdi		0x14066b12f
# 0x27c68	jmp rdi		0x1406380ad
# 0x27cf6	jmp rdi		0x1406380ad
# 0x27d84	jmp rdi		0x1406380ad
# 0x27e12	jmp rdi		0x1406380ad
# 0x27ea0	jmp rdi		0x1406ec8e1
# 0x27ed2	jmp r11		0x140412c27
# 0x27f29	jmp r11		0x140412c27
# 0x27f80	jmp r11		0x140585243
# 0x27fb7	jmp r11		0x1406bfabe
# 0x27ff6	ret 8		0x140705136
# 0x28055	ret 0x18		0x140705136
# 0x280b4	ret 0x18		0x140705136
# 0x28113	ret 0x18		0x140705136
# 0x28172	ret 0x18		0x140705136
# 0x281d1	ret 0x18		0x14064ee74
# 0x2824e	jmp r11		0x140497031
# 0x28293	jmp rax		0x140319dd4
# 0x282de	ret 0x18		0x14064ee74
# 0x2835b	jmp r11		0x140497031
# 0x283a0	jmp rax		0x14078e653
# 0x283cf	ret 8		0x14047eaca
# 0x28412	jmp r11		0x1404f3b49
# 0x28477	jmp r11		0x14078e653
# 0x284a6	ret 8		0x140736d01
# 0x284ce	jmp r11		0x140745a8c
# 0x28504	jmp r11		0x14058cfee
# 0x2853e	ret		0x1404f3b49
# 0x285a3	jmp r11		0x14078e653
# 0x285d2	ret 8		0x1405aef98
# 0x285fc	jmp rdi		0x14041c6fb
# 0x2864b	jmp rdi		0x14045f3e6
# 0x28673	jmp r11		0x14066f311
# 0x286c9	jmp r11		0x140689aff
# 0x28701	jmp r11		0x1403742ef
# 0x2872f	ret 8		0x1406a5ac2
# 0x287a2	jmp r11		0x14078e653
# 0x287d1	ret 8		0x14042e006
# 0x2880f	ret		0x140707435
# 0x28840	ret 8		0x1403d45a4
# 0x28886	ret 8		0x14065aad9
# 0x28914	jmp r11		0x14078e653
# 0x28943	ret 8		0x14042e006
# 0x28981	ret		0x1404e6c0c
# 0x289e6	jmp r11		0x14066f311
# 0x28a3c	jmp r11		0x140497031
# 0x28a81	jmp rax		0x14078e653
# 0x28ab0	ret 8		0x14075ac91
# 0x28af3	ret		0x1404f3b49
# 0x28b58	jmp r11		0x14078e653
# 0x28b87	ret 8		0x14042e006
# 0x28bc5	ret		0x1404f3b49
# 0x28c2a	jmp r11		0x14078e653
# 0x28c59	ret 8		0x14042e006
# 0x28c97	ret		0x140401609
# 0x28d02	jmp r11		0x14066f311
# 0x28d58	jmp r11		0x140497031
# 0x28d9d	jmp rax		0x140689aff
# 0x28dd5	jmp r11		0x1405c8d7e
# 0x28e22	jmp r11		0x14052159f
# 0x28e62	jmp r11		0x14071dd3c
# 0x28eb2	ret 0x28		0x1405b6e3d
# 0x28eed	jmp r11		0x1406e5137
# 0x28f3c	jmp rax		0x14055795a
# 0x28f8e	jmp r11		0x140753bf1
# 0x28ff0	jmp r11		0x1406e5137
# 0x2903f	jmp rax		0x140753bf1
# 0x290a1	jmp r11		0x140467ec7
# 0x290ea	ret 0x28		0x14066f311
# 0x29140	jmp r11		0x140689aff
# 0x29178	jmp r11		0x1405edd00
# 0x291ae	jmp rdx		0x14039d456
# 0x29200	jmp r11		0x140592064
# 0x29254	jmp r11		0x140753bf1
# 0x292b6	jmp r11		0x14037c548
# 0x292f6	jmp r11		0x1406e5137
# 0x29345	jmp rax		0x140385a74
# 0x293bc	jmp r11		0x1403eac58
# 0x293c4	jmp rsi		0x140415423
# 0x293dd	jmp r9		0x14032a84e
# 0x293e1	jmp rsi		0x140363c5b
# 0x29401	ret 0x38		0x14030ca16
# 0x29440	jmp r11		0x140753bf1
# 0x294a2	jmp r11		0x14030eadd
# 0x294d8	ret		0x14066f311
# 0x2952e	jmp r11		0x140497031
# 0x29573	jmp rax		0x14078e653
# 0x295a2	ret 8		0x140735067
# 0x296b2	ret		0x14064ee74
# 0x2972f	jmp r11		0x140497031
# 0x29774	jmp rax		0x140689aff
# 0x297ac	jmp r11		0x14033f880
# 0x297df	jmp r10		0x140715be8
# 0x29854	jmp r11		0x14069e415
# 0x298d7	jmp r11		0x140709b77
# 0x2995f	jmp r11		0x140335cf1
# 0x299dd	jmp r11		0x1405204a8
# 0x29a26	jmp r11		0x1404a84a3
# 0x29a8c	jmp r11		0x140306583
# 0x29ae3	ret		0x1400011c0
# 0x29ae6	ret		0x14000120b
