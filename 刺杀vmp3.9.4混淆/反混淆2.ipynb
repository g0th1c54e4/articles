# %%
import triton
import keystone
import SupertracePybind as Supertrace
from enum import Enum
from collections import defaultdict
import graphviz
from miasm.arch.x86.arch import mn_x86
from miasm.expression.expression import ExprMem, ExprId, ExprInt, ExprOp
from supertrace_util import initTritonCtxEnv, mergeRepeatIns, checkIndirectIns

# %%
ks = keystone.Ks(keystone.KS_ARCH_X86, keystone.KS_MODE_64)
def asmDecode(CODE: bytes, addr = 0) -> bytes:
    try:
        encoding, count = ks.asm(CODE, addr, True)
        if (count <= 0):
            raise keystone.KsError
        return bytes(encoding)
    except keystone.KsError as e:
        print("ERROR: %s" %e)
        return b""

# %%
tracepath = "1.trace64"

trace = Supertrace.parse_x64dbg_trace(tracepath)
record = trace.getRecord()
print(f"trace instruction num: {len(record)}")
# Out:
# trace instruction num: 110684

# %%
modules = trace.user.meta.getModules()
for mod in modules:
    if mod.isMainModule:
        main_module = mod
        break

main_secs = main_module.getSections()
print("No\tName")
for i, sec in enumerate(main_secs):
    print(f"{i}\t{sec.name}")
# Out:
# No	Name
# 0	.text
# 1	.rdata
# 2	.data
# 3	.pdata
# 4	.TO0
# 5	. bN
# 6	._Az
# 7	.rsrc
# 8	.reloc

# %%
vmpsec_begin = main_secs[4].addr
vmpsec_end = main_secs[7].addr
print(f"vmp begin: {hex(vmpsec_begin)}")
print(f"vmp end: {hex(vmpsec_end)}")
# Out:
# vmp begin: 0x140006000
# vmp end: 0x140d78000

# %%
ctx = triton.TritonContext()
ctx.setArchitecture(triton.ARCH.X86_64)
ctx.setMode(triton.MODE.ALIGNED_MEMORY, True)
ctx.setMode(triton.MODE.AST_OPTIMIZATIONS, True)
ctx.setMode(triton.MODE.CONSTANT_FOLDING, True)

def newLiftDot(expr_node) -> str:
    temp_ctx = triton.TritonContext()
    temp_ctx.setArchitecture(ctx.getArchitecture())
    return temp_ctx.liftToDot(expr_node)

def symUninitMem(ctx: triton.TritonContext, memacc: triton.MemoryAccess):
    for i in range(memacc.getSize()):
        memi = triton.MemoryAccess(memacc.getAddress() + i, 1)
        if (not ctx.isConcreteMemoryValueDefined(memi)):  
            ctx.symbolizeMemory(memi, f"SymMem_{hex(memi.getAddress())}")

def initTritonCtxEnvSym(
    ctx: triton.TritonContext,
    init_refer_ins: Supertrace.InstructionRecord,
    teb_addr: int, symbolizeDF: bool = False, symbolizeTF: bool = False, symbolizeIF: bool = False):

    initTritonCtxEnv(ctx, init_refer_ins, teb_addr) # 初始化具体化环境
    
    regs = ctx.registers
    if (ctx.getArchitecture() == triton.ARCH.X86):
        init_regdump = init_refer_ins.reg_dump32
    elif ctx.getArchitecture() == triton.ARCH.X86_64:
        init_regdump = init_refer_ins.reg_dump64
    else:
        print("unsurport arch")

    # 符号化所有寄存器
    for ttreg in ctx.getAllRegisters():
        ctx.symbolizeRegister(ttreg, ttreg.getName())

    # 平坦模型
    ctx.setConcreteRegisterValue(ctx.registers.ss, 0)
    ctx.setConcreteRegisterValue(ctx.registers.ds, 0)
    ctx.setConcreteRegisterValue(ctx.registers.es, 0)
    ctx.setConcreteRegisterValue(ctx.registers.cs, 0)
    
    if ctx.getArchitecture() == triton.ARCH.X86:
        ctx.setConcreteRegisterValue(ctx.registers.esp, init_regdump.regcontext.csp)
        ctx.setConcreteRegisterValue(ctx.registers.eip, init_regdump.regcontext.cip)
        ctx.setConcreteRegisterValue(regs.fs, teb_addr)
        ctx.setConcreteRegisterValue(regs.gs, 0) # 平坦模型
    elif ctx.getArchitecture() == triton.ARCH.X86_64:
        ctx.setConcreteRegisterValue(ctx.registers.rsp, init_regdump.regcontext.csp)
        ctx.setConcreteRegisterValue(ctx.registers.rip, init_regdump.regcontext.cip)
        ctx.setConcreteRegisterValue(regs.fs, 0) # 平坦模型
        ctx.setConcreteRegisterValue(regs.gs, teb_addr)

    if (symbolizeDF):
        ctx.setConcreteRegisterValue(ctx.registers.df, init_regdump.flags.d)
    if (symbolizeTF):
        ctx.setConcreteRegisterValue(ctx.registers.tf, init_regdump.flags.t)
    if (symbolizeIF):
        ctx.setConcreteRegisterValue(getattr(ctx.registers, "if"), init_regdump.flags.i)

    ctx.setConcreteRegisterValue(ctx.registers.nt, 0)
    ctx.setConcreteRegisterValue(ctx.registers.rf, 0)
    ctx.setConcreteRegisterValue(ctx.registers.id, 0)
    ctx.setConcreteRegisterValue(ctx.registers.vip, 0)
    ctx.setConcreteRegisterValue(ctx.registers.vif, 0)
    ctx.setConcreteRegisterValue(ctx.registers.ac, 0)
    ctx.setConcreteRegisterValue(ctx.registers.vm, 0)

# %%
record = mergeRepeatIns(ctx, record, True)
print(f"after mergeing 'rep' instructions, trace instruction num: {len(record)}")
# Out:
# after mergeing 'rep' instructions, trace instruction num: 110684

# %%
threads = trace.user.meta.getThreads()
for th in threads:
    if th.id == record[0].thread_id:
        main_thread = th
        break
print(f"main thread id: {main_thread.id} ({hex(main_thread.id)})")
print(f"teb: {hex(main_thread.teb)}")
initTritonCtxEnv(ctx, record[0], main_thread.teb)
# Out:
# main thread id: 33076 (0x8134)
# teb: 0xccd10d8000

# %% [markdown]
# ---

# %%
class ST_BasicBlock():
    def __init__(self, instructions: list[Supertrace.InstructionRecord]):
        self.instructions: list[Supertrace.InstructionRecord] = instructions
        self.recordRanges: list[range] = []
        
        # 针对基本块最后一条指令而言
        self.isControlflow: bool        = None
        self.isBranch: bool             = None

        self.isUnconditionalJump: bool  = None
        self.isConditionalJump: bool    = None
        self.isCall: bool               = None
        self.isRet: bool                = None

        self.isDirect: bool             = None

        self.targetAddr: int            = None
        self.fallThroughAddr: int       = None

        # (indirectTargetAddrs 不是正式的控制流意义字段，因为其数据来源于跟踪记录而非指令本身，因此按照原则，writeBBControlIns 函数不会处理它)
        self.indirectTargetAddrs: set[int]        = set()

    def __hash__(self):
        h: int = 0
        for ins in self.instructions:
            h1 = hash(ins.bytes)
            h2 = hash(ins.ins_address)
            h += (h1 + h2)
        h += hash(len(self.instructions))
        return h

    def __eq__(self, other):
        if not isinstance(other, ST_BasicBlock):
            return NotImplemented
        if (len(self.instructions) != len(other.instructions)):
            return False
        for i, ins in enumerate(self.instructions):
            if (ins.bytes != other.instructions[i].bytes):
                return False
            if (ins.ins_address != other.instructions[i].ins_address):
                return False
        return True
    
    def __repr__(self):
        return f"<{hex(self.getCurrentAddr())}> insCount: {len(self.instructions)}"
    
    def printbb(self):
        '''打印基本块里的所有指令'''
        for ins in self.instructions:
            print(f"{ins}\t{ins.ttins}")
    
    def getFirstIns(self) -> Supertrace.InstructionRecord:
        '''获取基本块的第一条指令'''
        return self.instructions[0]
    
    def getLastIns(self) -> Supertrace.InstructionRecord:
        '''获取基本块的最后一条指令'''
        return self.instructions[-1]
    
    def getCurrentAddr(self) -> int:
        '''获取当前基本块的地址'''
        return self.getFirstIns().ins_address
    
    def isReachMe(self, jumpAddr: int) -> bool:
        '''判断跳转地址是否能进入此基本块'''
        return jumpAddr == self.getFirstIns().ins_address
    
    def findSubIns(self, checkIns: Supertrace.InstructionRecord) -> int:
        '''如果包含，返回对应的索引位置，否则返回 -1'''
        for i, ins in enumerate(self.instructions):
            if (ins == checkIns):
                return i
        return -1
    
    def isContainsAddr(self, checkAddr: int) -> int:
        '''如果包含，返回对应的索引位置，否则返回 -1'''
        for i, ins in enumerate(self.instructions):
            if (ins.ins_address == checkAddr):
                return i
        return -1
    
    def findSubBasicBlock(self, otherBB) -> int:
        '''如果包含，返回对应在开头处的索引位置，否则返回 -1'''
        otherBB: ST_BasicBlock = otherBB
        
        if (self == otherBB): # 走上面的 __eq__ 方法
            return 0
        if (len(self.instructions) < len(otherBB.instructions)):
            return -1
        startIdx = self.findSubIns(otherBB.instructions[0])
        if (startIdx == -1):
            return -1
        
        i = startIdx
        for otherBBIns in otherBB.instructions:
            if (self.instructions[i] != otherBBIns):
                return -1
            i += 1

        return startIdx

def writeBBControlIns(bb: ST_BasicBlock, ttins: triton.Instruction):
    bb.isControlflow        = False
    bb.isBranch             = False

    bb.isUnconditionalJump  = False
    bb.isConditionalJump    = False
    bb.isCall               = False
    bb.isRet                = False

    bb.isDirect             = False

    bb.targetAddr           = 0
    bb.fallThroughAddr      = 0
    # ---------
    bb.isControlflow = ttins.isControlFlow()
    if (bb.isControlflow):
        ttinsType = ttins.getType()

        bb.isCall = (ttinsType == triton.OPCODE.X86.CALL)
        bb.isRet = (ttinsType == triton.OPCODE.X86.RET)
        bb.isBranch = ttins.isBranch()
        if (bb.isBranch):
            bb.isUnconditionalJump = (ttinsType == triton.OPCODE.X86.JMP)
            bb.isConditionalJump = (not bb.isUnconditionalJump)
        if (bb.isCall or bb.isBranch): # ret指令绝对不会是直接跳转
            ops = ttins.getOperands()
            bb.isDirect = (len(ops) == 1 and ops[0].getType() == triton.OPERAND.IMM)
            if (bb.isDirect):
                immop: triton.Immediate = ops[0]
                if (ttins.getAddress() == 0):
                    print("[警告] writeBBControlIns(): ttins.getAddress() 为 0")
                bb.targetAddr = immop.getValue()
    bb.fallThroughAddr = ttins.getNextAddress()

# %%
bbs: set[ST_BasicBlock] = set()

def FindBB(bbs: set[ST_BasicBlock], bbaddr: int) -> ST_BasicBlock:
    for bb in bbs:
        if (bb.isReachMe(bbaddr)):
            return bb
    return None

# %%
bbinsList: list[Supertrace.InstructionRecord] = []
bbQuickDict = {} # 缓存，用于加快基本块查询速度
for i, ins in enumerate(record):

    ttins = triton.Instruction()
    ttins.setOpcode(ins.bytes)
    ttins.setAddress(ins.ins_address)
    ctx.disassembly(ttins)
    ins.ttins = ttins

    bbinsList.append(ins)
    if (ttins.isControlFlow()):
        bb = ST_BasicBlock(bbinsList.copy())
        if (bb in bbs):
            find = bbQuickDict[bb.getCurrentAddr()] # 缓存查询。下面不用额外判断find是否正确，上面已经判断好了
            if (checkIndirectIns(ttins) and (i + 1 < len(record))): # 单独填充 indirectTargetAddrs 的信息
                find.indirectTargetAddrs.add(record[i + 1].ins_address)
            find.recordRanges.append
        else:
            writeBBControlIns(bb, ttins)
            if (checkIndirectIns(ttins) and (i + 1 < len(record))): # 单独填充 indirectTargetAddrs 的信息
                bb.indirectTargetAddrs.add(record[i + 1].ins_address)
            bbs.add(bb)
            bbQuickDict[bb.getCurrentAddr()] = bb # 缓存更新

        bbinsList.clear()

# %%
print(f"从trace采集到的基本块数量: {len(bbs)}")
# Out:
# 从trace采集到的基本块数量: 3577

# %% [markdown]
# 拆分独立基本块（预处理）

# %%
def split_basic_blocks(bbs: set[ST_BasicBlock]) -> tuple[set[ST_BasicBlock], bool]:
    """
    拆分所有存在“包含关系”的 BasicBlock
    保证最终结果中不存在一个 BB 严格包含另一个 BB
    """
    #TODO: 暂时没处理 bb.indirectTargetAddrs
    hasChange = False
    bbs = set(bbs)

    changed = True
    while changed:
        changed = False

        # 按长度排序，只允许 small 切 big
        sorted_bbs = sorted(bbs, key=lambda bb: len(bb.instructions))

        to_remove = set()
        to_add = set()

        for small in sorted_bbs:
            for big in sorted_bbs:
                if small is big:
                    continue

                if len(small.instructions) >= len(big.instructions):
                    continue

                subIdx = big.findSubBasicBlock(small)
                if subIdx == -1:
                    continue

                # ---- 开始拆分 ----
                changed = True
                hasChange = True
                to_remove.add(big)

                instrs = big.instructions

                # 前导基本块
                if subIdx > 0:
                    left = ST_BasicBlock(instrs[:subIdx])
                    writeBBControlIns(left, left.getLastIns().ttins)
                    to_add.add(left)

                # 后导基本块
                endIdx = subIdx + len(small.instructions)
                if endIdx < len(instrs):
                    right = ST_BasicBlock(instrs[endIdx:])
                    writeBBControlIns(right, right.getLastIns().ttins)
                    to_add.add(right)

                break

            if changed:
                break

        if changed:
            bbs.difference_update(to_remove)
            bbs.update(to_add)

    return bbs, hasChange

# %%
class BBLinkType(Enum):
    INDIRECT_UNCOND = 0            # 无条件间接跳转
    DIRECT_UNCOND = 1              # 无条件直接跳转
    DIRECT_COND_TAKEN = 2          # 有条件直接跳转(跳转已发生)
    DIRECT_COND_NOTTAKEN = 3       # 有条件直接跳转(跳转未发生)
    DIRECT_FALLTHROUGH = 4         # 顺序接续跳转(用于无控制流指令的基本块)

    OBF_JUMP = 5                   # 混淆跳转

class BBLink():
    def __init__(self, linkType: BBLinkType, linkAddress):
        self.type = linkType
        self.addr = linkAddress
    def __hash__(self):
        h: int = 0
        h += hash(self.type.name)
        h += hash(hex(self.addr))
        return h
    def __eq__(self, other):
        if not isinstance(other, BBLink):
            return NotImplemented
        if (other.type != self.type): return False
        if (other.addr != self.addr): return False
        return True
    def __repr__(self):
        return f"type: {self.type}\taddr: {hex(self.addr)}"

# %% [markdown]
# 合并基本块（jmp imm 和 call imm、无控制流指令基本块以及被证实为某些混淆控制流的基本块）

# %%
def merge_basic_block(bbs: set[ST_BasicBlock]) -> tuple[set[ST_BasicBlock], bool]:
    hasChange = False
    bbs = set(bbs)
    
    def mergeBasicBlock(a: ST_BasicBlock, b: ST_BasicBlock) -> ST_BasicBlock:
        '''将基本块b追加到a的后面，新的基本块继承b的属性'''
        newbb = ST_BasicBlock(a.instructions + b.instructions)
        writeBBControlIns(newbb, b.getLastIns().ttins)
        newbb.indirectTargetAddrs = b.indirectTargetAddrs
        for rge in a.recordRanges:
            newbb.recordRanges.append(range(rge.start, rge.stop + len(b.instructions)))
            
        return newbb

    def getPrec(precAddr: int, checkAddr: int) -> BBLink:
        for prec in precursors[precAddr]:
            if (prec.addr == checkAddr):
                return prec
        return None

    precursors = defaultdict(set[BBLink]) # 前驱
    successors = defaultdict(set[BBLink]) # 后继

    for bb in bbs:
        current = bb.getCurrentAddr()
        if (bb.isControlflow):
            if (bb.isDirect):

                if (bb.isConditionalJump): # 针对有条件跳转
                    if not (hasattr(bb, "obfOPStatus") and bb.obfOPStatus == True): # ObfOP 反混淆
                        taken1 = BBLink(BBLinkType.DIRECT_COND_TAKEN, bb.targetAddr)
                        taken2 = BBLink(BBLinkType.DIRECT_COND_NOTTAKEN, bb.fallThroughAddr)
                        target = set({taken1, taken2})
                    else:
                        if (bb.obfOPCondTaken):
                            taken = BBLink(BBLinkType.DIRECT_UNCOND, bb.targetAddr)
                        else:
                            taken = BBLink(BBLinkType.DIRECT_FALLTHROUGH, bb.fallThroughAddr)
                        target = set({taken})
                else: # 针对无条件跳转 到这里的基本块的跳转指令是 jmp imm 或 call imm
                    taken = BBLink(BBLinkType.DIRECT_UNCOND, bb.targetAddr)
                    target = set({taken})

            else: # 间接跳转
                if not (hasattr(bb, "obfIndirectStatus") and bb.obfIndirectStatus == True): # ObfIndirect 反混淆
                    target = set()
                    for indirectTargetAddr in bb.indirectTargetAddrs:
                        taken = BBLink(BBLinkType.INDIRECT_UNCOND, indirectTargetAddr)
                        target.add(taken)
                else:
                    taken = BBLink(BBLinkType.DIRECT_UNCOND, bb.obfIndirectAddr)
                    target = set({taken})
        else:
            # 到这里的基本块是没有控制流指令的
            taken = BBLink(BBLinkType.DIRECT_FALLTHROUGH, bb.fallThroughAddr)
            target = set({taken})
        
        successors[current] = successors[current].union(target)
        for taken in target:
            precursors[taken.addr].add(BBLink(taken.type, current))

    goNext = True
    while(goNext):
        goNext = False

        for bb in bbs:
            current = bb.getCurrentAddr()

            for succ in successors[current]:

                target = succ.addr
                
                succCheck = (len(successors[current]) == 1) and \
                    (succ.type == BBLinkType.DIRECT_UNCOND or succ.type == BBLinkType.DIRECT_FALLTHROUGH)
                
                precCheck = (target in precursors) and \
                    (len(precursors[target]) == 1) and \
                    (getPrec(target, current) != None) and \
                    (getPrec(target, current).type == BBLinkType.DIRECT_UNCOND or getPrec(target, current).type == BBLinkType.DIRECT_FALLTHROUGH)

                if (succCheck and precCheck):

                    targetBB = FindBB(bbs, target)
                    if (targetBB == None):
                        print(f"异常! target: {hex(target)} 不存在 bb: {bb}")
                        continue

                    mergebb = mergeBasicBlock(bb, targetBB)

                    mergeAddr = mergebb.getCurrentAddr()
                    assert(mergeAddr == current)

                    successors[mergeAddr] = successors[target].copy()
                    successors[target].clear()
                    
                    precursors[target].clear()
                    for newSucc in successors[mergeAddr]:
                        removePrec = getPrec(newSucc.addr, target)
                        assert(removePrec != None)
                        precursors[newSucc.addr].remove(removePrec)

                        precursors[newSucc.addr].add(BBLink(newSucc.type, mergeAddr))

                    bbs.remove(targetBB)
                    bbs.remove(bb)
                    bbs.add(mergebb)
                    
                    goNext = True
                    hasChange = True
                    break
            if (goNext):
                break

    return bbs, hasChange

# %% [markdown]
# 消除不透明谓词 (ObfOP)

# %%
def checkOpaquePredicate(bb: ST_BasicBlock):
    insList = bb.instructions

    tmpctx = triton.TritonContext()
    tmpctx.setArchitecture(ctx.getArchitecture())
    tmpctx.setMode(triton.MODE.ALIGNED_MEMORY, True)
    tmpctx.setMode(triton.MODE.AST_OPTIMIZATIONS, True)
    tmpctx.setMode(triton.MODE.CONSTANT_FOLDING, True)
    tmpctx.setMode(triton.MODE.SYMBOLIZE_INDEX_ROTATION, True)
    tmpctx.setMode(triton.MODE.PC_TRACKING_SYMBOLIC, False)
    # 不建议开启符号内存，这会导致求解时间显著增长
    tmpastctx = tmpctx.getAstContext()

    # 符号化寄存器环境
    initTritonCtxEnvSym(tmpctx, bb.getFirstIns(), main_thread.teb)

    for i, ins in enumerate(insList):
        ttins = triton.Instruction()
        ttins.setAddress(ins.ins_address)
        ttins.setOpcode(ins.bytes)

        for memAcc in ins.mem_accs:
            if (memAcc.type != Supertrace.AccessType.READ):
                continue
            for i in range(memAcc.acc_size):
                memi = triton.MemoryAccess(memAcc.acc_address + i, triton.CPUSIZE.BYTE)
                if (not tmpctx.isConcreteMemoryValueDefined(memi)):
                    oldby = (memAcc.old_data >> (i * 8)) & 0xFF
                    tmpctx.setConcreteMemoryValue(memi, oldby)
                    tmpctx.symbolizeMemory(memi, hex(memAcc.acc_address + i))

        tmpctx.processing(ttins)

        if ((i == len(insList) - 1) and ttins.isBranch() and ttins.getType() != triton.OPCODE.X86.JMP): # 筛选JCC有条件跳转指令
            if (hasattr(ins, "obfOPStatus") and ins.obfOPStatus == True): # 已经证明过了，跳过此次证明过程
                continue
            ins.obfOPStatus = False
            ins.obfOPCondTaken = False

            pathPredicate = tmpctx.getPathPredicate()

            satCount = 0
            if (pathPredicate.isSymbolized()):
                if (tmpctx.isSat(pathPredicate)):
                    satCount += 1
                if (tmpctx.isSat(tmpastctx.lnot(pathPredicate))):
                    satCount += 1
            else:
                satCount = 1

            if (satCount == 1):
                # 是不透明谓词
                ins.obfOPStatus = True
                ins.obfOPCondTaken = (ttins.getNextAddress() != record[ins.id + 1].ins_address)
                # print(f"{hex(ins.ins_address)} 是不透明谓词！跳转情况: {ins.obfOPCondTaken} {ttins}")

def prove_opaque_predicate(bbs: set[ST_BasicBlock]) -> tuple[set[ST_BasicBlock], bool]:
    hasChange = False
    bbs = set(bbs)

    for bb in bbs: # 在目前的实现中，只关注基本块的最后一条指令是JCC的情况
        if (bb.isConditionalJump):
            lastIns = bb.getLastIns()
            if (hasattr(lastIns, "obfOPStatus") and lastIns.obfOPStatus == True):
                continue # 已证明过，跳过
            checkOpaquePredicate(bb)
            if (hasattr(lastIns, "obfOPStatus") and lastIns.obfOPStatus == True):
                # print(f"{hex(bb.getCurrentAddr())} 存在OP: {lastIns.ttins}")
                # 将指令的不透明谓词的信息保存到基本块上
                bb.obfOPStatus = lastIns.obfOPStatus
                bb.obfOPCondTaken = lastIns.obfOPCondTaken
                hasChange = True

    return bbs, hasChange

# %% [markdown]
# 间接跳转混淆消除（ObfIndirect）

# %%
def checkObfIndirect(bb: ST_BasicBlock):
    insList = bb.instructions

    tmpctx = triton.TritonContext()
    tmpctx.setArchitecture(ctx.getArchitecture())
    tmpctx.setMode(triton.MODE.ALIGNED_MEMORY, True)
    tmpctx.setMode(triton.MODE.AST_OPTIMIZATIONS, True)
    tmpctx.setMode(triton.MODE.CONSTANT_FOLDING, True)
    tmpctx.setMode(triton.MODE.SYMBOLIZE_INDEX_ROTATION, True)
    # 不要开启符号内存，会丢失正确识别!

    # 符号化寄存器环境
    initTritonCtxEnvSym(tmpctx, bb.getFirstIns(), main_thread.teb)

    for i, ins in enumerate(insList):
        ttins = triton.Instruction()
        ttins.setAddress(ins.ins_address)
        ttins.setOpcode(ins.bytes)

        for memAcc in ins.mem_accs:
            if (memAcc.type != Supertrace.AccessType.READ):
                continue
            for i in range(memAcc.acc_size):
                memi = triton.MemoryAccess(memAcc.acc_address + i, triton.CPUSIZE.BYTE)
                if (not tmpctx.isConcreteMemoryValueDefined(memi)):
                    oldby = (memAcc.old_data >> (i * 8)) & 0xFF
                    tmpctx.setConcreteMemoryValue(memi, oldby)
                    tmpctx.symbolizeMemory(memi, hex(memAcc.acc_address + i))

        tmpctx.processing(ttins)

        if ((i == len(insList) - 1) and checkIndirectIns(ttins)):
            if (hasattr(ins, "obfIndirectStatus") and ins.obfIndirectStatus == True): # 已经证明过了，跳过此次证明过程
                continue
            ins.obfIndirectStatus = False
            ins.obfIndirectAddr = 0
            ins.obfIndirectInc = None
            if (not ttins.isSymbolized()):
                ins.obfIndirectStatus = True
                ins.obfIndirectAddr = record[ins.id + 1].ins_address
                ins.obfIndirectInc = (record[ins.id - 1], len(record[ins.id - 1].bytes) + len(ins.bytes))
                # print(f"{hex(ins.ins_address)} 是间接跳转混淆! 地址: {hex(ins.obfIndirectAddr)} {ttins}")

def prove_obfuse_indirect(bbs: set[ST_BasicBlock]) -> tuple[set[ST_BasicBlock], bool]:
    hasChange = False
    bbs = set(bbs)

    for bb in bbs:
        lastIns = bb.getLastIns()
        if (hasattr(lastIns, "obfIndirectStatus") and lastIns.obfIndirectStatus == True):
            continue # 已证明过，跳过
        checkObfIndirect(bb)
        if (hasattr(lastIns, "obfIndirectStatus") and lastIns.obfIndirectStatus == True):
            bb.obfIndirectStatus = lastIns.obfIndirectStatus
            bb.obfIndirectAddr = lastIns.obfIndirectAddr
            hasChange = True

    return bbs, hasChange

# %% [markdown]
# 内存操作数常量隐藏

# %%
def checkMemOpConstHide(bb: ST_BasicBlock) -> bool:
    hasChange = False
    insList = bb.instructions

    tmpctx = triton.TritonContext()
    tmpctx.setArchitecture(ctx.getArchitecture())
    tmpctx.setMode(triton.MODE.ALIGNED_MEMORY, True)
    tmpctx.setMode(triton.MODE.AST_OPTIMIZATIONS, True)
    tmpctx.setMode(triton.MODE.CONSTANT_FOLDING, True)
    tmpctx.setMode(triton.MODE.SYMBOLIZE_INDEX_ROTATION, True)

    initTritonCtxEnvSym(tmpctx, bb.getFirstIns(), main_thread.teb) # 初始化具体化环境
    tmpctx.symbolizeRegister(tmpctx.registers.rsp, tmpctx.registers.rsp.getName())

    for i, ins in enumerate(insList):
        ttins = triton.Instruction()
        ttins.setAddress(ins.ins_address)
        ttins.setOpcode(ins.bytes)

        tmpctx.disassembly(ttins)

        ops = ttins.getOperands()
        for op in ops:
            if (op.getType() != triton.OPERAND.MEM):
                continue
            memop: triton.MemoryAccess = op
            baseReg = memop.getBaseRegister()
            indexReg = memop.getIndexRegister()
            ins.obfMemConstHideStatus = False
            ins.obfMemConstHideDetail = set() # (TTRegID, TTRegName, RealValue)
            if (tmpctx.isRegisterValid(baseReg) and tmpctx.isRegisterValid(indexReg) and baseReg == indexReg and (not tmpctx.isRegisterSymbolized(baseReg))): # 如果是相同寄存器
                if (tmpctx.isRegisterValid(baseReg) and not tmpctx.isRegisterSymbolized(baseReg)):
                    hasChange = True
                    ins.obfMemConstHideStatus = True
                    real = tmpctx.getConcreteRegisterValue(baseReg)
                    ins.obfMemConstHideDetail.add( (baseReg.getId(), baseReg.getName(), real))
                    # print(f"{hex(ins.dbg_id)} {ins.ttins}\t\t的内存操作数的 {baseReg.getName()} 寄存器是常量 {hex(real)}")
            else:
                if (tmpctx.isRegisterValid(baseReg) and not tmpctx.isRegisterSymbolized(baseReg)):
                    hasChange = True
                    ins.obfMemConstHideStatus = True
                    real = tmpctx.getConcreteRegisterValue(baseReg)
                    ins.obfMemConstHideDetail.add( (baseReg.getId(), baseReg.getName(), real))
                    # print(f"{hex(ins.dbg_id)} {ins.ttins}\t\t的内存操作数的 {baseReg.getName()} 寄存器是常量 {hex(real)}")
                if (tmpctx.isRegisterValid(indexReg) and not tmpctx.isRegisterSymbolized(indexReg)):
                    hasChange = True
                    ins.obfMemConstHideStatus = True
                    real = tmpctx.getConcreteRegisterValue(indexReg)
                    ins.obfMemConstHideDetail.add( (indexReg.getId(), indexReg.getName(), real))
                    # print(f"{hex(ins.dbg_id)} {ins.ttins}\t\t的内存操作数的 {indexReg.getName()} 寄存器是常量 {hex(real)}")

        for memAcc in ins.mem_accs:
            if (memAcc.type != Supertrace.AccessType.READ):
                continue
            for i in range(memAcc.acc_size):
                memi = triton.MemoryAccess(memAcc.acc_address + i, triton.CPUSIZE.BYTE)
                if (not tmpctx.isConcreteMemoryValueDefined(memi)):
                    oldby = (memAcc.old_data >> (i * 8)) & 0xFF
                    tmpctx.setConcreteMemoryValue(memi, oldby)
                    tmpctx.symbolizeMemory(memi, hex(memAcc.acc_address + i))

        tmpctx.buildSemantics(ttins)

    return hasChange

def prove_obfuse_memopConstHide(bbs: set[ST_BasicBlock]) -> tuple[set[ST_BasicBlock], bool]:
    hasChange = False
    bbs = set(bbs)

    for bb in bbs:
        if (checkMemOpConstHide(bb)):
            hasChange = True

    return bbs, hasChange

# %% [markdown]
# 垃圾指令清除(活跃变量分析)

# %%
def checkDCE(bb: ST_BasicBlock, enableMemoryAnalysis: bool = False) -> bool:
    hasChange = False
    insList: list[Supertrace.InstructionRecord] = []
    for ins in bb.instructions:
        if (hasattr(ins, "obfDeadCodeStatus") and ins.obfDeadCodeStatus == True):
            continue
        insList.append(ins)

    m_in = []
    m_out = []
    m_def = []
    m_use = []
    appears = set()
    for _ in range(len(insList)):
        m_in.append(set())
        m_out.append(set())
        m_def.append(set())
        m_use.append(set())

    tmpctx = triton.TritonContext()
    tmpctx.setArchitecture(ctx.getArchitecture())
    tmpctx.setMode(triton.MODE.AST_OPTIMIZATIONS, True)
    tmpctx.setMode(triton.MODE.CONSTANT_FOLDING, True)
    tmpctx.setAstRepresentationMode(triton.AST_REPRESENTATION.PCODE)
    tmpastctx = tmpctx.getAstContext()

    if (enableMemoryAnalysis): # 有bug，有待研究
        tmpctx.addCallback(triton.CALLBACK.GET_CONCRETE_MEMORY_VALUE, symUninitMem)

    for ttreg in tmpctx.getAllRegisters():
        tmpctx.symbolizeRegister(ttreg, ttreg.getName())
    
    for i, ins in enumerate(insList):
        ttins = triton.Instruction()
        ttins.setAddress(ins.ins_address)
        ttins.setOpcode(ins.bytes)

        # 有bug
        # if (hasattr(ins, "obfMemConstHideStatus") and ins.obfMemConstHideStatus == True and hasattr(ins, "obfMemConstHideRep")):
        #     rep: bytes = ins.obfMemConstHideRep[0] # 第一个默认是最短的
        #     ttins.setOpcode(rep)

        tmpctx.processing(ttins)

        readRegs = ttins.getReadRegisters()
        writeRegs = ttins.getWrittenRegisters()
        readMems = ttins.getLoadAccess()
        writeMems = ttins.getStoreAccess()

        for readReg in readRegs:
            reg = readReg[0]
            parent = tmpctx.getParentRegister(reg)
            vec = reg.getBitvector()
            for c in range(vec.getLow(), vec.getHigh() + 1):
                read = f"Reg_{parent.getName().lower()}_{c}"
                m_use[i].add(read)
                appears.add(read)

        for writeReg in writeRegs:
            reg = writeReg[0]
            parent = tmpctx.getParentRegister(reg)
            vec = reg.getBitvector()
            for c in range(vec.getLow(), vec.getHigh() + 1):
                write = f"Reg_{parent.getName().lower()}_{c}"
                m_def[i].add(write)
                appears.add(write)

        if (not enableMemoryAnalysis):
            continue

        for readMem in readMems:
            memacc: triton.MemoryAccess = readMem[0]
            for c in range(memacc.getSize()):

                imm = memacc.getDisplacement()
                old = imm.getValue()
                imm.setValue(old + c, imm.getSize())
                memacc.setDisplacement(imm)
                tmpctx.initLeaAst(memacc)
                astNode = tmpastctx.unroll(memacc.getLeaAst())
                imm.setValue(old, imm.getSize())
                memacc.setDisplacement(imm)
                tmpctx.initLeaAst(memacc) # 恢复原始的LEA符号节点

                read = f"Mem_{astNode.getBitvectorSize()}_{hash(str(astNode))}"
                m_use[i].add(read)
                appears.add(read)

        for writeMem in writeMems:
            memacc: triton.MemoryAccess = writeMem[0]
            for c in range(memacc.getSize()):
                
                imm = memacc.getDisplacement()
                old = imm.getValue()
                imm.setValue(old + c, imm.getSize())
                memacc.setDisplacement(imm)
                tmpctx.initLeaAst(memacc)
                astNode = tmpastctx.unroll(memacc.getLeaAst())
                imm.setValue(old, imm.getSize())
                memacc.setDisplacement(imm)
                tmpctx.initLeaAst(memacc) # 恢复原始的LEA符号节点

                write = f"Mem_{astNode.getBitvectorSize()}_{hash(str(astNode))}"
                m_def[i].add(write)
                appears.add(write)

    m_out[-1] = appears

    for idx in range(len(insList) - 1, -1, -1):
        tem = m_out[idx] - m_def[idx]
        _in = m_use[idx].union(tem)
        m_in[idx] = _in
        if (idx != 0):
            m_out[idx - 1] = m_in[idx]

    delete_idxs = []
    for idx in range(len(insList)):
        if (m_def[idx].intersection(m_out[idx]) == set()):
            delete_idxs.append(idx)

    for i in range(len(insList)):
        if (i in delete_idxs): # 是垃圾代码
            insList[i].obfDeadCodeStatus = True
            hasChange = True

    return hasChange

def dead_code_elimination(bbs: set[ST_BasicBlock]) -> tuple[set[ST_BasicBlock], bool]:
    hasChange = False
    bbs = set(bbs)

    for bb in bbs:
        if checkDCE(bb, False):
            hasChange = True

    return bbs, hasChange

# %%
# 进行预处理
print(f"预处理前基本块数量: {len(bbs)}")
# bbs, _ = split_basic_blocks(bbs)
print(f"预处理后基本块数量: {len(bbs)}")
# Out:
# 预处理前基本块数量: 3577
# 预处理后基本块数量: 3577

# %%
def drawBBLinkGraph(bbs: set[ST_BasicBlock], createUnkNodeWhenBBInvalid: bool = False):
    '''createUnkNodeWhenBBInvalid: 检查目标节点是否存在，若不存在则根据此参数创建对应的UNK节点再绘制edge，否则取消edge绘制。'''
    g = graphviz.Digraph('BasicBlockLinkGraph', graph_attr={'rankdir': 'LR'})

    valids = set() # 用于快速检查某一个基本块是否存在
    for bb in bbs:
        node = bb.getCurrentAddr()
        valids.add(node)
        g.node(hex(node), label=f'{hex(node)}: {len(bb.instructions)}', color="")

    precursors = defaultdict(set[BBLink]) # 前驱
    successors = defaultdict(set[BBLink]) # 后继

    for bb in bbs:
        current = bb.getCurrentAddr()
        if (bb.isControlflow):
            if (bb.isDirect):

                if (bb.isConditionalJump): # 针对有条件跳转
                    if not (hasattr(bb, "obfOPStatus") and bb.obfOPStatus == True): # ObfOP 反混淆
                        taken1 = BBLink(BBLinkType.DIRECT_COND_TAKEN, bb.targetAddr)
                        taken2 = BBLink(BBLinkType.DIRECT_COND_NOTTAKEN, bb.fallThroughAddr)
                        target = set({taken1, taken2})
                    else:
                        if (bb.obfOPCondTaken):
                            taken = BBLink(BBLinkType.OBF_JUMP, bb.targetAddr)
                        else:
                            taken = BBLink(BBLinkType.OBF_JUMP, bb.fallThroughAddr)
                        target = set({taken})
                else: # 针对无条件跳转 到这里的基本块的跳转指令是 jmp imm 或 call imm
                    taken = BBLink(BBLinkType.DIRECT_UNCOND, bb.targetAddr)
                    target = set({taken})

            else: # 间接跳转
                if not (hasattr(bb, "obfIndirectStatus") and bb.obfIndirectStatus == True): # ObfIndirect 反混淆
                    target = set()
                    for indirectTargetAddr in bb.indirectTargetAddrs:
                        taken = BBLink(BBLinkType.INDIRECT_UNCOND, indirectTargetAddr)
                        target.add(taken)
                else:
                    taken = BBLink(BBLinkType.OBF_JUMP, bb.obfIndirectAddr)
                    target = set({taken})
        else:
            # 到这里的基本块是没有控制流指令的
            taken = BBLink(BBLinkType.DIRECT_FALLTHROUGH, bb.fallThroughAddr)
            target = set({taken})
        
        successors[current] = successors[current].union(target)
        for taken in target:
            precursors[taken.addr].add(BBLink(taken.type, current))

    for succSrc in successors:
        succDests = successors[succSrc]
        for succDestTaken in succDests:
            if (succDestTaken.type == BBLinkType.INDIRECT_UNCOND):
                color, style = "blue", "dashed"
            elif (succDestTaken.type == BBLinkType.DIRECT_UNCOND):
                color, style = "blue", "solid"
            elif (succDestTaken.type == BBLinkType.DIRECT_COND_TAKEN):
                color, style = "green", "solid"
            elif (succDestTaken.type == BBLinkType.DIRECT_COND_NOTTAKEN):
                color, style = "red", "solid"
            elif (succDestTaken.type == BBLinkType.DIRECT_FALLTHROUGH):
                color, style = "grey", "solid"
            elif (succDestTaken.type == BBLinkType.OBF_JUMP):
                color, style = "pink", "solid"
            else:
                raise RuntimeError()

            if (succDestTaken.addr in valids):
                g.edge(hex(succSrc), hex(succDestTaken.addr), color=color, style=style)
            else:
                if (createUnkNodeWhenBBInvalid):
                    g.edge(hex(succSrc), hex(succDestTaken.addr), color=color, style=style)
                    g.node(hex(succDestTaken.addr), label=f'UNK_{hex(succDestTaken.addr)}', color="red")

    return g

# %%
# drawBBLinkGraph(bbs) # 绘制基本块链接图

# %%
# 反混淆迭代循环
keepRun = True
runCount = 0
processors: list = [merge_basic_block, prove_opaque_predicate, prove_obfuse_indirect]
while(keepRun):
    runCount += 1
    keepRun = False

    for processor in processors:
        hasChange = False
        bbs, hasChange = processor(bbs)
        if (hasChange): 
            keepRun = True

print(f"反混淆循环结束! 共周转执行 {runCount} 次")
print(f"当前基本块数量: {len(bbs)}")
# Out:
# 反混淆循环结束! 共周转执行 8 次
# 当前基本块数量: 763

# %%
# drawBBLinkGraph(bbs) # 绘制基本块链接图

# %%
def writeBytesX64dbg(insaddr: int, bys: bytes) -> str:
    result = ""
    for i, by in enumerate(bys):
        result += f"memset {hex(insaddr + i)},{hex(by)},0x1"
        if (i != len(bys) - 1):
            result += "\n"
    return result

# %%
for ins in record:
    if (hasattr(ins, "obfOPStatus") and ins.obfOPStatus == True):
        print(f"{hex(ins.ins_address)} 是不透明谓词!  真实跳转谓词: {ins.obfOPCondTaken} \t{ins.ttins}")
# Out:
# 0x14033fb82 是不透明谓词!  真实跳转谓词: False 	0x14033fb82: jb 0x1402d2470
# 0x140292375 是不透明谓词!  真实跳转谓词: True 	0x140292375: jae 0x1402ec76b
# 0x1402ac3f2 是不透明谓词!  真实跳转谓词: True 	0x1402ac3f2: jle 0x14046a1e2
# 0x1401a38e3 是不透明谓词!  真实跳转谓词: False 	0x1401a38e3: je 0x140294c36
# 0x140215845 是不透明谓词!  真实跳转谓词: True 	0x140215845: jbe 0x14017528b
# 0x1402fa90c 是不透明谓词!  真实跳转谓词: True 	0x1402fa90c: jb 0x140432b3c
# 0x140432b44 是不透明谓词!  真实跳转谓词: False 	0x140432b44: jae 0x1403615ae
# 0x14026b2a0 是不透明谓词!  真实跳转谓词: True 	0x14026b2a0: jb 0x1403b1cf9
# 0x1403b1d49 是不透明谓词!  真实跳转谓词: True 	0x1403b1d49: jnp 0x14015bd79
# 0x14015bd7d 是不透明谓词!  真实跳转谓词: True 	0x14015bd7d: jge 0x14017528b
# 0x14018bc3f 是不透明谓词!  真实跳转谓词: True 	0x14018bc3f: je 0x1404253bf
# 0x1401f4125 是不透明谓词!  真实跳转谓词: True 	0x1401f4125: jp 0x1403911cc
# 0x14039120e 是不透明谓词!  真实跳转谓词: True 	0x14039120e: js 0x140316402
# 0x14031641b 是不透明谓词!  真实跳转谓词: True 	0x14031641b: js 0x1402910b3
# 0x1402910c4 是不透明谓词!  真实跳转谓词: True 	0x1402910c4: jl 0x14021a1d6
# 0x1401ad346 是不透明谓词!  真实跳转谓词: True 	0x1401ad346: jne 0x1404360ef
# 0x1404360fe 是不透明谓词!  真实跳转谓词: True 	0x1404360fe: jne 0x1401cfeeb
# 0x1401a1857 是不透明谓词!  真实跳转谓词: True 	0x1401a1857: jno 0x14017528b
# 0x14028726f 是不透明谓词!  真实跳转谓词: True 	0x14028726f: jae 0x14027043d
# 0x14042eb55 是不透明谓词!  真实跳转谓词: True 	0x14042eb55: jne 0x14017f1f6
# 0x14017f275 是不透明谓词!  真实跳转谓词: True 	0x14017f275: jnp 0x14017528b
# 0x1402b0853 是不透明谓词!  真实跳转谓词: False 	0x1402b0853: jnp 0x1402828d1
# 0x140482784 是不透明谓词!  真实跳转谓词: True 	0x140482784: jne 0x1403087cb
# 0x1402f295d 是不透明谓词!  真实跳转谓词: False 	0x1402f295d: jns 0x1401d1665
# 0x1402f2967 是不透明谓词!  真实跳转谓词: True 	0x1402f2967: ja 0x14017528b
# 0x14016baf9 是不透明谓词!  真实跳转谓词: True 	0x14016baf9: jno 0x1401ace9c
# 0x1401acec4 是不透明谓词!  真实跳转谓词: False 	0x1401acec4: jns 0x1403c33bd
# 0x1402a3f16 是不透明谓词!  真实跳转谓词: True 	0x1402a3f16: jae 0x14013b10c
# 0x14031c18f 是不透明谓词!  真实跳转谓词: False 	0x14031c18f: ja 0x14024038c
# 0x14031c1ae 是不透明谓词!  真实跳转谓词: True 	0x14031c1ae: jl 0x140286465
# 0x14022382a 是不透明谓词!  真实跳转谓词: True 	0x14022382a: jae 0x1401f39d1
# 0x1401f3a15 是不透明谓词!  真实跳转谓词: True 	0x1401f3a15: jle 0x14026ae65
# 0x1402ce819 是不透明谓词!  真实跳转谓词: True 	0x1402ce819: jne 0x14043c9c1
# 0x14042dea8 是不透明谓词!  真实跳转谓词: True 	0x14042dea8: jp 0x14041b704
# 0x140311e35 是不透明谓词!  真实跳转谓词: True 	0x140311e35: jb 0x140402bb5
# 0x1404773f9 是不透明谓词!  真实跳转谓词: True 	0x1404773f9: jl 0x14017528b
# 0x140429f66 是不透明谓词!  真实跳转谓词: True 	0x140429f66: jl 0x14017528b
# 0x140195f31 是不透明谓词!  真实跳转谓词: False 	0x140195f31: je 0x140427f34
# 0x140195f4c 是不透明谓词!  真实跳转谓词: True 	0x140195f4c: jno 0x14017528b
# 0x1402cf7f3 是不透明谓词!  真实跳转谓词: True 	0x1402cf7f3: jne 0x14017528b
# 0x1402d4cb4 是不透明谓词!  真实跳转谓词: True 	0x1402d4cb4: jae 0x14048a015
# 0x14048a0b4 是不透明谓词!  真实跳转谓词: True 	0x14048a0b4: jae 0x14017528b
# 0x14048cb91 是不透明谓词!  真实跳转谓词: False 	0x14048cb91: jb 0x1402b2e11
# 0x14048cbba 是不透明谓词!  真实跳转谓词: True 	0x14048cbba: jp 0x14042dccb
# 0x1404c07b6 是不透明谓词!  真实跳转谓词: True 	0x1404c07b6: jae 0x1404bc4fc
# 0x1404bc5ae 是不透明谓词!  真实跳转谓词: True 	0x1404bc5ae: jae 0x14017528b
# 0x1403e270f 是不透明谓词!  真实跳转谓词: True 	0x1403e270f: jae 0x140289501
# 0x14028957e 是不透明谓词!  真实跳转谓词: False 	0x14028957e: jnp 0x140137edd
# 0x14042eaf8 是不透明谓词!  真实跳转谓词: True 	0x14042eaf8: jl 0x1403103d9
# 0x140461969 是不透明谓词!  真实跳转谓词: True 	0x140461969: je 0x14017528b
# 0x140473aa6 是不透明谓词!  真实跳转谓词: True 	0x140473aa6: jae 0x1402c8cca
# 0x1404c384a 是不透明谓词!  真实跳转谓词: False 	0x1404c384a: je 0x140133dcc
# 0x14019af0b 是不透明谓词!  真实跳转谓词: True 	0x14019af0b: jnp 0x1401a1946
# 0x1404ba91e 是不透明谓词!  真实跳转谓词: True 	0x1404ba91e: jg 0x1401cf797
# 0x1401e3579 是不透明谓词!  真实跳转谓词: True 	0x1401e3579: jae 0x14020dc17
# 0x14020dc2b 是不透明谓词!  真实跳转谓词: True 	0x14020dc2b: jae 0x14017528b
# 0x1402b14c6 是不透明谓词!  真实跳转谓词: True 	0x1402b14c6: jae 0x1401e4dcd
# 0x1401e4e04 是不透明谓词!  真实跳转谓词: False 	0x1401e4e04: jb 0x14035660c
# 0x1401e4e75 是不透明谓词!  真实跳转谓词: True 	0x1401e4e75: jb 0x1403267a5
# 0x1402e48b6 是不透明谓词!  真实跳转谓词: True 	0x1402e48b6: jg 0x1401e81f8
# 0x140491b73 是不透明谓词!  真实跳转谓词: False 	0x140491b73: jnp 0x1403451a0
# 0x140491c05 是不透明谓词!  真实跳转谓词: True 	0x140491c05: jns 0x1402a986e
# 0x1402f28e5 是不透明谓词!  真实跳转谓词: True 	0x1402f28e5: jae 0x14017528b
# 0x14049122e 是不透明谓词!  真实跳转谓词: True 	0x14049122e: jb 0x14020181e
# 0x1401b850b 是不透明谓词!  真实跳转谓词: True 	0x1401b850b: jl 0x14017528b
# 0x14028d5f2 是不透明谓词!  真实跳转谓词: True 	0x14028d5f2: jb 0x14031ba64
# 0x14041943d 是不透明谓词!  真实跳转谓词: True 	0x14041943d: jae 0x1404b2a92
# 0x140321dfe 是不透明谓词!  真实跳转谓词: False 	0x140321dfe: je 0x14012993e
# 0x140321e13 是不透明谓词!  真实跳转谓词: True 	0x140321e13: jg 0x14017528b
# 0x1404b33c7 是不透明谓词!  真实跳转谓词: True 	0x1404b33c7: jae 0x1403952ed
# 0x140395348 是不透明谓词!  真实跳转谓词: False 	0x140395348: jg 0x1402431aa
# 0x14039536e 是不透明谓词!  真实跳转谓词: True 	0x14039536e: jge 0x14036e51a
# 0x1402434a6 是不透明谓词!  真实跳转谓词: True 	0x1402434a6: jns 0x14017528b
# 0x140167b29 是不透明谓词!  真实跳转谓词: True 	0x140167b29: js 0x14048249f
# 0x140482534 是不透明谓词!  真实跳转谓词: True 	0x140482534: jns 0x14017528b
# 0x140378aa5 是不透明谓词!  真实跳转谓词: True 	0x140378aa5: jle 0x140399e9b
# 0x1401d7301 是不透明谓词!  真实跳转谓词: True 	0x1401d7301: jne 0x140392543
# 0x140392546 是不透明谓词!  真实跳转谓词: True 	0x140392546: jp 0x14017528b
# 0x14018f338 是不透明谓词!  真实跳转谓词: True 	0x14018f338: ja 0x140167602
# 0x14048ff6b 是不透明谓词!  真实跳转谓词: True 	0x14048ff6b: jne 0x14028a139
# 0x1401357fe 是不透明谓词!  真实跳转谓词: True 	0x1401357fe: jne 0x14017528b
# 0x140433ac5 是不透明谓词!  真实跳转谓词: True 	0x140433ac5: jb 0x14027b690
# 0x1404ba31d 是不透明谓词!  真实跳转谓词: True 	0x1404ba31d: jle 0x14027a0af
# 0x14027a134 是不透明谓词!  真实跳转谓词: True 	0x14027a134: jne 0x14017528b
# 0x1402217ce 是不透明谓词!  真实跳转谓词: True 	0x1402217ce: jno 0x14022ff16
# 0x1404899b7 是不透明谓词!  真实跳转谓词: True 	0x1404899b7: jbe 0x140259558
# 0x140259558 是不透明谓词!  真实跳转谓词: True 	0x140259558: jae 0x1401b7f97
# 0x1401b8000 是不透明谓词!  真实跳转谓词: False 	0x1401b8000: jbe 0x14014b2a2
# 0x14041e722 是不透明谓词!  真实跳转谓词: True 	0x14041e722: js 0x1401d0c56
# 0x1404cd55f 是不透明谓词!  真实跳转谓词: True 	0x1404cd55f: js 0x14039c2e5
# 0x1402b61a7 是不透明谓词!  真实跳转谓词: True 	0x1402b61a7: jo 0x14032ba11
# 0x14032bac9 是不透明谓词!  真实跳转谓词: False 	0x14032bac9: jg 0x14024d8d4
# 0x14032bada 是不透明谓词!  真实跳转谓词: True 	0x14032bada: jb 0x1403a8557
# 0x14024087c 是不透明谓词!  真实跳转谓词: True 	0x14024087c: jne 0x14017528b
# 0x1403e87b8 是不透明谓词!  真实跳转谓词: True 	0x1403e87b8: jne 0x1402901be
# 0x140290207 是不透明谓词!  真实跳转谓词: False 	0x140290207: je 0x14046c89c
# 0x1403b4d6c 是不透明谓词!  真实跳转谓词: False 	0x1403b4d6c: jnp 0x1404bcd4c
# 0x140382f1b 是不透明谓词!  真实跳转谓词: True 	0x140382f1b: jns 0x1403926d0
# 0x1403926d8 是不透明谓词!  真实跳转谓词: True 	0x1403926d8: jae 0x14017528b
# 0x1401bc573 是不透明谓词!  真实跳转谓词: True 	0x1401bc573: ja 0x14017528b
# 0x1402b3a0e 是不透明谓词!  真实跳转谓词: True 	0x1402b3a0e: jp 0x1404aada0
# 0x14037795a 是不透明谓词!  真实跳转谓词: True 	0x14037795a: jnp 0x14017528b
# 0x140276a9a 是不透明谓词!  真实跳转谓词: False 	0x140276a9a: jb 0x1403aaaed
# 0x1401fd0f8 是不透明谓词!  真实跳转谓词: True 	0x1401fd0f8: jle 0x14042d29e
# 0x14031a7e4 是不透明谓词!  真实跳转谓词: True 	0x14031a7e4: jb 0x140311169
# 0x14020c45f 是不透明谓词!  真实跳转谓词: True 	0x14020c45f: js 0x140219aad
# 0x140219ac4 是不透明谓词!  真实跳转谓词: True 	0x140219ac4: jae 0x140196044
# 0x140196089 是不透明谓词!  真实跳转谓词: True 	0x140196089: jae 0x14017528b
# 0x14049bfd5 是不透明谓词!  真实跳转谓词: True 	0x14049bfd5: jae 0x14045da7b
# 0x140237a85 是不透明谓词!  真实跳转谓词: False 	0x140237a85: jbe 0x1401aa1d6
# 0x140278dc9 是不透明谓词!  真实跳转谓词: True 	0x140278dc9: jp 0x140295fcf
# 0x14029600c 是不透明谓词!  真实跳转谓词: True 	0x14029600c: jae 0x14017528b
# 0x140433877 是不透明谓词!  真实跳转谓词: True 	0x140433877: jno 0x140264b46
# 0x140264b4b 是不透明谓词!  真实跳转谓词: True 	0x140264b4b: jp 0x1404b8551
# 0x1404b85ed 是不透明谓词!  真实跳转谓词: True 	0x1404b85ed: jb 0x140478901
# 0x14047891d 是不透明谓词!  真实跳转谓词: True 	0x14047891d: jle 0x140188d73
# 0x14021abac 是不透明谓词!  真实跳转谓词: False 	0x14021abac: js 0x1404445ca
# 0x14021ac2a 是不透明谓词!  真实跳转谓词: True 	0x14021ac2a: jae 0x14017528b
# 0x1404c8306 是不透明谓词!  真实跳转谓词: True 	0x1404c8306: jns 0x140275cce
# 0x140275d13 是不透明谓词!  真实跳转谓词: True 	0x140275d13: ja 0x14017528b
# 0x1403f02b4 是不透明谓词!  真实跳转谓词: True 	0x1403f02b4: jnp 0x1401e8315
# 0x140295bc1 是不透明谓词!  真实跳转谓词: True 	0x140295bc1: jp 0x14016ef4a
# 0x14017ef48 是不透明谓词!  真实跳转谓词: True 	0x14017ef48: jne 0x14028fc0f
# 0x14028fc20 是不透明谓词!  真实跳转谓词: True 	0x14028fc20: jne 0x14043d84a
# 0x140150d3f 是不透明谓词!  真实跳转谓词: True 	0x140150d3f: jl 0x1402b01a5
# 0x140199480 是不透明谓词!  真实跳转谓词: True 	0x140199480: je 0x1404652c1
# 0x140268c03 是不透明谓词!  真实跳转谓词: True 	0x140268c03: je 0x1403d5767
# 0x14045eba5 是不透明谓词!  真实跳转谓词: True 	0x14045eba5: jne 0x14017528b
# 0x14013d82a 是不透明谓词!  真实跳转谓词: True 	0x14013d82a: jp 0x140127503
# 0x140127555 是不透明谓词!  真实跳转谓词: False 	0x140127555: jo 0x1403885f4
# 0x1404874ec 是不透明谓词!  真实跳转谓词: True 	0x1404874ec: ja 0x1401aa6c6
# 0x1401aa6cd 是不透明谓词!  真实跳转谓词: True 	0x1401aa6cd: jge 0x14017528b
# 0x14027cb53 是不透明谓词!  真实跳转谓词: False 	0x14027cb53: je 0x1403afb38
# 0x14027cc96 是不透明谓词!  真实跳转谓词: True 	0x14027cc96: jne 0x14017528b
# 0x1402f24a8 是不透明谓词!  真实跳转谓词: True 	0x1402f24a8: jb 0x14017528b
# 0x14048ca8d 是不透明谓词!  真实跳转谓词: False 	0x14048ca8d: jp 0x140416e7b
# 0x1401550b0 是不透明谓词!  真实跳转谓词: False 	0x1401550b0: ja 0x1401fdf5d
# 0x1401550ff 是不透明谓词!  真实跳转谓词: True 	0x1401550ff: jb 0x14017528b
# 0x1401ebee5 是不透明谓词!  真实跳转谓词: False 	0x1401ebee5: jb 0x1403df3d1
# 0x1403e8ecd 是不透明谓词!  真实跳转谓词: True 	0x1403e8ecd: jne 0x140165f13
# 0x140165f25 是不透明谓词!  真实跳转谓词: False 	0x140165f25: jg 0x140294c40
# 0x140165f5e 是不透明谓词!  真实跳转谓词: True 	0x140165f5e: jb 0x14017528b
# 0x14022f18f 是不透明谓词!  真实跳转谓词: True 	0x14022f18f: jg 0x1402867ab
# 0x1402e154f 是不透明谓词!  真实跳转谓词: True 	0x1402e154f: jno 0x14030445c
# 0x1403044f0 是不透明谓词!  真实跳转谓词: True 	0x1403044f0: je 0x140247ba5
# 0x1402cdbbe 是不透明谓词!  真实跳转谓词: True 	0x1402cdbbe: jae 0x1404bfc2a
# 0x14025b5dd 是不透明谓词!  真实跳转谓词: True 	0x14025b5dd: jno 0x14027da98
# 0x1402b2204 是不透明谓词!  真实跳转谓词: True 	0x1402b2204: jge 0x14024e35f
# 0x14024e3af 是不透明谓词!  真实跳转谓词: True 	0x14024e3af: jp 0x14044d25d
# 0x1404b157d 是不透明谓词!  真实跳转谓词: True 	0x1404b157d: jne 0x14017528b
# 0x140430d52 是不透明谓词!  真实跳转谓词: True 	0x140430d52: jns 0x14030c262
# 0x14030c2a9 是不透明谓词!  真实跳转谓词: False 	0x14030c2a9: jp 0x140401391
# 0x14030c2c6 是不透明谓词!  真实跳转谓词: True 	0x14030c2c6: jns 0x14026b0ab
# 0x14026b0c6 是不透明谓词!  真实跳转谓词: True 	0x14026b0c6: ja 0x140280fd4
# 0x14014808f 是不透明谓词!  真实跳转谓词: True 	0x14014808f: jb 0x14048ee84
# 0x1401e8e3d 是不透明谓词!  真实跳转谓词: False 	0x1401e8e3d: jbe 0x1401ea7b0
# 0x1401e8e54 是不透明谓词!  真实跳转谓词: True 	0x1401e8e54: jl 0x1404368fe
# 0x140436916 是不透明谓词!  真实跳转谓词: True 	0x140436916: jno 0x140412faf
# 0x140412fbf 是不透明谓词!  真实跳转谓词: True 	0x140412fbf: jbe 0x1404ce7c7
# 0x1402d884c 是不透明谓词!  真实跳转谓词: False 	0x1402d884c: jns 0x14034335c
# 0x14030eb3c 是不透明谓词!  真实跳转谓词: False 	0x14030eb3c: jo 0x1403ce4a9
# 0x1402c36c6 是不透明谓词!  真实跳转谓词: True 	0x1402c36c6: jbe 0x14033fb8b
# 0x1402ba07e 是不透明谓词!  真实跳转谓词: False 	0x1402ba07e: jl 0x1404a0a58
# 0x1402ba0cd 是不透明谓词!  真实跳转谓词: False 	0x1402ba0cd: jae 0x1401a2a60
# 0x14041dbee 是不透明谓词!  真实跳转谓词: True 	0x14041dbee: jp 0x14046b4e1
# 0x14028512e 是不透明谓词!  真实跳转谓词: True 	0x14028512e: jb 0x14017528b
# 0x1401986b4 是不透明谓词!  真实跳转谓词: False 	0x1401986b4: jb 0x140448fac
# 0x140198746 是不透明谓词!  真实跳转谓词: True 	0x140198746: jb 0x140174279
# 0x14017433c 是不透明谓词!  真实跳转谓词: True 	0x14017433c: jns 0x14017528b
# 0x140192add 是不透明谓词!  真实跳转谓词: True 	0x140192add: jb 0x140216316
# 0x14048ac1e 是不透明谓词!  真实跳转谓词: True 	0x14048ac1e: jae 0x14022eb36
# 0x14022eb79 是不透明谓词!  真实跳转谓词: True 	0x14022eb79: jb 0x1401863ad
# 0x140186425 是不透明谓词!  真实跳转谓词: True 	0x140186425: jno 0x14015bbc2
# 0x1402f498a 是不透明谓词!  真实跳转谓词: True 	0x1402f498a: jne 0x14012c820
# 0x14020b5e1 是不透明谓词!  真实跳转谓词: True 	0x14020b5e1: jb 0x1402021ac
# 0x1402021b6 是不透明谓词!  真实跳转谓词: True 	0x1402021b6: jp 0x140159d0d
# 0x1402b8ddf 是不透明谓词!  真实跳转谓词: True 	0x1402b8ddf: jae 0x14022d64a
# 0x1402e2c1a 是不透明谓词!  真实跳转谓词: True 	0x1402e2c1a: jae 0x1404c16c1
# 0x1404c16d7 是不透明谓词!  真实跳转谓词: False 	0x1404c16d7: jne 0x1402ade5c
# 0x14041ed87 是不透明谓词!  真实跳转谓词: True 	0x14041ed87: jbe 0x1403282ab
# 0x1403282e6 是不透明谓词!  真实跳转谓词: True 	0x1403282e6: jae 0x1403056c5
# 0x1402bbe43 是不透明谓词!  真实跳转谓词: True 	0x1402bbe43: jp 0x14015896d
# 0x14026641a 是不透明谓词!  真实跳转谓词: True 	0x14026641a: jne 0x1403286f2
# 0x1403286fa 是不透明谓词!  真实跳转谓词: True 	0x1403286fa: jg 0x14044a244
# 0x140494901 是不透明谓词!  真实跳转谓词: True 	0x140494901: jb 0x1402d0fad
# 0x1404a5879 是不透明谓词!  真实跳转谓词: True 	0x1404a5879: jb 0x140491d24
# 0x14048022d 是不透明谓词!  真实跳转谓词: True 	0x14048022d: jae 0x14031fa01
# 0x14020600c 是不透明谓词!  真实跳转谓词: False 	0x14020600c: je 0x1403e0501
# 0x140289bea 是不透明谓词!  真实跳转谓词: True 	0x140289bea: jp 0x140442b5e
# 0x14013175f 是不透明谓词!  真实跳转谓词: False 	0x14013175f: jnp 0x14038ea78
# 0x1403f3e22 是不透明谓词!  真实跳转谓词: True 	0x1403f3e22: jno 0x140327d65
# 0x140327d72 是不透明谓词!  真实跳转谓词: False 	0x140327d72: ja 0x14013b46f
# 0x140327d95 是不透明谓词!  真实跳转谓词: True 	0x140327d95: jle 0x1401b8712
# 0x1401b8724 是不透明谓词!  真实跳转谓词: True 	0x1401b8724: je 0x14020be4d
# 0x14020be62 是不透明谓词!  真实跳转谓词: False 	0x14020be62: ja 0x140376066
# 0x1404a8037 是不透明谓词!  真实跳转谓词: True 	0x1404a8037: jne 0x140492ca1
# 0x1402738eb 是不透明谓词!  真实跳转谓词: True 	0x1402738eb: jbe 0x1403815c9
# 0x14041f3fe 是不透明谓词!  真实跳转谓词: False 	0x14041f3fe: jo 0x1403afb50
# 0x14024a6ca 是不透明谓词!  真实跳转谓词: True 	0x14024a6ca: jg 0x1403815c9
# 0x1401ba974 是不透明谓词!  真实跳转谓词: True 	0x1401ba974: jb 0x14042a49a
# 0x1402c2e5e 是不透明谓词!  真实跳转谓词: True 	0x1402c2e5e: jae 0x1401fed5a
# 0x14023e820 是不透明谓词!  真实跳转谓词: True 	0x14023e820: jbe 0x140145138
# 0x1401451b8 是不透明谓词!  真实跳转谓词: True 	0x1401451b8: jae 0x1403815c9
# 0x1401eb532 是不透明谓词!  真实跳转谓词: True 	0x1401eb532: jg 0x140477af8
# 0x140477b09 是不透明谓词!  真实跳转谓词: True 	0x140477b09: js 0x14048566e
# 0x1401ae373 是不透明谓词!  真实跳转谓词: False 	0x1401ae373: jl 0x140200199
# 0x1401bb2fa 是不透明谓词!  真实跳转谓词: True 	0x1401bb2fa: jae 0x1404a0702
# 0x1401945e6 是不透明谓词!  真实跳转谓词: True 	0x1401945e6: jnp 0x140208b78
# 0x140208b83 是不透明谓词!  真实跳转谓词: True 	0x140208b83: jno 0x140466b03
# 0x1404c8e69 是不透明谓词!  真实跳转谓词: True 	0x1404c8e69: jne 0x14014dcbf
# 0x14014dcc8 是不透明谓词!  真实跳转谓词: True 	0x14014dcc8: jbe 0x1403815c9
# 0x1402883ef 是不透明谓词!  真实跳转谓词: False 	0x1402883ef: js 0x1403cbdc2
# 0x1401e63a1 是不透明谓词!  真实跳转谓词: True 	0x1401e63a1: jae 0x1402baf4e
# 0x1402baf6a 是不透明谓词!  真实跳转谓词: True 	0x1402baf6a: ja 0x1403815c9
# 0x14031efdd 是不透明谓词!  真实跳转谓词: True 	0x14031efdd: jno 0x14020c8df
# 0x14020c92c 是不透明谓词!  真实跳转谓词: True 	0x14020c92c: jb 0x1402d7d3c
# 0x140314f58 是不透明谓词!  真实跳转谓词: True 	0x140314f58: js 0x14028a4bf
# 0x14026d2f9 是不透明谓词!  真实跳转谓词: True 	0x14026d2f9: jae 0x1402c87f4
# 0x1402c885f 是不透明谓词!  真实跳转谓词: True 	0x1402c885f: jae 0x1403815c9
# 0x140227748 是不透明谓词!  真实跳转谓词: True 	0x140227748: jno 0x140249e8f
# 0x14012dd2a 是不透明谓词!  真实跳转谓词: True 	0x14012dd2a: js 0x1403815c9
# 0x1402fa665 是不透明谓词!  真实跳转谓词: True 	0x1402fa665: jno 0x1404960e7
# 0x14019ff47 是不透明谓词!  真实跳转谓词: True 	0x14019ff47: jbe 0x140317671
# 0x140281fd6 是不透明谓词!  真实跳转谓词: True 	0x140281fd6: jp 0x1403815c9
# 0x14031c6b6 是不透明谓词!  真实跳转谓词: True 	0x14031c6b6: jno 0x1403815c9
# 0x14032ae2e 是不透明谓词!  真实跳转谓词: True 	0x14032ae2e: jo 0x1404289b0
# 0x14043f036 是不透明谓词!  真实跳转谓词: False 	0x14043f036: jbe 0x14015d08a
# 0x14043f057 是不透明谓词!  真实跳转谓词: False 	0x14043f057: jns 0x1403eb73d
# 0x14043f081 是不透明谓词!  真实跳转谓词: True 	0x14043f081: jae 0x1403815c9
# 0x140460cc6 是不透明谓词!  真实跳转谓词: False 	0x140460cc6: jle 0x14041867a
# 0x1401b1987 是不透明谓词!  真实跳转谓词: True 	0x1401b1987: ja 0x1403815c9
# 0x1404317ea 是不透明谓词!  真实跳转谓词: True 	0x1404317ea: jns 0x1403d03cd
# 0x14044c074 是不透明谓词!  真实跳转谓词: False 	0x14044c074: jb 0x14048a798
# 0x1401cafa1 是不透明谓词!  真实跳转谓词: False 	0x1401cafa1: je 0x1402b3cab
# 0x1401f5474 是不透明谓词!  真实跳转谓词: True 	0x1401f5474: jno 0x14018b967
# 0x14018b9a5 是不透明谓词!  真实跳转谓词: False 	0x14018b9a5: je 0x14029f201
# 0x14024f7fa 是不透明谓词!  真实跳转谓词: True 	0x14024f7fa: jae 0x1402b0342
# 0x140167bdd 是不透明谓词!  真实跳转谓词: True 	0x140167bdd: jns 0x14045c8af
# 0x14045c96f 是不透明谓词!  真实跳转谓词: False 	0x14045c96f: jb 0x140323d80
# 0x14017401e 是不透明谓词!  真实跳转谓词: True 	0x14017401e: jae 0x140131716
# 0x14019d08d 是不透明谓词!  真实跳转谓词: True 	0x14019d08d: jb 0x1401d8d71
# 0x1401d8d79 是不透明谓词!  真实跳转谓词: True 	0x1401d8d79: jne 0x1403815c9
# 0x14037652d 是不透明谓词!  真实跳转谓词: True 	0x14037652d: js 0x14023a8f2
# 0x1402b9f84 是不透明谓词!  真实跳转谓词: True 	0x1402b9f84: jno 0x140165932
# 0x1401659da 是不透明谓词!  真实跳转谓词: True 	0x1401659da: je 0x1403815c9
# 0x14042bb8c 是不透明谓词!  真实跳转谓词: False 	0x14042bb8c: jae 0x1401413dd
# 0x140285e47 是不透明谓词!  真实跳转谓词: True 	0x140285e47: jnp 0x1402b8cec
# 0x1402f1bbf 是不透明谓词!  真实跳转谓词: False 	0x1402f1bbf: jo 0x14017d613
# 0x140293add 是不透明谓词!  真实跳转谓词: False 	0x140293add: ja 0x1404758fb
# 0x14019c599 是不透明谓词!  真实跳转谓词: True 	0x14019c599: jae 0x1404531a1
# 0x14014640f 是不透明谓词!  真实跳转谓词: True 	0x14014640f: jae 0x1403815c9
# 0x140459a7c 是不透明谓词!  真实跳转谓词: True 	0x140459a7c: jle 0x14018c1d9
# 0x1404646f4 是不透明谓词!  真实跳转谓词: True 	0x1404646f4: jbe 0x14043e196
# 0x14046c500 是不透明谓词!  真实跳转谓词: True 	0x14046c500: jge 0x1402d19ac
# 0x1401c1b25 是不透明谓词!  真实跳转谓词: True 	0x1401c1b25: jns 0x1404a6d10
# 0x140256891 是不透明谓词!  真实跳转谓词: False 	0x140256891: jns 0x140435fc4
# 0x1401aed57 是不透明谓词!  真实跳转谓词: True 	0x1401aed57: jp 0x140426d7d
# 0x140426d8f 是不透明谓词!  真实跳转谓词: True 	0x140426d8f: js 0x1403815c9
# 0x140395018 是不透明谓词!  真实跳转谓词: False 	0x140395018: jb 0x140359875
# 0x14016c79f 是不透明谓词!  真实跳转谓词: False 	0x14016c79f: jp 0x1401be792
# 0x140426fa8 是不透明谓词!  真实跳转谓词: False 	0x140426fa8: jns 0x1401453bd
# 0x140308045 是不透明谓词!  真实跳转谓词: True 	0x140308045: jae 0x1402f1dc8
# 0x1401cfb2e 是不透明谓词!  真实跳转谓词: True 	0x1401cfb2e: jl 0x14013ae11
# 0x14013ae11 是不透明谓词!  真实跳转谓词: True 	0x14013ae11: jne 0x14018767d
# 0x14023abaf 是不透明谓词!  真实跳转谓词: False 	0x14023abaf: jge 0x140368c45
# 0x1402937f7 是不透明谓词!  真实跳转谓词: False 	0x1402937f7: jg 0x140292b84
# 0x140293816 是不透明谓词!  真实跳转谓词: True 	0x140293816: jae 0x1403815c9
# 0x14019932d 是不透明谓词!  真实跳转谓词: True 	0x14019932d: jae 0x14049261a
# 0x140492631 是不透明谓词!  真实跳转谓词: True 	0x140492631: jbe 0x14043165d
# 0x1401bb936 是不透明谓词!  真实跳转谓词: True 	0x1401bb936: jae 0x1403815c9
# 0x14037bd4e 是不透明谓词!  真实跳转谓词: True 	0x14037bd4e: jae 0x140345533
# 0x140345535 是不透明谓词!  真实跳转谓词: True 	0x140345535: jae 0x140403096
# 0x14039b2d7 是不透明谓词!  真实跳转谓词: True 	0x14039b2d7: jge 0x140392330
# 0x14039239c 是不透明谓词!  真实跳转谓词: True 	0x14039239c: js 0x1403815c9
# 0x140466aa1 是不透明谓词!  真实跳转谓词: True 	0x140466aa1: jae 0x1403815c9
# 0x140130ef3 是不透明谓词!  真实跳转谓词: True 	0x140130ef3: jbe 0x1402773e2
# 0x14018e635 是不透明谓词!  真实跳转谓词: False 	0x14018e635: jns 0x140413eee
# 0x14018e64f 是不透明谓词!  真实跳转谓词: True 	0x14018e64f: jne 0x1404c6b43
# 0x1404c6b51 是不透明谓词!  真实跳转谓词: True 	0x1404c6b51: jae 0x1401df15f
# 0x1401df1c4 是不透明谓词!  真实跳转谓词: True 	0x1401df1c4: jg 0x1401e44b0
# 0x1401e44df 是不透明谓词!  真实跳转谓词: True 	0x1401e44df: jbe 0x14024d278
# 0x140440e5f 是不透明谓词!  真实跳转谓词: True 	0x140440e5f: jno 0x1403815c9
# 0x14018f705 是不透明谓词!  真实跳转谓词: False 	0x14018f705: je 0x140373c73
# 0x14018f76f 是不透明谓词!  真实跳转谓词: True 	0x14018f76f: jp 0x1401d1ee0
# 0x1401d1ee0 是不透明谓词!  真实跳转谓词: True 	0x1401d1ee0: jg 0x140317b70
# 0x140145de2 是不透明谓词!  真实跳转谓词: False 	0x140145de2: jl 0x14017c22f
# 0x1402f3b72 是不透明谓词!  真实跳转谓词: True 	0x1402f3b72: jne 0x140486812
# 0x1404868af 是不透明谓词!  真实跳转谓词: False 	0x1404868af: jnp 0x140375c5b
# 0x1402de58f 是不透明谓词!  真实跳转谓词: True 	0x1402de58f: jne 0x1404a067a
# 0x1404a0682 是不透明谓词!  真实跳转谓词: True 	0x1404a0682: jae 0x14022338f
# 0x1402233a6 是不透明谓词!  真实跳转谓词: True 	0x1402233a6: jp 0x140147c4a
# 0x140147c67 是不透明谓词!  真实跳转谓词: True 	0x140147c67: jno 0x1403815c9
# 0x140313243 是不透明谓词!  真实跳转谓词: False 	0x140313243: ja 0x14031a965
# 0x140432692 是不透明谓词!  真实跳转谓词: True 	0x140432692: jb 0x1403815c9
# 0x140188bb1 是不透明谓词!  真实跳转谓词: True 	0x140188bb1: jne 0x140199a7a
# 0x14028f9e8 是不透明谓词!  真实跳转谓词: True 	0x14028f9e8: jp 0x1401f3511
# 0x1401f3511 是不透明谓词!  真实跳转谓词: False 	0x1401f3511: je 0x1403efd8d
# 0x1401f3544 是不透明谓词!  真实跳转谓词: True 	0x1401f3544: jb 0x1402ca1dc
# 0x1402ca20e 是不透明谓词!  真实跳转谓词: True 	0x1402ca20e: jns 0x1401fd00d
# 0x14046f1f7 是不透明谓词!  真实跳转谓词: True 	0x14046f1f7: jne 0x14047d659
# 0x14047d66e 是不透明谓词!  真实跳转谓词: True 	0x14047d66e: jns 0x1401cda96
# 0x140254989 是不透明谓词!  真实跳转谓词: True 	0x140254989: jae 0x1402b1b67
# 0x1402ef499 是不透明谓词!  真实跳转谓词: False 	0x1402ef499: jb 0x1402abbe6
# 0x1402ef4b8 是不透明谓词!  真实跳转谓词: True 	0x1402ef4b8: jg 0x14023c6f1
# 0x14023c6fd 是不透明谓词!  真实跳转谓词: True 	0x14023c6fd: jb 0x1402c1028
# 0x1402c1028 是不透明谓词!  真实跳转谓词: True 	0x1402c1028: jb 0x1403815c9
# 0x140293854 是不透明谓词!  真实跳转谓词: True 	0x140293854: jge 0x1403815c9
# 0x14044d4f9 是不透明谓词!  真实跳转谓词: True 	0x14044d4f9: jge 0x1402f054e
# 0x1402f055f 是不透明谓词!  真实跳转谓词: True 	0x1402f055f: jae 0x1403815c9
# 0x14024b7aa 是不透明谓词!  真实跳转谓词: False 	0x14024b7aa: jae 0x1402616b9
# 0x1402926aa 是不透明谓词!  真实跳转谓词: True 	0x1402926aa: jno 0x140166170
# 0x1401562b4 是不透明谓词!  真实跳转谓词: True 	0x1401562b4: jl 0x14014b9a2
# 0x140188e13 是不透明谓词!  真实跳转谓词: True 	0x140188e13: jns 0x1403815c9
# 0x140278915 是不透明谓词!  真实跳转谓词: True 	0x140278915: jb 0x14023c935
# 0x14013a5cf 是不透明谓词!  真实跳转谓词: False 	0x14013a5cf: ja 0x14018acbe
# 0x1401b6fee 是不透明谓词!  真实跳转谓词: True 	0x1401b6fee: jp 0x1403815c9
# 0x14030a2a1 是不透明谓词!  真实跳转谓词: True 	0x14030a2a1: jae 0x1404c31a0
# 0x1401757d2 是不透明谓词!  真实跳转谓词: False 	0x1401757d2: jne 0x140471b12
# 0x1401757fa 是不透明谓词!  真实跳转谓词: True 	0x1401757fa: jne 0x14046f5ed
# 0x1401c7038 是不透明谓词!  真实跳转谓词: True 	0x1401c7038: jae 0x1403815c9
# 0x140467675 是不透明谓词!  真实跳转谓词: True 	0x140467675: jae 0x1403069b2
# 0x1403069ba 是不透明谓词!  真实跳转谓词: True 	0x1403069ba: jbe 0x140195fc5
# 0x1401bf98c 是不透明谓词!  真实跳转谓词: True 	0x1401bf98c: jno 0x1404407b5
# 0x14049a64f 是不透明谓词!  真实跳转谓词: True 	0x14049a64f: jg 0x14019df65
# 0x14019dfdc 是不透明谓词!  真实跳转谓词: True 	0x14019dfdc: jne 0x1403815c9
# 0x140246ed0 是不透明谓词!  真实跳转谓词: True 	0x140246ed0: jns 0x140277410
# 0x140277428 是不透明谓词!  真实跳转谓词: False 	0x140277428: jo 0x14030e7f1
# 0x1401c641a 是不透明谓词!  真实跳转谓词: True 	0x1401c641a: js 0x1401b1be0
# 0x1404774fa 是不透明谓词!  真实跳转谓词: False 	0x1404774fa: jb 0x1401472e3
# 0x140327aa9 是不透明谓词!  真实跳转谓词: True 	0x140327aa9: jbe 0x14023b71d
# 0x14042278a 是不透明谓词!  真实跳转谓词: True 	0x14042278a: jns 0x140426e3f
# 0x14025dcce 是不透明谓词!  真实跳转谓词: True 	0x14025dcce: jne 0x14043b6bc
# 0x14043d68f 是不透明谓词!  真实跳转谓词: True 	0x14043d68f: jg 0x14045bc5c
# 0x14045bc71 是不透明谓词!  真实跳转谓词: True 	0x14045bc71: jne 0x1403815c9
# 0x1401e72c9 是不透明谓词!  真实跳转谓词: False 	0x1401e72c9: jl 0x140415959
# 0x1402e3090 是不透明谓词!  真实跳转谓词: True 	0x1402e3090: ja 0x1403815c9
# 0x1402434de 是不透明谓词!  真实跳转谓词: True 	0x1402434de: jae 0x1401cc7aa
# 0x1401cc7b6 是不透明谓词!  真实跳转谓词: True 	0x1401cc7b6: jbe 0x14018a177
# 0x14018a1d3 是不透明谓词!  真实跳转谓词: True 	0x14018a1d3: jne 0x14031ee78
# 0x1401edd42 是不透明谓词!  真实跳转谓词: True 	0x1401edd42: jae 0x14042ea89
# 0x14042ea96 是不透明谓词!  真实跳转谓词: True 	0x14042ea96: jae 0x140184aa2
# 0x140184ad1 是不透明谓词!  真实跳转谓词: True 	0x140184ad1: ja 0x1403815c9
# 0x14042fe33 是不透明谓词!  真实跳转谓词: False 	0x14042fe33: jbe 0x140409950
# 0x14042fe74 是不透明谓词!  真实跳转谓词: True 	0x14042fe74: jne 0x140421c53
# 0x140421c6f 是不透明谓词!  真实跳转谓词: True 	0x140421c6f: jp 0x1401323f4
# 0x14014c2d7 是不透明谓词!  真实跳转谓词: False 	0x14014c2d7: jo 0x1403451a7
# 0x1404126c5 是不透明谓词!  真实跳转谓词: True 	0x1404126c5: jp 0x1401749fa
# 0x1401749fc 是不透明谓词!  真实跳转谓词: True 	0x1401749fc: jp 0x1403815c9
# 0x1401f86e6 是不透明谓词!  真实跳转谓词: True 	0x1401f86e6: jnp 0x14042dfb3
# 0x14042dffa 是不透明谓词!  真实跳转谓词: True 	0x14042dffa: jl 0x140136f85
# 0x14033625c 是不透明谓词!  真实跳转谓词: True 	0x14033625c: jb 0x1402bbaae
# 0x1404656bb 是不透明谓词!  真实跳转谓词: True 	0x1404656bb: jae 0x140492a09
# 0x14015ffc5 是不透明谓词!  真实跳转谓词: False 	0x14015ffc5: je 0x14045840b
# 0x14028afb0 是不透明谓词!  真实跳转谓词: True 	0x14028afb0: jge 0x14048d894
# 0x1402b8ad7 是不透明谓词!  真实跳转谓词: True 	0x1402b8ad7: jno 0x14025642c
# 0x1403cb737 是不透明谓词!  真实跳转谓词: False 	0x1403cb737: ja 0x1403938fb
# 0x1403cb77b 是不透明谓词!  真实跳转谓词: False 	0x1403cb77b: jp 0x1403ce137
# 0x140447562 是不透明谓词!  真实跳转谓词: True 	0x140447562: jno 0x14024033d
# 0x14032291b 是不透明谓词!  真实跳转谓词: False 	0x14032291b: jae 0x1403d664e
# 0x14032299f 是不透明谓词!  真实跳转谓词: True 	0x14032299f: jno 0x14024033d
# 0x14020a06e 是不透明谓词!  真实跳转谓词: False 	0x14020a06e: je 0x14032ccec
# 0x1403b03bf 是不透明谓词!  真实跳转谓词: True 	0x1403b03bf: je 0x14020eccf
# 0x14020ecdf 是不透明谓词!  真实跳转谓词: True 	0x14020ecdf: jae 0x1404830dc
# 0x14044dccc 是不透明谓词!  真实跳转谓词: True 	0x14044dccc: jae 0x140406260
# 0x140406261 是不透明谓词!  真实跳转谓词: True 	0x140406261: jae 0x14024033d
# 0x14029765d 是不透明谓词!  真实跳转谓词: True 	0x14029765d: jb 0x140205c3f
# 0x1401e38a7 是不透明谓词!  真实跳转谓词: True 	0x1401e38a7: jne 0x14015eb31
# 0x14015eb31 是不透明谓词!  真实跳转谓词: False 	0x14015eb31: jnp 0x1402eebff
# 0x140485e40 是不透明谓词!  真实跳转谓词: True 	0x140485e40: jle 0x14042191a
# 0x14047a2a7 是不透明谓词!  真实跳转谓词: True 	0x14047a2a7: jp 0x14029d87e
# 0x1402394e5 是不透明谓词!  真实跳转谓词: True 	0x1402394e5: jge 0x140285531
# 0x1402855b4 是不透明谓词!  真实跳转谓词: True 	0x1402855b4: jp 0x1402ce5a7
# 0x14027c64f 是不透明谓词!  真实跳转谓词: True 	0x14027c64f: jp 0x140486cca
# 0x1401b6e09 是不透明谓词!  真实跳转谓词: False 	0x1401b6e09: je 0x1401d3ff1
# 0x1401b6e5a 是不透明谓词!  真实跳转谓词: True 	0x1401b6e5a: jne 0x1401afb71
# 0x1401afbfd 是不透明谓词!  真实跳转谓词: True 	0x1401afbfd: jne 0x1402b1e5b
# 0x1402b1ef5 是不透明谓词!  真实跳转谓词: False 	0x1402b1ef5: ja 0x1402adec5
# 0x1402b1f01 是不透明谓词!  真实跳转谓词: True 	0x1402b1f01: jbe 0x14024033d
# 0x1401f56cc 是不透明谓词!  真实跳转谓词: True 	0x1401f56cc: js 0x14024033d
# 0x14044f895 是不透明谓词!  真实跳转谓词: True 	0x14044f895: jns 0x1402a13d5
# 0x140458f05 是不透明谓词!  真实跳转谓词: True 	0x140458f05: jno 0x1402d75e8
# 0x1402d7609 是不透明谓词!  真实跳转谓词: True 	0x1402d7609: jno 0x1401fb263
# 0x1401fb29c 是不透明谓词!  真实跳转谓词: True 	0x1401fb29c: jg 0x14024033d
# 0x14014d5a8 是不透明谓词!  真实跳转谓词: True 	0x14014d5a8: jne 0x1401be7cb
# 0x1401568ed 是不透明谓词!  真实跳转谓词: True 	0x1401568ed: jne 0x1402cebb1
# 0x1402cebd7 是不透明谓词!  真实跳转谓词: True 	0x1402cebd7: jb 0x1402ab886
# 0x1404282b2 是不透明谓词!  真实跳转谓词: True 	0x1404282b2: jae 0x140489c74
# 0x140489c79 是不透明谓词!  真实跳转谓词: True 	0x140489c79: jnp 0x140291ce9
# 0x140291d31 是不透明谓词!  真实跳转谓词: True 	0x140291d31: ja 0x1404a42ac
# 0x1404a42b7 是不透明谓词!  真实跳转谓词: False 	0x1404a42b7: jnp 0x1402c5271
# 0x140213ea2 是不透明谓词!  真实跳转谓词: True 	0x140213ea2: jae 0x140233c84
# 0x140139e82 是不透明谓词!  真实跳转谓词: False 	0x140139e82: jle 0x1403ba443
# 0x14027b9cb 是不透明谓词!  真实跳转谓词: False 	0x14027b9cb: jo 0x14013f510
# 0x1401696fe 是不透明谓词!  真实跳转谓词: True 	0x1401696fe: jno 0x140307ef8
# 0x140307f8d 是不透明谓词!  真实跳转谓词: True 	0x140307f8d: jge 0x1403f5809
# 0x1404a2924 是不透明谓词!  真实跳转谓词: True 	0x1404a2924: jb 0x14043387d
# 0x1402c0f45 是不透明谓词!  真实跳转谓词: False 	0x1402c0f45: ja 0x1401ef361
# 0x1402c1003 是不透明谓词!  真实跳转谓词: True 	0x1402c1003: jae 0x1403f5809
# 0x14046faa2 是不透明谓词!  真实跳转谓词: False 	0x14046faa2: jae 0x14020911a
# 0x140201124 是不透明谓词!  真实跳转谓词: True 	0x140201124: jp 0x1402edcda
# 0x1402edd7e 是不透明谓词!  真实跳转谓词: True 	0x1402edd7e: jne 0x1403f5809
# 0x14020f26f 是不透明谓词!  真实跳转谓词: True 	0x14020f26f: jne 0x1402199c8
# 0x140219a04 是不透明谓词!  真实跳转谓词: False 	0x140219a04: jae 0x14024cdf6
# 0x140219a0e 是不透明谓词!  真实跳转谓词: False 	0x140219a0e: jae 0x14015ece6
# 0x140219a2c 是不透明谓词!  真实跳转谓词: True 	0x140219a2c: jnp 0x14046441b
# 0x140464433 是不透明谓词!  真实跳转谓词: True 	0x140464433: jns 0x1401b5126
# 0x1401f4eea 是不透明谓词!  真实跳转谓词: True 	0x1401f4eea: jns 0x1403f5809
# 0x1401ba086 是不透明谓词!  真实跳转谓词: False 	0x1401ba086: jb 0x14047116f
# 0x140401dde 是不透明谓词!  真实跳转谓词: False 	0x140401dde: js 0x140483e96
# 0x140401e85 是不透明谓词!  真实跳转谓词: True 	0x140401e85: jns 0x1403f5809
# 0x140270900 是不透明谓词!  真实跳转谓词: True 	0x140270900: jbe 0x14018eddb
# 0x140217143 是不透明谓词!  真实跳转谓词: True 	0x140217143: jnp 0x14020d62b
# 0x14020d650 是不透明谓词!  真实跳转谓词: True 	0x14020d650: jbe 0x14048031e
# 0x14048f1fc 是不透明谓词!  真实跳转谓词: True 	0x14048f1fc: jb 0x1403f5809
# 0x140176796 是不透明谓词!  真实跳转谓词: True 	0x140176796: jne 0x1401653c5
# 0x14030dae2 是不透明谓词!  真实跳转谓词: False 	0x14030dae2: jp 0x140407a9b
# 0x140203661 是不透明谓词!  真实跳转谓词: True 	0x140203661: jl 0x14021b135
# 0x14045fff2 是不透明谓词!  真实跳转谓词: True 	0x14045fff2: jns 0x14045e1ce
# 0x140241db7 是不透明谓词!  真实跳转谓词: True 	0x140241db7: jne 0x140211f8b
# 0x140385346 是不透明谓词!  真实跳转谓词: True 	0x140385346: jae 0x14047840b
# 0x14042cfef 是不透明谓词!  真实跳转谓词: True 	0x14042cfef: jne 0x1403f5809
# 0x140340491 是不透明谓词!  真实跳转谓词: True 	0x140340491: jg 0x1403f5809
# 0x14024266e 是不透明谓词!  真实跳转谓词: True 	0x14024266e: jb 0x1402b0c90
# 0x14017ecfc 是不透明谓词!  真实跳转谓词: False 	0x14017ecfc: js 0x140364fa5
# 0x14025550b 是不透明谓词!  真实跳转谓词: False 	0x14025550b: jne 0x1402a2658
# 0x14045a232 是不透明谓词!  真实跳转谓词: True 	0x14045a232: jae 0x1403f5809
# 0x140310a39 是不透明谓词!  真实跳转谓词: True 	0x140310a39: jge 0x1402044ef
# 0x140499c10 是不透明谓词!  真实跳转谓词: True 	0x140499c10: jbe 0x14018b042
# 0x14031f3da 是不透明谓词!  真实跳转谓词: True 	0x14031f3da: jae 0x1403f5809
# 0x140489e7c 是不透明谓词!  真实跳转谓词: False 	0x140489e7c: jb 0x1403a51f0
# 0x1404ccf3f 是不透明谓词!  真实跳转谓词: True 	0x1404ccf3f: ja 0x14042f615
# 0x14042f61f 是不透明谓词!  真实跳转谓词: False 	0x14042f61f: jne 0x14048f952
# 0x1402a95bf 是不透明谓词!  真实跳转谓词: True 	0x1402a95bf: jge 0x14027e13a
# 0x1401483f7 是不透明谓词!  真实跳转谓词: True 	0x1401483f7: jae 0x1403f5809
# 0x14017832b 是不透明谓词!  真实跳转谓词: True 	0x14017832b: je 0x1403f5809
# 0x1403a798e 是不透明谓词!  真实跳转谓词: True 	0x1403a798e: jne 0x1403b64ad
# 0x1401abb35 是不透明谓词!  真实跳转谓词: True 	0x1401abb35: jno 0x1401287f7
# 0x140242a99 是不透明谓词!  真实跳转谓词: True 	0x140242a99: jl 0x1403f5809
# 0x140257c75 是不透明谓词!  真实跳转谓词: True 	0x140257c75: jnp 0x14016d8d5
# 0x14016d90e 是不透明谓词!  真实跳转谓词: False 	0x14016d90e: jnp 0x140204188
# 0x1401d4d13 是不透明谓词!  真实跳转谓词: True 	0x1401d4d13: jns 0x14048f15b
# 0x14048f1a9 是不透明谓词!  真实跳转谓词: True 	0x14048f1a9: jae 0x1403f5809
# 0x1402c7848 是不透明谓词!  真实跳转谓词: True 	0x1402c7848: jns 0x1402a738b
# 0x1402a73b9 是不透明谓词!  真实跳转谓词: True 	0x1402a73b9: jb 0x14023a2eb
# 0x1402d50ab 是不透明谓词!  真实跳转谓词: True 	0x1402d50ab: jne 0x1403f5809
# 0x1402e8ac8 是不透明谓词!  真实跳转谓词: True 	0x1402e8ac8: jp 0x14029fed1
# 0x1402f0820 是不透明谓词!  真实跳转谓词: True 	0x1402f0820: ja 0x140488b1a
# 0x140488b1a 是不透明谓词!  真实跳转谓词: True 	0x140488b1a: jne 0x1402cd3e5
# 0x14048c85e 是不透明谓词!  真实跳转谓词: False 	0x14048c85e: jo 0x1403a7ddb
# 0x14031eb82 是不透明谓词!  真实跳转谓词: True 	0x14031eb82: jae 0x1402ce9e7
# 0x14045d478 是不透明谓词!  真实跳转谓词: True 	0x14045d478: jns 0x1403f5809
# 0x14013347a 是不透明谓词!  真实跳转谓词: True 	0x14013347a: jne 0x1401dfedb
# 0x1402c7b2d 是不透明谓词!  真实跳转谓词: True 	0x1402c7b2d: jge 0x14013f33c
# 0x14013f40d 是不透明谓词!  真实跳转谓词: True 	0x14013f40d: js 0x1401f069e
# 0x1401f06a1 是不透明谓词!  真实跳转谓词: True 	0x1401f06a1: jne 0x1403f5809
# 0x1404c4af7 是不透明谓词!  真实跳转谓词: True 	0x1404c4af7: jns 0x140304f1d
# 0x140304f2e 是不透明谓词!  真实跳转谓词: True 	0x140304f2e: jne 0x1402e1b25
# 0x1401ade59 是不透明谓词!  真实跳转谓词: True 	0x1401ade59: jno 0x1401b4c16
# 0x1404458db 是不透明谓词!  真实跳转谓词: True 	0x1404458db: jb 0x14014337d
# 0x1402a03ae 是不透明谓词!  真实跳转谓词: True 	0x1402a03ae: jae 0x14047d6e1
# 0x14047d768 是不透明谓词!  真实跳转谓词: True 	0x14047d768: jb 0x14029901d
# 0x140228740 是不透明谓词!  真实跳转谓词: True 	0x140228740: js 0x1403f5809
# 0x1401f566c 是不透明谓词!  真实跳转谓词: True 	0x1401f566c: ja 0x140368ba7
# 0x14022dbd7 是不透明谓词!  真实跳转谓词: True 	0x14022dbd7: ja 0x1404323fc
# 0x1402fdd5d 是不透明谓词!  真实跳转谓词: True 	0x1402fdd5d: ja 0x1404471e7
# 0x1403011f5 是不透明谓词!  真实跳转谓词: True 	0x1403011f5: ja 0x1403f5809
# 0x14044e7e7 是不透明谓词!  真实跳转谓词: True 	0x14044e7e7: jb 0x1404ab369
# 0x1402f795e 是不透明谓词!  真实跳转谓词: True 	0x1402f795e: jae 0x1402cc8ba
# 0x14045ef25 是不透明谓词!  真实跳转谓词: True 	0x14045ef25: jg 0x140163cd2
# 0x14043ff2a 是不透明谓词!  真实跳转谓词: True 	0x14043ff2a: jne 0x140287fe4
# 0x14031866d 是不透明谓词!  真实跳转谓词: True 	0x14031866d: ja 0x1402408c9
# 0x1401b3bbc 是不透明谓词!  真实跳转谓词: False 	0x1401b3bbc: ja 0x140262116
# 0x1401712d7 是不透明谓词!  真实跳转谓词: True 	0x1401712d7: jl 0x1403f5809
# 0x14015d4ae 是不透明谓词!  真实跳转谓词: False 	0x14015d4ae: jb 0x140324151
# 0x14024db0b 是不透明谓词!  真实跳转谓词: False 	0x14024db0b: js 0x140471b5e
# 0x14024c257 是不透明谓词!  真实跳转谓词: True 	0x14024c257: ja 0x14043bddf
# 0x140473cba 是不透明谓词!  真实跳转谓词: True 	0x140473cba: jle 0x1403f5809
# 0x1402c8a59 是不透明谓词!  真实跳转谓词: True 	0x1402c8a59: jae 0x1402bf71b
# 0x140250a0d 是不透明谓词!  真实跳转谓词: True 	0x140250a0d: jne 0x1403f5809
# 0x140308e93 是不透明谓词!  真实跳转谓词: True 	0x140308e93: jbe 0x1403f5809
# 0x14025df78 是不透明谓词!  真实跳转谓词: True 	0x14025df78: jae 0x1401de7b2
# 0x140241414 是不透明谓词!  真实跳转谓词: True 	0x140241414: js 0x140256556
# 0x140430c7c 是不透明谓词!  真实跳转谓词: False 	0x140430c7c: jnp 0x1402dd64d
# 0x140430c94 是不透明谓词!  真实跳转谓词: True 	0x140430c94: jle 0x14017961e
# 0x1401cda72 是不透明谓词!  真实跳转谓词: True 	0x1401cda72: jp 0x1401e8483
# 0x1401e849d 是不透明谓词!  真实跳转谓词: True 	0x1401e849d: jae 0x140277e52
# 0x14048a8c9 是不透明谓词!  真实跳转谓词: True 	0x14048a8c9: jns 0x140172d1a
# 0x140172d1a 是不透明谓词!  真实跳转谓词: True 	0x140172d1a: jge 0x140461229
# 0x140461274 是不透明谓词!  真实跳转谓词: False 	0x140461274: jb 0x1404b1b8e
# 0x14022f1f5 是不透明谓词!  真实跳转谓词: True 	0x14022f1f5: jae 0x14025bbfe
# 0x14013cdca 是不透明谓词!  真实跳转谓词: True 	0x14013cdca: jae 0x1401db29f
# 0x14042b384 是不透明谓词!  真实跳转谓词: True 	0x14042b384: jne 0x1403f5809
# 0x1401cae70 是不透明谓词!  真实跳转谓词: True 	0x1401cae70: jns 0x14021ce2a
# 0x1404aa25e 是不透明谓词!  真实跳转谓词: False 	0x1404aa25e: jp 0x140462d6b
# 0x1404aa278 是不透明谓词!  真实跳转谓词: True 	0x1404aa278: ja 0x1404a07f7
# 0x140450be2 是不透明谓词!  真实跳转谓词: True 	0x140450be2: jae 0x1403f5809
# 0x1401f058a 是不透明谓词!  真实跳转谓词: True 	0x1401f058a: jne 0x1403f5809
# 0x14038372f 是不透明谓词!  真实跳转谓词: True 	0x14038372f: jae 0x14043b8b9
# 0x14043b8f2 是不透明谓词!  真实跳转谓词: True 	0x14043b8f2: jle 0x1403f5809
# 0x14045a6eb 是不透明谓词!  真实跳转谓词: True 	0x14045a6eb: jb 0x14030c05a
# 0x14030c09b 是不透明谓词!  真实跳转谓词: True 	0x14030c09b: js 0x1403f5809
# 0x1402fd833 是不透明谓词!  真实跳转谓词: True 	0x1402fd833: jb 0x1404cf356
# 0x140317021 是不透明谓词!  真实跳转谓词: True 	0x140317021: jl 0x140316296
# 0x140499d83 是不透明谓词!  真实跳转谓词: True 	0x140499d83: jns 0x1401bd134
# 0x14022634c 是不透明谓词!  真实跳转谓词: True 	0x14022634c: jns 0x1403f5809
# 0x1402cace2 是不透明谓词!  真实跳转谓词: True 	0x1402cace2: jns 0x140417e30
# 0x140417e48 是不透明谓词!  真实跳转谓词: True 	0x140417e48: jne 0x14036d8c8
# 0x140179537 是不透明谓词!  真实跳转谓词: True 	0x140179537: jno 0x1403f5809
# 0x14047ab1e 是不透明谓词!  真实跳转谓词: False 	0x14047ab1e: jp 0x1404272f8
# 0x14047ab46 是不透明谓词!  真实跳转谓词: True 	0x14047ab46: jae 0x14018c26f
# 0x14018c2e4 是不透明谓词!  真实跳转谓词: True 	0x14018c2e4: jae 0x140204419
# 0x14020444a 是不透明谓词!  真实跳转谓词: True 	0x14020444a: jne 0x1401a1788
# 0x1401a17d5 是不透明谓词!  真实跳转谓词: True 	0x1401a17d5: jg 0x14014eb8f
# 0x14014ec46 是不透明谓词!  真实跳转谓词: True 	0x14014ec46: jae 0x1403f5809
# 0x1401e928e 是不透明谓词!  真实跳转谓词: True 	0x1401e928e: jae 0x14027f092
# 0x1401e4282 是不透明谓词!  真实跳转谓词: True 	0x1401e4282: jne 0x140132514
# 0x140132527 是不透明谓词!  真实跳转谓词: False 	0x140132527: js 0x1402988c4
# 0x140148661 是不透明谓词!  真实跳转谓词: True 	0x140148661: jne 0x14029f1dd
# 0x14029f1ea 是不透明谓词!  真实跳转谓词: True 	0x14029f1ea: jne 0x1401f205f
# 0x14047c64d 是不透明谓词!  真实跳转谓词: True 	0x14047c64d: jno 0x1403f5809
# 0x140281b32 是不透明谓词!  真实跳转谓词: True 	0x140281b32: jno 0x1402819da
# 0x1402819da 是不透明谓词!  真实跳转谓词: True 	0x1402819da: jnp 0x14044406e
# 0x140444076 是不透明谓词!  真实跳转谓词: True 	0x140444076: ja 0x1403f5809
# 0x1402dd1a5 是不透明谓词!  真实跳转谓词: False 	0x1402dd1a5: jle 0x14032c62a
# 0x14027d648 是不透明谓词!  真实跳转谓词: True 	0x14027d648: jae 0x1403f5809
# 0x140151899 是不透明谓词!  真实跳转谓词: True 	0x140151899: jns 0x1403f5809
# 0x14024b198 是不透明谓词!  真实跳转谓词: True 	0x14024b198: js 0x1402c03cb
# 0x1402c0477 是不透明谓词!  真实跳转谓词: True 	0x1402c0477: jg 0x140177ed7
# 0x14045f6a4 是不透明谓词!  真实跳转谓词: True 	0x14045f6a4: js 0x1403f5809
# 0x1404b9527 是不透明谓词!  真实跳转谓词: True 	0x1404b9527: jb 0x1404abc42
# 0x1404abc64 是不透明谓词!  真实跳转谓词: True 	0x1404abc64: jb 0x1403f5809
# 0x1402ce4a9 是不透明谓词!  真实跳转谓词: True 	0x1402ce4a9: jns 0x140448441
# 0x140448488 是不透明谓词!  真实跳转谓词: True 	0x140448488: jbe 0x1403c1e11
# 0x14019f146 是不透明谓词!  真实跳转谓词: True 	0x14019f146: jg 0x14047a8ba
# 0x14047a8d5 是不透明谓词!  真实跳转谓词: True 	0x14047a8d5: jne 0x14020e6c7
# 0x14020e71b 是不透明谓词!  真实跳转谓词: True 	0x14020e71b: jne 0x140158205
# 0x140158218 是不透明谓词!  真实跳转谓词: True 	0x140158218: jl 0x1403f5809
# 0x1402f9cf2 是不透明谓词!  真实跳转谓词: True 	0x1402f9cf2: jno 0x1401d1ba9
# 0x140209e9b 是不透明谓词!  真实跳转谓词: True 	0x140209e9b: jne 0x140224d76
# 0x140224d76 是不透明谓词!  真实跳转谓词: False 	0x140224d76: ja 0x1402dde43
# 0x140224dab 是不透明谓词!  真实跳转谓词: True 	0x140224dab: jnp 0x14018ae07
# 0x14048c8e9 是不透明谓词!  真实跳转谓词: True 	0x14048c8e9: jb 0x140226fd8
# 0x1402bf9b4 是不透明谓词!  真实跳转谓词: True 	0x1402bf9b4: jne 0x1404708ba
# 0x140348712 是不透明谓词!  真实跳转谓词: True 	0x140348712: ja 0x14019ceac
# 0x1401aa64a 是不透明谓词!  真实跳转谓词: True 	0x1401aa64a: jg 0x1401369c2
# 0x1401c781a 是不透明谓词!  真实跳转谓词: True 	0x1401c781a: jb 0x1403f5809
# 0x140186f91 是不透明谓词!  真实跳转谓词: True 	0x140186f91: jle 0x14012f3f8
# 0x14049b3dc 是不透明谓词!  真实跳转谓词: True 	0x14049b3dc: jne 0x14022ff3f
# 0x1404b44f3 是不透明谓词!  真实跳转谓词: True 	0x1404b44f3: jns 0x1403f5809
# 0x1402c2fd0 是不透明谓词!  真实跳转谓词: True 	0x1402c2fd0: jns 0x140421039
# 0x1401c20ab 是不透明谓词!  真实跳转谓词: True 	0x1401c20ab: jae 0x140465f0d
# 0x140465f42 是不透明谓词!  真实跳转谓词: True 	0x140465f42: jae 0x14034a3e4
# 0x14034a44a 是不透明谓词!  真实跳转谓词: True 	0x14034a44a: jns 0x1403f5809
# 0x14024c43f 是不透明谓词!  真实跳转谓词: True 	0x14024c43f: jne 0x140281778
# 0x14028178c 是不透明谓词!  真实跳转谓词: False 	0x14028178c: jnp 0x14045515e
# 0x140456951 是不透明谓词!  真实跳转谓词: False 	0x140456951: jb 0x1404ae3f4
# 0x1402fe8e4 是不透明谓词!  真实跳转谓词: True 	0x1402fe8e4: ja 0x140239dba
# 0x140270b1b 是不透明谓词!  真实跳转谓词: True 	0x140270b1b: jg 0x140162788
# 0x140162862 是不透明谓词!  真实跳转谓词: True 	0x140162862: jge 0x1404787e9
# 0x140478821 是不透明谓词!  真实跳转谓词: True 	0x140478821: jne 0x1403f5809
# 0x1403ec4f7 是不透明谓词!  真实跳转谓词: True 	0x1403ec4f7: jg 0x1403f5809
# 0x140454489 是不透明谓词!  真实跳转谓词: True 	0x140454489: js 0x1401a069d
# 0x1401a06d7 是不透明谓词!  真实跳转谓词: True 	0x1401a06d7: je 0x1403f5809
# 0x1402eb9fd 是不透明谓词!  真实跳转谓词: False 	0x1402eb9fd: jb 0x1403a8a79
# 0x1402eba23 是不透明谓词!  真实跳转谓词: True 	0x1402eba23: ja 0x1402647c6
# 0x14026480c 是不透明谓词!  真实跳转谓词: False 	0x14026480c: js 0x14026d6b3
# 0x1402f5b6f 是不透明谓词!  真实跳转谓词: True 	0x1402f5b6f: jbe 0x14045dc5c
# 0x14045dcc3 是不透明谓词!  真实跳转谓词: False 	0x14045dcc3: ja 0x14045d945
# 0x14045dcd3 是不透明谓词!  真实跳转谓词: True 	0x14045dcd3: jne 0x1402880fa
# 0x14046078f 是不透明谓词!  真实跳转谓词: True 	0x14046078f: jb 0x1403f5809
# 0x14032a6e7 是不透明谓词!  真实跳转谓词: True 	0x14032a6e7: jle 0x1404740b0
# 0x1404740b9 是不透明谓词!  真实跳转谓词: True 	0x1404740b9: ja 0x140493e3b
# 0x14019428a 是不透明谓词!  真实跳转谓词: True 	0x14019428a: jl 0x1402c97cc
# 0x1402c97d6 是不透明谓词!  真实跳转谓词: True 	0x1402c97d6: jno 0x1403f5809
# 0x140320d3b 是不透明谓词!  真实跳转谓词: True 	0x140320d3b: jae 0x140308b95
# 0x14029e92a 是不透明谓词!  真实跳转谓词: True 	0x14029e92a: jno 0x1403f5809
# 0x14013250e 是不透明谓词!  真实跳转谓词: True 	0x14013250e: jae 0x1403f5809
# 0x140133a17 是不透明谓词!  真实跳转谓词: True 	0x140133a17: jae 0x1402addf4
# 0x140269417 是不透明谓词!  真实跳转谓词: True 	0x140269417: jbe 0x140451f84
# 0x140451f91 是不透明谓词!  真实跳转谓词: True 	0x140451f91: jns 0x140439514
# 0x1401f78ac 是不透明谓词!  真实跳转谓词: False 	0x1401f78ac: js 0x1404bfb9a
# 0x14045660c 是不透明谓词!  真实跳转谓词: False 	0x14045660c: jl 0x1402e2d5e
# 0x140456616 是不透明谓词!  真实跳转谓词: True 	0x140456616: jbe 0x1403f5809
# 0x1401ab94f 是不透明谓词!  真实跳转谓词: True 	0x1401ab94f: jne 0x1402fc8ca
# 0x14016276b 是不透明谓词!  真实跳转谓词: True 	0x14016276b: jne 0x1402d4d7a
# 0x1402d4d88 是不透明谓词!  真实跳转谓词: True 	0x1402d4d88: jae 0x1402f2509
# 0x140223ed8 是不透明谓词!  真实跳转谓词: True 	0x140223ed8: js 0x14047dc73
# 0x140164de8 是不透明谓词!  真实跳转谓词: True 	0x140164de8: ja 0x1403f5809
# 0x14032e06e 是不透明谓词!  真实跳转谓词: False 	0x14032e06e: jge 0x140387e9c
# 0x14046526e 是不透明谓词!  真实跳转谓词: False 	0x14046526e: jbe 0x1404a112c
# 0x14046528a 是不透明谓词!  真实跳转谓词: False 	0x14046528a: jb 0x1404218af
# 0x14046529e 是不透明谓词!  真实跳转谓词: True 	0x14046529e: jno 0x1403f5809
# 0x140146a06 是不透明谓词!  真实跳转谓词: True 	0x140146a06: jae 0x14014d35d
# 0x1404342f8 是不透明谓词!  真实跳转谓词: True 	0x1404342f8: jg 0x1404540cb
# 0x1403d00bb 是不透明谓词!  真实跳转谓词: False 	0x1403d00bb: jnp 0x14043b863
# 0x14018a41d 是不透明谓词!  真实跳转谓词: True 	0x14018a41d: jae 0x1403f5809
# 0x14017f6f6 是不透明谓词!  真实跳转谓词: True 	0x14017f6f6: jno 0x14041f2f1
# 0x1404ca4fb 是不透明谓词!  真实跳转谓词: True 	0x1404ca4fb: jnp 0x1403f5809
# 0x14024e14b 是不透明谓词!  真实跳转谓词: False 	0x14024e14b: jb 0x1403ff864
# 0x1402d14c3 是不透明谓词!  真实跳转谓词: True 	0x1402d14c3: jp 0x140274e13
# 0x1402c7618 是不透明谓词!  真实跳转谓词: True 	0x1402c7618: jbe 0x14016f654
# 0x14016f713 是不透明谓词!  真实跳转谓词: True 	0x14016f713: jno 0x140493f68
# 0x140262056 是不透明谓词!  真实跳转谓词: True 	0x140262056: jne 0x14047342b
# 0x14018949f 是不透明谓词!  真实跳转谓词: True 	0x14018949f: jb 0x140263c92
# 0x140263cb3 是不透明谓词!  真实跳转谓词: False 	0x140263cb3: jb 0x1401fc908
# 0x14036cbd0 是不透明谓词!  真实跳转谓词: True 	0x14036cbd0: jp 0x1402f11bd
# 0x1402b9186 是不透明谓词!  真实跳转谓词: True 	0x1402b9186: je 0x14017c441
# 0x14017c46e 是不透明谓词!  真实跳转谓词: False 	0x14017c46e: jb 0x140412f1c
# 0x140437a98 是不透明谓词!  真实跳转谓词: False 	0x140437a98: je 0x1403964d0
# 0x140250fbb 是不透明谓词!  真实跳转谓词: True 	0x140250fbb: jns 0x1403f5809
# 0x14013423a 是不透明谓词!  真实跳转谓词: False 	0x14013423a: jle 0x1404be139
# 0x140411c93 是不透明谓词!  真实跳转谓词: True 	0x140411c93: jae 0x1404604a8
# 0x1404604da 是不透明谓词!  真实跳转谓词: False 	0x1404604da: jae 0x1403f1c17
# 0x1404604e1 是不透明谓词!  真实跳转谓词: True 	0x1404604e1: jb 0x1403f5809
# 0x140197d30 是不透明谓词!  真实跳转谓词: True 	0x140197d30: js 0x140234f16
# 0x140234f22 是不透明谓词!  真实跳转谓词: True 	0x140234f22: jb 0x1402053c0
# 0x1404afdd8 是不透明谓词!  真实跳转谓词: True 	0x1404afdd8: jns 0x14017f079
# 0x1402a1751 是不透明谓词!  真实跳转谓词: True 	0x1402a1751: jle 0x1401a1f5f
# 0x1401a1f73 是不透明谓词!  真实跳转谓词: True 	0x1401a1f73: jp 0x1403f5809
# 0x14023547d 是不透明谓词!  真实跳转谓词: True 	0x14023547d: jl 0x14012da1b
# 0x14012db17 是不透明谓词!  真实跳转谓词: False 	0x14012db17: jg 0x14034a9b4
# 0x14012db67 是不透明谓词!  真实跳转谓词: True 	0x14012db67: jbe 0x1403f5809
# 0x1403dff8c 是不透明谓词!  真实跳转谓词: False 	0x1403dff8c: jnp 0x1404711a5
# 0x1401286ee 是不透明谓词!  真实跳转谓词: True 	0x1401286ee: jae 0x1403f5809
# 0x140462ce0 是不透明谓词!  真实跳转谓词: True 	0x140462ce0: jb 0x140451c92
# 0x1404ad6f3 是不透明谓词!  真实跳转谓词: True 	0x1404ad6f3: jb 0x1402a2309
# 0x1401928fc 是不透明谓词!  真实跳转谓词: False 	0x1401928fc: je 0x140442841
# 0x140440351 是不透明谓词!  真实跳转谓词: True 	0x140440351: jl 0x1403f5809
# 0x14015f85a 是不透明谓词!  真实跳转谓词: False 	0x14015f85a: jbe 0x140425cc3
# 0x1404bf733 是不透明谓词!  真实跳转谓词: False 	0x1404bf733: jne 0x1403327fd
# 0x1402c2ce0 是不透明谓词!  真实跳转谓词: False 	0x1402c2ce0: jb 0x1404ae3e6
# 0x140219414 是不透明谓词!  真实跳转谓词: False 	0x140219414: jns 0x140224d1a
# 0x1402cc52a 是不透明谓词!  真实跳转谓词: False 	0x1402cc52a: jae 0x14023e553
# 0x1401607dd 是不透明谓词!  真实跳转谓词: True 	0x1401607dd: jae 0x14032b860
# 0x140435bb3 是不透明谓词!  真实跳转谓词: True 	0x140435bb3: jp 0x140234aed
# 0x140234b32 是不透明谓词!  真实跳转谓词: True 	0x140234b32: jnp 0x14045c2e2
# 0x14045c361 是不透明谓词!  真实跳转谓词: False 	0x14045c361: jb 0x1403ffaf6
# 0x14048680c 是不透明谓词!  真实跳转谓词: True 	0x14048680c: jge 0x1403f5809
# 0x1401ef9df 是不透明谓词!  真实跳转谓词: True 	0x1401ef9df: jns 0x14033fd5a
# 0x14033fd5d 是不透明谓词!  真实跳转谓词: True 	0x14033fd5d: jns 0x1403daba0
# 0x1403dac13 是不透明谓词!  真实跳转谓词: True 	0x1403dac13: jle 0x1403863b0
# 0x1403863b0 是不透明谓词!  真实跳转谓词: False 	0x1403863b0: jg 0x1401c27ac
# 0x1403863b6 是不透明谓词!  真实跳转谓词: True 	0x1403863b6: js 0x1403f5809
# 0x1401ead55 是不透明谓词!  真实跳转谓词: False 	0x1401ead55: js 0x1403b81d2
# 0x1401eaddd 是不透明谓词!  真实跳转谓词: True 	0x1401eaddd: jb 0x140238e93
# 0x140186e81 是不透明谓词!  真实跳转谓词: True 	0x140186e81: jl 0x1401e0e03
# 0x14046f481 是不透明谓词!  真实跳转谓词: False 	0x14046f481: jb 0x1401e6cc4
# 0x140266720 是不透明谓词!  真实跳转谓词: False 	0x140266720: je 0x14039fae1
# 0x14026674b 是不透明谓词!  真实跳转谓词: True 	0x14026674b: jne 0x140471ca7
# 0x140277ef3 是不透明谓词!  真实跳转谓词: True 	0x140277ef3: jb 0x1402d50b1
# 0x1404691c9 是不透明谓词!  真实跳转谓词: True 	0x1404691c9: jp 0x14028f21c
# 0x14028f21c 是不透明谓词!  真实跳转谓词: True 	0x14028f21c: jne 0x1403f5809
# 0x140448bc7 是不透明谓词!  真实跳转谓词: False 	0x140448bc7: jb 0x140140251
# 0x140464b3e 是不透明谓词!  真实跳转谓词: False 	0x140464b3e: js 0x140249b99
# 0x140464b8e 是不透明谓词!  真实跳转谓词: True 	0x140464b8e: jae 0x1404376c6
# 0x1404376e0 是不透明谓词!  真实跳转谓词: True 	0x1404376e0: jae 0x140151f37
# 0x140252ac3 是不透明谓词!  真实跳转谓词: False 	0x140252ac3: jl 0x140403a4b
# 0x140359f66 是不透明谓词!  真实跳转谓词: True 	0x140359f66: jle 0x1404703cb
# 0x140470423 是不透明谓词!  真实跳转谓词: True 	0x140470423: jp 0x1403f5809
# 0x14045ad12 是不透明谓词!  真实跳转谓词: False 	0x14045ad12: jb 0x14018d414
# 0x14047cb0e 是不透明谓词!  真实跳转谓词: True 	0x14047cb0e: jae 0x1402cf536
# 0x1402ad666 是不透明谓词!  真实跳转谓词: True 	0x1402ad666: jne 0x1403f5809
# 0x1404a538f 是不透明谓词!  真实跳转谓词: False 	0x1404a538f: jb 0x14033ef64
# 0x1404a53e4 是不透明谓词!  真实跳转谓词: True 	0x1404a53e4: jae 0x14045b556
# 0x14045b5a0 是不透明谓词!  真实跳转谓词: True 	0x14045b5a0: ja 0x1402d7a28
# 0x140419236 是不透明谓词!  真实跳转谓词: False 	0x140419236: jne 0x14025b6d8
# 0x1404192d3 是不透明谓词!  真实跳转谓词: True 	0x1404192d3: jp 0x1403d65c5
# 0x14029e68d 是不透明谓词!  真实跳转谓词: False 	0x14029e68d: jae 0x140467379
# 0x1402da24a 是不透明谓词!  真实跳转谓词: True 	0x1402da24a: jae 0x140365dc5
# 0x140365dc5 是不透明谓词!  真实跳转谓词: True 	0x140365dc5: jae 0x1404085f3
# 0x1403710b0 是不透明谓词!  真实跳转谓词: True 	0x1403710b0: js 0x14018fd2d
# 0x14018fdb4 是不透明谓词!  真实跳转谓词: True 	0x14018fdb4: jbe 0x1403f5809
# 0x14013c7a7 是不透明谓词!  真实跳转谓词: True 	0x14013c7a7: jne 0x1402a20ee
# 0x140247bfd 是不透明谓词!  真实跳转谓词: False 	0x140247bfd: jo 0x14021224f
# 0x140449517 是不透明谓词!  真实跳转谓词: True 	0x140449517: jp 0x1402d380b
# 0x140178d99 是不透明谓词!  真实跳转谓词: False 	0x140178d99: js 0x14032f005
# 0x1404546fb 是不透明谓词!  真实跳转谓词: False 	0x1404546fb: jb 0x140346363
# 0x14045470b 是不透明谓词!  真实跳转谓词: True 	0x14045470b: jns 0x1403f5809
# 0x1403d73fe 是不透明谓词!  真实跳转谓词: True 	0x1403d73fe: jb 0x1403d7a79
# 0x1403d7a79 是不透明谓词!  真实跳转谓词: True 	0x1403d7a79: jb 0x1404c0003
# 0x1404c0014 是不透明谓词!  真实跳转谓词: True 	0x1404c0014: jp 0x14031512e
# 0x1401fa230 是不透明谓词!  真实跳转谓词: False 	0x1401fa230: js 0x140483ea6
# 0x1401fa236 是不透明谓词!  真实跳转谓词: True 	0x1401fa236: jg 0x1403f5809
# 0x1402c41ed 是不透明谓词!  真实跳转谓词: True 	0x1402c41ed: jae 0x14037246f
# 0x14031ee72 是不透明谓词!  真实跳转谓词: True 	0x14031ee72: ja 0x1403a7194
# 0x1403a7194 是不透明谓词!  真实跳转谓词: False 	0x1403a7194: jbe 0x140363000
# 0x1403a71ac 是不透明谓词!  真实跳转谓词: True 	0x1403a71ac: jb 0x1403f5809
# 0x1402a5849 是不透明谓词!  真实跳转谓词: True 	0x1402a5849: jle 0x140296f96
# 0x140206e80 是不透明谓词!  真实跳转谓词: False 	0x140206e80: ja 0x1403c64d8
# 0x140244977 是不透明谓词!  真实跳转谓词: True 	0x140244977: jge 0x1401fb022
# 0x1401fb02e 是不透明谓词!  真实跳转谓词: True 	0x1401fb02e: jno 0x1402d8059
# 0x14014c3bf 是不透明谓词!  真实跳转谓词: True 	0x14014c3bf: jge 0x1403f5809
# 0x14043eea1 是不透明谓词!  真实跳转谓词: True 	0x14043eea1: je 0x140143cd6
# 0x140182696 是不透明谓词!  真实跳转谓词: True 	0x140182696: jae 0x14045a326
# 0x1401c4b72 是不透明谓词!  真实跳转谓词: True 	0x1401c4b72: jne 0x140157e02
# 0x140157e43 是不透明谓词!  真实跳转谓词: False 	0x140157e43: jb 0x140392746
# 0x140157e50 是不透明谓词!  真实跳转谓词: True 	0x140157e50: jno 0x14014c797
# 0x14049de14 是不透明谓词!  真实跳转谓词: True 	0x14049de14: jp 0x140143f07
# 0x140143f10 是不透明谓词!  真实跳转谓词: True 	0x140143f10: jae 0x1401d0163
# 0x1401d0177 是不透明谓词!  真实跳转谓词: True 	0x1401d0177: jg 0x14026bf10
# 0x14042d927 是不透明谓词!  真实跳转谓词: True 	0x14042d927: jne 0x1403f5809
# 0x1401d2bf9 是不透明谓词!  真实跳转谓词: True 	0x1401d2bf9: jae 0x1402e7382
# 0x14015a7e3 是不透明谓词!  真实跳转谓词: True 	0x14015a7e3: jae 0x1403f5809
# 0x14015cd8c 是不透明谓词!  真实跳转谓词: True 	0x14015cd8c: jle 0x14038dc0c
# 0x14038dc9c 是不透明谓词!  真实跳转谓词: True 	0x14038dc9c: jnp 0x1401e560e
# 0x1403bcad8 是不透明谓词!  真实跳转谓词: True 	0x1403bcad8: jp 0x14034c307
# 0x140233725 是不透明谓词!  真实跳转谓词: True 	0x140233725: jno 0x140286966
# 0x140493bcb 是不透明谓词!  真实跳转谓词: True 	0x140493bcb: jae 0x1402b1343
# 0x14023a336 是不透明谓词!  真实跳转谓词: True 	0x14023a336: jb 0x14047eaa1
# 0x1403aaaee 是不透明谓词!  真实跳转谓词: True 	0x1403aaaee: jb 0x140449d60
# 0x140449d72 是不透明谓词!  真实跳转谓词: True 	0x140449d72: jnp 0x1404b0cac
# 0x1404b0cac 是不透明谓词!  真实跳转谓词: True 	0x1404b0cac: js 0x1404120d6
# 0x1402fc585 是不透明谓词!  真实跳转谓词: False 	0x1402fc585: jp 0x14040d584
# 0x1402644b7 是不透明谓词!  真实跳转谓词: True 	0x1402644b7: jg 0x140144720
# 0x140144756 是不透明谓词!  真实跳转谓词: True 	0x140144756: jge 0x140449d60
# 0x14046c9e5 是不透明谓词!  真实跳转谓词: True 	0x14046c9e5: jnp 0x14048c48f
# 0x1404385f3 是不透明谓词!  真实跳转谓词: False 	0x1404385f3: je 0x1404b44cb
# 0x1402f8e57 是不透明谓词!  真实跳转谓词: True 	0x1402f8e57: jb 0x14021599d
# 0x14021599d 是不透明谓词!  真实跳转谓词: True 	0x14021599d: jne 0x14016c3d4
# 0x14016c3ee 是不透明谓词!  真实跳转谓词: True 	0x14016c3ee: jne 0x14049495f
# 0x140494a1c 是不透明谓词!  真实跳转谓词: True 	0x140494a1c: jne 0x140449d60
# 0x1402e390b 是不透明谓词!  真实跳转谓词: False 	0x1402e390b: jge 0x1403124cc
# 0x1402e69f9 是不透明谓词!  真实跳转谓词: True 	0x1402e69f9: jl 0x14026a1c6
# 0x140261ac0 是不透明谓词!  真实跳转谓词: True 	0x140261ac0: jb 0x140449d60
# 0x14023cdd2 是不透明谓词!  真实跳转谓词: False 	0x14023cdd2: ja 0x14048a9e0
# 0x14023ce0c 是不透明谓词!  真实跳转谓词: True 	0x14023ce0c: jae 0x14031792a
# 0x140317945 是不透明谓词!  真实跳转谓词: True 	0x140317945: jne 0x140449d60
# 0x14035a9dc 是不透明谓词!  真实跳转谓词: False 	0x14035a9dc: jae 0x1403a0e5a
# 0x140249ce8 是不透明谓词!  真实跳转谓词: True 	0x140249ce8: js 0x140455786
# 0x1401de782 是不透明谓词!  真实跳转谓词: True 	0x1401de782: je 0x140174fd8
# 0x140175049 是不透明谓词!  真实跳转谓词: True 	0x140175049: ja 0x14045bd5a
# 0x14045bdba 是不透明谓词!  真实跳转谓词: True 	0x14045bdba: jns 0x140449d60
# 0x1401e6ae1 是不透明谓词!  真实跳转谓词: True 	0x1401e6ae1: ja 0x14014a57e
# 0x14014a581 是不透明谓词!  真实跳转谓词: True 	0x14014a581: ja 0x1401f20e6
# 0x1402a7d50 是不透明谓词!  真实跳转谓词: True 	0x1402a7d50: jl 0x1402f8178
# 0x140456500 是不透明谓词!  真实跳转谓词: True 	0x140456500: jge 0x1401ea705
# 0x140239d94 是不透明谓词!  真实跳转谓词: True 	0x140239d94: jae 0x14019a440
# 0x140132f14 是不透明谓词!  真实跳转谓词: True 	0x140132f14: js 0x140449d60
# 0x140326ff2 是不透明谓词!  真实跳转谓词: True 	0x140326ff2: jb 0x14049f983
# 0x14032c20b 是不透明谓词!  真实跳转谓词: True 	0x14032c20b: jae 0x140130c06
# 0x1404cba4a 是不透明谓词!  真实跳转谓词: True 	0x1404cba4a: jns 0x140257700
# 0x14025770c 是不透明谓词!  真实跳转谓词: True 	0x14025770c: jnp 0x14030cd5e
# 0x1404b2338 是不透明谓词!  真实跳转谓词: True 	0x1404b2338: ja 0x140449d60
# 0x140250fce 是不透明谓词!  真实跳转谓词: True 	0x140250fce: jo 0x140449d60
# 0x1401e2ddb 是不透明谓词!  真实跳转谓词: True 	0x1401e2ddb: jnp 0x140185c60
# 0x140185cce 是不透明谓词!  真实跳转谓词: True 	0x140185cce: jae 0x1404b03ed
# 0x1404b0471 是不透明谓词!  真实跳转谓词: False 	0x1404b0471: je 0x14045d525
# 0x14029f542 是不透明谓词!  真实跳转谓词: False 	0x14029f542: jb 0x140424355
# 0x1404850d6 是不透明谓词!  真实跳转谓词: False 	0x1404850d6: jb 0x1403b2530
# 0x1403578da 是不透明谓词!  真实跳转谓词: True 	0x1403578da: jp 0x140449d60
# 0x140294957 是不透明谓词!  真实跳转谓词: True 	0x140294957: jbe 0x140301543
# 0x14018debe 是不透明谓词!  真实跳转谓词: True 	0x14018debe: jle 0x14020107a
# ...
# 0x14045d718 是不透明谓词!  真实跳转谓词: True 	0x14045d718: jl 0x1403815c9
# 0x1402cf56e 是不透明谓词!  真实跳转谓词: True 	0x1402cf56e: jno 0x1404836ff
# 0x140483772 是不透明谓词!  真实跳转谓词: True 	0x140483772: js 0x14014f44e
# 0x1401bdf32 是不透明谓词!  真实跳转谓词: True 	0x1401bdf32: jg 0x140240ecc
# 0x14027b476 是不透明谓词!  真实跳转谓词: True 	0x14027b476: jle 0x14016037d
# 0x14020795a 是不透明谓词!  真实跳转谓词: True 	0x14020795a: jnp 0x14049ec48
# 0x14049ec6d 是不透明谓词!  真实跳转谓词: True 	0x14049ec6d: jnp 0x14017244f
# 0x1401ffd5b 是不透明谓词!  真实跳转谓词: False 	0x1401ffd5b: jo 0x14042432b
# 0x14024200d 是不透明谓词!  真实跳转谓词: True 	0x14024200d: jb 0x140414c6c
# 0x140414c85 是不透明谓词!  真实跳转谓词: True 	0x140414c85: jnp 0x1403f1f4c
# 0x140135ae8 是不透明谓词!  真实跳转谓词: True 	0x140135ae8: jg 0x140496bd4
# 0x140496bed 是不透明谓词!  真实跳转谓词: True 	0x140496bed: jl 0x14015cb17
# 0x14015cb83 是不透明谓词!  真实跳转谓词: False 	0x14015cb83: ja 0x140361cd1
# 0x140499bc7 是不透明谓词!  真实跳转谓词: True 	0x140499bc7: jno 0x14017d22a
# 0x1401787c9 是不透明谓词!  真实跳转谓词: True 	0x1401787c9: jno 0x14019397a
# 0x140193984 是不透明谓词!  真实跳转谓词: True 	0x140193984: jae 0x1402874c2
# 0x1402874f9 是不透明谓词!  真实跳转谓词: True 	0x1402874f9: ja 0x140144a4a
# 0x140167d54 是不透明谓词!  真实跳转谓词: True 	0x140167d54: jl 0x1403815c9
# 0x14047dd6e 是不透明谓词!  真实跳转谓词: True 	0x14047dd6e: js 0x1401e0729
# 0x1401e0758 是不透明谓词!  真实跳转谓词: True 	0x1401e0758: jno 0x1402f628b
# 0x1402f6383 是不透明谓词!  真实跳转谓词: True 	0x1402f6383: jae 0x1403815c9
# 0x14024f381 是不透明谓词!  真实跳转谓词: True 	0x14024f381: jp 0x14018cc04
# 0x14049c6a1 是不透明谓词!  真实跳转谓词: True 	0x14049c6a1: js 0x14022d19c
# 0x140128217 是不透明谓词!  真实跳转谓词: True 	0x140128217: jge 0x140467b2a
# 0x140136d03 是不透明谓词!  真实跳转谓词: True 	0x140136d03: jno 0x1401a59de
# 0x1401b618e 是不透明谓词!  真实跳转谓词: True 	0x1401b618e: jp 0x14020ef96
# 0x140241629 是不透明谓词!  真实跳转谓词: True 	0x140241629: jns 0x1404a15ac
# 0x1404a161c 是不透明谓词!  真实跳转谓词: True 	0x1404a161c: jbe 0x1403815c9
# 0x1402d500f 是不透明谓词!  真实跳转谓词: True 	0x1402d500f: jb 0x14032573c
# 0x140325754 是不透明谓词!  真实跳转谓词: True 	0x140325754: jbe 0x1404cac76
# 0x1404cac81 是不透明谓词!  真实跳转谓词: True 	0x1404cac81: jbe 0x14026cf90
# 0x140160114 是不透明谓词!  真实跳转谓词: True 	0x140160114: jb 0x1403815c9
# 0x140199f09 是不透明谓词!  真实跳转谓词: True 	0x140199f09: jb 0x1404d19cc
# 0x1404d19cc 是不透明谓词!  真实跳转谓词: True 	0x1404d19cc: jb 0x1402a0509
# 0x1402a051c 是不透明谓词!  真实跳转谓词: True 	0x1402a051c: jg 0x14024d0ee
# 0x14016395f 是不透明谓词!  真实跳转谓词: True 	0x14016395f: jg 0x14013e558
# 0x14013e55e 是不透明谓词!  真实跳转谓词: True 	0x14013e55e: jp 0x14023def1
# 0x14023df0a 是不透明谓词!  真实跳转谓词: True 	0x14023df0a: jne 0x1402f0491
# 0x14020c74d 是不透明谓词!  真实跳转谓词: True 	0x14020c74d: js 0x1403815c9
# 0x1402e6105 是不透明谓词!  真实跳转谓词: False 	0x1402e6105: jne 0x140190cc5
# 0x140298750 是不透明谓词!  真实跳转谓词: True 	0x140298750: jb 0x140455ede
# 0x1402ad825 是不透明谓词!  真实跳转谓词: True 	0x1402ad825: jl 0x1404a3a60
# 0x140495beb 是不透明谓词!  真实跳转谓词: False 	0x140495beb: jb 0x14015eefb
# 0x1402d1bba 是不透明谓词!  真实跳转谓词: True 	0x1402d1bba: jno 0x140315cda
# 0x140315cda 是不透明谓词!  真实跳转谓词: True 	0x140315cda: jl 0x14026e0b9
# 0x14026e0e7 是不透明谓词!  真实跳转谓词: True 	0x14026e0e7: ja 0x14013709c
# 0x14026856d 是不透明谓词!  真实跳转谓词: True 	0x14026856d: jnp 0x14018be7d
# 0x14018bec0 是不透明谓词!  真实跳转谓词: False 	0x14018bec0: jle 0x14012995a
# 0x14016187f 是不透明谓词!  真实跳转谓词: False 	0x14016187f: jo 0x1402be7c4
# 0x140148216 是不透明谓词!  真实跳转谓词: False 	0x140148216: jae 0x140235b0a
# 0x1401aeb44 是不透明谓词!  真实跳转谓词: True 	0x1401aeb44: jno 0x1403815c9
# 0x1402e1e96 是不透明谓词!  真实跳转谓词: True 	0x1402e1e96: jae 0x140447e98
# 0x140447f07 是不透明谓词!  真实跳转谓词: True 	0x140447f07: jae 0x14017fe15
# 0x140272e51 是不透明谓词!  真实跳转谓词: True 	0x140272e51: js 0x140226856
# 0x14022686e 是不透明谓词!  真实跳转谓词: True 	0x14022686e: jns 0x14043ddb0
# 0x1401a5da7 是不透明谓词!  真实跳转谓词: False 	0x1401a5da7: je 0x1401baa11
# 0x14025ddbe 是不透明谓词!  真实跳转谓词: True 	0x14025ddbe: jbe 0x1402766e0
# 0x1402a4e2d 是不透明谓词!  真实跳转谓词: True 	0x1402a4e2d: jnp 0x14048bc85
# 0x140473cd2 是不透明谓词!  真实跳转谓词: False 	0x140473cd2: jo 0x14038dc0c
# 0x140473cd8 是不透明谓词!  真实跳转谓词: True 	0x140473cd8: jno 0x14022c5cf
# 0x1404607c5 是不透明谓词!  真实跳转谓词: True 	0x1404607c5: jb 0x1402cbbaf
# 0x14024bf0d 是不透明谓词!  真实跳转谓词: True 	0x14024bf0d: jae 0x1403a1b10
# 0x140154b6d 是不透明谓词!  真实跳转谓词: False 	0x140154b6d: jo 0x14043b6a8
# 0x140311ddc 是不透明谓词!  真实跳转谓词: True 	0x140311ddc: jo 0x14019590b
# 0x1404cbdce 是不透明谓词!  真实跳转谓词: False 	0x1404cbdce: jb 0x140248de1
# 0x1401e6c91 是不透明谓词!  真实跳转谓词: True 	0x1401e6c91: jns 0x140139f74
# 0x140139fb6 是不透明谓词!  真实跳转谓词: True 	0x140139fb6: jns 0x1401ec81c
# 0x1404b91f6 是不透明谓词!  真实跳转谓词: False 	0x1404b91f6: jns 0x1403cebc6
# 0x1404b91fc 是不透明谓词!  真实跳转谓词: True 	0x1404b91fc: jp 0x14017a14c
# 0x14017a157 是不透明谓词!  真实跳转谓词: True 	0x14017a157: jge 0x14012aacb
# 0x14012aacd 是不透明谓词!  真实跳转谓词: True 	0x14012aacd: je 0x14030b1f3
# 0x1402e51e2 是不透明谓词!  真实跳转谓词: True 	0x1402e51e2: ja 0x1404a67ce
# 0x1403c0f41 是不透明谓词!  真实跳转谓词: False 	0x1403c0f41: jnp 0x14033196e
# 0x1401fc259 是不透明谓词!  真实跳转谓词: False 	0x1401fc259: jbe 0x1402ee53f
# 0x1404aaa61 是不透明谓词!  真实跳转谓词: True 	0x1404aaa61: jnp 0x1401a4aac
# 0x1404111b3 是不透明谓词!  真实跳转谓词: True 	0x1404111b3: jnp 0x1401b1576
# 0x1401f7fa1 是不透明谓词!  真实跳转谓词: True 	0x1401f7fa1: js 0x14030b1f3
# 0x14043e969 是不透明谓词!  真实跳转谓词: True 	0x14043e969: ja 0x14030b1f3
# 0x14032a7d0 是不透明谓词!  真实跳转谓词: True 	0x14032a7d0: jg 0x140182f7f
# 0x140442e45 是不透明谓词!  真实跳转谓词: True 	0x140442e45: jne 0x140466752
# 0x140466755 是不透明谓词!  真实跳转谓词: True 	0x140466755: jb 0x14015dfdb
# 0x14015e019 是不透明谓词!  真实跳转谓词: True 	0x14015e019: jb 0x14025953d
# 0x1402940fb 是不透明谓词!  真实跳转谓词: True 	0x1402940fb: jae 0x14019e4b8
# 0x14019e4dc 是不透明谓词!  真实跳转谓词: True 	0x14019e4dc: jno 0x1401f90b5
# 0x1401f90be 是不透明谓词!  真实跳转谓词: True 	0x1401f90be: jns 0x14029185b
# 0x140254a00 是不透明谓词!  真实跳转谓词: True 	0x140254a00: jg 0x14030b1f3
# 0x1401aac19 是不透明谓词!  真实跳转谓词: True 	0x1401aac19: jle 0x14027174c
# 0x14027175c 是不透明谓词!  真实跳转谓词: True 	0x14027175c: ja 0x1402f95dd
# 0x14015ded0 是不透明谓词!  真实跳转谓词: False 	0x14015ded0: jl 0x1401b87bb
# 0x1401cadbd 是不透明谓词!  真实跳转谓词: True 	0x1401cadbd: jne 0x14030b1f3
# 0x1401b8416 是不透明谓词!  真实跳转谓词: False 	0x1401b8416: js 0x14045cd0a
# 0x1402a71a6 是不透明谓词!  真实跳转谓词: False 	0x1402a71a6: jo 0x14042a14a
# 0x14020c843 是不透明谓词!  真实跳转谓词: True 	0x14020c843: jae 0x1404309cd
# 0x1404309e2 是不透明谓词!  真实跳转谓词: True 	0x1404309e2: jno 0x14030b1f3
# 0x14018d547 是不透明谓词!  真实跳转谓词: True 	0x14018d547: jns 0x1402f283a
# 0x1402f286c 是不透明谓词!  真实跳转谓词: True 	0x1402f286c: jns 0x1402682f5
# 0x14026831f 是不透明谓词!  真实跳转谓词: False 	0x14026831f: jo 0x140368579
# 0x14047291b 是不透明谓词!  真实跳转谓词: True 	0x14047291b: jp 0x14030b1f3
# 0x140233d5a 是不透明谓词!  真实跳转谓词: True 	0x140233d5a: jp 0x14020f8f2
# 0x14020f8f2 是不透明谓词!  真实跳转谓词: True 	0x14020f8f2: je 0x1401ec6e4
# 0x1401ec6e4 是不透明谓词!  真实跳转谓词: True 	0x1401ec6e4: jae 0x14049ea5d
# 0x14049ea61 是不透明谓词!  真实跳转谓词: True 	0x14049ea61: jp 0x140466c0c
# 0x140466c1b 是不透明谓词!  真实跳转谓词: False 	0x140466c1b: je 0x1401e17cf
# 0x140466cb6 是不透明谓词!  真实跳转谓词: True 	0x140466cb6: jae 0x14030b1f3
# 0x14026497f 是不透明谓词!  真实跳转谓词: True 	0x14026497f: ja 0x14029177c
# 0x1402917f1 是不透明谓词!  真实跳转谓词: True 	0x1402917f1: jno 0x1403a14aa
# 0x1403a14d3 是不透明谓词!  真实跳转谓词: True 	0x1403a14d3: jae 0x140371bf6
# 0x14027cdb3 是不透明谓词!  真实跳转谓词: False 	0x14027cdb3: jae 0x140302978
# 0x1403c53b4 是不透明谓词!  真实跳转谓词: True 	0x1403c53b4: jne 0x140407d6a
# 0x1403cad6b 是不透明谓词!  真实跳转谓词: True 	0x1403cad6b: jae 0x140457b60
# 0x1401dab52 是不透明谓词!  真实跳转谓词: True 	0x1401dab52: jae 0x14025338c
# 0x140253391 是不透明谓词!  真实跳转谓词: True 	0x140253391: jae 0x14024dbb5
# 0x14024dbb5 是不透明谓词!  真实跳转谓词: True 	0x14024dbb5: jae 0x14023d6df
# 0x14017d84e 是不透明谓词!  真实跳转谓词: True 	0x14017d84e: jne 0x1401415e3
# 0x140141649 是不透明谓词!  真实跳转谓词: True 	0x140141649: jae 0x1402366c4
# 0x140243d43 是不透明谓词!  真实跳转谓词: True 	0x140243d43: jne 0x1401ca7e7
# 0x140201609 是不透明谓词!  真实跳转谓词: True 	0x140201609: jae 0x1404b475e
# 0x140220fd1 是不透明谓词!  真实跳转谓词: True 	0x140220fd1: jle 0x140323075
# 0x140323082 是不透明谓词!  真实跳转谓词: False 	0x140323082: je 0x1402ec1da
# 0x1403230d4 是不透明谓词!  真实跳转谓词: True 	0x1403230d4: ja 0x140434cd8
# 0x140257657 是不透明谓词!  真实跳转谓词: False 	0x140257657: jb 0x140315d10
# 0x140257680 是不透明谓词!  真实跳转谓词: True 	0x140257680: jae 0x14033fb8b
# 0x1403a0070 是不透明谓词!  真实跳转谓词: False 	0x1403a0070: jae 0x14025207c
# 0x1401bac65 是不透明谓词!  真实跳转谓词: True 	0x1401bac65: js 0x1404507d6
# 0x1404507d6 是不透明谓词!  真实跳转谓词: True 	0x1404507d6: jbe 0x14031ed1b
# 0x14031ed3b 是不透明谓词!  真实跳转谓词: True 	0x14031ed3b: jae 0x140244282
# 0x1401db45d 是不透明谓词!  真实跳转谓词: False 	0x1401db45d: jae 0x140405020
# 0x140233255 是不透明谓词!  真实跳转谓词: True 	0x140233255: jl 0x140311a07
# 0x14019d9cf 是不透明谓词!  真实跳转谓词: True 	0x14019d9cf: jne 0x14017528b
# 0x140151d0e 是不透明谓词!  真实跳转谓词: True 	0x140151d0e: jae 0x14017528b
# 0x1401dd590 是不透明谓词!  真实跳转谓词: False 	0x1401dd590: js 0x140418f49
# 0x140243fb7 是不透明谓词!  真实跳转谓词: True 	0x140243fb7: jne 0x14041d0b0
# 0x14041d0cb 是不透明谓词!  真实跳转谓词: False 	0x14041d0cb: jbe 0x1403618cf
# 0x1401b2b43 是不透明谓词!  真实跳转谓词: True 	0x1401b2b43: jno 0x14017528b
# 0x140318e36 是不透明谓词!  真实跳转谓词: False 	0x140318e36: jb 0x1403f87ef
# 0x14023d426 是不透明谓词!  真实跳转谓词: False 	0x14023d426: jo 0x140267442
# 0x14018527e 是不透明谓词!  真实跳转谓词: True 	0x14018527e: jnp 0x14040ff81
# 0x1401cd6e7 是不透明谓词!  真实跳转谓词: True 	0x1401cd6e7: jae 0x14017528b
# 0x1403eb6b6 是不透明谓词!  真实跳转谓词: True 	0x1403eb6b6: jnp 0x140428e5e
# 0x140428eb5 是不透明谓词!  真实跳转谓词: True 	0x140428eb5: jno 0x14016ab37
# 0x140474347 是不透明谓词!  真实跳转谓词: True 	0x140474347: ja 0x1404ab8bc
# 0x1404ab902 是不透明谓词!  真实跳转谓词: True 	0x1404ab902: jae 0x140231245
# 0x1403f37fb 是不透明谓词!  真实跳转谓词: True 	0x1403f37fb: jae 0x14018c0a9
# 0x140412d5b 是不透明谓词!  真实跳转谓词: True 	0x140412d5b: jge 0x14046a5f1
# 0x140366bf5 是不透明谓词!  真实跳转谓词: False 	0x140366bf5: je 0x140224d11
# 0x140419d80 是不透明谓词!  真实跳转谓词: False 	0x140419d80: jb 0x1403dd682
# 0x140419e37 是不透明谓词!  真实跳转谓词: True 	0x140419e37: jae 0x14017528b
# 0x1402b4a2d 是不透明谓词!  真实跳转谓词: True 	0x1402b4a2d: jae 0x14049b2f2
# 0x14019ef63 是不透明谓词!  真实跳转谓词: True 	0x14019ef63: jno 0x14017528b
# 0x1403224f2 是不透明谓词!  真实跳转谓词: False 	0x1403224f2: jo 0x1404bd9d3
# 0x1402a21a4 是不透明谓词!  真实跳转谓词: True 	0x1402a21a4: jae 0x14017528b
# 0x140332218 是不透明谓词!  真实跳转谓词: False 	0x140332218: ja 0x1403076ba
# 0x140200951 是不透明谓词!  真实跳转谓词: True 	0x140200951: jne 0x14035b953
# 0x14035b97f 是不透明谓词!  真实跳转谓词: True 	0x14035b97f: jns 0x1403e4988
# 0x1403e498e 是不透明谓词!  真实跳转谓词: True 	0x1403e498e: jp 0x14020e9de
# 0x1402b8b4d 是不透明谓词!  真实跳转谓词: True 	0x1402b8b4d: jae 0x140448b69
# 0x14021b340 是不透明谓词!  真实跳转谓词: True 	0x14021b340: jno 0x14020cdc5
# 0x14020ce4d 是不透明谓词!  真实跳转谓词: True 	0x14020ce4d: jb 0x140304370
# 0x14025d9ed 是不透明谓词!  真实跳转谓词: True 	0x14025d9ed: jnp 0x140213b6a
# 0x140213b75 是不透明谓词!  真实跳转谓词: True 	0x140213b75: jl 0x14015405e
# 0x1401e4577 是不透明谓词!  真实跳转谓词: True 	0x1401e4577: jns 0x14017528b
# 0x1401f38b8 是不透明谓词!  真实跳转谓词: True 	0x1401f38b8: jb 0x14017528b
# 0x1403f9789 是不透明谓词!  真实跳转谓词: True 	0x1403f9789: jp 0x140322dc3
# 0x140322dc4 是不透明谓词!  真实跳转谓词: True 	0x140322dc4: jp 0x14017528b
# 0x14017b91c 是不透明谓词!  真实跳转谓词: False 	0x14017b91c: jo 0x14015c243
# 0x1401761f7 是不透明谓词!  真实跳转谓词: True 	0x1401761f7: jb 0x1401b0cb2
# 0x140257181 是不透明谓词!  真实跳转谓词: True 	0x140257181: jne 0x14016b24e
# 0x14016b24e 是不透明谓词!  真实跳转谓词: True 	0x14016b24e: ja 0x1404b3737
# 0x1404b3770 是不透明谓词!  真实跳转谓词: True 	0x1404b3770: ja 0x14017528b
# 0x14015de72 是不透明谓词!  真实跳转谓词: True 	0x14015de72: jge 0x14044c0da
# 0x14047ddfc 是不透明谓词!  真实跳转谓词: True 	0x14047ddfc: jns 0x1401d705c
# 0x1401d7099 是不透明谓词!  真实跳转谓词: True 	0x1401d7099: jns 0x1401e1cf6
# 0x1401e1d60 是不透明谓词!  真实跳转谓词: True 	0x1401e1d60: jae 0x14030757d
# 0x1403075bd 是不透明谓词!  真实跳转谓词: True 	0x1403075bd: jae 0x14017528b
# 0x1403ffb71 是不透明谓词!  真实跳转谓词: False 	0x1403ffb71: jb 0x1403b61af
# 0x1403e80be 是不透明谓词!  真实跳转谓词: True 	0x1403e80be: jge 0x1403e0ab0
# 0x14016856d 是不透明谓词!  真实跳转谓词: False 	0x14016856d: js 0x140127eec
# 0x14047cce9 是不透明谓词!  真实跳转谓词: True 	0x14047cce9: jno 0x1402dda34
# 0x1404baf81 是不透明谓词!  真实跳转谓词: True 	0x1404baf81: jle 0x1401ae9a2
# 0x1401ae9bc 是不透明谓词!  真实跳转谓词: True 	0x1401ae9bc: jnp 0x14017528b
# 0x1403d2e33 是不透明谓词!  真实跳转谓词: True 	0x1403d2e33: jae 0x14037f832
# 0x1402d8223 是不透明谓词!  真实跳转谓词: False 	0x1402d8223: jo 0x14041da1e
# 0x14044359a 是不透明谓词!  真实跳转谓词: True 	0x14044359a: js 0x14017528b
# 0x140265571 是不透明谓词!  真实跳转谓词: False 	0x140265571: jb 0x1403cebd6
# 0x1402655f8 是不透明谓词!  真实跳转谓词: False 	0x1402655f8: jb 0x140405c20
# 0x14026563b 是不透明谓词!  真实跳转谓词: True 	0x14026563b: jp 0x140303dcd
# 0x14016c3a8 是不透明谓词!  真实跳转谓词: True 	0x14016c3a8: jnp 0x1403b8c1c
# 0x14043fed3 是不透明谓词!  真实跳转谓词: False 	0x14043fed3: jae 0x140386515
# 0x14043ff03 是不透明谓词!  真实跳转谓词: False 	0x14043ff03: js 0x14042dc68
# 0x14043ff09 是不透明谓词!  真实跳转谓词: True 	0x14043ff09: jp 0x1402e6dbb
# 0x1402bc74c 是不透明谓词!  真实跳转谓词: True 	0x1402bc74c: jle 0x140491f32
# 0x140491f5f 是不透明谓词!  真实跳转谓词: True 	0x140491f5f: jp 0x14017528b
# 0x1401feb81 是不透明谓词!  真实跳转谓词: True 	0x1401feb81: jae 0x1402ba51e
# 0x14012a94a 是不透明谓词!  真实跳转谓词: True 	0x14012a94a: jae 0x140139fbc
# 0x140278c96 是不透明谓词!  真实跳转谓词: False 	0x140278c96: jb 0x1403392d9
# 0x140278cd6 是不透明谓词!  真实跳转谓词: True 	0x140278cd6: jge 0x1402b6c02
# 0x1402fc712 是不透明谓词!  真实跳转谓词: True 	0x1402fc712: jbe 0x1402ab24e
# 0x1403695d1 是不透明谓词!  真实跳转谓词: True 	0x1403695d1: jl 0x14017528b
# 0x1401534ce 是不透明谓词!  真实跳转谓词: True 	0x1401534ce: jle 0x14041fa28
# 0x14041fa51 是不透明谓词!  真实跳转谓词: True 	0x14041fa51: jne 0x14015e1bb
# 0x1404cfea8 是不透明谓词!  真实跳转谓词: True 	0x1404cfea8: jne 0x14025fb53
# 0x140229daf 是不透明谓词!  真实跳转谓词: True 	0x140229daf: jne 0x14015b463
# 0x14015b4f7 是不透明谓词!  真实跳转谓词: True 	0x14015b4f7: jae 0x14031e9db
# 0x14031ea24 是不透明谓词!  真实跳转谓词: True 	0x14031ea24: jns 0x14017528b
# 0x14023680b 是不透明谓词!  真实跳转谓词: True 	0x14023680b: jnp 0x140439dad
# 0x14019df46 是不透明谓词!  真实跳转谓词: True 	0x14019df46: jae 0x14024c79c
# 0x1401aef37 是不透明谓词!  真实跳转谓词: True 	0x1401aef37: jge 0x1402dc843
# 0x1402dc84e 是不透明谓词!  真实跳转谓词: True 	0x1402dc84e: jns 0x14017528b
# 0x1401b9da0 是不透明谓词!  真实跳转谓词: True 	0x1401b9da0: jne 0x14049d45a
# 0x14049d483 是不透明谓词!  真实跳转谓词: False 	0x14049d483: js 0x1402c3ce2
# 0x140490a57 是不透明谓词!  真实跳转谓词: True 	0x140490a57: jae 0x1404464cd
# 0x1404464df 是不透明谓词!  真实跳转谓词: True 	0x1404464df: jns 0x14019dfe7
# 0x14019e0bc 是不透明谓词!  真实跳转谓词: True 	0x14019e0bc: je 0x14017528b
# 0x1403b5b68 是不透明谓词!  真实跳转谓词: True 	0x1403b5b68: jns 0x140447568
# 0x1403b6f21 是不透明谓词!  真实跳转谓词: True 	0x1403b6f21: jno 0x14016af8b
# 0x14016afe0 是不透明谓词!  真实跳转谓词: True 	0x14016afe0: jnp 0x14017528b
# 0x1401cbb27 是不透明谓词!  真实跳转谓词: True 	0x1401cbb27: jl 0x1401f385a
# 0x1404557f0 是不透明谓词!  真实跳转谓词: True 	0x1404557f0: jb 0x14047b198
# 0x14042b25b 是不透明谓词!  真实跳转谓词: True 	0x14042b25b: jae 0x14029c23a
# 0x14047d9e9 是不透明谓词!  真实跳转谓词: True 	0x14047d9e9: jg 0x1404b2386
# 0x1404b23d3 是不透明谓词!  真实跳转谓词: True 	0x1404b23d3: jg 0x1402dc271
# 0x140427f94 是不透明谓词!  真实跳转谓词: True 	0x140427f94: jne 0x14041aafa
# 0x1404881cc 是不透明谓词!  真实跳转谓词: True 	0x1404881cc: jne 0x14012685e
# 0x1401268a7 是不透明谓词!  真实跳转谓词: True 	0x1401268a7: ja 0x14017528b
# 0x14014760b 是不透明谓词!  真实跳转谓词: True 	0x14014760b: jb 0x14028bd84
# 0x140238be7 是不透明谓词!  真实跳转谓词: False 	0x140238be7: jae 0x1402b1c44
# 0x1401b1fb5 是不透明谓词!  真实跳转谓词: True 	0x1401b1fb5: jae 0x14017528b
# 0x14044ec29 是不透明谓词!  真实跳转谓词: True 	0x14044ec29: jns 0x14013eeee
# 0x14042a1d5 是不透明谓词!  真实跳转谓词: True 	0x14042a1d5: jg 0x1404446ac
# 0x1401e9634 是不透明谓词!  真实跳转谓词: True 	0x1401e9634: jns 0x14047417b
# 0x1404741c1 是不透明谓词!  真实跳转谓词: True 	0x1404741c1: jnp 0x140175dd9
# 0x140175dde 是不透明谓词!  真实跳转谓词: True 	0x140175dde: js 0x14017528b
# 0x1402f83c1 是不透明谓词!  真实跳转谓词: False 	0x1402f83c1: jbe 0x1404058bf
# 0x14025e00c 是不透明谓词!  真实跳转谓词: True 	0x14025e00c: jle 0x14017528b
# 0x140181b25 是不透明谓词!  真实跳转谓词: True 	0x140181b25: jb 0x14033fb8b
# 0x1401434b4 是不透明谓词!  真实跳转谓词: True 	0x1401434b4: jae 0x14024033d
# 0x140265cec 是不透明谓词!  真实跳转谓词: True 	0x140265cec: jle 0x1404191bb
# 0x1404191ff 是不透明谓词!  真实跳转谓词: True 	0x1404191ff: jge 0x1402569ac
# 0x1402569d1 是不透明谓词!  真实跳转谓词: True 	0x1402569d1: jae 0x14024033d
# 0x1404b5471 是不透明谓词!  真实跳转谓词: True 	0x1404b5471: jno 0x14031a46d
# 0x14031a479 是不透明谓词!  真实跳转谓词: True 	0x14031a479: jb 0x1401569ad
# 0x1401569e0 是不透明谓词!  真实跳转谓词: True 	0x1401569e0: jne 0x14045dd89
# 0x14045ddb1 是不透明谓词!  真实跳转谓词: True 	0x14045ddb1: js 0x14024033d
# 0x14028a030 是不透明谓词!  真实跳转谓词: True 	0x14028a030: jae 0x140437cac
# 0x140437cfb 是不透明谓词!  真实跳转谓词: False 	0x140437cfb: js 0x1402de1a9
# 0x140437d3f 是不透明谓词!  真实跳转谓词: True 	0x140437d3f: jp 0x140146b46
# 0x140146b73 是不透明谓词!  真实跳转谓词: True 	0x140146b73: ja 0x1404594dc
# 0x140459505 是不透明谓词!  真实跳转谓词: True 	0x140459505: jbe 0x14024033d
# 0x14041c459 是不透明谓词!  真实跳转谓词: False 	0x14041c459: jo 0x1403e3f86
# 0x14041c488 是不透明谓词!  真实跳转谓词: True 	0x14041c488: jb 0x14024033d

# %%
# 生成不透明谓词的x64dbg还原脚本
for ins in record:
    if (hasattr(ins, "obfOPStatus") and ins.obfOPStatus == True):
        print(f"memset {hex(ins.ins_address)},0x90,{hex(len(ins.bytes))}")
        if (ins.obfOPCondTaken):
            ops = ins.ttins.getOperands()
            immop: triton.Immediate = ops[0]
            writestr = f"jmp {hex(immop.getValue())}"
            bys = asmDecode(writestr, ins.ins_address)
            print(writeBytesX64dbg(ins.ins_address, bys))

# %%
for ins in record:
    if (hasattr(ins, "obfIndirectStatus") and ins.obfIndirectStatus == True):
        print(f"{hex(ins.ins_address)} 是间接跳转混淆!  真实跳转地址: {hex(ins.obfIndirectAddr)} \t{ins.ttins}")
# Out:
# 0x140401020 是间接跳转混淆!  真实跳转地址: 0x14026b27b 	0x140401020: jmp r8
# 0x140223ef7 是间接跳转混淆!  真实跳转地址: 0x1402a3eb0 	0x140223ef7: jmp r11
# 0x14019995b 是间接跳转混淆!  真实跳转地址: 0x14031c143 	0x14019995b: jmp r8
# 0x1401f5c4d 是间接跳转混淆!  真实跳转地址: 0x140429e53 	0x1401f5c4d: jmp rdx
# 0x14028baba 是间接跳转混淆!  真实跳转地址: 0x1401b84d1 	0x14028baba: jmp r11
# 0x140307391 是间接跳转混淆!  真实跳转地址: 0x14015f51f 	0x140307391: jmp rbx
# 0x140199be7 是间接跳转混淆!  真实跳转地址: 0x140141f4b 	0x140199be7: jmp r8
# 0x140269424 是间接跳转混淆!  真实跳转地址: 0x14047aed0 	0x140269424: jmp rax
# 0x14014393c 是间接跳转混淆!  真实跳转地址: 0x1404a857f 	0x14014393c: jmp r11
# 0x14017b159 是间接跳转混淆!  真实跳转地址: 0x140260e2d 	0x14017b159: jmp rsi
# 0x1402ff6ce 是间接跳转混淆!  真实跳转地址: 0x1403e8773 	0x1402ff6ce: jmp rbx
# 0x1401ffc1d 是间接跳转混淆!  真实跳转地址: 0x140382ef7 	0x1401ffc1d: jmp rcx
# 0x14018df7d 是间接跳转混淆!  真实跳转地址: 0x140377910 	0x14018df7d: jmp rcx
# 0x1402deff7 是间接跳转混淆!  真实跳转地址: 0x1401f8fd3 	0x1402deff7: jmp r11
# 0x1401664b7 是间接跳转混淆!  真实跳转地址: 0x14041b2c6 	0x1401664b7: jmp rdx
# 0x14020e3c8 是间接跳转混淆!  真实跳转地址: 0x140295b92 	0x14020e3c8: jmp rsi
# 0x14044ac35 是间接跳转混淆!  真实跳转地址: 0x1404a7148 	0x14044ac35: jmp rdx
# 0x140181da0 是间接跳转混淆!  真实跳转地址: 0x1403e8e98 	0x140181da0: jmp rdx
# 0x1401c3ac9 是间接跳转混淆!  真实跳转地址: 0x140275283 	0x1401c3ac9: jmp rbx
# 0x1404095da 是间接跳转混淆!  真实跳转地址: 0x140186f97 	0x1404095da: jmp rdi
# 0x14044d51c 是间接跳转混淆!  真实跳转地址: 0x140454124 	0x14044d51c: jmp rbx
# 0x140480b88 是间接跳转混淆!  真实跳转地址: 0x140177a28 	0x140480b88: jmp rbx
# 0x140149ea8 是间接跳转混淆!  真实跳转地址: 0x1402767ea 	0x140149ea8: jmp rax
# 0x140160ec1 是间接跳转混淆!  真实跳转地址: 0x140205f95 	0x140160ec1: jmp rdi
# 0x14031fd3f 是间接跳转混淆!  真实跳转地址: 0x140166a42 	0x14031fd3f: jmp rcx
# 0x14043c3a8 是间接跳转混淆!  真实跳转地址: 0x140180d3d 	0x14043c3a8: jmp rcx
# 0x140490317 是间接跳转混淆!  真实跳转地址: 0x1402c6cb8 	0x140490317: jmp rbx
# 0x140295926 是间接跳转混淆!  真实跳转地址: 0x140293a1f 	0x140295926: jmp rcx
# 0x1402528c6 是间接跳转混淆!  真实跳转地址: 0x1404870f3 	0x1402528c6: jmp r9
# 0x1404a6d6b 是间接跳转混淆!  真实跳转地址: 0x140493fc5 	0x1404a6d6b: jmp rax
# 0x1401fe617 是间接跳转混淆!  真实跳转地址: 0x1401aecab 	0x1401fe617: jmp rdi
# 0x140451b34 是间接跳转混淆!  真实跳转地址: 0x140443d64 	0x140451b34: jmp rax
# 0x140426fbd 是间接跳转混淆!  真实跳转地址: 0x140294de2 	0x140426fbd: jmp rcx
# 0x1402997a0 是间接跳转混淆!  真实跳转地址: 0x1401cfab5 	0x1402997a0: jmp rdi
# 0x1404245d8 是间接跳转混淆!  真实跳转地址: 0x140478c43 	0x1404245d8: jmp rbp
# 0x1402fbfe5 是间接跳转混淆!  真实跳转地址: 0x140129a10 	0x1402fbfe5: jmp r9
# 0x14044c541 是间接跳转混淆!  真实跳转地址: 0x1401447c8 	0x14044c541: jmp rdx
# 0x1402e8bbd 是间接跳转混淆!  真实跳转地址: 0x1404575e0 	0x1402e8bbd: jmp r9
# 0x140225ada 是间接跳转混淆!  真实跳转地址: 0x140322311 	0x140225ada: jmp rbp
# 0x1404acea3 是间接跳转混淆!  真实跳转地址: 0x1401fd44f 	0x1404acea3: jmp rbx
# 0x14031c0c3 是间接跳转混淆!  真实跳转地址: 0x1404c2dfc 	0x14031c0c3: jmp rbx
# 0x140203f4e 是间接跳转混淆!  真实跳转地址: 0x1404970f4 	0x140203f4e: jmp rdi
# 0x14015f6cd 是间接跳转混淆!  真实跳转地址: 0x1402db56f 	0x14015f6cd: jmp rax
# 0x140252092 是间接跳转混淆!  真实跳转地址: 0x140477442 	0x140252092: jmp rbp
# 0x14042f5b4 是间接跳转混淆!  真实跳转地址: 0x140422751 	0x14042f5b4: jmp rbp
# 0x1404814e0 是间接跳转混淆!  真实跳转地址: 0x140450be8 	0x1404814e0: jmp rbp
# 0x1402b0050 是间接跳转混淆!  真实跳转地址: 0x1401e7287 	0x1402b0050: jmp rcx
# 0x140309d6d 是间接跳转混淆!  真实跳转地址: 0x140412650 	0x140309d6d: jmp rbp
# 0x14016e7ea 是间接跳转混淆!  真实跳转地址: 0x1402b8aaa 	0x14016e7ea: jmp rdi
# 0x1401c6372 是间接跳转混淆!  真实跳转地址: 0x14025d23a 	0x1401c6372: jmp r9
# 0x14041878a 是间接跳转混淆!  真实跳转地址: 0x14027c623 	0x14041878a: jmp rbx
# 0x140217dc5 是间接跳转混淆!  真实跳转地址: 0x14032257e 	0x140217dc5: jmp rax
# 0x1401c49f1 是间接跳转混淆!  真实跳转地址: 0x14019f46b 	0x1401c49f1: jmp r10
# 0x14028618e 是间接跳转混淆!  真实跳转地址: 0x1401fcf19 	0x14028618e: jmp rbp
# 0x1404cb9ef 是间接跳转混淆!  真实跳转地址: 0x1402c0f00 	0x1404cb9ef: jmp rdx
# 0x1402c8789 是间接跳转混淆!  真实跳转地址: 0x14020f214 	0x1402c8789: jmp rcx
# 0x140137665 是间接跳转混淆!  真实跳转地址: 0x14045e0be 	0x140137665: jmp rdx
# 0x140456b3f 是间接跳转混淆!  真实跳转地址: 0x1404a7104 	0x140456b3f: jmp rcx
# 0x1404adcec 是间接跳转混淆!  真实跳转地址: 0x1404cd210 	0x1404adcec: jmp rbx
# 0x1401a4c42 是间接跳转混淆!  真实跳转地址: 0x140242a57 	0x1401a4c42: jmp rbx
# 0x14048f4cd 是间接跳转混淆!  真实跳转地址: 0x1402d5053 	0x14048f4cd: jmp rbp
# 0x14031b7ef 是间接跳转混淆!  真实跳转地址: 0x14045d447 	0x14031b7ef: jmp r10
# 0x1401a1841 是间接跳转混淆!  真实跳转地址: 0x140133435 	0x1401a1841: jmp rax
# 0x1401dd300 是间接跳转混淆!  真实跳转地址: 0x140473c98 	0x1401dd300: jmp rbx
# 0x1402f2ffd 是间接跳转混淆!  真实跳转地址: 0x140322815 	0x1402f2ffd: jmp rbx
# 0x14018c556 是间接跳转混淆!  真实跳转地址: 0x1404b4f0e 	0x14018c556: jmp rbp
# 0x140431c6d 是间接跳转混淆!  真实跳转地址: 0x1401c288a 	0x140431c6d: jmp r10
# 0x1401ba9d4 是间接跳转混淆!  真实跳转地址: 0x1404899bd 	0x1401ba9d4: jmp r9
# 0x1404899d0 是间接跳转混淆!  真实跳转地址: 0x14045322e 	0x1404899d0: jmp r8
# 0x1403bdda4 是间接跳转混淆!  真实跳转地址: 0x14013f972 	0x1403bdda4: jmp rdx
# 0x140281eab 是间接跳转混淆!  真实跳转地址: 0x1402ae85c 	0x140281eab: jmp r10
# 0x1401e1a01 是间接跳转混淆!  真实跳转地址: 0x1404b77be 	0x1401e1a01: jmp rbp
# 0x14019e205 是间接跳转混淆!  真实跳转地址: 0x140186f32 	0x14019e205: jmp rbx
# 0x1401c9068 是间接跳转混淆!  真实跳转地址: 0x14022020d 	0x1401c9068: jmp rcx
# 0x140284d65 是间接跳转混淆!  真实跳转地址: 0x1401e48a6 	0x140284d65: jmp rcx
# 0x140266d7d 是间接跳转混淆!  真实跳转地址: 0x14047abb9 	0x140266d7d: jmp rbx
# 0x1402b15ed 是间接跳转混淆!  真实跳转地址: 0x14032e058 	0x1402b15ed: jmp rbp
# 0x1401b2be2 是间接跳转混淆!  真实跳转地址: 0x140237690 	0x1401b2be2: jmp rdx
# 0x140277c8d 是间接跳转混淆!  真实跳转地址: 0x1401aff36 	0x140277c8d: jmp r8
# 0x14048f622 是间接跳转混淆!  真实跳转地址: 0x140440327 	0x14048f622: jmp rax
# 0x1404aa813 是间接跳转混淆!  真实跳转地址: 0x1402c2c75 	0x1404aa813: jmp rax
# 0x140161daf 是间接跳转混淆!  真实跳转地址: 0x1403710a4 	0x140161daf: jmp rdx
# 0x1402197af 是间接跳转混淆!  真实跳转地址: 0x1401d036f 	0x1402197af: jmp rcx
# 0x1402a2109 是间接跳转混淆!  真实跳转地址: 0x140247bed 	0x1402a2109: jmp rdx
# 0x14048cfea 是间接跳转混淆!  真实跳转地址: 0x14025a7e7 	0x14048cfea: jmp rcx
# 0x1403b0a16 是间接跳转混淆!  真实跳转地址: 0x1401b4bb0 	0x1403b0a16: jmp rcx
# 0x140263048 是间接跳转混淆!  真实跳转地址: 0x1404487a0 	0x140263048: jmp rax
# 0x1404b034f 是间接跳转混淆!  真实跳转地址: 0x1401d2bbb 	0x1404b034f: jmp rbp
# 0x1402ca2b4 是间接跳转混淆!  真实跳转地址: 0x14015a7bc 	0x1402ca2b4: jmp rdx
# 0x1404597a8 是间接跳转混淆!  真实跳转地址: 0x1403845b3 	0x1404597a8: jmp r10
# 0x14048327a 是间接跳转混淆!  真实跳转地址: 0x1401f2dc1 	0x14048327a: jmp rdx
# 0x1402c5046 是间接跳转混淆!  真实跳转地址: 0x1402336cb 	0x1402c5046: jmp rax
# 0x1401a6e47 是间接跳转混淆!  真实跳转地址: 0x1402fc4f8 	0x1401a6e47: jmp rdi
# 0x140301a07 是间接跳转混淆!  真实跳转地址: 0x1401aeb4a 	0x140301a07: jmp r9
# 0x14048e583 是间接跳转混淆!  真实跳转地址: 0x1404cba0e 	0x14048e583: jmp rdi
# 0x14031d6c3 是间接跳转混淆!  真实跳转地址: 0x140457c7a 	0x14031d6c3: jmp rbx
# 0x1403569ce 是间接跳转混淆!  真实跳转地址: 0x140294954 	0x1403569ce: jmp rcx
# 0x1402cf65c 是间接跳转混淆!  真实跳转地址: 0x14012be76 	0x1402cf65c: jmp rbx
# 0x140263600 是间接跳转混淆!  真实跳转地址: 0x1403c2bba 	0x140263600: jmp rbx
# 0x14045a7ba 是间接跳转混淆!  真实跳转地址: 0x140125f1d 	0x14045a7ba: jmp rdi
# 0x14023142e 是间接跳转混淆!  真实跳转地址: 0x1402a9b89 	0x14023142e: jmp rbx
# 0x14012a588 是间接跳转混淆!  真实跳转地址: 0x140395d7d 	0x14012a588: jmp rcx
# 0x14026daee 是间接跳转混淆!  真实跳转地址: 0x1401f298e 	0x14026daee: jmp rbx
# 0x14024ea39 是间接跳转混淆!  真实跳转地址: 0x14027118b 	0x14024ea39: jmp rcx
# 0x1404826b5 是间接跳转混淆!  真实跳转地址: 0x14014f66b 	0x1404826b5: jmp rax
# 0x140197601 是间接跳转混淆!  真实跳转地址: 0x1404ce507 	0x140197601: jmp rax
# 0x14032c165 是间接跳转混淆!  真实跳转地址: 0x14027b5c6 	0x14032c165: jmp r9
# 0x14027b5d1 是间接跳转混淆!  真实跳转地址: 0x1402af5fc 	0x14027b5d1: jmp rax
# 0x14043a1b3 是间接跳转混淆!  真实跳转地址: 0x1401bb7a6 	0x14043a1b3: jmp r10
# 0x14043a76e 是间接跳转混淆!  真实跳转地址: 0x1402d37ae 	0x14043a76e: jmp rdi
# 0x1401e3a35 是间接跳转混淆!  真实跳转地址: 0x1403aa612 	0x1401e3a35: jmp rbx
# 0x1403b3c9f 是间接跳转混淆!  真实跳转地址: 0x1401c4587 	0x1403b3c9f: jmp rbx
# 0x1402e8c13 是间接跳转混淆!  真实跳转地址: 0x140188cf2 	0x1402e8c13: jmp rax
# 0x140317928 是间接跳转混淆!  真实跳转地址: 0x140255348 	0x140317928: jmp rcx
# 0x14025ed55 是间接跳转混淆!  真实跳转地址: 0x1404adff2 	0x14025ed55: jmp r10
# 0x1404ae031 是间接跳转混淆!  真实跳转地址: 0x14023528b 	0x1404ae031: jmp rbp
# 0x140233cdb 是间接跳转混淆!  真实跳转地址: 0x1401559a6 	0x140233cdb: jmp rdi
# 0x14046358d 是间接跳转混淆!  真实跳转地址: 0x1404b4a32 	0x14046358d: jmp rbp
# 0x140184103 是间接跳转混淆!  真实跳转地址: 0x14045bf64 	0x140184103: jmp rcx
# 0x1402674df 是间接跳转混淆!  真实跳转地址: 0x1401aadf2 	0x1402674df: jmp rcx
# 0x1402a0a5b 是间接跳转混淆!  真实跳转地址: 0x140304299 	0x1402a0a5b: jmp rcx
# 0x14033e3ae 是间接跳转混淆!  真实跳转地址: 0x1403d8432 	0x14033e3ae: jmp r11
# 0x1401a354f 是间接跳转混淆!  真实跳转地址: 0x140166473 	0x1401a354f: jmp rdi
# 0x14023bb3b 是间接跳转混淆!  真实跳转地址: 0x1402bd6a5 	0x14023bb3b: jmp rcx
# 0x1404c0111 是间接跳转混淆!  真实跳转地址: 0x1401a786b 	0x1404c0111: jmp rax
# 0x1401df408 是间接跳转混淆!  真实跳转地址: 0x140327066 	0x1401df408: jmp rbx
# 0x140157fce 是间接跳转混淆!  真实跳转地址: 0x1401b6160 	0x140157fce: jmp rcx
# 0x14013066a 是间接跳转混淆!  真实跳转地址: 0x140180b80 	0x14013066a: jmp rbx
# 0x140199d91 是间接跳转混淆!  真实跳转地址: 0x1401a5da1 	0x140199d91: jmp rdi
# 0x1402e8812 是间接跳转混淆!  真实跳转地址: 0x140190eda 	0x1402e8812: jmp rbx
# 0x1403cea80 是间接跳转混淆!  真实跳转地址: 0x1403fe98b 	0x1403cea80: jmp rcx
# 0x14039563e 是间接跳转混淆!  真实跳转地址: 0x1403531a4 	0x14039563e: jmp rcx
# 0x14046758d 是间接跳转混淆!  真实跳转地址: 0x1404b38d8 	0x14046758d: jmp rbx
# 0x140140446 是间接跳转混淆!  真实跳转地址: 0x1404727e8 	0x140140446: jmp rdx
# 0x140126fdb 是间接跳转混淆!  真实跳转地址: 0x140314a95 	0x140126fdb: jmp r11
# 0x1401ec450 是间接跳转混淆!  真实跳转地址: 0x1404cd215 	0x1401ec450: jmp rax
# 0x1403dc9dd 是间接跳转混淆!  真实跳转地址: 0x1403adcf1 	0x1403dc9dd: jmp rdx
# 0x1402fff1e 是间接跳转混淆!  真实跳转地址: 0x1401685a9 	0x1402fff1e: jmp r8
# 0x14016baab 是间接跳转混淆!  真实跳转地址: 0x1402945e4 	0x14016baab: jmp rdx
# 0x14018c8d8 是间接跳转混淆!  真实跳转地址: 0x14023d403 	0x14018c8d8: jmp rsi
# 0x14030d480 是间接跳转混淆!  真实跳转地址: 0x1402a210b 	0x14030d480: jmp rsi
# 0x140414af8 是间接跳转混淆!  真实跳转地址: 0x14032ca63 	0x140414af8: jmp rdx
# 0x140312f90 是间接跳转混淆!  真实跳转地址: 0x1402ce98d 	0x140312f90: jmp rdx
# 0x140290317 是间接跳转混淆!  真实跳转地址: 0x14015de3f 	0x140290317: jmp r8
# 0x1402e9cef 是间接跳转混淆!  真实跳转地址: 0x1403a307a 	0x1402e9cef: jmp r11
# 0x1403e8771 是间接跳转混淆!  真实跳转地址: 0x1404364fd 	0x1403e8771: jmp rdx
# 0x140148d30 是间接跳转混淆!  真实跳转地址: 0x140306a3a 	0x140148d30: jmp rbx
# 0x140454122 是间接跳转混淆!  真实跳转地址: 0x1402fc692 	0x140454122: jmp rdx
# 0x1404a3ea0 是间接跳转混淆!  真实跳转地址: 0x1402dd579 	0x1404a3ea0: jmp rsi
# 0x1402b379c 是间接跳转混淆!  真实跳转地址: 0x1401ad066 	0x1402b379c: jmp r11
# 0x14035d64c 是间接跳转混淆!  真实跳转地址: 0x1401b1bba 	0x14035d64c: jmp r11
# 0x1402c3ce2 是间接跳转混淆!  真实跳转地址: 0x1402cc631 	0x1402c3ce2: jmp rax
# 0x140455167 是间接跳转混淆!  真实跳转地址: 0x1403ca403 	0x140455167: jmp rdx

# %%
# 生成间接跳转混淆的x64dbg还原脚本
# 注意，这只针对增量指令与间接跳转指令紧靠在一起的情况，不保证对后续的vmp版本有效
for ins in record:
    if (hasattr(ins, "obfIndirectStatus") and ins.obfIndirectStatus == True):
        print(f"memset {hex(ins.obfIndirectInc[0].ins_address)},0x90,{hex(ins.obfIndirectInc[1])}")
        writestr = f"jmp {hex(ins.obfIndirectAddr)}"
        bys = asmDecode(writestr, ins.obfIndirectInc[0].ins_address)
        if (len(bys) <= ins.obfIndirectInc[1]):
            print(writeBytesX64dbg(ins.obfIndirectInc[0].ins_address, bys))

# %% [markdown]
# 处理 obfMemConstHide

# %%
for bb in bbs:
    for ins in bb.instructions:
        if (hasattr(ins, "obfMemConstHideStatus")):
            del ins.obfMemConstHideStatus
        if (hasattr(ins, "obfMemConstHideDetail")):
            del ins.obfMemConstHideDetail
        if (hasattr(ins, "obfMemConstHideRep")):
            del ins.obfMemConstHideRep

# %%
bbs, _ = prove_obfuse_memopConstHide(bbs)

# %%
# 用于解决与lea指令有关的指令反混淆时所产生的disp32问题
def eval_const_expr(expr, size):
    mask = (1 << size) - 1

    if isinstance(expr, ExprInt):
        return ExprInt(expr.arg & mask, size)

    if isinstance(expr, ExprId):
        return None

    if isinstance(expr, ExprOp):
        op = expr.op
        args = expr.args

        eval_args = []
        for a in args:
            r = eval_const_expr(a, size)
            if r is None:
                return None
            eval_args.append(r.arg)

        try:
            if op == '+':
                val = sum(eval_args)
            elif op == '-':
                val = eval_args[0]
                for x in eval_args[1:]:
                    val -= x
            elif op == '*':
                val = 1
                for x in eval_args:
                    val *= x
            elif op == '<<':
                val = eval_args[0] << eval_args[1]
            elif op == '>>':
                val = eval_args[0] >> eval_args[1]
            elif op == '&':
                val = eval_args[0]
                for x in eval_args[1:]:
                    val &= x
            elif op == '|':
                val = eval_args[0]
                for x in eval_args[1:]:
                    val |= x
            elif op == '^':
                val = eval_args[0]
                for x in eval_args[1:]:
                    val ^= x
            else:
                return None

        except Exception:
            return None

        return ExprInt(val & mask, size)

    return None

def try_fix_lea(ins):
    if ins.name != 'LEA':
        return ins

    dst, src = ins.args

    assert(isinstance(src, ExprMem))
    addrExpr = src.ptr

    const_addr = eval_const_expr(addrExpr, 64)
    if const_addr is None:
        return ins

    # LEA reg, [const] -> MOV reg, const
    new_ins = mn_x86.fromstring(
        f"MOV {dst}, 0x{const_addr.arg:x}",
        None,
        64
    )
    return new_ins

# %%
for bb in bbs:
    for ins in bb.instructions:
        if (hasattr(ins, "obfMemConstHideStatus") and ins.obfMemConstHideStatus == True):
            mmins = mn_x86.dis(ins.bytes, 64)
            rep = {}
            for detail in ins.obfMemConstHideDetail:
                bit = ctx.getRegister(detail[0]).getBitSize()
                rep[ExprId(detail[1].upper(), bit)] = ExprInt(detail[2], bit)
            for i, arg in enumerate(mmins.args):
                if (arg.is_mem()):
                    mmins.args[i] = arg.replace_expr(rep)
            try:
                asm = mn_x86.asm(try_fix_lea(mmins))
                ins.obfMemConstHideRep = asm
            except ValueError:
                print(f"{ins} 错误!\t{mmins}")
                continue
# Out:
# <DbgId: 8b28> ip: 1404c4aa2 insSize: 8 错误!	LEA        EBX, DWORD PTR [0xEF3FB826 + RBX + 0xFFFFFFFF95C3D277]
# <DbgId: 591e> ip: 140303d70 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0xC6090DB4 + 0x1CB0C44F]
# <DbgId: 5030> ip: 14018f6fa insSize: 7 错误!	LEA        EBX, DWORD PTR [RBX + 0x8E000600 + 0x1F3F088D]
# <DbgId: 2880> ip: 1402b21f2 insSize: 8 错误!	LEA        R8D, DWORD PTR [R8 + 0xFFFFFFFF8395303F * 0x2 + 0x112AC3EF]
# <DbgId: 889b> ip: 14013f151 insSize: 8 错误!	LEA        R8D, DWORD PTR [R8 + 0xA76CA91C + 0xFFFFFFFFDC9C7383]
# <DbgId: b3b3> ip: 1401469cb insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0xAB38A8AF + 0xFFFFFFFFE6FC44E7]
# <DbgId: 15f63> ip: 1402d57d9 insSize: 8 错误!	LEA        R8D, DWORD PTR [R8 + 0xFFFFFFBB + 0xFFFFFFFFEE17C0F3]
# <DbgId: 15e8e> ip: 1401762b1 insSize: 8 错误!	LEA        R8D, DWORD PTR [R8 + 0xACD00000 + 0x3754DBA3]
# <DbgId: 4089> ip: 14031c61a insSize: 7 错误!	LEA        EBX, DWORD PTR [RBX + 0xFB5BAFC5 + 0xFFFFFFFFE02556CA]
# <DbgId: 409b> ip: 14031c65e insSize: 7 错误!	LEA        EBX, DWORD PTR [0xFFFFF84B + RBX + 0xFFFFFFFFA63B6D55]
# <DbgId: 10e98> ip: 1401a98f8 insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0xFFFFFFFFC606CD2A * 0x4 + 0x3DCDBCB]
# <DbgId: 14fab> ip: 140488edc insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0xFFFFFFFFD2B1F384 * 0x2 + 0xFFFFFFFFD50DE1DC]
# <DbgId: 3d50> ip: 1402e2615 insSize: 8 错误!	LEA        EBP, DWORD PTR [0xEABECC06 + RBP + 0xFFFFFFFFF0C23A89]
# <DbgId: 3d5f> ip: 140207e6c insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0x5C2C510B + 0x4A0F1495]
# <DbgId: 186d0> ip: 14025fba5 insSize: 8 错误!	LEA        EBX, DWORD PTR [0x89B31524 + RBX + 0x2505B95C]
# <DbgId: 3f99> ip: 1401e3124 insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0x80524D5 * 0x8 + 0x6D95170F]
# <DbgId: 3625> ip: 14020b5b2 insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0x74C8A9EB * 0x2 + 0xFFFFFFFFF50E65D4]
# <DbgId: 4eb7> ip: 140130eec insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x600001A2 * 0x2 + 0x22B9CEBF]
# <DbgId: b96> ip: 140195f15 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0xA8011802 + 0xFFFFFFFFF48F08A5]
# <DbgId: 15efe> ip: 14041118d insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0x8DC54600 + 0x3DC21906]
# <DbgId: e6f2> ip: 1402d99b3 insSize: 8 错误!	LEA        ECX, DWORD PTR [0xFFFFFFFF9634879A + RCX + 0xFFFFFFFFC638AE3A]
# <DbgId: e8a6> ip: 14035a995 insSize: 8 错误!	LEA        EDX, DWORD PTR [0xFFFFFFFEE5FFFF31 + RDX + 0x6C755335]
# <DbgId: b279> ip: 1402d4d81 insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0x1F93FFFF * 0x4 + 0x13E4ED9A]
# <DbgId: 3a3e> ip: 140275830 insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0xF0000000 + 0xFFFFFFFFEB81068F]
# <DbgId: 14f1f> ip: 140199d82 insSize: 7 错误!	LEA        EDX, DWORD PTR [0xA7AC6E1B + RDX + 0xFFFFFFFFEE817F72]
# <DbgId: 11ab2> ip: 14031370a insSize: 7 错误!	LEA        EBP, DWORD PTR [0x3988E227 + RBP + 0x768E6D10]
# <DbgId: 78d1> ip: 1401568bf insSize: 8 错误!	LEA        EDX, DWORD PTR [0x62B0069F + RDX + 0x2F84E6F7]
# <DbgId: 41a4> ip: 14049b3f6 insSize: 7 错误!	LEA        EDI, DWORD PTR [0xEE157FBC + RDI + 0xFFFFFFFFD9A9C557]
# <DbgId: 5b72> ip: 14042c2b3 insSize: 8 错误!	LEA        EAX, DWORD PTR [RAX + 0x52001280 * 0x2 + 0x488202A1]
# <DbgId: 428f> ip: 1404317c8 insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0x9F29162C * 0x2 + 0xFFFFFFFF9D2EDA37]
# <DbgId: 429c> ip: 1403d03df insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0x9F29162C + 0x7124F74]
# <DbgId: 39b8> ip: 14031fd29 insSize: 7 错误!	LEA        EDX, DWORD PTR [0xB02FA289 + RDX + 0x2D662A2A]
# <DbgId: 9b0b> ip: 140281a89 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0xE45F3278 + 0xFFFFFFFFEED4AEC7]
# <DbgId: 9b0f> ip: 140281a95 insSize: 8 错误!	LEA        EAX, DWORD PTR [RAX + 0xFFFFFFFFD82B2004 * 0x4 + 0xFFFFFFFFA341795B]
# <DbgId: 9b17> ip: 140281ab2 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x9E940861 + 0xFFFFFFFFFC7F35CE]
# <DbgId: 10165> ip: 140142425 insSize: 7 错误!	LEA        ECX, DWORD PTR [0xFFFFFFFFB0B9A30B + RCX + 0xFFFFFFFFA9ADD8E5]
# <DbgId: 10168> ip: 140142432 insSize: 8 错误!	LEA        ECX, DWORD PTR [0xF6BAB013 + RCX + 0xFFFFFFFFD4724671]
# <DbgId: 59e0> ip: 14013a5ab insSize: 7 错误!	LEA        ECX, DWORD PTR [0xFFFFFF81 + RCX + 0xFFFFFFFFE2B9D282]
# <DbgId: 1424d> ip: 140483709 insSize: 7 错误!	LEA        ECX, DWORD PTR [0xBCBA7440 + RCX + 0xFFFFFFFFE980F160]
# <DbgId: 18ddf> ip: 14016af8b insSize: 8 错误!	LEA        R11D, DWORD PTR [R11 + 0x5B9B0010 + 0x531DCE70]
# <DbgId: 9c4e> ip: 140476a9a insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0x130A9341B + 0xFFFFFFFFA28AAD24]
# <DbgId: 9c5c> ip: 14024b190 insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0x9BC8B754 + 0xFFFFFFFFFF4A86DB]
# <DbgId: 9317> ip: 140461256 insSize: 8 错误!	LEA        EBX, DWORD PTR [0x2D216914 + RBX + 0x5A885C6C]
# <DbgId: 1d88> ip: 1402322bf insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0x21B71D8E * 0x4 + 0x47BAD2E2]
# <DbgId: acc5> ip: 1402647f1 insSize: 7 错误!	LEA        ECX, DWORD PTR [0x2D819D2C + RCX + 0x6DAB947C]
# <DbgId: acc9> ip: 140264802 insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0x2D819D2C * 0x4 + 0xFFFFFFFFEF351CD8]
# <DbgId: 110cf> ip: 14037750f insSize: 7 错误!	LEA        EDI, DWORD PTR [0xFFFFFF8D + RDI + 0xFFFFFFFFD69907FF]
# <DbgId: 5acd> ip: 14025da26 insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0xFFFFFFFFF624ECA3 * 0x2 + 0xFFFFFFFF8E27EF9E]
# <DbgId: b5d9> ip: 1402376a8 insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0x21BA0818 * 0x2 + 0x4EC0DD66]
# <DbgId: 3b22> ip: 140164421 insSize: 7 错误!	LEA        EDI, DWORD PTR [0xC5BE5A39 + RDI + 0x26C3CD68]
# <DbgId: 7d4e> ip: 140245263 insSize: 7 错误!	LEA        ECX, DWORD PTR [0x2C9D002F + RCX + 0x576C1C70]
# <DbgId: 10bcf> ip: 14020c535 insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0xFFFFFFFF60000000 * 0x2 + 0x5BF81073]
# <DbgId: 17ed0> ip: 1404baeff insSize: 8 错误!	LEA        ECX, DWORD PTR [0x9AA0CE8C + RCX + 0x33F67A8E]
# <DbgId: 42f0> ip: 14044c096 insSize: 7 错误!	LEA        EBP, DWORD PTR [0x2AA11BBE + RBP + 0x5A0B917A]
# <DbgId: a3a0> ip: 1401472b1 insSize: 7 错误!	LEA        EDX, DWORD PTR [0xAF3C0804 + RDX + 0x23F7D93B]
# <DbgId: a3ad> ip: 1404a1276 insSize: 8 错误!	LEA        EDX, DWORD PTR [0x2C43B66D + RDX + 0x6ECF87C2]
# <DbgId: a45f> ip: 14045691e insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0x3DC27B9D * 0x4 + 0xFFFFFFFFD6B0AA38]
# <DbgId: 231f> ip: 14045739f insSize: 7 错误!	LEA        ECX, DWORD PTR [0xFFFFFFFFBAA4FF99 + RCX + 0xFFFFFFFFB35165D8]
# <DbgId: 142b3> ip: 1401bdf19 insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0x800040E9 * 0x2 + 0xFFFFFFFF962D6BBB]
# <DbgId: 15d8a> ip: 1404b90cd insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0x47B01B1A * 0x2 + 0x5EB78A7A]
# <DbgId: 18d52> ip: 140291388 insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0xA9F02E6 * 0x8 + 0x59C0B750]
# <DbgId: a3d6> ip: 140322b3d insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x1B2D73C9 * 0x4 + 0x667E121B]
# <DbgId: a3dd> ip: 140322b57 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x1B2D73C9 + 0x7FE5CA66]
# <DbgId: 11802> ip: 14022378b insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0x180A1A56 * 0x4 + 0x4FEEE5DF]
# <DbgId: a011> ip: 1402e786e insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0x6591EB00 * 0x2 + 0xFFFFFFFFBC85EF80]
# <DbgId: 1663b> ip: 1402917e6 insSize: 8 错误!	LEA        ECX, DWORD PTR [0x736536A3 + RCX + 0x1F203166]
# <DbgId: 106aa> ip: 1403b9de8 insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0xFFFFFFFFA81546BA * 0x2 + 0x24AC4F2]
# <DbgId: 1179e> ip: 1402208d0 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x80000000 + 0x30174F37]
# <DbgId: 12aa0> ip: 140469b4c insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0x438D40B9 * 0x2 + 0x5466851D]
# <DbgId: 12aaa> ip: 140469b85 insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0x438D40DC * 0x2 + 0x1F20E3E8]
# <DbgId: 50db> ip: 1401447e0 insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0x9E3BC82A + 0x447E09D9]
# <DbgId: 9365> ip: 14013cd6e insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0x2C14E525 + 0x5B94E05B]
# <DbgId: bd43> ip: 140355756 insSize: 8 错误!	LEA        EDX, DWORD PTR [RDX + 0x342D3ABE * 0x2 + 0x1F4F5004]
# <DbgId: f9cd> ip: 14045930f insSize: 7 错误!	LEA        EBX, DWORD PTR [RBX + 0x67800000 * 0x2 + 0xFFFFFFFFEB37E4A1]
# <DbgId: 8eb5> ip: 140247cf1 insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0xA0BF83C3 + 0xFFFFFFFFE6EA41BD]
# <DbgId: 149e5> ip: 14018f454 insSize: 7 错误!	LEA        EBX, DWORD PTR [RBX + 0xFFFFFFFFB094CF03 * 0x2 + 0x19482ADE]
# <DbgId: 7bc0> ip: 140254c65 insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0xFFFFFFFFDA99AEF1 * 0x2 + 0xFFFFFFFF8DC4B704]
# <DbgId: 11a73> ip: 1403deedb insSize: 8 错误!	LEA        EAX, DWORD PTR [0x3597905F + RAX + 0x7A7FBED8]
# <DbgId: 88f> ip: 14013b16f insSize: 8 错误!	LEA        R8D, DWORD PTR [R8 + 0xFFFFFFFFC9361CAD * 0x2 + 0xFFFFFFFFB58A948D]
# <DbgId: e721> ip: 140229a65 insSize: 8 错误!	LEA        ECX, DWORD PTR [0xFFFFFFFF6EC1BAC4 + RCX + 0xFFFFFFFFFD396EFD]
# <DbgId: 8d65> ip: 14022dbba insSize: 8 错误!	LEA        EAX, DWORD PTR [RAX + 0x5BBA00FF * 0x2 + 0xFFFFFFFFCD8F889F]
# <DbgId: 8c45> ip: 140299031 insSize: 8 错误!	LEA        EDX, DWORD PTR [RDX + 0x38391ECA * 0x2 + 0x173787EC]
# <DbgId: 5126> ip: 1402f3b40 insSize: 7 错误!	LEA        EDI, DWORD PTR [0x949B760F + RDI + 0x57E6B192]
# <DbgId: 1618c> ip: 140466d59 insSize: 7 错误!	LEA        EDX, DWORD PTR [0xFFFFFFFF + RDX + 0xFFFFFFFFAB0FB8AB]
# <DbgId: 9faa> ip: 1404708f2 insSize: 8 错误!	LEA        EBX, DWORD PTR [0xFFFFFFFF + RBX + 0xFFFFFFFF87A9C581]
# <DbgId: 402f> ip: 140317671 insSize: 8 错误!	LEA        EAX, DWORD PTR [0xBBB83F4 + RAX + 0x78F12944]
# <DbgId: cef2> ip: 14041923f insSize: 8 错误!	LEA        ECX, DWORD PTR [0x168C353D + RCX + 0x7BA8B859]
# <DbgId: 60e1> ip: 14043ffdf insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0x899D5800 + 0x23A1B68D]
# <DbgId: 1249c> ip: 14018770e insSize: 7 错误!	LEA        EDI, DWORD PTR [0xE21E000E + RDI + 0xFFFFFFFFB01EA681]
# <DbgId: 99c5> ip: 140485722 insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0x18167715 + 0x7A1E7681]
# <DbgId: dd67> ip: 1401c4b3f insSize: 8 错误!	LEA        EDX, DWORD PTR [0x7BA0A628 + RDX + 0xC091F58]
# <DbgId: 625a> ip: 1401e7287 insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0xFFFFFF86 + 0xFFFFFFFFE2B9D27D]
# <DbgId: 92ac> ip: 140256561 insSize: 8 错误!	LEA        R8D, DWORD PTR [R8 + 0x9CB8F6E3 * 0x2 + 0xFFFFFFFF90BC3545]
# <DbgId: 39f7> ip: 140289bcb insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0xFFFFA490 + 0xFFFFFFFFC7BFA083]
# <DbgId: 12bcf> ip: 1401ef788 insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0xEA8AC8C3 + 0xFFFFFFFFABA324CA]
# <DbgId: 17206> ip: 1404ca123 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x4015413C + 0x6EA38D44]
# <DbgId: d5c4> ip: 14024495e insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0xFFFFFFFF84AEE400 * 0x2 + 0x399A4CE6]
# <DbgId: 65e0> ip: 14014c2c6 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x80000000 + 0x123CA68F]
# <DbgId: 16689> ip: 14027ce0f insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0x100000000 + 0xFFFFFFFFE315EF9B]
# <DbgId: bf63> ip: 1402c2c9d insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0xFFFFA284 + 0xFFFFFFFF87AA22FC]
# <DbgId: 165dc> ip: 140233d30 insSize: 8 错误!	LEA        ECX, DWORD PTR [0xFFF2D1FF + RCX + 0xFFFFFFFFAB1CE6AB]
# <DbgId: e867> ip: 14017ccc2 insSize: 7 错误!	LEA        EDX, DWORD PTR [0x5C9BA800 + RDX + 0x4E716A0C]
# <DbgId: 8bdc> ip: 140445884 insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0x5D937731 + 0x34A17665]
# <DbgId: 148b5> ip: 14024f363 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0xFFFFB520 + 0xFFFFFFFF923CF16F]
# <DbgId: 4163> ip: 14031f75a insSize: 8 错误!	LEA        EDX, DWORD PTR [0xFFFF0005 + RDX + 0xFFFFFFFF962EED88]
# <DbgId: 16909> ip: 14021efc4 insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0x55177BAA * 0x4 + 0xFFFFFFFF8EB800F3]
# <DbgId: 10fde> ip: 140220e0c insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0xFFFFFFFFBCACABB3 * 0x2 + 0xFFFFFFFFA29EB90D]
# <DbgId: a03e> ip: 1403486c3 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0xEF982208 + 0xFFFFFFFFDE2276A4]
# <DbgId: 4ddc> ip: 1403fb254 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x392E0016 * 0x2 + 0x3AE30E61]
# <DbgId: c75> ip: 14019165b insSize: 8 错误!	LEA        R11D, DWORD PTR [R11 + 0xFFFFFFFFE53AF2D6 * 0x8 + 0xC0C9343]
# <DbgId: 28f1> ip: 14030c272 insSize: 7 错误!	LEA        EBX, DWORD PTR [RBX + 0xFDFF43FF + 0xFFFFFFFF9E90DCA8]
# <DbgId: 13781> ip: 14041488e insSize: 7 错误!	LEA        EBX, DWORD PTR [RBX + 0xFFFFFFFF + 0xFFFFFFFFC80C4138]
# <DbgId: 140e2> ip: 140128773 insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0xA00104A0 + 0x3B8001EF]
# <DbgId: 140ea> ip: 14012879a insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0xBA098444 + 0xFFFFFFFFEC31E15C]
# <DbgId: 176bf> ip: 14033217d insSize: 8 错误!	LEA        R8D, DWORD PTR [R8 + 0x5C2BC774 + 0x726B81A6]
# <DbgId: 11857> ip: 14017b237 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0xFFFFFF6B + 0xFFFFFFFFB0174FCC]
# <DbgId: 3e7e> ip: 14026d2bb insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0xFFFFFFFF96C932D6 * 0x2 + 0x4CDF6338]
# <DbgId: b8fc> ip: 14021b65a insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0xCEB20399 + 0x481DDA6]
# <DbgId: b906> ip: 1402911c9 insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0xCEB20399 + 0xFFFFFFFFCC613A96]
# <DbgId: 18cac> ip: 14019015d insSize: 8 错误!	LEA        EBX, DWORD PTR [RBX + 0xFFFFFFFFBAFE90D2 * 0x2 + 0xFFFFFFFFF7F943CD]
# <DbgId: 137dd> ip: 1402cc11e insSize: 8 错误!	LEA        EBX, DWORD PTR [0x2A144A3D + RBX + 0x7CA23EC6]
# <DbgId: 9403> ip: 1401cae4d insSize: 8 错误!	LEA        EBP, DWORD PTR [0x77003488 + RBP + 0x10A990F8]
# <DbgId: 59bc> ip: 14023c985 insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0x1E3AD86D * 0x4 + 0x69CE704F]
# <DbgId: ad7c> ip: 140493e49 insSize: 7 错误!	LEA        EBP, DWORD PTR [0xBFFFFFE9 + RBP + 0x200E6D9A]
# <DbgId: 14817> ip: 1401491b9 insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0x7A2ECDBA * 0x2 + 0xFFFFFFFF9DDF0B1B]
# <DbgId: 466c> ip: 140459a0c insSize: 7 错误!	LEA        EBX, DWORD PTR [0xF83F411F + RBX + 0xFFFFFFFFB4FFCD6E]
# <DbgId: 160e5> ip: 1404b3907 insSize: 7 错误!	LEA        EDX, DWORD PTR [0xFFFFFFA4 + RDX + 0xFFFFFFFFAA304A15]
# <DbgId: 913c> ip: 140134602 insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0xAA62CD0B + 0xFFFFFFFFDD46F875]
# <DbgId: 3c97> ip: 1401eb50b insSize: 7 错误!	LEA        EDI, DWORD PTR [0xFA9A4203 + RDI + 0xFFFFFFFFE0E6C48C]
# <DbgId: 3ca9> ip: 14048566e insSize: 8 错误!	LEA        EDI, DWORD PTR [0xFA9A4203 + RDI + 0xFFFFFFFFABA1239D]
# <DbgId: 14ed1> ip: 140447ee8 insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0x758FEDEE + 0x209DFF9F]
# <DbgId: 9a4c> ip: 14013254a insSize: 8 错误!	LEA        EDX, DWORD PTR [0xFFFFFFF4 + RDX + 0xFFFFFFFF87A9C58C]
# <DbgId: d5a> ip: 14047fa2e insSize: 8 错误!	LEA        ESI, DWORD PTR [0xFFFFBABE + RSI + 0xFFFFFFFFCE978E5C]
# <DbgId: 48d2> ip: 1401aad38 insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0x5EB28814 * 0x2 + 0x2554C1DB]
# <DbgId: 394c> ip: 14031fa01 insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0x7DBD4E55 * 0x2 + 0xFFFFFFFFF1078AF7]
# <DbgId: f175> ip: 14018e160 insSize: 8 错误!	LEA        EDX, DWORD PTR [0xAA113BEB + RDX + 0xFFFFFFFFF7156EB6]
# <DbgId: 83cd> ip: 1402bdca8 insSize: 8 错误!	LEA        EBX, DWORD PTR [RBX + 0x280DEB46 * 0x2 + 0x7A124C7F]
# <DbgId: c08e> ip: 1402194f6 insSize: 8 错误!	LEA        EDX, DWORD PTR [RDX + 0x47B20686 * 0x2 + 0x43CFD433]
# <DbgId: c098> ip: 140219524 insSize: 8 错误!	LEA        EDX, DWORD PTR [0x47B20686 + RDX + 0x536137A9]
# <DbgId: aeae> ip: 1401339f9 insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0xFFFFFFFF + 0xFFFFFFFFD333E140]
# <DbgId: aeb9> ip: 1402ade09 insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0xFFFFFFFF + 0xFFFFFFFF9B133E30]
# <DbgId: e5b2> ip: 140493bbc insSize: 8 错误!	LEA        EBX, DWORD PTR [0xFFFFFF32 + RBX + 0xFFFFFFFFA126AB6F]
# <DbgId: 46ac> ip: 14042c433 insSize: 7 错误!	LEA        EBX, DWORD PTR [RBX + 0x5EBD302F * 0x2 + 0xFFFFFFFFEFC4AE2F]
# <DbgId: 1920e> ip: 14046f933 insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0x12238C1A * 0x4 + 0x662A9E18]
# <DbgId: 5d88> ip: 14022ed8d insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0x4145321C * 0x2 + 0x69F7C369]
# <DbgId: 3dd1> ip: 14031efb2 insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0x4282A5A4 * 0x2 + 0x1128A245]
# <DbgId: 5e12> ip: 1401b1c0f insSize: 7 错误!	LEA        EBP, DWORD PTR [RBP + 0xBB1DC8B * 0x4 + 0x7E779C61]
# <DbgId: 5172> ip: 140314bdc insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0xFFFFFFFFD0298178 * 0x4 + 0x39CBC304]
# <DbgId: 17326> ip: 140243f8b insSize: 8 错误!	LEA        EDX, DWORD PTR [0x550FB0C7 + RDX + 0x59A91DB9]
# <DbgId: 127d2> ip: 1404503e6 insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0x28C0FFFF + 0x697BA690]
# <DbgId: 79ad> ip: 1401450ed insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0x152B823A + 0x7D096B5C]
# <DbgId: 7ff2> ip: 14021710c insSize: 8 错误!	LEA        EAX, DWORD PTR [0xF5B8393C + RAX + 0xFFFFFFFF9C7CB45A]
# <DbgId: 3391> ip: 140186fbf insSize: 7 错误!	LEA        EBP, DWORD PTR [0x8C8E0007 + RBP + 0x5F1A8A0E]
# <DbgId: 4d3b> ip: 1402e1076 insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0xFFFFB40D + 0xFFFFFFFFE2BA1DF6]
# <DbgId: 9101> ip: 14030296f insSize: 7 错误!	LEA        ECX, DWORD PTR [0x74BC8320 + RCX + 0x4E575D8F]
# <DbgId: 4a9d> ip: 1402b16aa insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0x407993BC + 0x51C312D3]
# <DbgId: b47f> ip: 140447cbc insSize: 8 错误!	LEA        R8D, DWORD PTR [0xAD550000 + R8 + 0x25DEE13F]
# <DbgId: b48b> ip: 1404ca45e insSize: 8 错误!	LEA        R8D, DWORD PTR [R8 + 0xAD450002 + 0xFFFFFFFFEDCE3E2D]
# <DbgId: d070> ip: 1401d0389 insSize: 8 错误!	LEA        EAX, DWORD PTR [0x4C2959A3 + RAX + 0x4EE9E48C]
# <DbgId: 5444> ip: 140199ade insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x7828344D * 0x2 + 0xFFFFFFFFED456419]
# <DbgId: 14138> ip: 140467d5b insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0xBB9F3906 + 0x1FE1CD89]
# <DbgId: 14147> ip: 140467d9c insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0xBB9F3900 + 0xFFFFFFFFEA9C2CA0]
# <DbgId: 169ef> ip: 1402f1d43 insSize: 8 错误!	LEA        EAX, DWORD PTR [0x19B2FFFF + RAX + 0x6A5E8B96]
# <DbgId: 169f6> ip: 1402f1d5d insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0xB61F2205 + 0xFFFFFFFFEBF50808]
# <DbgId: cfef> ip: 1404085f5 insSize: 7 错误!	LEA        ECX, DWORD PTR [0xFFFFFFA6 + RCX + 0xFFFFFFFFD333E199]
# <DbgId: cff5> ip: 14040860d insSize: 8 错误!	LEA        ECX, DWORD PTR [0xFFFFFFFF2E0AA81B + RCX + 0xFFFFFFFFD5E35150]
# <DbgId: cffb> ip: 140223d1a insSize: 7 错误!	LEA        ECX, DWORD PTR [0xAE1BF4DE + RCX + 0xFFFFFFFFECF74951]
# <DbgId: 3e1c> ip: 1401f6f6e insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0x1093D326 * 0x2 + 0x75064741]
# <DbgId: 16072> ip: 140291874 insSize: 8 错误!	LEA        EDX, DWORD PTR [RDX + 0x61000024 * 0x2 + 0x2224DB5B]
# <DbgId: 4554> ip: 1401d2e26 insSize: 7 错误!	LEA        EDI, DWORD PTR [0xFFFFFF66 + RDI + 0xFFFFFFFFDE9FBA44]
# <DbgId: c0f3> ip: 1403cb4d6 insSize: 7 错误!	LEA        EBX, DWORD PTR [RBX + 0x1D97AB04 * 0x8 + 0xFFFFFFFFE0FD408C]
# <DbgId: 14dd3> ip: 14015e07d insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0xB7BC00E8 + 0x23C505A7]
# <DbgId: 14de4> ip: 14015e0c8 insSize: 8 错误!	LEA        R9D, DWORD PTR [R9 + 0xB7BC00E8 + 0xFFFFFFFFEE7F64B8]
# <DbgId: 1907> ip: 14032ba96 insSize: 8 错误!	LEA        R8D, DWORD PTR [R8 + 0xFFFFFFFFDE214428 * 0x4 + 0xFFFFFFFF89C259C2]
# <DbgId: 4322> ip: 1401f5465 insSize: 8 错误!	LEA        EBX, DWORD PTR [0x76A52B9A + RBX + 0x66F0A119]
# <DbgId: 4c61> ip: 1401992c4 insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0x2D7FFFFF * 0x2 + 0x373CA691]
# <DbgId: 19d01> ip: 14036eea8 insSize: 8 错误!	LEA        R11D, DWORD PTR [R11 + 0xFFFFFFFFEFC6E8D0 * 0x2 + 0xFFFFFFFF8E6893D1]
# <DbgId: c152> ip: 14045c350 insSize: 8 错误!	LEA        R8D, DWORD PTR [R8 + 0x2227C000 * 0x4 + 0x451B98AC]
# <DbgId: 423f> ip: 14018aa76 insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x9C114FFA * 0x2 + 0xFFFFFFFFB45F87AD]
# <DbgId: 10aeb> ip: 1402115f0 insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0xFFFFFFFF8AF141BA * 0x2 + 0x468AB260]
# <DbgId: 5aaa> ip: 140497185 insSize: 7 错误!	LEA        EDI, DWORD PTR [RDI + 0x1F160002 * 0x4 + 0x30E70E85]
# <DbgId: 14777> ip: 140144a53 insSize: 7 错误!	LEA        EDX, DWORD PTR [0xFFFF7FFF + RDX + 0xFFFFFFFFDEA039AB]
# <DbgId: 11d8> ip: 14027db4f insSize: 8 错误!	LEA        ECX, DWORD PTR [RCX + 0x75178200 * 0x2 + 0xFFFFFFFFDEFE5537]
# <DbgId: f3ce> ip: 1402f046e insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0xFFFFFFFFEF1AB50D * 0x8 + 0xFFFFFFFFE3978D6C]
# <DbgId: 16034> ip: 1402a303d insSize: 7 错误!	LEA        ECX, DWORD PTR [RCX + 0xB835FFFF + 0xC57F395]
# <DbgId: 3ce9> ip: 1401bb2f3 insSize: 7 错误!	LEA        EDX, DWORD PTR [RDX + 0x48B1FA34 * 0x4 + 0xFFFFFFFFB8B91DBF]
# <DbgId: 3cf6> ip: 1401945d9 insSize: 7 错误!	LEA        EDX, DWORD PTR [0x48B1FA34 + RDX + 0x5D896B6C]
# <DbgId: c2cb> ip: 140489d1e insSize: 7 错误!	LEA        EDX, DWORD PTR [0xCE9C8311 + RDX + 0xFFFFFFFFB90D426F]
# <DbgId: 162e8> ip: 14020c823 insSize: 7 错误!	LEA        EBX, DWORD PTR [RBX + 0xFFFFFFFE + 0xFFFFFFFFAB0FB8AC]
# <DbgId: 1752c> ip: 14038ea3d insSize: 8 错误!	LEA        ECX, DWORD PTR [0xFFFFFFFF9C308233 + RCX + 0xFFFFFFFFABC64BB4]
# <DbgId: e94a> ip: 1401aebd2 insSize: 8 错误!	LEA        EDX, DWORD PTR [RDX + 0xFFFFFFFFEE8CFEB3 * 0x2 + 0xFFFFFFFF8EE12C5B]
# <DbgId: 13915> ip: 14014cd1b insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x8F8C0930 + 0x172A7FD3]
# <DbgId: ba54> ip: 1404afdb3 insSize: 8 错误!	LEA        EAX, DWORD PTR [0xE81B81AC + RAX + 0xFFFFFFFFEB185F93]
# <DbgId: ba5c> ip: 14017f079 insSize: 8 错误!	LEA        EAX, DWORD PTR [0xE81B81AC + RAX + 0xFFFFFFFFB2F7BC83]
# <DbgId: 1810e> ip: 14043feaf insSize: 7 错误!	LEA        EAX, DWORD PTR [RAX + 0x3D2D0B36 + 0x718BC34A]
# <DbgId: bc0a> ip: 14032774e insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0x2A7FE217 + 0x67B50B7F]
# <DbgId: ef03> ip: 1402fe1f5 insSize: 8 错误!	LEA        R10D, DWORD PTR [R10 + 0x800060E0 + 0x5B8616BA]
# <DbgId: 546d> ip: 1404cabef insSize: 7 错误!	LEA        EDX, DWORD PTR [0x7D93801A + RDX + 0x189A6D73]
# <DbgId: 15fee> ip: 140302eca insSize: 7 错误!	LEA        ESI, DWORD PTR [0xA8001400 + RSI + 0x4617ACAE]
# <DbgId: a42e> ip: 14024c436 insSize: 7 错误!	LEA        EDX, DWORD PTR [0xFFFFD91C + RDX + 0xFFFFFFFFCA2E49EF]
# <DbgId: 14910> ip: 1401a59de insSize: 8 错误!	LEA        EBP, DWORD PTR [0x102069834 + RBP + 0xFFFFFFFF90360E5B]
# <DbgId: 17f59> ip: 1402d8255 insSize: 7 错误!	LEA        ESI, DWORD PTR [0xA0BF4D88 + RSI + 0xFFFFFFFFFBD0D31F]
# <DbgId: 5c52> ip: 14046765a insSize: 7 错误!	LEA        EDX, DWORD PTR [0xA192707D + RDX + 0x41276186]
# <DbgId: 1926e> ip: 1402cc968 insSize: 8 错误!	LEA        R11D, DWORD PTR [R11 + 0x1D08270D * 0x4 + 0x3A98324C]

# %%
# 生成内存操作数常量隐藏的x64dbg还原脚本
for bb in bbs:
    for ins in bb.instructions:
        if (hasattr(ins, "obfMemConstHideStatus") and ins.obfMemConstHideStatus == True and hasattr(ins, "obfMemConstHideRep")):
            if (not len(ins.obfMemConstHideRep) > 0):
                # print("数量异常")
                continue
            rep: bytes = ins.obfMemConstHideRep[0] # 第一个默认是最短的
            if (len(rep) > len(ins.bytes)):
                # print("长度不够")
                continue
            print(f"memset {hex(ins.ins_address)},0x90,{hex(len(ins.bytes))}")
            print(writeBytesX64dbg(ins.ins_address, rep))

# %%
bbs, _ = dead_code_elimination(bbs) # 似乎迭代第二次就会出错，可能删除了有副作用的指令

# %%
# 当前检测到的垃圾指令（不全面，有待研究）
for ins in record:
    if (hasattr(ins, "obfDeadCodeStatus") and ins.obfDeadCodeStatus == True):
        if ((not ins.ttins.isControlFlow()) and len(ins.mem_accs) == 0):
            print(f"{ins}\t{ins.ttins}")
# Out:
# <DbgId: 5> ip: 14010a742 insSize: 4	0x14010a742: movsx bx, bl
# <DbgId: 24> ip: 1403a7380 insSize: 1	0x1403a7380: cdq
# <DbgId: 32> ip: 14013b6d5 insSize: 7	0x14013b6d5: and r9d, 0x9d1fce14
# <DbgId: 42> ip: 14013b72a insSize: 4	0x14013b72a: rol r8, 0x89
# <DbgId: 49> ip: 14013b74a insSize: 3	0x14013b74a: and rdx, rcx
# <DbgId: 5a> ip: 14033fb4f insSize: 8	0x14033fb4f: lea rbp, [rax + rbx*2 + 0x38b675b0]
# <DbgId: 5d> ip: 14033fb5e insSize: 4	0x14033fb5e: movzx r8d, sil
# <DbgId: 62> ip: 14033fb72 insSize: 6	0x14033fb72: mov r10d, 0xa6168e1f
# <DbgId: 80> ip: 1402f4cef insSize: 3	0x1402f4cef: rol si, cl
# <DbgId: eb> ip: 1402ac3d3 insSize: 7	0x1402ac3d3: lea r8, [r11 - 0x5f495c77]
# <DbgId: fc> ip: 14046a223 insSize: 5	0x14046a223: bt rdx, 0x1b
# <DbgId: 315> ip: 140480c98 insSize: 2	0x140480c98: inc edx
# <DbgId: 376> ip: 1404a9bba insSize: 3	0x1404a9bba: shr eax, 0x7a
# <DbgId: 394> ip: 1402157fb insSize: 3	0x1402157fb: mov r10d, r11d
# <DbgId: 3a6> ip: 140175290 insSize: 6	0x140175290: mov r11d, 0xa1bf131f
# <DbgId: 3ef> ip: 140432b9b insSize: 4	0x140432b9b: bt r8, rax
# <DbgId: 41b> ip: 1403b1cfb insSize: 2	0x1403b1cfb: neg dl
# <DbgId: 427> ip: 1403b1d1c insSize: 3	0x1403b1d1c: mov r10d, edx
# <DbgId: 430> ip: 1403b1d42 insSize: 5	0x1403b1d42: shl r11w, 0xcf
# <DbgId: 470> ip: 14018bbc3 insSize: 2	0x14018bbc3: not edx
# <DbgId: 478> ip: 14018bbeb insSize: 3	0x14018bbeb: dec r8
# <DbgId: 4b1> ip: 140305753 insSize: 3	0x140305753: mov r10d, ecx
# <DbgId: 4c2> ip: 140383ed8 insSize: 2	0x140383ed8: not ebx
# <DbgId: 4ce> ip: 140383f0d insSize: 5	0x140383f0d: btc ax, r8w
# <DbgId: 4e3> ip: 140383f77 insSize: 3	0x140383f77: movsx ebx, cl
# <DbgId: 4eb> ip: 140383f96 insSize: 8	0x140383f96: lea r10, [rax*8 - 0x8cf0770]
# <DbgId: 4f4> ip: 140383fc8 insSize: 8	0x140383fc8: lea rcx, [rcx + rsi - 0x58eb2276]
# <DbgId: 59e> ip: 1403911d4 insSize: 7	0x1403911d4: xor r11d, 0xbc8b508d
# <DbgId: 5b5> ip: 1402910b8 insSize: 3	0x1402910b8: movzx ecx, dl
# <DbgId: 5eb> ip: 1403e6454 insSize: 8	0x1403e6454: lea rsi, [r8*2 + 0x6e254da1]
# <DbgId: 5f0> ip: 1403e6477 insSize: 6	0x1403e6477: bt r11w, 0x25
# <DbgId: 613> ip: 1402fea82 insSize: 3	0x1402fea82: movzx esi, al
# <DbgId: 626> ip: 1402fead8 insSize: 3	0x1402fead8: movsx ebx, dx
# <DbgId: 6ed> ip: 140287260 insSize: 2	0x140287260: dec al
# <DbgId: 706> ip: 14042eb1b insSize: 4	0x14042eb1b: bt si, dx
# <DbgId: 714> ip: 14042eb4f insSize: 3	0x14042eb4f: sar r8b, 1
# <DbgId: 725> ip: 14017f231 insSize: 5	0x14017f231: sar r11w, 0x47
# <DbgId: 74c> ip: 1402376f0 insSize: 7	0x1402376f0: add r8, 0x47b74493
# <DbgId: 756> ip: 14023771e insSize: 4	0x14023771e: bt si, bx
# <DbgId: 79d> ip: 14024bdd7 insSize: 3	0x14024bdd7: movsx edx, si
# <DbgId: 7b0> ip: 14020c95d insSize: 4	0x14020c95d: sal dx, 0xeb
# <DbgId: 7c1> ip: 14020c99c insSize: 8	0x14020c99c: lea r11, [rsi*4 - 0x51e1786e]
# <DbgId: 7c5> ip: 14020c9ac insSize: 4	0x14020c9ac: bt cx, cx
# <DbgId: 805> ip: 140138957 insSize: 4	0x140138957: movzx r11d, bx
# <DbgId: 85d> ip: 140223ee7 insSize: 7	0x140223ee7: lea r11, [rbx - 0x3dfcef00]
# <DbgId: 861> ip: 1402a3eb0 insSize: 3	0x1402a3eb0: mov ecx, r8d
# <DbgId: 898> ip: 14013b197 insSize: 3	0x14013b197: shl al, 6
# <DbgId: 926> ip: 14019994c insSize: 2	0x14019994c: not edx
# <DbgId: 952> ip: 14022381f insSize: 4	0x14022381f: shl r11b, 0x85
# <DbgId: 976> ip: 1402801c3 insSize: 4	0x1402801c3: movsx r10d, sil
# <DbgId: 9af> ip: 14042de89 insSize: 3	0x14042de89: mov r8d, esi
# <DbgId: 9c0> ip: 14041b733 insSize: 5	0x14041b733: bt dx, 0x94
# <DbgId: 9c5> ip: 14041b74f insSize: 4	0x14041b74f: movzx r10d, cl
# <DbgId: 9c6> ip: 14041b753 insSize: 3	0x14041b753: shr dx, 1
# <DbgId: a77> ip: 1403d343a insSize: 3	0x1403d343a: bt edx, edx
# <DbgId: a84> ip: 1404772f1 insSize: 4	0x1404772f1: movsx r8d, r11w
# <DbgId: a8b> ip: 14047731b insSize: 3	0x14047731b: adc rbx, rbx
# <DbgId: ab2> ip: 1404773b2 insSize: 3	0x1404773b2: sar al, 0xc1
# <DbgId: b15> ip: 140429edf insSize: 3	0x140429edf: bt esi, edx
# <DbgId: b52> ip: 1402896ba insSize: 2	0x1402896ba: bswap ebx
# <DbgId: b54> ip: 1402896c2 insSize: 4	0x1402896c2: sal si, 0xce
# <DbgId: b5c> ip: 1402896e1 insSize: 3	0x1402896e1: shr cl, 4
# <DbgId: bc3> ip: 14022e068 insSize: 2	0x14022e068: cbw
# <DbgId: bdc> ip: 1404a0161 insSize: 3	0x1404a0161: neg rsi
# <DbgId: bec> ip: 1401b3ffb insSize: 2	0x1401b3ffb: cqo
# <DbgId: c42> ip: 1402cf7be insSize: 3	0x1402cf7be: btc ecx, ebx
# <DbgId: c7d> ip: 1401b82cb insSize: 2	0x1401b82cb: bswap esi
# <DbgId: c91> ip: 1402d4c8d insSize: 4	0x1402d4c8d: sal rcx, 0x65
# <DbgId: c9f> ip: 14048a03a insSize: 3	0x14048a03a: rol r8, cl
# <DbgId: cf1> ip: 14048cbaa insSize: 3	0x14048cbaa: adc cl, 0x19
# <DbgId: d00> ip: 14042dcf7 insSize: 8	0x14042dcf7: lea rax, [rbx + rbx*2 - 0x5eff56fd]
# <DbgId: d0c> ip: 1404c0779 insSize: 5	0x1404c0779: bt rsi, 0x36
# <DbgId: d1c> ip: 1404bc503 insSize: 3	0x1404bc503: dec rbx
# <DbgId: d2f> ip: 1404bc548 insSize: 5	0x1404bc548: shl r11w, 0x43
# <DbgId: d33> ip: 1404bc55c insSize: 3	0x1404bc55c: neg dx
# <DbgId: d69> ip: 14047fa64 insSize: 2	0x14047fa64: cqo
# <DbgId: d7d> ip: 1401a44a3 insSize: 3	0x1401a44a3: movsx esi, bl
# <DbgId: d90> ip: 1401a4501 insSize: 5	0x1401a4501: btr dx, r11w
# <DbgId: dd8> ip: 140289509 insSize: 1	0x140289509: cdq
# <DbgId: dd9> ip: 14028950a insSize: 1	0x14028950a: cdq
# <DbgId: de8> ip: 140289549 insSize: 4	0x140289549: bt edx, 0x88
# <DbgId: e19> ip: 14042eae9 insSize: 5	0x14042eae9: btr r10w, r11w
# <DbgId: e21> ip: 1403103e6 insSize: 3	0x1403103e6: movzx ecx, ax
# <DbgId: e71> ip: 1403b55c3 insSize: 3	0x1403b55c3: xchg r10b, r11b
# <DbgId: e76> ip: 1403b55d2 insSize: 4	0x1403b55d2: ror ax, 0xc9
# <DbgId: e9a> ip: 14046900e insSize: 8	0x14046900e: lea rbx, [r11 + r11*2 - 0x21d5db6a]
# <DbgId: eab> ip: 14027172d insSize: 4	0x14027172d: bt rdx, rsi
# <DbgId: eb4> ip: 14021ddb5 insSize: 4	0x14021ddb5: bt esi, 0x81
# <DbgId: eca> ip: 14019aeb6 insSize: 3	0x14019aeb6: sal dl, 0xa1
# <DbgId: ef8> ip: 14018cbfb insSize: 4	0x14018cbfb: movsx r10d, r8w
# <DbgId: f06> ip: 1402d8f88 insSize: 6	0x1402d8f88: mov r8d, 0xc209f134
# <DbgId: f0c> ip: 1402d8fa6 insSize: 3	0x1402d8fa6: and dx, dx
# <DbgId: f20> ip: 1404ba8e5 insSize: 4	0x1404ba8e5: movzx r11d, bx
# <DbgId: f28> ip: 1404ba903 insSize: 4	0x1404ba903: bt esi, 0xa4
# <DbgId: f40> ip: 140174d7a insSize: 3	0x140174d7a: not r8
# <DbgId: f6a> ip: 1401c3a80 insSize: 6	0x1401c3a80: mov r11d, 0x38103c04
# <DbgId: f76> ip: 14015ae11 insSize: 3	0x14015ae11: neg dx
# <DbgId: f8a> ip: 1401e3500 insSize: 3	0x1401e3500: bt eax, ecx
# <DbgId: fbb> ip: 140244b9c insSize: 5	0x140244b9c: mov ebx, 0x95940e06
# <DbgId: fd9> ip: 1401e4dec insSize: 4	0x1401e4dec: sal r10, 0x42
# <DbgId: 1085> ip: 140491b45 insSize: 8	0x140491b45: lea rdx, [r8 + rsi - 0x4ae82741]
# <DbgId: 10c0> ip: 1402a989d insSize: 3	0x1402a989d: sal bl, 0x23
# <DbgId: 1135> ip: 1401b84d1 insSize: 5	0x1401b84d1: bt r8d, 0x28
# <DbgId: 1137> ip: 1401b84d8 insSize: 1	0x1401b84d8: cwde
# <DbgId: 113b> ip: 1401b84e7 insSize: 3	0x1401b84e7: shl cl, 7
# <DbgId: 1169> ip: 14028d5c6 insSize: 3	0x14028d5c6: dec si
# <DbgId: 116c> ip: 14028d5d5 insSize: 5	0x14028d5d5: mov ebx, 0xc11c885
# <DbgId: 1170> ip: 14028d5ea insSize: 8	0x14028d5ea: lea rdx, [r8*2 + 0x53258da9]
# <DbgId: 118f> ip: 1404b2a9d insSize: 4	0x1404b2a9d: shr dx, 0x23
# <DbgId: 11dc> ip: 14027db63 insSize: 8	0x14027db63: lea r10, [rdx + rax*4 + 0x6193572f]
# <DbgId: 11e1> ip: 14027db76 insSize: 3	0x14027db76: not r8b
# <DbgId: 1223> ip: 14039534e insSize: 2	0x14039534e: not dl
# <DbgId: 1225> ip: 140395357 insSize: 5	0x140395357: bt rax, 0x88
# <DbgId: 1233> ip: 140164585 insSize: 4	0x140164585: movzx r8d, sil
# <DbgId: 123d> ip: 14024340a insSize: 3	0x14024340a: not r11b
# <DbgId: 124b> ip: 14024344a insSize: 5	0x14024344a: btc rsi, 0x2c
# <DbgId: 12a5> ip: 1401e4c4b insSize: 4	0x1401e4c4b: xor r11w, r8w
# <DbgId: 12e3> ip: 140167aeb insSize: 5	0x140167aeb: rol r8w, 0x82
# <DbgId: 12f8> ip: 1404824d4 insSize: 3	0x1404824d4: or dx, ax
# <DbgId: 1335> ip: 1402d8383 insSize: 4	0x1402d8383: bt esi, 0x27
# <DbgId: 14c3> ip: 14043e3db insSize: 3	0x14043e3db: dec dx
# <DbgId: 1564> ip: 14018f301 insSize: 4	0x14018f301: sar dx, 0x69
# <DbgId: 1590> ip: 14016765e insSize: 4	0x14016765e: shr dx, 4
# <DbgId: 1594> ip: 140167670 insSize: 4	0x140167670: movsx r10d, bl
# <DbgId: 15aa> ip: 14048ff59 insSize: 3	0x14048ff59: bt ebx, ebx
# <DbgId: 15b1> ip: 14028a13e insSize: 3	0x14028a13e: movsx edx, ax
# <DbgId: 15bd> ip: 14048daa8 insSize: 3	0x14048daa8: dec r10b
# <DbgId: 15d6> ip: 140429758 insSize: 3	0x140429758: dec rax
# <DbgId: 15fe> ip: 140433a1a insSize: 5	0x140433a1a: mov esi, 0xc3867ab7
# <DbgId: 1651> ip: 140264656 insSize: 8	0x140264656: lea r8, [rdx + rdx*4 - 0x1d7c6cb]
# <DbgId: 166d> ip: 1402646d3 insSize: 8	0x1402646d3: lea r8, [rdx*4 - 0x4cce13d8]
# <DbgId: 1676> ip: 140264703 insSize: 4	0x140264703: bt rbx, rax
# <DbgId: 1683> ip: 1404a8585 insSize: 2	0x1404a8585: mov ecx, eax
# <DbgId: 168e> ip: 1404a85a7 insSize: 3	0x1404a85a7: bt eax, eax
# <DbgId: 169f> ip: 1404ba1b9 insSize: 5	0x1404ba1b9: mov ebx, 0x9c2b5422
# <DbgId: 16b1> ip: 1404ba1f7 insSize: 3	0x1404ba1f7: bt edx, edx
# <DbgId: 16d3> ip: 1404ba273 insSize: 4	0x1404ba273: movzx r10d, r8w
# <DbgId: 170c> ip: 14027a0fe insSize: 4	0x14027a0fe: rol cx, 0x8e
# <DbgId: 173f> ip: 1402085f0 insSize: 5	0x1402085f0: mov esi, 0xb2a9f88e
# <DbgId: 1773> ip: 1402c4d61 insSize: 3	0x1402c4d61: and al, sil
# <DbgId: 1781> ip: 1402c4da3 insSize: 4	0x1402c4da3: movsx r10d, r8b
# <DbgId: 180d> ip: 1404ab03e insSize: 3	0x1404ab03e: shr dx, cl
# <DbgId: 182f> ip: 1401282e0 insSize: 3	0x1401282e0: shr r8b, cl
# <DbgId: 1847> ip: 14041e705 insSize: 8	0x14041e705: lea r10, [r11*8 + 0x2b03aa18]
# <DbgId: 185a> ip: 1401eb046 insSize: 7	0x1401eb046: xor r11d, 0x753ee290
# <DbgId: 18b0> ip: 1404a6bf6 insSize: 3	0x1404a6bf6: dec rsi
# <DbgId: 18b1> ip: 1404a6bf9 insSize: 2	0x1404a6bf9: not cl
# <DbgId: 18bc> ip: 1404a6c1f insSize: 2	0x1404a6c1f: cbw
# <DbgId: 1902> ip: 14032ba87 insSize: 4	0x14032ba87: shl ax, 0x49
# <DbgId: 190d> ip: 14032bab1 insSize: 8	0x14032bab1: lea rax, [rcx + rsi*8 + 0x7632ce9a]
# <DbgId: 199d> ip: 14024084f insSize: 4	0x14024084f: rol r11d, 0x12
# <DbgId: 1aa5> ip: 1403e878a insSize: 5	0x1403e878a: btc rdx, 0x1e
# <DbgId: 1ab4> ip: 1402901c9 insSize: 5	0x1402901c9: bt cx, r11w
# <DbgId: 1ac8> ip: 140290227 insSize: 5	0x140290227: bt rax, 8
# <DbgId: 1ae9> ip: 1403b4d66 insSize: 4	0x1403b4d66: movsx r10d, cx
# <DbgId: 1b04> ip: 1403b4dc6 insSize: 3	0x1403b4dc6: sal r8d, cl
# <DbgId: 1bac> ip: 14012a3e0 insSize: 4	0x14012a3e0: bt rdx, rdx
# <DbgId: 1bc2> ip: 1401bc4eb insSize: 4	0x1401bc4eb: btr esi, r11d
# <DbgId: 1bc6> ip: 1401bc504 insSize: 3	0x1401bc504: bt ecx, ebx
# <DbgId: 1bcf> ip: 1401bc52a insSize: 7	0x1401bc52a: and r8, 0xffffffff933edd18
# <DbgId: 1bd4> ip: 1401bc54f insSize: 4	0x1401bc54f: bt esi, 0x39
# <DbgId: 1bed> ip: 1402b39a7 insSize: 4	0x1402b39a7: bt rbx, rbx
# <DbgId: 1c26> ip: 140377940 insSize: 8	0x140377940: lea r10, [rdx*4 + 0x5e993baa]
# <DbgId: 1c49> ip: 1404627a9 insSize: 3	0x1404627a9: ror cl, 0xe2
# <DbgId: 1c9e> ip: 14042d2fb insSize: 4	0x14042d2fb: shr si, 0x81
# <DbgId: 1ce3> ip: 1403111a4 insSize: 4	0x1403111a4: bt edx, r8d
# <DbgId: 1d46> ip: 14020c42e insSize: 4	0x14020c42e: btr r8d, r8d
# <DbgId: 1d79> ip: 14023226d insSize: 3	0x14023226d: movzx ebx, dx
# <DbgId: 1d96> ip: 14045da7e insSize: 6	0x14045da7e: add ebx, 0x17854c0a
# <DbgId: 1f35> ip: 14023b0e0 insSize: 4	0x14023b0e0: bt ebx, 0x25
# <DbgId: 1f4a> ip: 14016648f insSize: 8	0x14016648f: lea r10, [rsi*2 + 0x4cb5f12c]
# <DbgId: 1f4c> ip: 14016649e insSize: 3	0x14016649e: and rax, r11
# <DbgId: 1f5f> ip: 14029bbce insSize: 3	0x14029bbce: movzx ecx, dx
# <DbgId: 1fb0> ip: 1404b85a6 insSize: 6	0x1404b85a6: bt r8w, 0x8b
# <DbgId: 1fde> ip: 140132361 insSize: 4	0x140132361: bt ax, dx
# <DbgId: 200e> ip: 140163764 insSize: 3	0x140163764: mov r8d, ebx
# <DbgId: 2096> ip: 140473576 insSize: 5	0x140473576: mov ebx, 0x88b6b73e
# <DbgId: 20b5> ip: 140207016 insSize: 4	0x140207016: bt rcx, rbx
# <DbgId: 20f2> ip: 1403f02ae insSize: 3	0x1403f02ae: sete dl
# <DbgId: 20fa> ip: 1401e832e insSize: 5	0x1401e832e: bt r8w, si
# <DbgId: 2102> ip: 1401e834e insSize: 5	0x1401e834e: bt cx, 9
# <DbgId: 213a> ip: 1404a9a4b insSize: 3	0x1404a9a4b: movsx ecx, bl
# <DbgId: 213e> ip: 140157472 insSize: 6	0x140157472: mov r10d, 0xe231e220
# <DbgId: 2163> ip: 14017ef03 insSize: 8	0x14017ef03: lea rsi, [r11 + rdx*4 - 0x5adb97ed]
# <DbgId: 216b> ip: 14017ef32 insSize: 4	0x14017ef32: movzx r8d, sil
# <DbgId: 21cd> ip: 14047c43f insSize: 3	0x14047c43f: sal dx, cl
# <DbgId: 21db> ip: 14041c098 insSize: 4	0x14041c098: sbb r11b, 3
# <DbgId: 2208> ip: 140199453 insSize: 4	0x140199453: setg sil
# <DbgId: 22b4> ip: 140268bc0 insSize: 6	0x140268bc0: mov r10d, 0x9fbd6490
# <DbgId: 22cc> ip: 1403d5771 insSize: 5	0x1403d5771: shr r11w, 0xa5
# <DbgId: 2305> ip: 140457328 insSize: 2	0x140457328: sal edx, cl
# <DbgId: 2375> ip: 14013d7f9 insSize: 3	0x14013d7f9: add rbx, rcx
# <DbgId: 2392> ip: 140127542 insSize: 4	0x140127542: sal si, 0x43
# <DbgId: 23b2> ip: 1404874a7 insSize: 8	0x1404874a7: lea rsi, [rax + rax*4 - 0x5f530ec2]
# <DbgId: 23b4> ip: 1404874b4 insSize: 3	0x1404874b4: shr edx, 0xcc
# <DbgId: 23bc> ip: 1404874cb insSize: 2	0x1404874cb: cbw
# <DbgId: 23ee> ip: 14027cb39 insSize: 4	0x14027cb39: movzx ecx, r8w
# <DbgId: 2423> ip: 14027cc37 insSize: 3	0x14027cc37: sbb r8, rcx
# <DbgId: 244c> ip: 140478b18 insSize: 4	0x140478b18: sal rsi, 0x42
# <DbgId: 2456> ip: 140478b45 insSize: 5	0x140478b45: bt r11w, r11w
# <DbgId: 247b> ip: 14025511f insSize: 4	0x14025511f: movsx r10d, r11w
# <DbgId: 2492> ip: 1402f244f insSize: 4	0x1402f244f: ror rcx, 0x21
# <DbgId: 2493> ip: 1402f2453 insSize: 4	0x1402f2453: bt rax, rdx
# <DbgId: 24c7> ip: 1401b35a5 insSize: 7	0x1401b35a5: add rcx, -0x5b5edcd4
# <DbgId: 24cf> ip: 14048ca73 insSize: 3	0x14048ca73: mov r10d, r8d
# <DbgId: 24df> ip: 14048cac4 insSize: 3	0x14048cac4: shr dl, 0x64
# <DbgId: 24f1> ip: 140155097 insSize: 3	0x140155097: bt ecx, eax
# <DbgId: 2536> ip: 1401ebee2 insSize: 3	0x1401ebee2: setb dl
# <DbgId: 2540> ip: 1403e8e98 insSize: 1	0x1403e8e98: cdq
# <DbgId: 267d> ip: 14022f113 insSize: 6	0x14022f113: mov r11d, 0x8c1a1cb7
# <DbgId: 2696> ip: 14022f173 insSize: 3	0x14022f173: movsx ebx, cx
# <DbgId: 289e> ip: 1401c3aa5 insSize: 3	0x1401c3aa5: dec bx
# <DbgId: 28ab> ip: 1404b1515 insSize: 4	0x1404b1515: shr r8, 0x92
# <DbgId: 28ae> ip: 1404b1522 insSize: 2	0x1404b1522: dec ecx
# <DbgId: 28b7> ip: 1404b155c insSize: 4	0x1404b155c: movsx eax, r11b
# <DbgId: 293f> ip: 14014802b insSize: 4	0x14014802b: and r8w, si
# <DbgId: 2961> ip: 1402e975b insSize: 8	0x1402e975b: lea rcx, [r11 + rbx + 0x3911fa85]
# <DbgId: 2969> ip: 1402e978d insSize: 8	0x1402e978d: lea rcx, [rbx + rbx*8 - 0x575af867]
# <DbgId: 298c> ip: 140436910 insSize: 4	0x140436910: movsx r10d, r11b
# <DbgId: 29b1> ip: 140141b76 insSize: 6	0x140141b76: mov r11d, 0x8c2cdb03
# <DbgId: 29d1> ip: 140461292 insSize: 5	0x140461292: bt dx, r11w
# <DbgId: 2a16> ip: 14030eaea insSize: 3	0x14030eaea: btr edx, ebx
# <DbgId: 2a27> ip: 14030eb27 insSize: 4	0x14030eb27: setb r11b
# <DbgId: 301b> ip: 14028511b insSize: 6	0x14028511b: adc edx, 0xfc176b93
# <DbgId: 303f> ip: 140131544 insSize: 4	0x140131544: sar bx, 0x6e
# <DbgId: 3040> ip: 140131548 insSize: 5	0x140131548: bt ax, 7
# <DbgId: 3043> ip: 140131553 insSize: 2	0x140131553: not edx
# <DbgId: 3065> ip: 14019870b insSize: 3	0x14019870b: sub ax, dx
# <DbgId: 3079> ip: 1401742a6 insSize: 3	0x1401742a6: mov r10d, edx
# <DbgId: 307f> ip: 1401742bc insSize: 8	0x1401742bc: lea rdx, [rsi*2 - 0x2ae70ddb]
# <DbgId: 3084> ip: 1401742dc insSize: 3	0x1401742dc: bt ecx, eax
# <DbgId: 3356> ip: 140192a6c insSize: 4	0x140192a6c: sbb dx, r11w
# <DbgId: 335e> ip: 140192a89 insSize: 3	0x140192a89: xor r10b, bl
# <DbgId: 3369> ip: 140192ac2 insSize: 4	0x140192ac2: bt edx, 0xa3
# <DbgId: 3374> ip: 140216328 insSize: 3	0x140216328: movzx ebp, cl
# <DbgId: 337c> ip: 14021634b insSize: 5	0x14021634b: mov edi, 0x99bcfd33
# <DbgId: 33a3> ip: 14030bfd0 insSize: 6	0x14030bfd0: mov r9d, 0xd5915cb4
# <DbgId: 33ba> ip: 14021cdd2 insSize: 4	0x14021cdd2: sal bpl, 0x22
# <DbgId: 33cd> ip: 140238d96 insSize: 1	0x140238d96: cdq
# <DbgId: 33f1> ip: 14048ab8c insSize: 4	0x14048ab8c: bt ecx, 0xaf
# <DbgId: 340f> ip: 14048ac0f insSize: 5	0x14048ac0f: bt rcx, 0x9d
# <DbgId: 3426> ip: 1401863c0 insSize: 3	0x1401863c0: bswap r9
# <DbgId: 3458> ip: 14026f2d8 insSize: 3	0x14026f2d8: shr ebx, 0xc1
# <DbgId: 345d> ip: 140127220 insSize: 5	0x140127220: bt rdx, 0x1f
# <DbgId: 346e> ip: 14012727c insSize: 5	0x14012727c: or eax, 0x9128113d
# <DbgId: 3482> ip: 1402f4985 insSize: 3	0x1402f4985: not cx
# <DbgId: 363f> ip: 140159d2a insSize: 2	0x140159d2a: mov edi, ebp
# <DbgId: 364b> ip: 1402b8d9c insSize: 8	0x1402b8d9c: lea rdi, [r9 + r9*2 - 0x57f3d0fe]
# <DbgId: 3692> ip: 14041ed3c insSize: 2	0x14041ed3c: not edx
# <DbgId: 36a3> ip: 14041ed70 insSize: 6	0x14041ed70: bt r9w, 0x37
# <DbgId: 3720> ip: 140174bd9 insSize: 3	0x140174bd9: shl dl, 3
# <DbgId: 3726> ip: 140174bfc insSize: 2	0x140174bfc: xor ebp, ebx
# <DbgId: 3740> ip: 1402bbe25 insSize: 5	0x1402bbe25: mov edx, 0xdd858fac
# <DbgId: 37b1> ip: 1404948fb insSize: 2	0x1404948fb: xor ebx, ebx
# <DbgId: 37c5> ip: 1402d0ff3 insSize: 4	0x1402d0ff3: bt eax, 0x1a
# <DbgId: 37e1> ip: 140276835 insSize: 4	0x140276835: movzx r8d, dx
# <DbgId: 3810> ip: 140427c2e insSize: 4	0x140427c2e: bt eax, 0xac
# <DbgId: 384a> ip: 1404a5866 insSize: 4	0x1404a5866: rol r9, 0xd1
# <DbgId: 3881> ip: 140260ee8 insSize: 8	0x140260ee8: lea r8, [rax + rbp*2 - 0x3e60f67e]
# <DbgId: 3937> ip: 1404801d7 insSize: 4	0x1404801d7: bt di, ax
# <DbgId: 3955> ip: 14025abf0 insSize: 4	0x14025abf0: sub dil, 0xa
# <DbgId: 3983> ip: 1404c0dd7 insSize: 2	0x1404c0dd7: dec bl
# <DbgId: 398d> ip: 140160ea3 insSize: 8	0x140160ea3: lea rcx, [rax + rdi*8 + 0x5603c80b]
# <DbgId: 39c9> ip: 140166a78 insSize: 8	0x140166a78: lea rbp, [rbp*2 + 0x6a2ae09b]
# <DbgId: 3a33> ip: 140275807 insSize: 3	0x140275807: or rcx, rax
# <DbgId: 3a3b> ip: 140275827 insSize: 4	0x140275827: bt ebx, 0xb2
# <DbgId: 3a98> ip: 140327d78 insSize: 4	0x140327d78: bt rax, rbx
# <DbgId: 3ade> ip: 140492cc4 insSize: 3	0x140492cc4: movsx edi, dl
# <DbgId: 3b0d> ip: 14046db93 insSize: 4	0x14046db93: shr r9b, 0x83
# <DbgId: 3b39> ip: 140164477 insSize: 4	0x140164477: ror rax, 0x2e
# <DbgId: 3b54> ip: 140163f3a insSize: 3	0x140163f3a: movsx ebx, di
# <DbgId: 3b58> ip: 140163f51 insSize: 5	0x140163f51: mov edx, 0x50922221
# <DbgId: 3b62> ip: 140163f7c insSize: 1	0x140163f7c: cdq
# <DbgId: 3bae> ip: 14024a5f7 insSize: 4	0x14024a5f7: bt dx, bx
# <DbgId: 3bb4> ip: 14024a619 insSize: 4	0x14024a619: bt r9, r9
# <DbgId: 3bc3> ip: 14024a674 insSize: 5	0x14024a674: sbb cx, 0x60b9
# <DbgId: 3bec> ip: 1401ba964 insSize: 3	0x1401ba964: inc bp
# <DbgId: 3bfb> ip: 140146953 insSize: 3	0x140146953: not rcx
# <DbgId: 3c02> ip: 140146975 insSize: 7	0x140146975: lea rcx, [rbx + 0x79138d99]
# <DbgId: 3c49> ip: 1401fed6c insSize: 3	0x1401fed6c: or dx, bp
# <DbgId: 3c50> ip: 1401fed85 insSize: 3	0x1401fed85: not bx
# <DbgId: 3c66> ip: 140145148 insSize: 8	0x140145148: lea rcx, [rcx + rcx*4 + 0xba684aa]
# <DbgId: 3c70> ip: 14014516e insSize: 2	0x14014516e: neg ebp
# <DbgId: 3d14> ip: 140466b5e insSize: 3	0x140466b5e: sub r9b, cl
# <DbgId: 3d1c> ip: 140466b7e insSize: 3	0x140466b7e: setl al
# <DbgId: 3d5d> ip: 140207e61 insSize: 5	0x140207e61: bt di, 7
# <DbgId: 3d75> ip: 1402883b2 insSize: 8	0x1402883b2: lea r9, [rax*8 + 0x1e333ab7]
# <DbgId: 3dcf> ip: 14031efac insSize: 4	0x14031efac: movsx r9d, di
# <DbgId: 3de8> ip: 14020c903 insSize: 1	0x14020c903: cwde
# <DbgId: 3dec> ip: 14020c916 insSize: 4	0x14020c916: movsx r8d, al
# <DbgId: 3e15> ip: 1401f6f4e insSize: 3	0x1401f6f4e: movzx edx, cl
# <DbgId: 3e19> ip: 1401f6f64 insSize: 4	0x1401f6f64: bt bp, cx
# <DbgId: 3e39> ip: 14017f15b insSize: 6	0x14017f15b: add edi, 0xf4125e33
# <DbgId: 3e42> ip: 14017f18d insSize: 7	0x14017f18d: lea r9, [rbp + 0x682e32b8]
# <DbgId: 3e97> ip: 1402c884a insSize: 3	0x1402c884a: dec rbx
# <DbgId: 3eda> ip: 1402276f9 insSize: 4	0x1402276f9: movsx r8d, bpl
# <DbgId: 3f09> ip: 14022c241 insSize: 4	0x14022c241: rol bpl, 0xa4
# <DbgId: 3f24> ip: 140329655 insSize: 4	0x140329655: bt r9d, r9d
# <DbgId: 3f72> ip: 1404ae734 insSize: 3	0x1404ae734: not r8b
# <DbgId: 3f8d> ip: 1401e8b45 insSize: 3	0x1401e8b45: movzx ebp, cl
# <DbgId: 3f8e> ip: 1401e8b48 insSize: 4	0x1401e8b48: setae bpl
# <DbgId: 3faa> ip: 1402fa659 insSize: 2	0x1402fa659: cqo
# <DbgId: 3fe1> ip: 140248320 insSize: 2	0x140248320: rol edi, cl
# <DbgId: 4015> ip: 14019fee3 insSize: 6	0x14019fee3: or edi, 0x8387dd3f
# <DbgId: 403a> ip: 140281f68 insSize: 7	0x140281f68: and rcx, 0xfffffffff681b617
# <DbgId: 403d> ip: 140281f77 insSize: 3	0x140281f77: mov r8d, ebx
# <DbgId: 4050> ip: 140281fb5 insSize: 4	0x140281fb5: bt ax, cx
# <DbgId: 40d5> ip: 1404289dc insSize: 8	0x1404289dc: lea r8, [rdx + rcx*8 - 0x6cd32942]
# <DbgId: 40e1> ip: 140428a0e insSize: 4	0x140428a0e: sal r9w, cl
# <DbgId: 4146> ip: 14031f6e3 insSize: 5	0x14031f6e3: bt r9d, 0xe
# <DbgId: 4162> ip: 14031f755 insSize: 5	0x14031f755: bt bx, 0x24
# <DbgId: 4174> ip: 14043f043 insSize: 4	0x14043f043: bt ebx, 0xb1
# <DbgId: 419d> ip: 140460ce6 insSize: 4	0x140460ce6: or r9b, 0x3e
# <DbgId: 41ad> ip: 14049b419 insSize: 2	0x14049b419: mov ebx, ecx
# <DbgId: 41ba> ip: 14049b44c insSize: 3	0x14049b44c: or rdx, rax
# <DbgId: 41bb> ip: 14049b44f insSize: 3	0x14049b44f: and bpl, bpl
# <DbgId: 422b> ip: 14018aa25 insSize: 2	0x14018aa25: inc edx
# <DbgId: 4234> ip: 14018aa48 insSize: 2	0x14018aa48: cqo
# <DbgId: 4247> ip: 14018aa96 insSize: 4	0x14018aa96: movzx r8d, cl
# <DbgId: 4250> ip: 14018aabd insSize: 3	0x14018aabd: inc bp
# <DbgId: 428d> ip: 1404317bf insSize: 3	0x1404317bf: bt edi, edi
# <DbgId: 4292> ip: 1404317d9 insSize: 5	0x1404317d9: mov ebx, 0xc5118ca2
# <DbgId: 4296> ip: 1403d03cd insSize: 3	0x1403d03cd: setns bl
# <DbgId: 42bb> ip: 1402cc42a insSize: 3	0x1402cc42a: and dl, 0x3e
# <DbgId: 432d> ip: 14018b992 insSize: 7	0x14018b992: lea r8, [rbp - 0x47dd0249]
# <DbgId: 4375> ip: 140167bb2 insSize: 4	0x140167bb2: bt rdx, rcx
# <DbgId: 4391> ip: 14045c90b insSize: 3	0x14045c90b: mov r8d, ecx
# <DbgId: 4392> ip: 14045c90e insSize: 3	0x14045c90e: and r9b, bpl
# <DbgId: 43d7> ip: 14023e800 insSize: 3	0x14023e800: movsx edx, cl
# <DbgId: 43db> ip: 1402215e3 insSize: 4	0x1402215e3: movsx r8d, r9b
# <DbgId: 43e4> ip: 140221607 insSize: 2	0x140221607: cqo
# <DbgId: 43e7> ip: 140221611 insSize: 3	0x140221611: setb cl
# <DbgId: 43e8> ip: 140221614 insSize: 2	0x140221614: cqo
# <DbgId: 442a> ip: 14031a8af insSize: 3	0x14031a8af: movsx edi, dl
# <DbgId: 4438> ip: 140173f84 insSize: 3	0x140173f84: dec di
# <DbgId: 443b> ip: 140173f8b insSize: 3	0x140173f8b: btc ebp, edx
# <DbgId: 4456> ip: 140173feb insSize: 3	0x140173feb: neg bpl
# <DbgId: 44d5> ip: 1404bf96d insSize: 4	0x1404bf96d: bt edx, 0xf
# <DbgId: 44da> ip: 1404bf983 insSize: 3	0x1404bf983: bt ebp, ebp
# <DbgId: 44ea> ip: 14025e9f9 insSize: 4	0x14025e9f9: movsx ebx, r9w
# <DbgId: 4500> ip: 14025ea56 insSize: 4	0x14025ea56: bt edx, 8
# <DbgId: 450c> ip: 14025ea8b insSize: 2	0x14025ea8b: cwd
# <DbgId: 4560> ip: 1401d2e6b insSize: 1	0x1401d2e6b: cwde
# <DbgId: 456b> ip: 140285e03 insSize: 4	0x140285e03: bt ecx, 0x21
# <DbgId: 4573> ip: 140285e2f insSize: 3	0x140285e2f: rol bx, cl
# <DbgId: 4576> ip: 140285e3e insSize: 4	0x140285e3e: ror r9b, 0x41
# <DbgId: 45b2> ip: 140293a59 insSize: 5	0x140293a59: bt bx, r9w
# <DbgId: 4621> ip: 14020a74b insSize: 5	0x14020a74b: bt ax, r9w
# <DbgId: 4623> ip: 14020a758 insSize: 2	0x14020a758: inc edi
# <DbgId: 4637> ip: 1401463a5 insSize: 3	0x1401463a5: movzx ebx, ax
# <DbgId: 463d> ip: 1401463c1 insSize: 7	0x1401463c1: lea rcx, [rax + 0xf8ed8b3]
# <DbgId: 4659> ip: 1404599b7 insSize: 6	0x1404599b7: mov r9d, 0xfa3b0f3f
# <DbgId: 467c> ip: 140459a49 insSize: 3	0x140459a49: ror edx, 0xd9
# <DbgId: 467f> ip: 140459a51 insSize: 4	0x140459a51: bt r9d, eax
# <DbgId: 4682> ip: 140459a5d insSize: 5	0x140459a5d: btc bp, r9w
# <DbgId: 46b2> ip: 14042c44d insSize: 6	0x14042c44d: bt r9w, 0x9d
# <DbgId: 472c> ip: 1401fe5ed insSize: 3	0x1401fe5ed: not r9d
# <DbgId: 4769> ip: 140439558 insSize: 5	0x140439558: mov edx, 0xd98ff612
# <DbgId: 4778> ip: 140463c92 insSize: 5	0x140463c92: mov edi, 0xca2d8201
# <DbgId: 4786> ip: 140463cd3 insSize: 5	0x140463cd3: bt dx, 9
# <DbgId: 478d> ip: 14033b6a6 insSize: 4	0x14033b6a6: bt r9d, edx
# <DbgId: 4820> ip: 14016c75d insSize: 4	0x14016c75d: sub bp, r9w
# <DbgId: 4834> ip: 14016c7b2 insSize: 3	0x14016c7b2: movsx eax, bp
# <DbgId: 4836> ip: 14016c7bd insSize: 3	0x14016c7bd: sets al
# <DbgId: 4910> ip: 1402f1dcb insSize: 4	0x1402f1dcb: add dil, 0x37
# <DbgId: 4924> ip: 1401cfad5 insSize: 4	0x1401cfad5: sal dx, 0x64
# <DbgId: 493f> ip: 140276446 insSize: 6	0x140276446: mov r9d, 0x2baadfb6
# <DbgId: 497f> ip: 1404bb0a6 insSize: 5	0x1404bb0a6: mov edi, 0xc301610f
# <DbgId: 4996> ip: 1404bb0f4 insSize: 2	0x1404bb0f4: mov ebx, eax
# <DbgId: 4997> ip: 1404bb0f6 insSize: 3	0x1404bb0f6: setg bl
# <DbgId: 499b> ip: 1404bb102 insSize: 4	0x1404bb102: movzx r8d, bpl
# <DbgId: 49ad> ip: 140478c49 insSize: 3	0x140478c49: rol edx, 0x5d
# <DbgId: 4a81> ip: 1402b163c insSize: 3	0x1402b163c: rol dl, 0x66
# <DbgId: 4a8a> ip: 1402b1659 insSize: 4	0x1402b1659: sar bpl, 0xc1
# <DbgId: 4ac4> ip: 140129a4e insSize: 8	0x140129a4e: lea rbp, [rcx*4 - 0x32c3fbdd]
# <DbgId: 4c74> ip: 140199311 insSize: 2	0x140199311: and edi, ebp
# <DbgId: 4cac> ip: 1401bb929 insSize: 6	0x1401bb929: mov r9d, 0x8b8cf8be
# <DbgId: 4d8f> ip: 14037bd2c insSize: 6	0x14037bd2c: or ecx, 0x3232e8af
# <DbgId: 4db1> ip: 14039236d insSize: 4	0x14039236d: rol bp, 0x2f
# <DbgId: 4dcc> ip: 1403fb204 insSize: 4	0x1403fb204: movsx r9d, bx
# <DbgId: 4de3> ip: 1403fb27a insSize: 4	0x1403fb27a: movsx r8d, cl
# <DbgId: 4e51> ip: 1404669a8 insSize: 4	0x1404669a8: btc edx, 8
# <DbgId: 4e7b> ip: 140466a82 insSize: 3	0x140466a82: rol edx, 8
# <DbgId: 4ec2> ip: 1404c6b43 insSize: 3	0x1404c6b43: dec bx
# <DbgId: 4ecc> ip: 1401df172 insSize: 5	0x1401df172: mov eax, 0x12c0dbc
# <DbgId: 4eec> ip: 14024d278 insSize: 8	0x14024d278: lea rcx, [r9 + rax - 0x21f494cb]
# <DbgId: 4fc4> ip: 1402e16ad insSize: 4	0x1402e16ad: bt di, di
# <DbgId: 4fc7> ip: 1402e16c1 insSize: 2	0x1402e16c1: mov ecx, ebp
# <DbgId: 4fcc> ip: 1402e16db insSize: 5	0x1402e16db: bt rdi, 0x82
# <DbgId: 4fd0> ip: 140440dac insSize: 4	0x140440dac: bt rax, rbx
# <DbgId: 4fd3> ip: 140440dbb insSize: 3	0x140440dbb: movsx edx, di
# <DbgId: 4fdf> ip: 140440de4 insSize: 5	0x140440de4: mov ebp, 0xa1956c0b
# <DbgId: 4fef> ip: 140440e26 insSize: 4	0x140440e26: bt ax, bx
# <DbgId: 4ff7> ip: 140440e42 insSize: 4	0x140440e42: movsx r8d, r9b
# <DbgId: 50ce> ip: 14021c79f insSize: 3	0x14021c79f: mov r9d, edx
# <DbgId: 50e1> ip: 1401447fd insSize: 2	0x1401447fd: cwd
# <DbgId: 50eb> ip: 140145ddd insSize: 2	0x140145ddd: neg bl
# <DbgId: 5113> ip: 140261e8e insSize: 3	0x140261e8e: movsx edi, al
# <DbgId: 513b> ip: 14048684a insSize: 2	0x14048684a: not ebp
# <DbgId: 5155> ip: 1404868c8 insSize: 4	0x1404868c8: setae bpl
# <DbgId: 51c6> ip: 140313228 insSize: 4	0x140313228: bt dx, dx
# <DbgId: 51da> ip: 140313271 insSize: 4	0x140313271: shr cx, 0x82
# <DbgId: 5245> ip: 1404325af insSize: 4	0x1404325af: movsx r9d, cl
# <DbgId: 5248> ip: 1404325be insSize: 3	0x1404325be: bts edx, edx
# <DbgId: 524f> ip: 1404325dd insSize: 1	0x1404325dd: cdq
# <DbgId: 5252> ip: 1404325e4 insSize: 1	0x1404325e4: cdq
# <DbgId: 5255> ip: 1404325f5 insSize: 6	0x1404325f5: or edx, 0x93858300
# <DbgId: 5263> ip: 14043262b insSize: 5	0x14043262b: adc cx, 0xe13
# <DbgId: 5458> ip: 140199b39 insSize: 3	0x140199b39: sal di, cl
# <DbgId: 5496> ip: 14032464e insSize: 3	0x14032464e: movzx edi, dl
# <DbgId: 549f> ip: 14032467c insSize: 4	0x14032467c: sal r9, 0xb8
# <DbgId: 54d1> ip: 1401fd02c insSize: 4	0x1401fd02c: movsx r8d, r9w
# <DbgId: 54f1> ip: 1404265f6 insSize: 3	0x1404265f6: movsx eax, bl
# <DbgId: 552c> ip: 1401fdc92 insSize: 5	0x1401fdc92: mov ebx, 0x9d25f616
# <DbgId: 5562> ip: 1401f7681 insSize: 2	0x1401f7681: dec cl
# <DbgId: 561a> ip: 14025f407 insSize: 4	0x14025f407: bt rdi, rax
# <DbgId: 561f> ip: 14025f422 insSize: 3	0x14025f422: neg dx
# <DbgId: 5659> ip: 14045763e insSize: 2	0x14045763e: cwd
# <DbgId: 565c> ip: 140457646 insSize: 2	0x140457646: cqo
# <DbgId: 5698> ip: 140484eca insSize: 8	0x140484eca: lea rax, [rdi*4 + 0x7197d0a2]
# <DbgId: 569d> ip: 140484edf insSize: 5	0x140484edf: bt di, 0xb
# <DbgId: 56a4> ip: 140484efa insSize: 4	0x140484efa: bt rdi, rax
# <DbgId: 56a7> ip: 140484f06 insSize: 3	0x140484f06: not bpl
# <DbgId: 56a8> ip: 140484f09 insSize: 3	0x140484f09: shr cl, 0x67
# <DbgId: 56b3> ip: 140484f34 insSize: 8	0x140484f34: lea rax, [rdi*8 + 0x20897235]
# <DbgId: 5711> ip: 140323bbf insSize: 8	0x140323bbf: lea rdx, [rdx*4 - 0x5459d04d]
# <DbgId: 5722> ip: 140323bfe insSize: 4	0x140323bfe: setle dil
# <DbgId: 5840> ip: 1401fd4e8 insSize: 4	0x1401fd4e8: shl rdi, 0xd3
# <DbgId: 584d> ip: 14024b7d0 insSize: 3	0x14024b7d0: bswap rbp
# <DbgId: 5874> ip: 140292638 insSize: 4	0x140292638: movzx eax, dil
# <DbgId: 589d> ip: 140156285 insSize: 3	0x140156285: not bx
# <DbgId: 58bc> ip: 140188dc5 insSize: 1	0x140188dc5: cdq
# <DbgId: 58be> ip: 140188dc8 insSize: 5	0x140188dc8: bts di, r9w
# <DbgId: 591f> ip: 140303d77 insSize: 3	0x140303d77: neg di
# <DbgId: 59ef> ip: 14013a5f0 insSize: 8	0x14013a5f0: lea r8, [rdi*4 - 0x86b6fe7]
# <DbgId: 5aa0> ip: 140497154 insSize: 5	0x140497154: mov edi, 0x3222080b
# <DbgId: 5aa8> ip: 14049717b insSize: 3	0x14049717b: bt ebp, ebx
# <DbgId: 5adf> ip: 1401b6f82 insSize: 8	0x1401b6f82: lea r8, [rdx + rdi*8 + 0x25a0d710]
# <DbgId: 5ae4> ip: 1401b6f9b insSize: 5	0x1401b6f9b: bt r9w, ax
# <DbgId: 5ae7> ip: 1401b6fa7 insSize: 2	0x1401b6fa7: sub edi, ebp
# <DbgId: 5b11> ip: 1404c31b2 insSize: 4	0x1404c31b2: movzx ebx, r9w
# <DbgId: 5b1e> ip: 140175741 insSize: 5	0x140175741: bt rdi, 0xa0
# <DbgId: 5b36> ip: 1401757c6 insSize: 3	0x1401757c6: sub ax, ax
# <DbgId: 5b44> ip: 14046f5f5 insSize: 3	0x14046f5f5: adc rdx, r9
# <DbgId: 5b82> ip: 140486c65 insSize: 2	0x140486c65: neg ebx
# <DbgId: 5bcc> ip: 1402db593 insSize: 4	0x1402db593: sal r9, 0x51
# <DbgId: 5c5f> ip: 140195fd6 insSize: 3	0x140195fd6: bt ebx, ecx
# <DbgId: 5d1b> ip: 1404407e3 insSize: 1	0x1404407e3: cdq
# <DbgId: 5d1e> ip: 1404407ee insSize: 4	0x1404407ee: sal dx, 0xed
# <DbgId: 5d72> ip: 14022ed24 insSize: 5	0x14022ed24: bt rbx, 0x16
# <DbgId: 5d85> ip: 14022ed7a insSize: 3	0x14022ed7a: adc r9, rax
# <DbgId: 5d8d> ip: 14022eda8 insSize: 2	0x14022eda8: neg eax
# <DbgId: 5d95> ip: 14022edd3 insSize: 4	0x14022edd3: movsx ebp, r9w
# <DbgId: 5da4> ip: 14019df85 insSize: 4	0x14019df85: bt rbx, r9
# <DbgId: 5dcc> ip: 140246e4d insSize: 3	0x140246e4d: movzx ebp, bx
# <DbgId: 5dce> ip: 140246e51 insSize: 3	0x140246e51: movzx eax, bp
# <DbgId: 5dd8> ip: 140246e6f insSize: 3	0x140246e6f: sets al
# <DbgId: 5de6> ip: 140246ea9 insSize: 3	0x140246ea9: movzx edx, cl
# <DbgId: 5dff> ip: 1401c63d4 insSize: 4	0x1401c63d4: bt cx, ax
# <DbgId: 5e01> ip: 1401c63e0 insSize: 4	0x1401c63e0: movsx r8d, al
# <DbgId: 5e08> ip: 1401c6412 insSize: 8	0x1401c6412: lea r9, [rdi*2 - 0x5ec8a9de]
# <DbgId: 5e10> ip: 1401b1c07 insSize: 2	0x1401b1c07: xor edi, ecx
# <DbgId: 5e1e> ip: 1401b1c55 insSize: 3	0x1401b1c55: dec r9d
# <DbgId: 5fd6> ip: 1404774ce insSize: 4	0x1404774ce: bt ebp, 0x3f
# <DbgId: 5fe4> ip: 140477500 insSize: 4	0x140477500: sub r9w, ax
# <DbgId: 6044> ip: 14023b72d insSize: 4	0x14023b72d: bt rbx, rbx
# <DbgId: 6049> ip: 14023b74a insSize: 3	0x14023b74a: mov r8d, ebx
# <DbgId: 6054> ip: 1404a6437 insSize: 7	0x1404a6437: lea rdx, [rax + 0x28a48486]
# <DbgId: 6082> ip: 14025dc43 insSize: 2	0x14025dc43: neg edi
# <DbgId: 6083> ip: 14025dc45 insSize: 4	0x14025dc45: neg r9w
# <DbgId: 6092> ip: 14025dc91 insSize: 4	0x14025dc91: bt cx, cx
# <DbgId: 60e6> ip: 1401e0d10 insSize: 5	0x1401e0d10: bt bx, 0x31
# <DbgId: 60e7> ip: 1401e0d15 insSize: 4	0x1401e0d15: movzx r8d, dil
# <DbgId: 6266> ip: 1401e72cf insSize: 8	0x1401e72cf: lea r8, [rdi + rbp - 0x2375c0d2]
# <DbgId: 6286> ip: 1402e2fdc insSize: 3	0x1402e2fdc: xor r9, rdi
# <DbgId: 62c8> ip: 14028fbc0 insSize: 8	0x14028fbc0: lea rbp, [rcx + rdi*2 + 0x550537a9]
# <DbgId: 62d6> ip: 14028fbf1 insSize: 8	0x14028fbf1: lea r8, [rcx*2 - 0x33cf6956]
# <DbgId: 6308> ip: 14031ee85 insSize: 4	0x14031ee85: movzx r8d, cl
# <DbgId: 6310> ip: 14031eeaa insSize: 5	0x14031eeaa: bt di, 0xc
# <DbgId: 63bf> ip: 1401edd08 insSize: 8	0x1401edd08: lea r9, [rdi + rbx + 0x603d52bd]
# <DbgId: 63c1> ip: 1401edd14 insSize: 4	0x1401edd14: bt edi, 0xb0
# <DbgId: 63ee> ip: 14042fe0e insSize: 4	0x14042fe0e: movsx ecx, r9b
# <DbgId: 6414> ip: 14013241f insSize: 7	0x14013241f: xor rbp, 0x782275b3
# <DbgId: 6417> ip: 140132432 insSize: 3	0x140132432: inc r8b
# <DbgId: 641f> ip: 140132452 insSize: 4	0x140132452: setns bpl
# <DbgId: 642b> ip: 140442a2d insSize: 2	0x140442a2d: mov eax, edi
# <DbgId: 6450> ip: 140284958 insSize: 4	0x140284958: bt cx, ax
# <DbgId: 6614> ip: 1404126ab insSize: 2	0x1404126ab: not cl
# <DbgId: 6631> ip: 1401f86d5 insSize: 4	0x1401f86d5: rol r8d, 0x2a
# <DbgId: 663c> ip: 14042dfcc insSize: 4	0x14042dfcc: movzx r10d, si
# <DbgId: 6652> ip: 140136fb4 insSize: 4	0x140136fb4: bt dx, di
# <DbgId: 6692> ip: 14015ffdd insSize: 3	0x14015ffdd: and bx, cx
# <DbgId: 669d> ip: 14016001a insSize: 4	0x14016001a: and dil, 0x17
# <DbgId: 66c1> ip: 14042f5ee insSize: 4	0x14042f5ee: bt rax, rax
# <DbgId: 697f> ip: 14028af5a insSize: 4	0x14028af5a: bt bx, cx
# <DbgId: 6995> ip: 14048d89b insSize: 3	0x14048d89b: adc bx, si
# <DbgId: 699d> ip: 140327ba0 insSize: 4	0x140327ba0: bt ecx, r9d
# <DbgId: 699e> ip: 140327ba4 insSize: 2	0x140327ba4: inc edi
# <DbgId: 69a3> ip: 140327bbd insSize: 3	0x140327bbd: bt eax, edi
# <DbgId: 69b4> ip: 14012aabb insSize: 2	0x14012aabb: mov eax, edx
# <DbgId: 69c0> ip: 1404bd6e7 insSize: 4	0x1404bd6e7: movzx esi, r9w
# <DbgId: 69cb> ip: 14016e7da insSize: 8	0x14016e7da: lea rdi, [rcx*4 - 0x10e871f9]
# <DbgId: 6a10> ip: 1403c60e5 insSize: 2	0x1403c60e5: mov ebp, eax
# <DbgId: 6a21> ip: 1403c6122 insSize: 3	0x1403c6122: mov ecx, r9d
# <DbgId: 6a4a> ip: 1403cb735 insSize: 2	0x1403cb735: mov edx, eax
# <DbgId: 6a6d> ip: 14044752c insSize: 8	0x14044752c: lea rbp, [rax + rsi*2 - 0x4e54e1cc]
# <DbgId: 6aa9> ip: 140322927 insSize: 3	0x140322927: movzx eax, bl
# <DbgId: 6ade> ip: 1402104c5 insSize: 2	0x1402104c5: dec al
# <DbgId: 6ae5> ip: 14020a04c insSize: 2	0x14020a04c: bswap edx
# <DbgId: 6b08> ip: 140137977 insSize: 4	0x140137977: neg r9w
# <DbgId: 6b1a> ip: 1401379ca insSize: 3	0x1401379ca: not rbx
# <DbgId: 6b46> ip: 14030f136 insSize: 4	0x14030f136: movsx ebp, dil
# <DbgId: 6b79> ip: 1404830f0 insSize: 2	0x1404830f0: sub esi, esi
# <DbgId: 6b83> ip: 140170ae4 insSize: 4	0x140170ae4: bts ax, ax
# <DbgId: 6b8c> ip: 140170b03 insSize: 8	0x140170b03: lea rsi, [rbx + rcx*4 - 0x67dad14c]
# <DbgId: 6ba9> ip: 1402975ea insSize: 4	0x1402975ea: movzx edi, r9w
# <DbgId: 6bab> ip: 1402975f3 insSize: 8	0x1402975f3: lea rdx, [r9*4 - 0x16dd1bcf]
# <DbgId: 6bbc> ip: 14029763b insSize: 3	0x14029763b: shl cl, 0x25
# <DbgId: 6bd1> ip: 1401e3882 insSize: 3	0x1401e3882: movsx ebx, si
# <DbgId: 6c45> ip: 140198cec insSize: 2	0x140198cec: mov edi, eax
# <DbgId: 6c4a> ip: 140198d03 insSize: 5	0x140198d03: bt rax, 0x31
# <DbgId: 6c85> ip: 1402c79b6 insSize: 3	0x1402c79b6: movsx esi, al
# <DbgId: 6c92> ip: 1402c79e9 insSize: 8	0x1402c79e9: lea rdi, [rcx*2 - 0x786743]
# <DbgId: 6c9f> ip: 1402c7a1b insSize: 2	0x1402c7a1b: or ebx, ebx
# <DbgId: 6cc8> ip: 1402d65b6 insSize: 3	0x1402d65b6: movzx ebx, si
# <DbgId: 6d26> ip: 1402ce603 insSize: 5	0x1402ce603: bt rcx, 0x9c
# <DbgId: 6d3b> ip: 14027c644 insSize: 5	0x14027c644: bt si, 0x97
# <DbgId: 70e9> ip: 1403fd9d1 insSize: 4	0x1403fd9d1: movsx r11d, dl
# <DbgId: 743b> ip: 1401b6e13 insSize: 4	0x1401b6e13: bt rbx, rdx
# <DbgId: 7445> ip: 1401b6e38 insSize: 3	0x1401b6e38: bt edx, ebx
# <DbgId: 7447> ip: 1401b6e3e insSize: 5	0x1401b6e3e: bts bx, 0x2d
# <DbgId: 7448> ip: 1401b6e43 insSize: 3	0x1401b6e43: bt edi, edi
# <DbgId: 747a> ip: 1402b1e62 insSize: 4	0x1402b1e62: ror dx, 0xa
# <DbgId: 7497> ip: 1402b1ee9 insSize: 3	0x1402b1ee9: bt edi, edi
# <DbgId: 765b> ip: 140144cdd insSize: 2	0x140144cdd: sub esi, ebx
# <DbgId: 7684> ip: 140144d5e insSize: 3	0x140144d5e: or dx, dx
# <DbgId: 768c> ip: 140144d7b insSize: 2	0x140144d7b: cwd
# <DbgId: 7792> ip: 1402a13f8 insSize: 3	0x1402a13f8: movsx eax, dl
# <DbgId: 77b6> ip: 140458ec0 insSize: 2	0x140458ec0: cqo
# <DbgId: 7857> ip: 14014d5a5 insSize: 3	0x14014d5a5: ror bpl, 1
# <DbgId: 785f> ip: 14043b82e insSize: 3	0x14043b82e: movsx eax, bx
# <DbgId: 7892> ip: 1401567c2 insSize: 5	0x1401567c2: bt rbx, 0x1f
# <DbgId: 78a4> ip: 140156807 insSize: 3	0x140156807: bt edx, ebp
# <DbgId: 78a7> ip: 140156810 insSize: 4	0x140156810: add dx, r8w
# <DbgId: 78c4> ip: 140156887 insSize: 3	0x140156887: setl dl
# <DbgId: 79ae> ip: 1401450f4 insSize: 4	0x1401450f4: bt bp, bx
# <DbgId: 79c2> ip: 14042827c insSize: 8	0x14042827c: lea rcx, [r8 + r8*8 + 0x5f0c8e2b]
# <DbgId: 79c3> ip: 140428284 insSize: 4	0x140428284: bt rbp, r8
# <DbgId: 79c4> ip: 140428288 insSize: 1	0x140428288: cwde
# <DbgId: 7b97> ip: 1402543d2 insSize: 3	0x1402543d2: or r10, r10
# <DbgId: 7bd3> ip: 140314926 insSize: 5	0x140314926: btr rcx, 0x3a
# <DbgId: 7bde> ip: 1402e75a3 insSize: 2	0x1402e75a3: sbb ebx, ebp
# <DbgId: 7bf0> ip: 140178fb4 insSize: 8	0x140178fb4: lea rcx, [r10*8 - 0x33d712e9]
# <DbgId: 7c4b> ip: 14027ba25 insSize: 4	0x14027ba25: movzx r9d, r8b
# <DbgId: 7c9f> ip: 140307f2f insSize: 7	0x140307f2f: adc r10d, 0xe5865400
# <DbgId: 7cc9> ip: 14013162f insSize: 4	0x14013162f: movsx r10d, bl
# <DbgId: 7cec> ip: 1401fcf1b insSize: 3	0x1401fcf1b: shr rdx, cl
# <DbgId: 7d0c> ip: 1402c0f73 insSize: 8	0x1402c0f73: lea rdx, [rcx + rax*8 + 0x7fb5140e]
# <DbgId: 7d11> ip: 1402c0f88 insSize: 2	0x1402c0f88: cwd
# <DbgId: 7d1f> ip: 1402c0fda insSize: 3	0x1402c0fda: adc ebp, r8d
# <DbgId: 7dbe> ip: 1402401b6 insSize: 2	0x1402401b6: cwd
# <DbgId: 7e78> ip: 14013711c insSize: 3	0x14013711c: sbb r10b, dl
# <DbgId: 7f5a> ip: 14018ede5 insSize: 3	0x14018ede5: not r9d
# <DbgId: 7f66> ip: 14018ee16 insSize: 3	0x14018ee16: sub dx, bp
# <DbgId: 7fee> ip: 140217102 insSize: 3	0x140217102: movsx ebp, dl
# <DbgId: 8000> ip: 14020d633 insSize: 3	0x14020d633: or r9, rdx
# <DbgId: 800e> ip: 14048032b insSize: 3	0x14048032b: add rbp, r10
# <DbgId: 8014> ip: 140480352 insSize: 5	0x140480352: bts r8d, 0xf
# <DbgId: 8084> ip: 14014502c insSize: 4	0x14014502c: movsx r8d, ax
# <DbgId: 8087> ip: 140145038 insSize: 3	0x140145038: mov r10d, eax
# <DbgId: 809a> ip: 140321dc8 insSize: 3	0x140321dc8: bt ecx, ecx
# <DbgId: 809f> ip: 140321dda insSize: 8	0x140321dda: lea r9, [rbx + rbx - 0x787daa4d]
# <DbgId: 810e> ip: 1404552dc insSize: 4	0x1404552dc: bt ebx, 0xb4
# <DbgId: 8125> ip: 1404ce0ba insSize: 4	0x1404ce0ba: movzx r8d, bl
# <DbgId: 818c> ip: 14045ffd9 insSize: 6	0x14045ffd9: or ebx, 0x343b1a9d
# <DbgId: 8197> ip: 14045e1d8 insSize: 4	0x14045e1d8: sal r10, 0x4a
# <DbgId: 81dc> ip: 14033fa64 insSize: 4	0x14033fa64: movsx ecx, r10w
# <DbgId: 81e9> ip: 140400462 insSize: 4	0x140400462: bt rcx, r10
# <DbgId: 81fa> ip: 1401314fb insSize: 2	0x1401314fb: cdqe
# <DbgId: 8256> ip: 1403f64a5 insSize: 1	0x1403f64a5: cdq
# <DbgId: 8263> ip: 1403f64c8 insSize: 4	0x1403f64c8: movsx r8d, ax
# <DbgId: 8267> ip: 1403f64d7 insSize: 8	0x1403f64d7: lea r8, [rdx*2 - 0x42f4a4ef]
# <DbgId: 826e> ip: 1403f64ec insSize: 5	0x1403f64ec: bt rbp, 0
# <DbgId: 8291> ip: 140340486 insSize: 3	0x140340486: neg r10b
# <DbgId: 82bd> ip: 1402d2c55 insSize: 5	0x1402d2c55: bt bp, 0x22
# <DbgId: 82d4> ip: 140242611 insSize: 4	0x140242611: movsx r9d, r10b
# <DbgId: 8300> ip: 14017ecbf insSize: 3	0x14017ecbf: sar cx, cl
# <DbgId: 8370> ip: 14025557b insSize: 5	0x14025557b: bt r10w, r10w
# <DbgId: 837b> ip: 1402555a0 insSize: 8	0x1402555a0: lea r9, [rbx*8 + 0x679922b8]
# <DbgId: 83a6> ip: 14045a1f6 insSize: 2	0x14045a1f6: mov ebx, eax
# <DbgId: 83d7> ip: 1402bdcdd insSize: 4	0x1402bdcdd: and r10b, 0x1e
# <DbgId: 83da> ip: 1402bdcec insSize: 8	0x1402bdcec: lea r10, [rcx*8 - 0x185214ee]
# <DbgId: 83dc> ip: 1402bdcfc insSize: 8	0x1402bdcfc: lea r10, [r8 + rdx + 0x3a206997]
# <DbgId: 83e0> ip: 1402bdd0a insSize: 4	0x1402bdd0a: bts ax, ax
# <DbgId: 83e9> ip: 1402bdd31 insSize: 3	0x1402bdd31: movzx eax, cl
# <DbgId: 83ea> ip: 1402bdd34 insSize: 5	0x1402bdd34: mov ebp, 0x681cf704
# <DbgId: 8442> ip: 140206565 insSize: 2	0x140206565: dec ebp
# <DbgId: 84a0> ip: 1404a62bd insSize: 3	0x1404a62bd: add bx, cx
# <DbgId: 84a1> ip: 1404a62c0 insSize: 5	0x1404a62c0: bt rbp, 0xa9
# <DbgId: 84c6> ip: 140499bcd insSize: 4	0x140499bcd: bt ebp, 0x9e
# <DbgId: 84f3> ip: 140327ef7 insSize: 2	0x140327ef7: inc cl
# <DbgId: 8516> ip: 14042df12 insSize: 4	0x14042df12: movsx r9d, r8b
# <DbgId: 8518> ip: 14042df1d insSize: 8	0x14042df1d: lea r9, [rcx + rbp*4 + 0x3304e6a6]
# <DbgId: 8537> ip: 140489e2c insSize: 3	0x140489e2c: add r10d, ebp
# <DbgId: 8565> ip: 14042b8c2 insSize: 4	0x14042b8c2: bt ebp, 0xb8
# <DbgId: 8578> ip: 14042b90d insSize: 4	0x14042b90d: bt bx, bx
# <DbgId: 8582> ip: 14042b939 insSize: 4	0x14042b939: not r9w
# <DbgId: 85ab> ip: 1404ccef9 insSize: 4	0x1404ccef9: sal r10, 0xb7
# <DbgId: 85d0> ip: 14042f65a insSize: 6	0x14042f65a: add edx, 0x8f891c20
# <DbgId: 85da> ip: 14042f67a insSize: 1	0x14042f67a: cdq
# <DbgId: 861d> ip: 1403238ca insSize: 4	0x1403238ca: movsx r9d, bl
# <DbgId: 8628> ip: 1403238f5 insSize: 4	0x1403238f5: bt r10d, eax
# <DbgId: 86a0> ip: 14041b9a8 insSize: 2	0x14041b9a8: cdqe
# <DbgId: 86ea> ip: 1402fc152 insSize: 6	0x1402fc152: or edx, 0x84a70a10
# <DbgId: 870a> ip: 140178230 insSize: 4	0x140178230: bt r10, rax
# <DbgId: 870c> ip: 140178238 insSize: 3	0x140178238: rol eax, 0xfc
# <DbgId: 8720> ip: 14017828c insSize: 4	0x14017828c: bt bp, bp
# <DbgId: 8731> ip: 1401782df insSize: 3	0x1401782df: not dx
# <DbgId: 8737> ip: 1401782fa insSize: 3	0x1401782fa: not bx
# <DbgId: 8817> ip: 14048f164 insSize: 4	0x14048f164: sal bx, 0x61
# <DbgId: 8852> ip: 1401a2587 insSize: 3	0x1401a2587: mov r9d, ecx
# <DbgId: 8855> ip: 1401a2595 insSize: 3	0x1401a2595: xor rbp, rax
# <DbgId: 8863> ip: 1401a25d1 insSize: 4	0x1401a25d1: sal r8, 0x81
# <DbgId: 886e> ip: 140482232 insSize: 5	0x140482232: mov ecx, 0x8292f4b5
# <DbgId: 88a0> ip: 14013f163 insSize: 5	0x14013f163: bt rax, 0xad
# <DbgId: 88b8> ip: 14048f4a2 insSize: 3	0x14048f4a2: dec rax
# <DbgId: 892a> ip: 14048466d insSize: 2	0x14048466d: mov ebp, eax
# <DbgId: 8a14> ip: 1402f07af insSize: 5	0x1402f07af: mov ecx, 0x81356d26
# <DbgId: 8a65> ip: 1404a5b9d insSize: 4	0x1404a5b9d: shl cx, 4
# <DbgId: 8a9e> ip: 14045d44b insSize: 4	0x14045d44b: movsx r9d, cx
# <DbgId: 8ad6> ip: 1401dfee2 insSize: 4	0x1401dfee2: ror bx, 0xaa
# <DbgId: 8b22> ip: 1404c4a87 insSize: 2	0x1404c4a87: inc dl
# <DbgId: 8b24> ip: 1404c4a8b insSize: 2	0x1404c4a8b: sub al, ah
# <DbgId: 8b2b> ip: 1404c4ab1 insSize: 1	0x1404c4ab1: cdq
# <DbgId: 8b2f> ip: 1404c4ab9 insSize: 4	0x1404c4ab9: movsx r9d, r8b
# <DbgId: 8b5b> ip: 140290c4a insSize: 2	0x140290c4a: mov ebp, ebx
# <DbgId: 8b64> ip: 140290c74 insSize: 6	0x140290c74: mov r8d, 0xaf152b04
# <DbgId: 8b6f> ip: 140290cad insSize: 4	0x140290cad: bt eax, r10d
# <DbgId: 8b94> ip: 140228e6d insSize: 3	0x140228e6d: movzx ebp, cl
# <DbgId: 8bbc> ip: 1401b4c45 insSize: 5	0x1401b4c45: bt ax, 5
# <DbgId: 8be9> ip: 1404458cf insSize: 4	0x1404458cf: movsx r9d, bpl
# <DbgId: 8c05> ip: 1401433d8 insSize: 5	0x1401433d8: bt r8w, cx
# <DbgId: 8c4d> ip: 1404a13a2 insSize: 4	0x1404a13a2: movzx r9d, al
# <DbgId: 8c73> ip: 1403697a2 insSize: 4	0x1403697a2: rol dx, 0xe8
# <DbgId: 8c74> ip: 1403697a6 insSize: 5	0x1403697a6: and bx, 0xdeae
# <DbgId: 8c7b> ip: 1403697cc insSize: 8	0x1403697cc: lea r8, [rbp*4 + 0x193c6c1e]
# <DbgId: 8c8b> ip: 140369818 insSize: 3	0x140369818: bt edx, ebp
# <DbgId: 8c95> ip: 14036983b insSize: 8	0x14036983b: lea r9, [rbx*8 + 0x30b776b4]
# <DbgId: 8cb3> ip: 1402285fb insSize: 4	0x1402285fb: sal bx, 0x25
# <DbgId: 8cb7> ip: 14022860b insSize: 2	0x14022860b: mov edx, ebp
# <DbgId: 8cbf> ip: 140228627 insSize: 8	0x140228627: lea rdx, [rcx*2 - 0x25e0b3e2]
# <DbgId: 8cd8> ip: 14022869e insSize: 3	0x14022869e: mov r9d, ecx
# <DbgId: 8cdc> ip: 1402286af insSize: 2	0x1402286af: add dl, bh
# <DbgId: 8d0c> ip: 1404a95b9 insSize: 6	0x1404a95b9: mov r10d, 0xe1af6c0d
# <DbgId: 8d1a> ip: 1404a95fb insSize: 5	0x1404a95fb: mov ebp, 0xcc3bc69b
# <DbgId: 8d2e> ip: 1401a8e14 insSize: 8	0x1401a8e14: lea r10, [r8 + r8*8 - 0x4ae0a85c]
# <DbgId: 8d36> ip: 1401a8e33 insSize: 5	0x1401a8e33: bt bx, 0x17
# <DbgId: 8d3a> ip: 1404365ca insSize: 3	0x1404365ca: mov r9d, r10d
# <DbgId: 8d68> ip: 14022dbc9 insSize: 4	0x14022dbc9: movsx r9d, dl
# <DbgId: 8da5> ip: 1403011c4 insSize: 4	0x1403011c4: bts edx, r10d
# <DbgId: 8dc8> ip: 1404ab38c insSize: 4	0x1404ab38c: bt r10d, ecx
# <DbgId: 8e4e> ip: 1401f4de8 insSize: 4	0x1401f4de8: bt bx, bx
# <DbgId: 8ebe> ip: 140247d20 insSize: 2	0x140247d20: not cl
# <DbgId: 8fe8> ip: 1401b3b39 insSize: 8	0x1401b3b39: lea r9, [rdx + r8*2 + 0x283dfa2d]
# <DbgId: 8fee> ip: 1401b3b50 insSize: 1	0x1401b3b50: cdq
# <DbgId: 901d> ip: 1401c3ad0 insSize: 8	0x1401c3ad0: lea rbx, [rdx + rdx*2 - 0x3eda0b47]
# <DbgId: 9047> ip: 14024db46 insSize: 2	0x14024db46: add al, 0xb4
# <DbgId: 9052> ip: 14024c1f4 insSize: 4	0x14024c1f4: bt ebx, 0xe
# <DbgId: 9072> ip: 14043be02 insSize: 4	0x14043be02: movsx r9d, dx
# <DbgId: 909c> ip: 1402a4174 insSize: 5	0x1402a4174: bt cx, 0x2a
# <DbgId: 90b9> ip: 1402a41ef insSize: 2	0x1402a41ef: dec al
# <DbgId: 90f3> ip: 140346ba4 insSize: 4	0x140346ba4: rol cx, 0xa9
# <DbgId: 90f9> ip: 14030294e insSize: 3	0x14030294e: movsx ebx, al
# <DbgId: 9107> ip: 14030298d insSize: 6	0x14030298d: mov r9d, 0x7098cfba
# <DbgId: 9127> ip: 1402cb2b8 insSize: 3	0x1402cb2b8: movzx ebp, bx
# <DbgId: 9142> ip: 140134626 insSize: 3	0x140134626: mov r9d, edx
# <DbgId: 9160> ip: 14033e120 insSize: 8	0x14033e120: lea r9, [rbp*8 - 0xf060d0]
# <DbgId: 91a5> ip: 1401755df insSize: 3	0x1401755df: not rax
# <DbgId: 91b2> ip: 140175612 insSize: 3	0x140175612: setae dl
# <DbgId: 91c0> ip: 140308e8b insSize: 1	0x140308e8b: cwde
# <DbgId: 91d7> ip: 1403b5f0a insSize: 4	0x1403b5f0a: bt r10d, r10d
# <DbgId: 91e3> ip: 1403b5f33 insSize: 3	0x1403b5f33: btc edx, ebx
# <DbgId: 91f5> ip: 1403b5f7c insSize: 4	0x1403b5f7c: movzx r9d, bx
# <DbgId: 91fc> ip: 14035c511 insSize: 4	0x14035c511: movzx r8d, bp
# <DbgId: 922f> ip: 1402fdc1f insSize: 4	0x1402fdc1f: movsx r8d, bp
# <DbgId: 9230> ip: 1402fdc23 insSize: 5	0x1402fdc23: mov ebx, 0xffb44f3d
# <DbgId: 9247> ip: 1403ac1a4 insSize: 4	0x1403ac1a4: shl dx, 0xc7
# <DbgId: 924b> ip: 1403ac1b1 insSize: 8	0x1403ac1b1: lea rdx, [rbp + rcx*4 - 0x78c9b8e5]
# <DbgId: 9275> ip: 14025df54 insSize: 8	0x14025df54: lea rcx, [rax*8 - 0x4dd9aec2]
# <DbgId: 9286> ip: 1401de7c6 insSize: 8	0x1401de7c6: lea r9, [rax + rax + 0x59ae4f0d]
# <DbgId: 928c> ip: 140147b50 insSize: 5	0x140147b50: btr dx, r10w
# <DbgId: 92bb> ip: 14017962e insSize: 3	0x14017962e: sub dl, 0x8a
# <DbgId: 92d8> ip: 1401cda57 insSize: 3	0x1401cda57: and bl, 0xa9
# <DbgId: 92ec> ip: 140277e5b insSize: 8	0x140277e5b: lea r9, [rcx*8 + 0x7aa2b7a9]
# <DbgId: 92f3> ip: 140277e76 insSize: 2	0x140277e76: xchg ah, al
# <DbgId: 92f5> ip: 140277e7f insSize: 4	0x140277e7f: bt ecx, 0xae
# <DbgId: 92f7> ip: 140277e87 insSize: 4	0x140277e87: bt ecx, 0x8b
# <DbgId: 9320> ip: 14046127a insSize: 8	0x14046127a: lea rdx, [r8 + rcx*4 - 0x59fcaad0]
# <DbgId: 9354> ip: 14013cd07 insSize: 3	0x14013cd07: add dl, r8b
# <DbgId: 936c> ip: 14013cd98 insSize: 4	0x14013cd98: movsx r9d, bl
# <DbgId: 936e> ip: 14013cd9e insSize: 3	0x14013cd9e: dec rdx
# <DbgId: 939a> ip: 1404bd512 insSize: 5	0x1404bd512: bt r8d, 0x90
# <DbgId: 93b7> ip: 14042b344 insSize: 4	0x14042b344: bt r10, rax
# <DbgId: 93f0> ip: 1403c5e8a insSize: 4	0x1403c5e8a: movzx r9d, bpl
# <DbgId: 940e> ip: 14021ce37 insSize: 4	0x14021ce37: movsx r9d, bl
# <DbgId: 9429> ip: 1404aa24c insSize: 3	0x1404aa24c: sub ebx, r10d
# <DbgId: 9457> ip: 140450bc6 insSize: 5	0x140450bc6: bt bx, 0x1b
# <DbgId: 9492> ip: 14031f1aa insSize: 4	0x14031f1aa: btc dx, cx
# <DbgId: 94cf> ip: 1403836ff insSize: 2	0x1403836ff: dec cl
# <DbgId: 9518> ip: 14045a69d insSize: 4	0x14045a69d: ror dx, 0x6b
# <DbgId: 9523> ip: 14045a6d2 insSize: 5	0x14045a6d2: bts rdx, 0x87
# <DbgId: 9557> ip: 14046d8a2 insSize: 2	0x14046d8a2: cwd
# <DbgId: 9564> ip: 14046d8cc insSize: 3	0x14046d8cc: or r10, rcx
# <DbgId: 9575> ip: 1404cf36c insSize: 8	0x1404cf36c: lea r10, [rbx*2 + 0x151cea81]
# <DbgId: 95a2> ip: 1403162bf insSize: 4	0x1403162bf: movzx edx, r9w
# <DbgId: 95a6> ip: 1403162d2 insSize: 4	0x1403162d2: btc r9, r9
# <DbgId: 95cc> ip: 1403b380a insSize: 4	0x1403b380a: setb r9b
# <DbgId: 960c> ip: 1402bc2d3 insSize: 3	0x1402bc2d3: bt ebp, eax
# <DbgId: 97a0> ip: 1403807bc insSize: 8	0x1403807bc: lea rcx, [rbp + r10*2 - 0x49e83dc5]
# <DbgId: 97ad> ip: 1402cacb5 insSize: 5	0x1402cacb5: bt rax, 0x18
# <DbgId: 97b4> ip: 1402caccb insSize: 7	0x1402caccb: lea r9, [rcx - 0x68c673f9]
# <DbgId: 97b6> ip: 1402cacd4 insSize: 4	0x1402cacd4: bt rcx, rdx
# <DbgId: 97bc> ip: 140417e32 insSize: 2	0x140417e32: dec al
# <DbgId: 97c0> ip: 140417e40 insSize: 5	0x140417e40: btr bx, 0x2b
# <DbgId: 97d1> ip: 14046eac1 insSize: 5	0x14046eac1: mov eax, 0x8228dd8d
# ...
# <DbgId: 162f5> ip: 1404309d4 insSize: 5	0x1404309d4: btr r10w, r10w
# <DbgId: 16310> ip: 14018d463 insSize: 3	0x14018d463: movsx edx, bx
# <DbgId: 16313> ip: 14018d46b insSize: 4	0x14018d46b: bt ecx, 0x3b
# <DbgId: 16323> ip: 14018d4a3 insSize: 3	0x14018d4a3: bt esi, ebp
# <DbgId: 1633d> ip: 14018d50d insSize: 3	0x14018d50d: ror edx, 0x79
# <DbgId: 16354> ip: 1402f284b insSize: 4	0x1402f284b: dec r10w
# <DbgId: 163a1> ip: 140472807 insSize: 2	0x140472807: cdqe
# <DbgId: 163c8> ip: 1404728b1 insSize: 3	0x1404728b1: inc r8
# <DbgId: 165ce> ip: 140485622 insSize: 2	0x140485622: bswap ecx
# <DbgId: 1661b> ip: 140264963 insSize: 4	0x140264963: movsx r8d, si
# <DbgId: 1661d> ip: 14026496a insSize: 4	0x14026496a: movzx eax, sil
# <DbgId: 16621> ip: 140264978 insSize: 3	0x140264978: movzx ebp, dl
# <DbgId: 1662b> ip: 14029179e insSize: 4	0x14029179e: movsx edi, r10w
# <DbgId: 1664d> ip: 140371bf7 insSize: 4	0x140371bf7: bt esi, 0xac
# <DbgId: 1669b> ip: 14027ce5e insSize: 4	0x14027ce5e: dec r11w
# <DbgId: 166b4> ip: 140314ac7 insSize: 4	0x140314ac7: sub r11w, si
# <DbgId: 16904> ip: 14021efb0 insSize: 5	0x14021efb0: bt di, 0x82
# <DbgId: 169a4> ip: 1401415eb insSize: 4	0x1401415eb: bt r11d, eax
# <DbgId: 169a6> ip: 1401415f6 insSize: 3	0x1401415f6: setle dl
# <DbgId: 169be> ip: 1402366cd insSize: 4	0x1402366cd: rol rdi, 0xa7
# <DbgId: 169f3> ip: 1402f1d53 insSize: 3	0x1402f1d53: and sil, bpl
# <DbgId: 16acb> ip: 140220f55 insSize: 2	0x140220f55: dec cl
# <DbgId: 16add> ip: 140220f9a insSize: 2	0x140220f9a: or al, dh
# <DbgId: 16ae0> ip: 140220fa0 insSize: 4	0x140220fa0: btc edx, 0x2c
# <DbgId: 16aff> ip: 1403230cc insSize: 3	0x1403230cc: bswap r11d
# <DbgId: 16db5> ip: 140257625 insSize: 4	0x140257625: bt edi, 0x1a
# <DbgId: 16dba> ip: 140257632 insSize: 3	0x140257632: neg rcx
# <DbgId: 16dc2> ip: 14025764b insSize: 2	0x14025764b: xor bl, dl
# <DbgId: 1707b> ip: 1403a0015 insSize: 8	0x1403a0015: lea rax, [rcx + rcx*2 - 0x537defd8]
# <DbgId: 170a9> ip: 1404a7e44 insSize: 3	0x1404a7e44: mov r10d, r8d
# <DbgId: 170d4> ip: 14022466c insSize: 4	0x14022466c: bt r11, rsi
# <DbgId: 1719d> ip: 140274ee7 insSize: 4	0x140274ee7: shl cx, 0xc9
# <DbgId: 171bc> ip: 140274f4d insSize: 4	0x140274f4d: movzx r10d, dx
# <DbgId: 171d0> ip: 1404c0140 insSize: 4	0x1404c0140: bt r8d, edx
# <DbgId: 1720f> ip: 1404ca140 insSize: 3	0x1404ca140: bswap r8
# <DbgId: 17246> ip: 14019d9c3 insSize: 1	0x14019d9c3: cdq
# <DbgId: 17283> ip: 140151c7d insSize: 5	0x140151c7d: bt dx, r8w
# <DbgId: 1728f> ip: 140151ca9 insSize: 4	0x140151ca9: movzx r10d, r8b
# <DbgId: 17303> ip: 1401dd538 insSize: 8	0x1401dd538: lea rax, [rdx + rdx*2 - 0xfdabb4a]
# <DbgId: 1731a> ip: 140243f56 insSize: 3	0x140243f56: sar cl, 0x61
# <DbgId: 1733f> ip: 14041d0e7 insSize: 3	0x14041d0e7: sub r11b, al
# <DbgId: 17346> ip: 14041d103 insSize: 3	0x14041d103: movzx ebx, si
# <DbgId: 1734b> ip: 14016ba82 insSize: 5	0x14016ba82: bt r8d, 0x99
# <DbgId: 1734f> ip: 14016ba8e insSize: 3	0x14016ba8e: dec si
# <DbgId: 17353> ip: 14016ba9e insSize: 3	0x14016ba9e: movsx edx, bx
# <DbgId: 17379> ip: 1401b2b28 insSize: 2	0x1401b2b28: dec dl
# <DbgId: 173af> ip: 140245328 insSize: 3	0x140245328: xor ax, bx
# <DbgId: 173b1> ip: 140245332 insSize: 5	0x140245332: sar r10w, 0x2f
# <DbgId: 17413> ip: 140185251 insSize: 1	0x140185251: cwde
# <DbgId: 17469> ip: 1402fb51e insSize: 5	0x1402fb51e: btr r11, 0xb1
# <DbgId: 174c3> ip: 14014a27c insSize: 4	0x14014a27c: movsx r10d, r11w
# <DbgId: 174cf> ip: 14014a29e insSize: 5	0x14014a29e: bt r11w, ax
# <DbgId: 174e3> ip: 140229d94 insSize: 4	0x140229d94: movsx r11d, cl
# <DbgId: 17508> ip: 1404ab8dc insSize: 4	0x1404ab8dc: bt dx, cx
# <DbgId: 1759a> ip: 140419d9e insSize: 8	0x140419d9e: lea rax, [rsi*8 + 0x6e2af301]
# <DbgId: 175ae> ip: 140419ded insSize: 4	0x140419ded: rol r11, 0xc4
# <DbgId: 175b7> ip: 140419e26 insSize: 8	0x140419e26: lea rbx, [rax + rcx - 0x12d7dbfb]
# <DbgId: 175d4> ip: 1402b49aa insSize: 2	0x1402b49aa: mov esi, ebx
# <DbgId: 175d8> ip: 1402b49b8 insSize: 4	0x1402b49b8: movsx r11d, cx
# <DbgId: 175df> ip: 1402b49d8 insSize: 4	0x1402b49d8: bt si, si
# <DbgId: 175f3> ip: 1402b4a2c insSize: 1	0x1402b4a2c: cwde
# <DbgId: 175f9> ip: 14049b300 insSize: 4	0x14049b300: shl r8b, 0x85
# <DbgId: 17636> ip: 1404b5750 insSize: 3	0x1404b5750: mov r11d, r8d
# <DbgId: 1763f> ip: 1404b577a insSize: 2	0x1404b577a: mov edx, ecx
# <DbgId: 1765b> ip: 1403224df insSize: 3	0x1403224df: xor rdx, r11
# <DbgId: 1769a> ip: 1402a2180 insSize: 4	0x1402a2180: bt r8d, r8d
# <DbgId: 176e2> ip: 1403f3c3e insSize: 8	0x1403f3c3e: lea rcx, [r11*8 + 0x681fbe22]
# <DbgId: 17727> ip: 1402b8b2c insSize: 2	0x1402b8b2c: ror edx, cl
# <DbgId: 1775b> ip: 14032caec insSize: 8	0x14032caec: lea r10, [rsi + rbx*8 + 0x38041a21]
# <DbgId: 177da> ip: 14021b2e0 insSize: 7	0x14021b2e0: xor r11d, 0xa51d4721
# <DbgId: 17811> ip: 140304388 insSize: 3	0x140304388: bt eax, edx
# <DbgId: 1786e> ip: 1402ce99e insSize: 5	0x1402ce99e: bt si, 0x36
# <DbgId: 1787d> ip: 1402ce9d4 insSize: 4	0x1402ce9d4: bt rdx, rsi
# <DbgId: 17ab0> ip: 14047ece2 insSize: 4	0x14047ece2: bt rcx, rax
# <DbgId: 17abd> ip: 14015ec80 insSize: 4	0x14015ec80: bt rax, rdx
# <DbgId: 17b02> ip: 1403d8e6e insSize: 3	0x1403d8e6e: shl edx, 0x2b
# <DbgId: 17b0c> ip: 1404a91a2 insSize: 3	0x1404a91a2: add dx, bx
# <DbgId: 17b16> ip: 1404a91c1 insSize: 1	0x1404a91c1: cdq
# <DbgId: 17b20> ip: 1404497e5 insSize: 2	0x1404497e5: cwd
# <DbgId: 17b40> ip: 14027faca insSize: 2	0x14027faca: neg edx
# <DbgId: 17ba1> ip: 140226d17 insSize: 4	0x140226d17: movsx r10d, ax
# <DbgId: 17bb5> ip: 14017b8f4 insSize: 8	0x14017b8f4: lea rbx, [rsi*8 + 0x1326e09a]
# <DbgId: 17bc0> ip: 14017b922 insSize: 2	0x14017b922: cwd
# <DbgId: 17c7c> ip: 14030e63a insSize: 5	0x14030e63a: bts rbx, 0xba
# <DbgId: 17c95> ip: 1404b3765 insSize: 2	0x1404b3765: not eax
# <DbgId: 17cae> ip: 14049162e insSize: 3	0x14049162e: movsx eax, cl
# <DbgId: 17cba> ip: 140491661 insSize: 3	0x140491661: btc edx, edx
# <DbgId: 17cd1> ip: 14015de53 insSize: 3	0x14015de53: mov r10d, eax
# <DbgId: 17d68> ip: 14047dde7 insSize: 8	0x14047dde7: lea r8, [rsi*8 - 0x694c7075]
# <DbgId: 17d90> ip: 1401e1d44 insSize: 3	0x1401e1d44: btc eax, ecx
# <DbgId: 17db4> ip: 1404a3154 insSize: 3	0x1404a3154: movzx ebx, cx
# <DbgId: 17e08> ip: 1403e0adb insSize: 3	0x1403e0adb: shl cl, 0x26
# <DbgId: 17e1c> ip: 14016857c insSize: 5	0x14016857c: bt ax, 0x91
# <DbgId: 17e21> ip: 140168595 insSize: 4	0x140168595: cmovae rbx, r8
# <DbgId: 17eac> ip: 140215ebc insSize: 3	0x140215ebc: adc r8b, bl
# <DbgId: 17eb3> ip: 140215edf insSize: 4	0x140215edf: btr cx, dx
# <DbgId: 17ed2> ip: 1404baf0b insSize: 2	0x1404baf0b: cqo
# <DbgId: 17ed8> ip: 1404baf1e insSize: 4	0x1404baf1e: ror r8, 0xa6
# <DbgId: 17f33> ip: 1402e9ccc insSize: 8	0x1402e9ccc: lea r11, [r11*4 - 0x24d5dff5]
# <DbgId: 17f34> ip: 1402e9cd4 insSize: 4	0x1402e9cd4: movzx r10d, bx
# <DbgId: 17f71> ip: 1402d82b7 insSize: 5	0x1402d82b7: btr bx, 0xb8
# <DbgId: 17fc8> ip: 1402655fe insSize: 4	0x1402655fe: bt cx, si
# <DbgId: 17fcd> ip: 14026560f insSize: 4	0x14026560f: ror r11b, 0xc2
# <DbgId: 17fd9> ip: 140303dd1 insSize: 4	0x140303dd1: movzx r11d, si
# <DbgId: 18042> ip: 1403e8757 insSize: 8	0x1403e8757: lea rdx, [r8*8 + 0x70abca1d]
# <DbgId: 1805d> ip: 140436562 insSize: 6	0x140436562: mov r10d, 0x8b36099f
# <DbgId: 1805e> ip: 140436568 insSize: 5	0x140436568: bt r11w, si
# <DbgId: 1806f> ip: 14016c398 insSize: 4	0x14016c398: movsx esi, r8b
# <DbgId: 18073> ip: 1403b8c1c insSize: 7	0x1403b8c1c: sbb rbx, -0x5074cd6a
# <DbgId: 1811b> ip: 14043fedf insSize: 3	0x14043fedf: mov r8d, edx
# <DbgId: 1811f> ip: 14043fef0 insSize: 4	0x14043fef0: movzx r10d, r11w
# <DbgId: 18135> ip: 14027716b insSize: 4	0x14027716b: bt rcx, rax
# <DbgId: 1813f> ip: 14027718e insSize: 2	0x14027718e: cwd
# <DbgId: 18198> ip: 1401feb6a insSize: 4	0x1401feb6a: movsx r10d, dx
# <DbgId: 1822a> ip: 140471203 insSize: 5	0x140471203: mov ecx, 0xfb8a7fbc
# <DbgId: 1822e> ip: 14047121d insSize: 3	0x14047121d: movsx edx, al
# <DbgId: 1823a> ip: 14012a928 insSize: 1	0x14012a928: cdq
# <DbgId: 18246> ip: 14031926c insSize: 6	0x14031926c: mov r10d, 0x29294205
# <DbgId: 1826b> ip: 1401de9c5 insSize: 4	0x1401de9c5: bt rbx, rdx
# <DbgId: 1826c> ip: 1401de9c9 insSize: 4	0x1401de9c9: movsx eax, r8b
# <DbgId: 182da> ip: 1404276cc insSize: 5	0x1404276cc: mov edx, 0xb237a22a
# <DbgId: 182f6> ip: 140427752 insSize: 4	0x140427752: bt eax, 0x95
# <DbgId: 182f7> ip: 140427756 insSize: 3	0x140427756: mov r10d, ecx
# <DbgId: 184c9> ip: 140278ca7 insSize: 2	0x140278ca7: mov ebx, esi
# <DbgId: 184d1> ip: 140278cbc insSize: 3	0x140278cbc: and dl, 0x14
# <DbgId: 184de> ip: 1402b6c0b insSize: 4	0x1402b6c0b: btr r8d, ebx
# <DbgId: 184f5> ip: 140172b32 insSize: 3	0x140172b32: sub dl, 0x2e
# <DbgId: 184fa> ip: 140172b40 insSize: 3	0x140172b40: not r8
# <DbgId: 184ff> ip: 140172b55 insSize: 2	0x140172b55: mov ecx, edx
# <DbgId: 18512> ip: 140172bab insSize: 2	0x140172bab: not cl
# <DbgId: 18513> ip: 140172bad insSize: 3	0x140172bad: and dl, r11b
# <DbgId: 1853a> ip: 1402fc6ad insSize: 8	0x1402fc6ad: lea rsi, [r11*8 - 0x73e853e7]
# <DbgId: 18559> ip: 1402ab266 insSize: 3	0x1402ab266: sal rdx, cl
# <DbgId: 1855a> ip: 1402ab269 insSize: 5	0x1402ab269: or eax, 0xa6a2c19a
# <DbgId: 18581> ip: 1402ff482 insSize: 4	0x1402ff482: bt r8, rax
# <DbgId: 18596> ip: 140369590 insSize: 4	0x140369590: bt rdx, rcx
# <DbgId: 18616> ip: 14015e1e9 insSize: 3	0x14015e1e9: mov ebx, r11d
# <DbgId: 18628> ip: 14015e22c insSize: 3	0x14015e22c: setbe bl
# <DbgId: 18640> ip: 140456d01 insSize: 4	0x140456d01: movzx r11d, cx
# <DbgId: 18647> ip: 140456d22 insSize: 8	0x140456d22: lea r8, [rdx*4 - 0x60dad877]
# <DbgId: 18677> ip: 140309c1a insSize: 5	0x140309c1a: bt ax, r8w
# <DbgId: 1868c> ip: 14022f67b insSize: 8	0x14022f67b: lea rdx, [rax*2 + 0x52088b89]
# <DbgId: 186c2> ip: 14025fb59 insSize: 3	0x14025fb59: mov esi, r11d
# <DbgId: 186c5> ip: 14025fb69 insSize: 4	0x14025fb69: bt r8d, eax
# <DbgId: 186e1> ip: 14015b46c insSize: 4	0x14015b46c: shr r10b, 0x61
# <DbgId: 186e3> ip: 14015b475 insSize: 5	0x14015b475: bt rax, 0x23
# <DbgId: 18704> ip: 14031e9e6 insSize: 3	0x14031e9e6: rol edx, 0x46
# <DbgId: 1870c> ip: 14031ea0c insSize: 5	0x14031ea0c: adc dx, 0xd897
# <DbgId: 18739> ip: 14020d262 insSize: 3	0x14020d262: and r11, rdx
# <DbgId: 1873e> ip: 1404a3e7d insSize: 4	0x1404a3e7d: shr sil, 0xa2
# <DbgId: 18742> ip: 1404a3e93 insSize: 2	0x1404a3e93: mov ebx, eax
# <DbgId: 18747> ip: 1402dd579 insSize: 2	0x1402dd579: xor dl, ah
# <DbgId: 1875c> ip: 140273700 insSize: 3	0x140273700: add cx, dx
# <DbgId: 18781> ip: 1401942b3 insSize: 4	0x1401942b3: inc r11w
# <DbgId: 1887b> ip: 1402f6b56 insSize: 4	0x1402f6b56: movsx r8d, sil
# <DbgId: 18898> ip: 14019dee6 insSize: 4	0x14019dee6: movzx r10d, r11b
# <DbgId: 1889a> ip: 14019def1 insSize: 3	0x14019def1: and dx, cx
# <DbgId: 188c8> ip: 1402394f2 insSize: 3	0x1402394f2: movsx ebx, ax
# <DbgId: 188d6> ip: 1403014e1 insSize: 2	0x1403014e1: cbw
# <DbgId: 18b0b> ip: 1401b9d74 insSize: 4	0x1401b9d74: movzx esi, r8b
# <DbgId: 18b33> ip: 14049d4de insSize: 2	0x14049d4de: neg ecx
# <DbgId: 18c09> ip: 1401de5da insSize: 8	0x1401de5da: lea rbx, [rdx*8 - 0x2e85b50]
# <DbgId: 18c9a> ip: 1401900ef insSize: 3	0x1401900ef: ror bl, 2
# <DbgId: 18cb3> ip: 140190171 insSize: 3	0x140190171: rol dl, 0xe2
# <DbgId: 18cb4> ip: 140190174 insSize: 1	0x140190174: cdq
# <DbgId: 18d35> ip: 140424cbe insSize: 5	0x140424cbe: mov ecx, 0xcd8c1008
# <DbgId: 18d80> ip: 14019e02c insSize: 4	0x14019e02c: rol r11, 0x9f
# <DbgId: 18dc7> ip: 1403b6e93 insSize: 3	0x1403b6e93: sub r11b, al
# <DbgId: 18dd5> ip: 1403b6ef1 insSize: 2	0x1403b6ef1: cqo
# <DbgId: 18ddd> ip: 1403b6f1f insSize: 2	0x1403b6f1f: cwd
# <DbgId: 191eb> ip: 1401cbae7 insSize: 3	0x1401cbae7: bt ecx, ebx
# <DbgId: 191f1> ip: 1401cbb04 insSize: 3	0x1401cbb04: and edx, r11d
# <DbgId: 191f8> ip: 1401f385a insSize: 3	0x1401f385a: inc r11b
# <DbgId: 19203> ip: 1404557cb insSize: 3	0x1404557cb: neg cx
# <DbgId: 1926c> ip: 1402cc961 insSize: 3	0x1402cc961: bt eax, eax
# <DbgId: 1927c> ip: 14042b1a2 insSize: 2	0x14042b1a2: not cl
# <DbgId: 19290> ip: 14042b1f1 insSize: 3	0x14042b1f1: inc rdx
# <DbgId: 19299> ip: 14042b20f insSize: 3	0x14042b20f: neg r8d
# <DbgId: 1937e> ip: 14047d96a insSize: 4	0x14047d96a: movsx r10d, r8w
# <DbgId: 19383> ip: 14047d98a insSize: 2	0x14047d98a: cwd
# <DbgId: 19387> ip: 14047d99f insSize: 3	0x14047d99f: not r8d
# <DbgId: 193b7> ip: 1402dc2a2 insSize: 8	0x1402dc2a2: lea r10, [rdx*8 - 0x5cfdafc1]
# <DbgId: 1951a> ip: 1401bde4f insSize: 4	0x1401bde4f: movzx r11d, dl
# <DbgId: 19521> ip: 1401bde71 insSize: 3	0x1401bde71: mov ecx, r8d
# <DbgId: 1952e> ip: 1401bdeb4 insSize: 8	0x1401bdeb4: lea rax, [rsi + r8*4 - 0x70632ad2]
# <DbgId: 19533> ip: 1402a8ad6 insSize: 2	0x1402a8ad6: cqo
# <DbgId: 1953b> ip: 1402a8aeb insSize: 8	0x1402a8aeb: lea rax, [rbx*2 + 0x3d21ac03]
# <DbgId: 1955a> ip: 1403f032d insSize: 4	0x1403f032d: xor r8b, 0x81
# <DbgId: 19562> ip: 140427f90 insSize: 4	0x140427f90: movzx r8d, bx
# <DbgId: 1957a> ip: 140433607 insSize: 4	0x140433607: movzx r10d, dx
# <DbgId: 1968b> ip: 14031b0f3 insSize: 5	0x14031b0f3: mov ecx, 0xfdb78b3f
# <DbgId: 196a6> ip: 14031b181 insSize: 4	0x14031b181: shl r11d, 0x69
# <DbgId: 196a8> ip: 14031b18d insSize: 4	0x14031b18d: movsx r8d, si
# <DbgId: 196c1> ip: 140126893 insSize: 3	0x140126893: neg r8b
# <DbgId: 196c3> ip: 140126899 insSize: 3	0x140126899: movzx eax, cx
# <DbgId: 19a91> ip: 14014755a insSize: 3	0x14014755a: bt ebx, edx
# <DbgId: 19a92> ip: 14014755d insSize: 3	0x14014755d: movzx eax, bx
# <DbgId: 19ade> ip: 140238bdc insSize: 3	0x140238bdc: movsx eax, si
# <DbgId: 19aef> ip: 140451895 insSize: 3	0x140451895: setl dl
# <DbgId: 19af8> ip: 1404518ba insSize: 3	0x1404518ba: bt esi, edx
# <DbgId: 19afd> ip: 1404518ce insSize: 4	0x1404518ce: dec r8w
# <DbgId: 19b14> ip: 140451940 insSize: 2	0x140451940: cwd
# <DbgId: 19b20> ip: 1401b1f95 insSize: 3	0x1401b1f95: cmovnp edx, eax
# <DbgId: 19b86> ip: 14044ebfd insSize: 5	0x14044ebfd: bt rbx, 0x24
# <DbgId: 19b98> ip: 14013eefc insSize: 5	0x14013eefc: bt r8, 0xbd
# <DbgId: 19ba0> ip: 14013ef1a insSize: 4	0x14013ef1a: movsx r10d, dl
# <DbgId: 19ba1> ip: 14013ef1e insSize: 3	0x14013ef1e: rol rbx, cl
# <DbgId: 19bd7> ip: 140404d4a insSize: 3	0x140404d4a: movzx esi, al
# <DbgId: 19bd9> ip: 140404d50 insSize: 5	0x140404d50: bt ax, r8w
# <DbgId: 19c09> ip: 14044acf9 insSize: 4	0x14044acf9: movsx r10d, bx
# <DbgId: 19c17> ip: 14042a1a4 insSize: 2	0x14042a1a4: not bl
# <DbgId: 19c21> ip: 1404446ac insSize: 4	0x1404446ac: bt r8d, ecx
# <DbgId: 19c4d> ip: 14028a2f2 insSize: 3	0x14028a2f2: ror eax, 9
# <DbgId: 19c64> ip: 140433b2c insSize: 4	0x140433b2c: movsx r10d, dx
# <DbgId: 19c85> ip: 1401e95c8 insSize: 3	0x1401e95c8: movsx ebx, cl
# <DbgId: 19ca2> ip: 14047418f insSize: 1	0x14047418f: cwde
# <DbgId: 19ccc> ip: 1402f83a0 insSize: 8	0x1402f83a0: lea rsi, [rcx + rdx*2 + 0x65022b39]
# <DbgId: 19ce3> ip: 1402f8405 insSize: 3	0x1402f8405: mov r10d, ecx
# <DbgId: 19d12> ip: 14036eef6 insSize: 4	0x14036eef6: movzx r10d, dl
# <DbgId: 19dd5> ip: 1401966a9 insSize: 5	0x1401966a9: bt r8w, dx
# <DbgId: 19df8> ip: 14025dfbd insSize: 4	0x14025dfbd: movsx r11d, al
# <DbgId: 1a8e7> ip: 14048a925 insSize: 6	0x14048a925: mov r11d, 0xefb41e8a
# <DbgId: 1ac73> ip: 140493f23 insSize: 5	0x140493f23: mov ecx, 0xc1aaf504
# <DbgId: 1ac79> ip: 140493f3f insSize: 3	0x140493f3f: movsx edx, bl
# <DbgId: 1ad7d> ip: 1404a5fbd insSize: 3	0x1404a5fbd: movsx ebp, bx
# <DbgId: 1ad97> ip: 1404191bd insSize: 3	0x1404191bd: sal rbx, cl
# <DbgId: 1ae5f> ip: 14032e2e9 insSize: 4	0x14032e2e9: bt ax, bx
# <DbgId: 1ae64> ip: 14032e2fc insSize: 7	0x14032e2fc: lea rdi, [rdx - 0xae5e24f]
# <DbgId: 1ae75> ip: 140232480 insSize: 4	0x140232480: shl cx, 0xc1
# <DbgId: 1ae8a> ip: 1402324d7 insSize: 7	0x1402324d7: lea r9, [rbx + 0x5009d028]
# <DbgId: 1ae8d> ip: 1402324ee insSize: 5	0x1402324ee: bt rdx, 0x1f
# <DbgId: 1aeb8> ip: 14043ffeb insSize: 4	0x14043ffeb: bt rdx, rsi
# <DbgId: 1aee4> ip: 1403ee468 insSize: 8	0x1403ee468: lea rbp, [rsi*2 + 0x70803d11]
# <DbgId: 1b026> ip: 140413772 insSize: 4	0x140413772: movzx esi, r11b
# <DbgId: 1b043> ip: 1403984fc insSize: 4	0x1403984fc: movsx r9d, r13w
# <DbgId: 1b049> ip: 140398526 insSize: 7	0x140398526: lea rcx, [rbp + 0x1698120c]
# <DbgId: 1b053> ip: 1403ca403 insSize: 5	0x1403ca403: mov edx, 0xb80bc8bc
# <DbgId: 1b059> ip: 1400011c0 insSize: 1	0x1400011c0: nop

# %%
# 生成垃圾指令的x64dbg还原脚本（不全面，有待研究）
for ins in record:
    if (hasattr(ins, "obfDeadCodeStatus") and ins.obfDeadCodeStatus == True):
        if ((not ins.ttins.isControlFlow()) and len(ins.mem_accs) == 0):
            print(f"memset {hex(ins.ins_address)},0x90,{hex(len(ins.bytes))}")
        # print(f"{ins}\t{ins.ttins}")
